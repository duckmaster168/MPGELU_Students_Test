# %% [markdown]
# # Introduction
#
# <center>
# <h2>
# Computational Experiments with Modern Parametrized Gaussian Error Linear Unit (MPGELU)
# </h2>
# <b>A demonstration by: Jose Aries E. De Los Santos</b>
# </center>

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.13/dist-packages (1.8.0)

# %% [markdown]
# # Import Libraries

# %%
import os
import sys
from pathlib import Path
from functools import partial

#PyTorch
import torch as torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import time
from torchinfo import summary

import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import random
from typing import Iterable, Callable


#sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

#Import torchvision
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor
from torchinfo import summary

#Import tqdm for a cool progress bar
from tqdm.auto import tqdm

# Measure time
from timeit import default_timer as timer

seed = 143
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)


print(f"PyTorch Version: {torch.__version__}")
print(f"Numpy Version: {np.__version__}")
print(f"Pandas Version: {pd.__version__}")
# print(f"Matplotlib Version: {matplotlib.__version__}")
print(f"SciPy Version: {scipy.__version__}")

# device = "cuda" if torch.cuda.is_available() else "cpu"

if torch.cuda.is_available():
    device = "cuda"
    print(f"Device: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = "mps"
    print(f"Device: {torch.backends.mps.is_available()}")
else:
    device = "cpu"
    print(f"Device: {device}")
# Out:
# PyTorch Version: 2.11.0+cu128
# Numpy Version: 2.1.3
# Pandas Version: 2.2.3
# SciPy Version: 1.16.3
# Device: NVIDIA A100-SXM4-40GB

# %% [markdown]
# # Dynamic Path Modification
#
# * It is a runtime technique used to explicitly tell Python where to look for modules or packages when you run an ``import`` statement.

# %% [markdown]
# ## Import Helper Functions

# %%
### Add the parent directory to the sys.path to import MyCNN and MPGELU
#%reload_ext autoreload
#%autoreload 2
mother_path = Path.cwd()
for folder in ["utility", "act_fns", "models"]:
    path = os.path.join(mother_path , folder)
    if path not in sys.path:
        sys.path.append(path)
from MPGELU import MPGELU
from PGELU import PGELU
from MyCNN import MyCNN
from DataTransforms import DataTransforms
from Trainer import Trainer
from LoadedModel import LoadedModel

# %% [markdown]
# # MP GELU
#
# * Modified Parametric Gaussian Error Linear Unit
# $$
# f(x) = \frac{x}{2} \left[ 1 + \text{erf}\left( \frac{\lambda x}{\sqrt{2}}\right)\right] = \frac{x}{2} + \frac{x}{\sqrt{\pi}}\int_{0}^{\lambda x / \sqrt{2}} e^{-u^{2}}du
# $$
# where $\lambda  = (1 + \ln(1 + e^{s})) \geq 1$   $\forall s \in \mathbb{R}$
#
# * Check MPGELU.py file for the implementation of the MPGELU activation function

# %%
x_np = np.linspace(-4.0, 4.0, 400)
x_tensor = torch.tensor(x_np, dtype=torch.float32)
# s_values = np.arange(-2.0, 2.0, 0.1)
s_values = [-100, 0.0, 100, ]
plt.figure(figsize=(9, 6))

for s_val in s_values:
    activation1 = MPGELU(s_param=s_val)
    activation2 = MPGELU(s_param=s_val, use_softplus=False)
    with torch.inference_mode():
        y_tensor1 = activation1(x_tensor)
        y_tensor2 = activation2(x_tensor)

    lam_val = (1.0 + F.softplus(torch.tensor(s_val, dtype=torch.float32))).item()
    plt.plot(x_np, y_tensor1.numpy(), label=f"s = {s_val}", linewidth=2.5)
    # plt.plot(x_np, y_tensor2.numpy(), label=f"s = {s_val}", linewidth=2)

# 4. Format the plot
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.axvline(0, color='black', linewidth=0.8, linestyle='--')
plt.title("Modified Parametric GELU (MP-GELU) Activation Function", fontsize=15)
xticks = np.arange(-4, 5, 0.8)
plt.xticks(xticks,fontsize=12)
plt.xlabel("Input ($x$)", fontsize=12)
yticks = np.arange(-2, 5, 0.8)
plt.yticks(yticks,fontsize=12)
plt.ylabel("Output ($f(x)$)", fontsize=12)
plt.grid(True, linestyle=':', alpha=0.9)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # Data Processing

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Create the target directory and extract the file from your ModelDatasets folder
# !mkdir -p ./data
# !tar -xzvf "/content/drive/MyDrive/ModelDatasets/cifar-10-python.tar.gz" -C "./data/"

# 3. Your original transformer setup (unaffected)
transformer = DataTransforms(dataset='cifar10', use_augmentation=True, use_stats=False)
train_transform = transformer.get_train_transform()
test_transform = transformer.get_test_transform()

# 4. UPDATED PyTorch dataset loading
# Change download to False so it instantly reads your local extracted files
train_data = datasets.CIFAR10(root='./data', train=True, download=False, transform=train_transform)
test_data = datasets.CIFAR10(root='./data', train=False, download=False, transform=test_transform)

# 5. Your original DataLoaders (unaffected)
train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True, num_workers=10, pin_memory=True, persistent_workers=True)
test_dataloader = DataLoader(test_data, batch_size=128, shuffle=False, num_workers=10, pin_memory=True, persistent_workers=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1

# %% [markdown]
# ## Visualize Sample Images

# %%
fig = plt.figure(figsize=(8, 8))
rows, columns = 4, 4

for i in range(1, rows * columns + 1):
    idx = torch.randint(0, len(train_data), size=[1]).item()  # Random index
    img, label = train_data[idx][0], train_data[idx][1]
    fig.add_subplot(rows, columns, i)

    # Display image without converting to grayscale
    plt.imshow(img.permute(1, 2, 0))  # Change channels to last dimension (H, W, C)
    plt.title(train_data.classes[label])
    plt.grid(False)
    plt.axis(False)

plt.axis(False)
# plt.savefig("cifar10_dataset.jpg",dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Model

# %%
def init_custom_weights(m):
    if isinstance(m, (nn.Linear, nn.Conv2d)):
        nn.init.normal_(m.weight, mean=-1, std=0.1)
        # nn.init.constant_(m.weight, 0.0)
        if m.bias is not None:
            # nn.init.constant_(m.bias, 0.0)
            nn.init.normal_(m.bias, mean=-1, std=0.1)

# %% [markdown]
# ## Set its Parameters

# %%
chosen_model_params = [32, 32, 'MaxPool', 64, 64, 'MaxPool', 128, 128, 128, 'MaxPool']

model = MyCNN(input_shape=3,
                  output_shape=10,
                  activation = MPGELU,
                  params = chosen_model_params).to(device)

print(summary(model=model,
        input = torch.randn(size=(3, 32, 32)).unsqueeze(dim=0)))

total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MyCNN                                    --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       896
# │    └─MPGELU: 2-2                       1
# │    └─Conv2d: 2-3                       9,248
# │    └─MPGELU: 2-4                       1
# │    └─MaxPool2d: 2-5                    --
# │    └─Conv2d: 2-6                       18,496
# │    └─MPGELU: 2-7                       1
# │    └─Conv2d: 2-8                       36,928
# │    └─MPGELU: 2-9                       1
# │    └─MaxPool2d: 2-10                   --
# │    └─Conv2d: 2-11                      73,856
# │    └─MPGELU: 2-12                      1
# │    └─Conv2d: 2-13                      147,584
# │    └─MPGELU: 2-14                      1
# │    └─Conv2d: 2-15                      147,584
# │    └─MPGELU: 2-16                      1
# │    └─MaxPool2d: 2-17                   --
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-18                      524,544
# │    └─MPGELU: 2-19                      1
# │    └─Linear: 2-20                      65,792
# │    └─MPGELU: 2-21                      1
# │    └─Linear: 2-22                      2,570
# =================================================================
# Total params: 1,027,507
# Trainable params: 1,027,507
# Non-trainable params: 0
# =================================================================
# Total number of parameters: 1027507

# %%
model.apply(init_custom_weights)
for name, param in model.named_parameters():
  if "weight" in name:
    print(f"Layer: {name}:, Weights: {param.data}")
  elif "bias" in name:
    print(f"Layer: {name}, Biases: {param.data}")
# Out:
# Layer: conv_layers.0.weight:, Weights: tensor([[[[-0.9833, -0.9928, -0.9529],
#           [-1.0421, -1.2733, -1.0524],
#           [-0.9851, -0.9481, -0.9983]],
#
#          [[-0.9239, -0.9176, -1.0316],
#           [-0.9749, -0.9028, -1.0153],
#           [-1.1527, -0.9273, -0.9983]],
#
#          [[-1.1194, -0.9533, -0.9385],
#           [-0.8398, -1.1189, -0.8645],
#           [-1.2063, -1.0392, -0.8676]]],
#
#
#         [[[-0.9852, -0.8643, -0.9871],
#           [-0.9148, -1.0242, -1.1805],
#           [-1.0227, -0.8404, -0.9276]],
#
#          [[-0.9988, -1.0976, -0.9845],
#           [-1.2416, -0.9642, -0.9323],
#           [-0.8031, -1.1899, -1.0612]],
#
#          [[-0.9860, -0.9208, -0.9091],
#           [-0.8842, -1.0758, -1.1671],
#           [-0.8464, -1.0023, -1.0279]]],
#
#
#         [[[-1.0862, -0.9950, -1.0672],
#           [-0.8941, -1.0613, -0.7547],
#           [-1.1202, -0.9618, -1.0642]],
#
#          [[-0.8647, -1.2073, -1.1288],
#           [-1.0298, -1.1538, -0.9834],
#           [-0.9348, -1.2154, -0.9664]],
#
#          [[-0.8985, -0.9925, -1.0204],
#           [-1.1059, -0.9360, -1.0205],
#           [-0.9469, -1.0018, -1.0154]]],
#
#
#         [[[-1.0658, -0.9102, -0.9549],
#           [-0.9838, -1.0074, -1.2193],
#           [-0.9896, -1.1641, -0.9987]],
#
#          [[-0.9706, -0.8589, -1.0022],
#           [-1.0775, -0.9028, -0.8417],
#           [-0.8657, -0.9061, -0.8853]],
#
#          [[-1.0711, -0.9345, -1.1898],
#           [-1.0910, -0.9370, -1.1664],
#           [-0.8947, -0.9641, -0.9614]]],
#
#
#         [[[-0.9023, -0.9797, -0.9855],
#           [-0.9548, -1.1724, -1.0998],
#           [-0.8866, -1.1785, -1.0747]],
#
#          [[-1.0396, -1.1366, -0.9905],
#           [-1.0117, -1.1827, -0.9396],
#           [-1.0585, -1.0862, -1.1619]],
#
#          [[-1.0620, -0.9019, -1.0443],
#           [-1.1308, -1.0725, -1.1599],
#           [-0.9022, -0.9929, -1.0288]]],
#
#
#         [[[-0.9438, -1.1785, -0.9217],
#           [-1.0957, -1.0525, -1.0856],
#           [-1.0370, -0.9871, -1.0103]],
#
#          [[-1.1101, -1.0242, -0.9866],
#           [-0.8479, -1.0077, -0.7693],
#           [-0.8380, -0.8501, -1.1232]],
#
#          [[-0.8671, -0.8412, -0.9626],
#           [-1.0938, -0.8504, -0.7798],
#           [-1.0727, -0.9772, -1.0737]]],
#
#
#         [[[-0.9440, -1.0410, -1.0338],
#           [-0.9293, -0.8344, -1.3185],
#           [-0.9771, -0.9354, -0.9148]],
#
#          [[-1.0453, -1.0346, -0.9666],
#           [-1.1794, -1.0760, -0.9952],
#           [-1.2044, -0.9257, -1.0949]],
#
#          [[-0.9641, -0.9924, -1.0544],
#           [-1.0390, -0.8719, -0.9406],
#           [-1.0192, -0.8416, -0.9934]]],
#
#
#         [[[-0.8884, -0.8251, -1.0204],
#           [-1.1077, -0.9305, -1.2317],
#           [-0.8722, -1.0048, -0.9657]],
#
#          [[-0.8955, -1.0663, -1.0098],
#           [-0.9290, -1.1164, -1.0129],
#           [-1.0612, -0.9913, -1.0181]],
#
#          [[-1.0282, -1.0526, -0.8642],
#           [-1.0659, -0.9843, -0.8545],
#           [-1.1809, -1.1043, -1.0241]]],
#
#
#         [[[-1.0253, -1.1069, -1.1551],
#           [-0.9202, -1.1055, -1.0242],
#           [-1.1080, -1.0161, -0.9261]],
#
#          [[-1.0592, -0.9101, -0.9558],
#           [-0.8760, -0.9077, -1.0711],
#           [-1.0621, -1.0371, -0.8919]],
#
#          [[-1.0327, -1.1228, -1.0182],
#           [-0.9135, -0.8920, -1.1150],
#           [-0.9019, -0.9766, -0.9485]]],
#
#
#         [[[-0.9607, -0.9636, -0.9635],
#           [-1.1394, -1.0078, -1.0308],
#           [-1.0455, -1.1090, -1.2391]],
#
#          [[-0.8895, -1.0119, -1.0235],
#           [-1.1231, -1.0022, -1.0251],
#           [-1.0014, -1.2823, -0.9380]],
#
#          [[-1.0181, -1.1087, -0.9309],
#           [-1.1678, -0.9256, -1.0115],
#           [-1.2252, -0.8969, -0.9618]]],
#
#
#         [[[-0.7885, -0.6463, -0.9993],
#           [-1.1428, -1.2109, -0.9113],
#           [-0.8725, -0.9819, -0.9595]],
#
#          [[-0.8527, -0.9158, -0.9537],
#           [-0.8338, -0.9721, -0.9932],
#           [-0.9026, -1.0275, -0.9658]],
#
#          [[-1.0915, -0.9344, -1.1055],
#           [-0.9532, -0.7650, -0.8400],
#           [-0.9936, -1.0225, -0.9794]]],
#
#
#         [[[-1.0570, -1.0741, -0.9647],
#           [-0.8768, -1.0652, -1.2075],
#           [-1.0537, -1.1289, -0.8340]],
#
#          [[-1.0187, -1.0925, -0.8718],
#           [-0.8907, -1.0868, -0.8290],
#           [-1.1172, -0.9282, -1.1572]],
#
#          [[-1.2746, -1.0972, -0.9503],
#           [-1.0722, -1.0721, -1.1606],
#           [-0.8811, -1.1440, -1.0094]]],
#
#
#         [[[-0.9751, -0.9271, -1.1324],
#           [-0.9561, -0.8764, -0.9433],
#           [-1.0583, -1.1192, -0.9282]],
#
#          [[-0.7530, -1.0947, -0.9188],
#           [-1.1219, -0.9851, -0.9090],
#           [-0.9651, -1.1067, -1.0786]],
#
#          [[-1.0830, -1.2350, -1.0738],
#           [-1.1139, -1.0320, -1.0779],
#           [-0.9344, -1.0310, -1.0121]]],
#
#
#         [[[-0.9116, -1.0013, -1.1996],
#           [-1.0784, -1.0037, -1.0808],
#           [-1.0502, -0.8707, -1.0228]],
#
#          [[-1.0358, -0.7402, -0.9706],
#           [-1.2208, -1.1569, -0.8364],
#           [-0.8856, -1.0655, -0.9971]],
#
#          [[-0.8743, -1.1083, -0.9900],
#           [-0.9947, -1.0489, -1.1936],
#           [-0.9643, -1.1540, -0.8253]]],
#
#
#         [[[-1.1540, -1.0994, -0.9770],
#           [-1.0144, -1.0922, -0.8691],
#           [-1.0457, -1.0490, -1.0032]],
#
#          [[-0.9650, -1.2201, -1.0592],
#           [-0.9349, -0.9059, -1.0420],
#           [-1.0696, -1.0132, -1.0356]],
#
#          [[-0.9991, -0.8895, -1.0212],
#           [-0.7003, -0.9044, -0.9435],
#           [-1.1462, -0.9885, -1.1128]]],
#
#
#         [[[-0.9875, -1.1081, -1.0050],
#           [-0.9053, -1.0185, -0.9098],
#           [-0.9885, -1.0730, -0.9191]],
#
#          [[-1.1325, -1.0578, -1.0362],
#           [-0.8648, -1.1708, -0.9326],
#           [-1.0138, -0.8378, -1.1807]],
#
#          [[-0.8988, -0.9945, -0.7441],
#           [-1.0477, -1.0600, -1.0758],
#           [-0.7345, -1.1289, -0.9341]]],
#
#
#         [[[-0.9983, -1.1141, -0.9228],
#           [-0.9921, -1.0227, -0.9192],
#           [-1.0720, -1.1158, -1.0877]],
#
#          [[-0.8291, -0.8475, -1.0357],
#           [-0.8149, -1.0617, -0.9075],
#           [-1.2003, -0.8611, -1.0762]],
#
#          [[-1.0384, -0.8588, -1.0953],
#           [-1.1800, -1.0128, -1.0228],
#           [-0.8928, -1.0492, -0.9311]]],
#
#
#         [[[-0.9567, -0.9887, -1.0758],
#           [-0.8591, -1.0602, -0.9263],
#           [-1.0025, -0.8761, -0.8902]],
#
#          [[-1.0683, -1.0313, -0.9848],
#           [-1.0624, -1.0880, -1.0407],
#           [-0.9996, -1.0158, -0.9560]],
#
#          [[-1.0267, -0.8311, -0.9773],
#           [-0.9344, -0.9439, -0.7746],
#           [-0.9253, -1.0573, -0.8092]]],
#
#
#         [[[-1.0171, -1.0011, -0.9294],
#           [-1.0516, -0.8673, -1.0488],
#           [-0.9005, -1.1383, -1.0571]],
#
#          [[-1.1096, -1.1380, -0.9944],
#           [-0.9700, -1.0227, -0.9684],
#           [-1.0130, -1.0602, -0.8888]],
#
#          [[-1.1316, -1.1427, -1.1254],
#           [-0.8536, -0.9468, -1.0073],
#           [-0.8927, -1.0640, -0.8405]]],
#
#
#         [[[-0.8567, -0.9297, -0.9885],
#           [-0.7805, -0.8670, -0.8331],
#           [-1.1117, -0.9363, -1.0051]],
#
#          [[-1.1366, -1.1645, -1.0508],
#           [-0.7967, -0.8864, -1.1366],
#           [-0.8867, -0.9901, -1.1520]],
#
#          [[-0.6897, -1.1021, -1.0274],
#           [-1.0554, -1.1741, -0.9749],
#           [-1.0119, -0.8250, -0.9347]]],
#
#
#         [[[-0.9069, -0.9579, -0.9188],
#           [-1.0977, -1.1034, -1.1627],
#           [-1.0483, -0.9177, -1.0436]],
#
#          [[-0.9182, -1.0045, -0.9553],
#           [-0.8475, -0.9443, -1.0308],
#           [-1.0057, -0.8525, -1.1375]],
#
#          [[-0.9982, -0.9731, -0.9943],
#           [-1.0752, -0.9073, -0.9854],
#           [-1.1133, -1.0692, -0.8720]]],
#
#
#         [[[-1.0816, -0.8741, -1.1692],
#           [-1.1238, -1.0401, -1.0646],
#           [-0.9564, -1.0046, -0.9670]],
#
#          [[-0.9713, -1.0844, -0.8649],
#           [-1.0223, -0.8576, -1.0098],
#           [-1.0108, -0.8488, -1.0200]],
#
#          [[-0.9305, -1.0959, -0.9247],
#           [-1.0514, -1.1497, -0.8720],
#           [-0.9455, -0.9322, -1.1113]]],
#
#
#         [[[-0.9341, -0.9476, -1.0042],
#           [-0.7328, -0.8993, -1.1575],
#           [-1.1532, -0.8936, -0.8975]],
#
#          [[-1.0496, -0.9501, -1.1555],
#           [-1.1688, -0.8459, -0.9321],
#           [-0.8991, -0.9755, -0.9658]],
#
#          [[-0.9558, -1.0625, -1.0523],
#           [-0.9621, -0.9631, -1.0087],
#           [-1.1553, -1.0659, -0.9397]]],
#
#
#         [[[-0.8801, -1.0014, -1.1179],
#           [-1.2457, -1.0369, -1.1575],
#           [-0.8587, -1.1263, -1.0417]],
#
#          [[-0.8177, -0.9995, -0.9893],
#           [-0.8629, -0.8545, -0.9449],
#           [-1.1569, -1.0855, -1.0151]],
#
#          [[-0.6906, -1.0535, -1.0418],
#           [-1.1116, -0.9991, -0.9281],
#           [-1.0271, -1.0662, -0.9526]]],
#
#
#         [[[-1.0926, -0.8469, -1.0839],
#           [-1.0115, -0.8266, -0.9623],
#           [-0.9626, -1.1617, -1.0079]],
#
#          [[-0.8557, -0.8533, -0.8543],
#           [-0.8596, -1.0907, -0.9917],
#           [-0.8917, -0.9285, -0.9471]],
#
#          [[-1.2489, -1.1411, -1.0757],
#           [-1.0401, -0.9328, -1.0379],
#           [-0.9149, -1.0188, -1.0902]]],
#
#
#         [[[-1.2011, -1.1419, -1.0186],
#           [-0.9635, -0.9477, -1.1110],
#           [-0.8433, -0.9229, -0.9369]],
#
#          [[-0.8179, -0.9619, -0.7530],
#           [-0.8886, -1.1054, -1.0266],
#           [-0.8674, -1.2590, -0.8850]],
#
#          [[-1.0150, -1.0395, -1.1763],
#           [-0.9788, -0.8363, -1.0146],
#           [-1.0536, -1.1071, -0.9859]]],
#
#
#         [[[-0.8905, -1.0312, -1.0341],
#           [-1.0965, -1.0905, -1.1788],
#           [-0.8667, -0.9285, -0.9069]],
#
#          [[-0.9087, -0.9326, -1.0309],
#           [-1.0029, -0.9971, -1.2139],
#           [-1.1017, -1.0933, -1.2359]],
#
#          [[-1.1417, -0.9720, -0.9596],
#           [-0.9267, -1.0356, -0.8858],
#           [-0.9715, -0.8601, -1.0502]]],
#
#
#         [[[-0.8764, -0.9725, -0.9968],
#           [-1.0814, -0.9060, -0.9882],
#           [-0.9352, -0.9259, -0.9467]],
#
#          [[-1.0492, -0.7948, -1.1034],
#           [-0.9616, -1.1083, -0.8643],
#           [-0.9442, -0.8981, -1.1829]],
#
#          [[-0.9220, -0.8700, -0.8938],
#           [-0.9243, -1.0363, -0.8867],
#           [-0.9043, -0.9494, -1.2411]]],
#
#
#         [[[-1.0166, -1.0709, -1.0498],
#           [-1.0587, -0.8060, -1.1536],
#           [-0.9138, -0.8847, -0.9388]],
#
#          [[-1.0064, -0.8450, -1.0090],
#           [-1.0628, -0.9994, -0.8116],
#           [-0.8913, -1.0470, -1.1003]],
#
#          [[-1.0629, -0.9897, -1.1414],
#           [-1.0149, -1.0559, -1.0255],
#           [-0.8771, -1.1108, -1.0189]]],
#
#
#         [[[-1.0665, -0.9760, -1.1432],
#           [-0.9502, -1.0469, -0.9237],
#           [-0.9615, -1.0434, -1.0415]],
#
#          [[-1.0598, -1.0205, -0.8107],
#           [-1.1169, -0.8853, -0.8815],
#           [-1.0877, -1.0645, -0.9381]],
#
#          [[-0.9728, -0.8918, -1.1585],
#           [-0.8722, -1.0725, -1.1090],
#           [-1.1366, -1.0059, -0.9996]]],
#
#
#         [[[-0.9320, -0.9489, -1.0846],
#           [-1.0025, -0.9766, -1.0353],
#           [-1.0147, -0.8214, -1.0873]],
#
#          [[-1.0181, -0.8266, -0.9833],
#           [-1.0239, -1.0809, -1.0947],
#           [-0.8571, -0.9493, -0.9854]],
#
#          [[-1.0637, -1.1574, -1.0556],
#           [-1.2155, -0.8977, -1.0744],
#           [-0.8733, -0.8194, -0.8936]]],
#
#
#         [[[-1.0975, -1.0162, -0.8511],
#           [-0.8948, -0.9407, -0.9943],
#           [-1.0315, -0.9973, -1.0457]],
#
#          [[-0.9885, -0.9536, -1.0917],
#           [-1.0184, -1.1025, -0.9352],
#           [-0.9827, -0.9476, -1.0579]],
#
#          [[-0.9599, -1.1082, -1.0387],
#           [-0.9522, -1.0552, -1.0209],
#           [-0.8601, -1.1129, -0.9432]]]], device='cuda:0')
# Layer: conv_layers.0.bias, Biases: tensor([-0.9282, -1.0105, -0.9556, -0.9534, -0.9668, -0.9092, -1.0745, -0.9940,
#         -1.0132, -1.0405, -1.0187, -1.1812, -0.9370, -0.7344, -1.0595, -0.8914,
#         -1.0909, -1.1709, -1.0648, -0.9168, -0.8241, -0.8306, -0.9082, -1.0156,
#         -0.9965, -1.0429, -0.9388, -0.9564, -1.0188, -0.9722, -0.8658, -1.0397],
#        device='cuda:0')
# Layer: conv_layers.2.weight:, Weights: tensor([[[[-1.0023, -1.0703, -1.0848],
#           [-1.0421, -1.0062, -0.9149],
#           [-1.0516, -0.8677, -0.9449]],
#
#          [[-1.1264, -0.8091, -1.0367],
#           [-0.9620, -1.0017, -0.9447],
#           [-0.9264, -1.0331, -1.1359]],
#
#          [[-1.1859, -0.9913, -0.8768],
#           [-0.9337, -1.0883, -1.0036],
#           [-0.9685, -1.0794, -1.0013]],
#
#          ...,
#
#          [[-1.0031, -0.8851, -0.8275],
#           [-0.8823, -0.8850, -0.9892],
#           [-1.1221, -0.9831, -0.8992]],
#
#          [[-1.0448, -0.9875, -0.9621],
#           [-0.9299, -1.0140, -0.9471],
#           [-1.1940, -1.0449, -0.9228]],
#
#          [[-1.1308, -0.9911, -0.8816],
#           [-0.8092, -1.0639, -0.7832],
#           [-1.0696, -0.8128, -0.9790]]],
#
#
#         [[[-0.9250, -0.8951, -1.0430],
#           [-1.0051, -0.9053, -0.9991],
#           [-0.8987, -0.9440, -0.7912]],
#
#          [[-0.8339, -0.9734, -1.1220],
#           [-0.9954, -1.0254, -0.7644],
#           [-1.0031, -1.1859, -1.1129]],
#
#          [[-1.1425, -0.8684, -1.0989],
#           [-1.0017, -1.0892, -0.9667],
#           [-0.9615, -1.0770, -1.1461]],
#
#          ...,
#
#          [[-0.9853, -0.8966, -0.8875],
#           [-0.9001, -1.0933, -0.8398],
#           [-1.1035, -0.9525, -0.9911]],
#
#          [[-1.0793, -1.0599, -1.0047],
#           [-0.9701, -1.2234, -0.9944],
#           [-0.8398, -1.0398, -0.9398]],
#
#          [[-0.9164, -0.9964, -0.9171],
#           [-1.1690, -0.9525, -0.9405],
#           [-1.1449, -1.0495, -0.8275]]],
#
#
#         [[[-1.1532, -1.0098, -0.8373],
#           [-1.0335, -0.8687, -0.9070],
#           [-0.9248, -1.0075, -0.8980]],
#
#          [[-0.9477, -0.9476, -0.9963],
#           [-0.9883, -1.1024, -1.0210],
#           [-0.9549, -0.8603, -0.8602]],
#
#          [[-1.0729, -0.8008, -0.9027],
#           [-0.9650, -1.1005, -0.9973],
#           [-1.0863, -1.0271, -0.9173]],
#
#          ...,
#
#          [[-1.1781, -1.1488, -1.0771],
#           [-1.0334, -0.9808, -0.9506],
#           [-1.0353, -0.9608, -0.9212]],
#
#          [[-1.0737, -0.9321, -0.8124],
#           [-1.0377, -1.0666, -1.1526],
#           [-1.1446, -1.0409, -1.0215]],
#
#          [[-0.9983, -1.0050, -1.1216],
#           [-0.8771, -0.9839, -1.0980],
#           [-0.9723, -1.1142, -1.0151]]],
#
#
#         ...,
#
#
#         [[[-0.9609, -1.1207, -0.9890],
#           [-0.9206, -0.8997, -1.0376],
#           [-0.8304, -0.9773, -0.9898]],
#
#          [[-0.9800, -0.9644, -1.0380],
#           [-0.9299, -0.8918, -1.0557],
#           [-0.9897, -1.0528, -0.8918]],
#
#          [[-1.0849, -1.1470, -1.1553],
#           [-0.9783, -0.9445, -0.9323],
#           [-0.9125, -0.8991, -1.0357]],
#
#          ...,
#
#          [[-1.1154, -0.9135, -1.0106],
#           [-1.0557, -1.1996, -1.1766],
#           [-0.9588, -0.9167, -0.9344]],
#
#          [[-1.0489, -1.0213, -1.0964],
#           [-1.0749, -1.1078, -1.0055],
#           [-0.8461, -0.9431, -1.0364]],
#
#          [[-1.1688, -0.8221, -1.1137],
#           [-1.0533, -1.1343, -0.9963],
#           [-0.9629, -1.0369, -1.0069]]],
#
#
#         [[[-0.7753, -1.2051, -1.0700],
#           [-0.9184, -1.0575, -1.0424],
#           [-0.9064, -0.9432, -1.0982]],
#
#          [[-1.0054, -0.7601, -0.7136],
#           [-0.9218, -1.0041, -1.0001],
#           [-0.9344, -1.1466, -1.0519]],
#
#          [[-0.8481, -0.9917, -1.0824],
#           [-1.1607, -0.9065, -0.9338],
#           [-1.0961, -0.9443, -1.0553]],
#
#          ...,
#
#          [[-0.9708, -1.0378, -0.8738],
#           [-1.1400, -1.0064, -1.0734],
#           [-0.9304, -0.9413, -0.8886]],
#
#          [[-0.8882, -1.0860, -1.0407],
#           [-0.9266, -0.9800, -1.0695],
#           [-0.8370, -0.9188, -1.0221]],
#
#          [[-1.1117, -1.0131, -0.9654],
#           [-0.9965, -0.9514, -0.9299],
#           [-1.1802, -1.1171, -0.9722]]],
#
#
#         [[[-1.2013, -0.9556, -0.8199],
#           [-1.0486, -0.9689, -1.1176],
#           [-0.8930, -1.0442, -1.1566]],
#
#          [[-1.0701, -1.0434, -0.9488],
#           [-1.0590, -0.9649, -1.0162],
#           [-1.1683, -0.9378, -0.9949]],
#
#          [[-1.0482, -1.0460, -1.1191],
#           [-0.9405, -0.9461, -1.0613],
#           [-1.1390, -0.9682, -0.9374]],
#
#          ...,
#
#          [[-0.9721, -0.9894, -0.8967],
#           [-1.0772, -1.0143, -1.0292],
#           [-1.0090, -0.9310, -0.8571]],
#
#          [[-1.0101, -1.0249, -0.9732],
#           [-1.0246, -0.9913, -1.0787],
#           [-1.1649, -0.9676, -0.9856]],
#
#          [[-1.0090, -1.1182, -1.1367],
#           [-1.0694, -0.9230, -0.9721],
#           [-1.1223, -0.7699, -0.9695]]]], device='cuda:0')
# Layer: conv_layers.2.bias, Biases: tensor([-0.8878, -0.9249, -1.0883, -0.8897, -0.8911, -0.8905, -1.0108, -0.9349,
#         -0.9588, -1.0634, -0.9935, -0.9143, -0.9858, -1.0694, -0.9593, -0.8150,
#         -1.0134, -0.9489, -1.0240, -1.1371, -1.0516, -0.9266, -1.1369, -1.1066,
#         -1.0981, -0.9494, -0.9847, -0.9369, -1.0978, -1.0876, -1.0658, -1.0045],
#        device='cuda:0')
# Layer: conv_layers.5.weight:, Weights: tensor([[[[-1.1146, -1.0504, -0.8209],
#           [-1.1611, -0.9161, -1.0568],
#           [-1.0223, -0.8506, -0.8260]],
#
#          [[-0.9206, -1.0334, -1.1211],
#           [-1.0344, -1.0118, -0.9480],
#           [-0.7515, -0.9993, -0.9502]],
#
#          [[-1.1059, -0.9675, -1.0862],
#           [-1.0873, -1.1307, -1.1586],
#           [-1.0219, -0.9982, -0.9382]],
#
#          ...,
#
#          [[-0.9519, -0.8949, -0.9929],
#           [-1.0874, -1.1155, -1.1258],
#           [-1.0423, -1.0452, -1.0385]],
#
#          [[-1.0028, -1.0018, -1.1655],
#           [-1.0946, -0.9526, -0.9423],
#           [-0.7260, -1.0394, -1.1589]],
#
#          [[-0.9518, -0.8747, -0.9527],
#           [-0.8237, -0.8843, -0.9832],
#           [-1.0243, -1.1719, -0.9344]]],
#
#
#         [[[-0.9188, -1.0869, -1.0823],
#           [-0.9478, -1.1345, -1.1120],
#           [-0.8763, -0.9709, -0.9743]],
#
#          [[-1.0613, -1.0668, -0.9869],
#           [-0.9895, -1.0306, -1.0771],
#           [-1.0591, -0.9952, -1.0262]],
#
#          [[-0.9414, -0.8002, -0.9809],
#           [-1.0021, -1.1055, -1.0515],
#           [-0.8273, -1.0541, -1.0833]],
#
#          ...,
#
#          [[-0.9250, -1.0587, -1.0116],
#           [-1.1051, -1.1546, -0.9890],
#           [-0.8881, -1.1423, -0.9013]],
#
#          [[-1.0509, -1.0850, -0.9413],
#           [-1.1349, -1.0094, -0.9598],
#           [-1.1503, -0.9248, -1.0055]],
#
#          [[-0.9296, -0.9757, -0.9906],
#           [-1.0360, -0.9084, -0.9908],
#           [-1.0164, -0.9318, -1.0818]]],
#
#
#         [[[-1.1188, -1.1466, -1.0222],
#           [-0.9154, -1.1186, -1.0678],
#           [-1.1546, -1.0834, -1.0041]],
#
#          [[-1.0456, -1.1007, -0.8003],
#           [-0.8923, -0.9316, -1.1041],
#           [-1.0580, -0.9067, -1.0056]],
#
#          [[-1.1457, -1.1330, -0.9869],
#           [-1.0622, -0.8113, -1.0259],
#           [-1.1189, -1.0140, -0.8891]],
#
#          ...,
#
#          [[-1.0961, -1.2795, -1.0777],
#           [-1.0066, -1.1029, -0.9699],
#           [-0.9973, -0.7394, -1.1892]],
#
#          [[-0.9038, -0.9696, -0.9373],
#           [-0.9755, -0.9339, -0.9540],
#           [-0.9604, -0.9874, -1.0017]],
#
#          [[-0.7799, -0.8692, -1.2071],
#           [-1.0227, -1.0149, -0.8371],
#           [-1.0915, -1.0962, -0.8626]]],
#
#
#         ...,
#
#
#         [[[-0.8943, -1.1829, -1.1090],
#           [-0.8202, -0.9710, -0.9497],
#           [-0.8145, -1.0619, -1.2020]],
#
#          [[-1.0787, -0.9575, -0.9987],
#           [-1.2581, -0.9338, -1.0377],
#           [-0.9782, -1.0816, -0.8986]],
#
#          [[-0.9231, -1.0296, -1.1298],
#           [-1.1108, -0.8907, -0.9689],
#           [-0.8940, -0.9612, -1.0139]],
#
#          ...,
#
#          [[-0.8349, -0.8763, -0.9847],
#           [-1.1033, -0.7471, -1.0983],
#           [-0.9928, -0.9265, -0.8441]],
#
#          [[-1.0913, -1.1649, -0.8086],
#           [-0.9272, -1.0885, -0.8302],
#           [-0.8640, -1.1563, -1.1755]],
#
#          [[-0.8994, -0.9386, -1.0548],
#           [-1.1178, -1.0586, -1.0271],
#           [-1.1069, -1.0375, -1.0058]]],
#
#
#         [[[-1.0121, -0.9015, -0.9260],
#           [-1.0009, -1.0475, -1.0864],
#           [-0.8190, -0.9412, -0.8473]],
#
#          [[-1.0338, -0.8810, -0.8596],
#           [-1.1430, -1.1608, -1.1023],
#           [-1.2244, -1.0964, -1.0115]],
#
#          [[-1.0347, -1.0082, -1.1776],
#           [-0.9858, -0.9351, -1.1392],
#           [-1.0039, -0.8728, -0.9462]],
#
#          ...,
#
#          [[-1.0279, -0.8717, -1.1561],
#           [-1.0755, -0.9114, -0.9958],
#           [-0.9164, -1.0093, -0.9517]],
#
#          [[-1.0153, -1.0144, -1.0992],
#           [-1.0080, -0.9027, -0.9594],
#           [-0.9941, -1.0648, -0.8459]],
#
#          [[-0.9599, -1.1851, -1.0570],
#           [-1.1261, -0.9685, -0.9510],
#           [-0.9635, -1.1394, -1.0547]]],
#
#
#         [[[-0.8852, -1.0602, -1.0942],
#           [-0.9541, -1.0886, -0.9869],
#           [-0.9390, -0.8089, -0.9572]],
#
#          [[-1.0848, -0.8981, -1.0531],
#           [-1.0274, -0.9707, -1.0201],
#           [-1.0945, -1.0668, -1.0880]],
#
#          [[-0.8800, -1.0750, -0.9204],
#           [-0.8849, -0.9638, -1.0082],
#           [-0.9140, -1.0506, -1.1936]],
#
#          ...,
#
#          [[-0.7960, -1.0708, -1.0058],
#           [-0.9363, -0.7445, -1.0729],
#           [-0.8310, -0.9053, -1.1920]],
#
#          [[-1.0119, -1.1202, -0.8905],
#           [-0.9700, -0.9341, -0.9865],
#           [-0.9131, -1.0481, -0.7611]],
#
#          [[-0.9262, -0.8397, -0.9597],
#           [-0.9936, -0.9490, -1.2773],
#           [-0.9738, -0.9010, -0.9777]]]], device='cuda:0')
# Layer: conv_layers.5.bias, Biases: tensor([-1.0409, -0.9394, -0.9814, -1.1303, -1.0531, -1.0144, -1.0360, -1.1413,
#         -1.0076, -1.0894, -1.0249, -0.9736, -0.9028, -0.9493, -1.0655, -0.8383,
#         -1.0011, -0.9945, -0.9699, -0.9367, -0.8086, -1.2300, -0.9916, -1.0533,
#         -1.0855, -0.9662, -1.1474, -0.8936, -0.7697, -1.1381, -0.8737, -0.9751,
#         -1.0599, -1.0961, -1.0384, -1.0155, -0.9967, -0.8870, -0.9883, -1.2728,
#         -1.0832, -1.0631, -0.9751, -0.8942, -0.9780, -0.9777, -1.0754, -1.1724,
#         -1.0090, -1.1353, -1.0479, -1.0725, -1.3423, -1.0735, -0.6971, -0.9716,
#         -1.0723, -0.7975, -0.9310, -1.0621, -0.9433, -0.9524, -0.9377, -0.8574],
#        device='cuda:0')
# Layer: conv_layers.7.weight:, Weights: tensor([[[[-0.8839, -0.8419, -1.0394],
#           [-1.1658, -0.9954, -0.9497],
#           [-1.0335, -0.9838, -0.9625]],
#
#          [[-1.0587, -1.0433, -1.1232],
#           [-0.9261, -0.9304, -0.9911],
#           [-1.0874, -1.0512, -0.9743]],
#
#          [[-1.0790, -1.0899, -1.1895],
#           [-0.9974, -1.1627, -1.0232],
#           [-0.8674, -1.0477, -0.8951]],
#
#          ...,
#
#          [[-1.0426, -0.9726, -1.0429],
#           [-0.9417, -1.0078, -0.9931],
#           [-0.9407, -1.0044, -1.0056]],
#
#          [[-1.1279, -0.9676, -1.0395],
#           [-0.9218, -1.0069, -0.7819],
#           [-1.1550, -1.1351, -1.1152]],
#
#          [[-0.9833, -0.9771, -0.9612],
#           [-0.8746, -1.0290, -0.8798],
#           [-1.0079, -1.0069, -0.8854]]],
#
#
#         [[[-0.9831, -1.0790, -1.2134],
#           [-0.9256, -1.1326, -0.9897],
#           [-1.1993, -0.8941, -1.0056]],
#
#          [[-0.9125, -1.0002, -1.0567],
#           [-1.0215, -0.9221, -0.9942],
#           [-0.8357, -1.0763, -0.9958]],
#
#          [[-0.9073, -1.0680, -0.9269],
#           [-0.9647, -0.9276, -1.0861],
#           [-1.0981, -0.9545, -0.9525]],
#
#          ...,
#
#          [[-0.8394, -1.1384, -1.1281],
#           [-1.0498, -0.9754, -1.1175],
#           [-1.1675, -1.0054, -1.1529]],
#
#          [[-1.1011, -0.9695, -1.0942],
#           [-0.9638, -1.1601, -0.9136],
#           [-1.0863, -0.9331, -0.9476]],
#
#          [[-1.0897, -1.0715, -0.9182],
#           [-1.1045, -0.8462, -1.1032],
#           [-1.0464, -0.9058, -0.9874]]],
#
#
#         [[[-0.9184, -0.7878, -1.2192],
#           [-1.0743, -0.9095, -0.8847],
#           [-1.0834, -0.9691, -1.0463]],
#
#          [[-1.0340, -0.8318, -0.9690],
#           [-1.0107, -1.1631, -1.0612],
#           [-0.9557, -0.9448, -1.1718]],
#
#          [[-1.0242, -0.7695, -0.9889],
#           [-0.9436, -1.0281, -0.9708],
#           [-0.8388, -0.8766, -1.0229]],
#
#          ...,
#
#          [[-0.9824, -1.1880, -1.0619],
#           [-0.9063, -0.9571, -0.9499],
#           [-0.9204, -0.8973, -0.9799]],
#
#          [[-1.1560, -0.9212, -1.1382],
#           [-0.9482, -0.9354, -0.9247],
#           [-1.0181, -0.9687, -1.0083]],
#
#          [[-0.8406, -0.9123, -1.0301],
#           [-1.1336, -0.9462, -1.0521],
#           [-0.9984, -1.0358, -1.0100]]],
#
#
#         ...,
#
#
#         [[[-0.8353, -0.8969, -1.2114],
#           [-1.0461, -0.9684, -0.9078],
#           [-0.9571, -0.8803, -0.8701]],
#
#          [[-0.9811, -0.9388, -0.9402],
#           [-1.0932, -1.0946, -0.9835],
#           [-1.1290, -1.0657, -1.0026]],
#
#          [[-1.1792, -1.0451, -1.0361],
#           [-1.0824, -1.0750, -1.0608],
#           [-0.9025, -0.9550, -0.9578]],
#
#          ...,
#
#          [[-0.8362, -1.0194, -1.1330],
#           [-0.9586, -1.1845, -1.0795],
#           [-0.8192, -1.0794, -0.9701]],
#
#          [[-1.0532, -1.1757, -1.0485],
#           [-1.0867, -0.9259, -0.9215],
#           [-1.0098, -0.9789, -0.9458]],
#
#          [[-0.9245, -1.0539, -1.0292],
#           [-0.9873, -0.9896, -1.0542],
#           [-0.8704, -0.8669, -1.0163]]],
#
#
#         [[[-0.9984, -0.9105, -1.0724],
#           [-0.9311, -1.0820, -1.0360],
#           [-0.9674, -1.0329, -0.9795]],
#
#          [[-0.9825, -1.0473, -1.0376],
#           [-0.9513, -0.9938, -1.0994],
#           [-0.9244, -1.2131, -0.9348]],
#
#          [[-1.0607, -0.8779, -0.9676],
#           [-0.8500, -0.9886, -1.0076],
#           [-1.0016, -0.9536, -0.9211]],
#
#          ...,
#
#          [[-0.9662, -1.1485, -0.9513],
#           [-1.1386, -0.9499, -0.8788],
#           [-1.0427, -0.9522, -1.1192]],
#
#          [[-1.0601, -0.9588, -1.0467],
#           [-0.9574, -1.0181, -0.9328],
#           [-0.9487, -0.9226, -0.9426]],
#
#          [[-1.1449, -0.9356, -0.9250],
#           [-1.1246, -1.1787, -1.0164],
#           [-0.8741, -0.9828, -1.1116]]],
#
#
#         [[[-0.9893, -1.0261, -1.1676],
#           [-0.8894, -0.9321, -0.9943],
#           [-0.9710, -0.9390, -0.9263]],
#
#          [[-0.8582, -1.0515, -1.0841],
#           [-1.0368, -1.0228, -0.8512],
#           [-0.9426, -1.0451, -0.9593]],
#
#          [[-0.9939, -1.0201, -1.1226],
#           [-1.2331, -1.0374, -0.9479],
#           [-0.8910, -0.9254, -0.9799]],
#
#          ...,
#
#          [[-1.1679, -1.0652, -0.9493],
#           [-1.0191, -1.1155, -0.8446],
#           [-0.9601, -0.9014, -1.0708]],
#
#          [[-0.8916, -0.9817, -0.9657],
#           [-0.9685, -0.9152, -0.9897],
#           [-0.9952, -1.0381, -1.0192]],
#
#          [[-0.9222, -0.9260, -1.1721],
#           [-0.8275, -0.8090, -0.9782],
#           [-0.9614, -1.0755, -1.0471]]]], device='cuda:0')
# Layer: conv_layers.7.bias, Biases: tensor([-1.1379, -0.9344, -0.9430, -0.8956, -1.0249, -1.0726, -1.0866, -0.9583,
#         -0.8894, -1.1434, -0.9700, -0.9599, -0.9251, -0.8621, -1.1207, -0.9742,
#         -0.9462, -0.9300, -0.8896, -1.0911, -1.0162, -1.0254, -1.1823, -0.9510,
#         -0.8473, -0.9436, -1.0276, -1.0299, -0.8250, -0.8457, -1.1125, -1.0173,
#         -1.1582, -0.8012, -1.0947, -0.9943, -0.9122, -1.0248, -0.9762, -1.2635,
#         -1.1154, -0.9326, -1.0334, -1.1264, -1.1956, -0.9775, -0.9090, -0.9257,
#         -0.8935, -1.0848, -1.1015, -1.0364, -1.0131, -1.1239, -0.9594, -0.8971,
#         -1.1444, -1.0257, -0.9697, -0.8714, -0.8330, -1.0194, -1.0148, -1.1150],
#        device='cuda:0')
# Layer: conv_layers.10.weight:, Weights: tensor([[[[-1.0567, -0.9039, -1.0530],
#           [-1.0843, -0.9386, -1.1010],
#           [-0.8829, -1.0517, -1.1045]],
#
#          [[-0.9771, -0.9788, -0.9590],
#           [-0.9823, -1.0755, -1.0356],
#           [-0.9553, -1.1329, -0.8075]],
#
#          [[-1.0069, -0.9335, -0.8940],
#           [-0.9539, -0.8242, -0.8285],
#           [-0.9377, -0.9268, -0.9757]],
#
#          ...,
#
#          [[-1.0418, -0.9714, -1.1190],
#           [-0.8688, -1.1988, -1.0349],
#           [-0.9222, -0.8281, -0.9650]],
#
#          [[-0.8720, -0.9188, -0.8787],
#           [-0.8808, -0.9623, -0.9508],
#           [-0.9782, -0.8741, -1.1235]],
#
#          [[-0.7973, -0.9428, -1.1008],
#           [-1.1480, -1.1330, -0.9998],
#           [-0.9724, -0.8815, -0.8735]]],
#
#
#         [[[-1.0507, -0.9160, -1.0161],
#           [-0.8047, -0.9531, -1.0250],
#           [-0.9560, -1.0576, -0.9437]],
#
#          [[-1.1694, -0.9655, -0.8350],
#           [-0.9306, -0.9841, -1.1195],
#           [-1.0071, -1.0503, -0.9689]],
#
#          [[-0.7777, -0.7897, -1.0603],
#           [-0.9497, -1.0936, -1.1215],
#           [-1.0384, -1.1601, -0.9911]],
#
#          ...,
#
#          [[-1.0800, -0.8371, -0.7878],
#           [-0.9130, -1.0219, -1.0934],
#           [-1.0373, -0.7969, -1.1266]],
#
#          [[-1.1364, -1.0193, -1.0241],
#           [-0.9715, -0.9612, -1.0242],
#           [-0.9664, -1.0694, -0.8360]],
#
#          [[-0.9463, -1.0814, -1.0680],
#           [-0.9112, -0.8224, -0.8911],
#           [-1.1157, -0.8465, -0.9946]]],
#
#
#         [[[-0.9758, -1.0654, -1.0402],
#           [-0.9281, -1.0383, -1.0673],
#           [-1.2245, -0.9535, -0.9526]],
#
#          [[-0.7850, -1.0402, -0.8706],
#           [-0.9181, -1.0858, -0.9021],
#           [-0.9799, -0.9666, -1.0118]],
#
#          [[-0.9107, -1.1195, -0.9175],
#           [-1.2413, -0.9611, -0.8772],
#           [-1.2046, -0.8963, -1.1936]],
#
#          ...,
#
#          [[-0.9142, -0.9278, -0.9508],
#           [-1.0492, -1.0558, -0.9106],
#           [-1.0798, -1.0256, -0.9929]],
#
#          [[-0.9714, -1.0802, -1.0598],
#           [-1.0883, -1.0930, -0.7883],
#           [-0.9219, -0.8057, -1.0967]],
#
#          [[-0.9671, -1.1595, -0.9996],
#           [-0.9720, -1.0426, -0.9350],
#           [-0.9585, -0.8636, -1.0956]]],
#
#
#         ...,
#
#
#         [[[-0.8664, -1.2212, -0.9392],
#           [-1.1812, -1.0569, -1.0761],
#           [-1.1987, -1.0499, -0.9454]],
#
#          [[-1.0387, -1.2046, -1.1393],
#           [-1.1833, -1.0097, -1.0434],
#           [-1.0955, -1.0997, -0.9976]],
#
#          [[-1.0902, -1.0840, -0.9346],
#           [-1.0099, -0.9273, -1.0065],
#           [-0.9628, -0.9001, -0.9897]],
#
#          ...,
#
#          [[-1.0049, -1.0881, -0.9002],
#           [-1.1647, -0.9794, -1.2744],
#           [-1.0144, -0.9170, -1.1321]],
#
#          [[-0.7933, -0.9132, -0.8622],
#           [-0.9146, -0.9891, -0.9065],
#           [-0.8114, -1.0324, -1.1650]],
#
#          [[-0.9936, -0.9698, -1.0132],
#           [-1.0089, -0.8611, -0.9657],
#           [-0.8696, -0.8682, -0.8572]]],
#
#
#         [[[-0.9182, -1.0289, -1.0568],
#           [-0.8142, -1.0229, -0.9561],
#           [-0.9726, -0.9240, -1.0349]],
#
#          [[-0.9157, -1.0239, -1.1856],
#           [-0.9945, -0.8709, -1.0470],
#           [-0.9298, -0.9176, -0.8351]],
#
#          [[-0.8998, -1.0236, -0.8805],
#           [-1.0060, -1.0287, -0.9903],
#           [-1.1566, -1.1557, -0.9408]],
#
#          ...,
#
#          [[-0.9504, -0.9174, -1.0451],
#           [-1.0837, -1.0545, -0.9158],
#           [-0.8776, -0.8414, -0.8917]],
#
#          [[-1.0259, -0.9447, -1.2360],
#           [-1.1277, -0.9632, -0.8610],
#           [-1.0160, -0.8892, -0.8186]],
#
#          [[-0.9958, -1.0278, -0.9663],
#           [-1.0939, -1.1460, -1.0651],
#           [-1.2597, -0.9806, -0.8767]]],
#
#
#         [[[-1.1891, -0.9874, -1.0443],
#           [-0.9380, -0.8998, -0.9795],
#           [-0.9964, -1.0129, -1.0034]],
#
#          [[-0.9474, -0.9904, -1.0503],
#           [-1.0324, -0.9174, -0.8885],
#           [-1.1151, -1.0597, -1.0536]],
#
#          [[-0.9674, -0.9030, -0.9527],
#           [-1.2400, -1.0678, -1.0017],
#           [-1.0421, -0.9706, -1.0987]],
#
#          ...,
#
#          [[-1.0494, -1.0660, -0.9921],
#           [-1.0137, -0.9836, -1.0044],
#           [-0.8439, -0.9479, -1.0171]],
#
#          [[-1.0917, -0.9807, -0.9797],
#           [-0.8021, -0.9335, -0.9866],
#           [-0.9722, -1.0810, -1.0031]],
#
#          [[-1.1075, -0.9844, -1.0108],
#           [-1.0124, -1.1936, -1.1359],
#           [-1.0229, -0.9263, -1.1257]]]], device='cuda:0')
# Layer: conv_layers.10.bias, Biases: tensor([-0.9346, -0.9117, -0.9532, -1.1497, -0.9555, -0.9279, -0.8560, -0.9137,
#         -0.9816, -1.0691, -0.7397, -1.0444, -1.1567, -1.0069, -1.0153, -0.9689,
#         -1.1031, -0.9261, -1.0700, -0.9387, -1.0312, -0.8803, -1.1459, -1.0296,
#         -0.9257, -0.8121, -1.0655, -1.0482, -0.9650, -1.0169, -0.9502, -0.9462,
#         -1.0782, -1.1503, -0.9465, -1.0950, -1.0511, -0.9841, -0.9570, -0.9542,
#         -1.0412, -0.9458, -0.9619, -0.9653, -0.8968, -1.0856, -1.0209, -0.9972,
#         -1.0369, -1.0294, -0.9744, -0.8743, -1.0373, -0.8907, -0.9683, -0.9148,
#         -0.8115, -0.9461, -0.7927, -0.9887, -1.0243, -1.1082, -0.8803, -1.0296,
#         -0.9699, -0.9780, -0.9091, -1.0825, -1.0052, -1.0739, -0.9270, -1.1026,
#         -1.0464, -0.9337, -1.1097, -1.1769, -1.0601, -0.9906, -0.9765, -1.2480,
#         -0.9431, -1.0770, -1.1095, -1.0404, -0.7290, -1.0621, -0.8983, -0.8863,
#         -1.0513, -1.0350, -0.9490, -0.9400, -1.2040, -0.9315, -1.0854, -0.9828,
#         -0.8728, -0.8920, -0.9127, -1.1718, -0.7992, -1.0018, -1.0763, -1.2368,
#         -0.9933, -1.0872, -0.8180, -0.9912, -1.2738, -0.9448, -1.0531, -0.9652,
#         -1.0288, -1.0346, -1.0790, -1.0047, -0.9949, -0.9490, -0.9267, -0.8323,
#         -0.9979, -1.0483, -1.0411, -0.9462, -1.2239, -1.0532, -0.9282, -0.8976],
#        device='cuda:0')
# Layer: conv_layers.12.weight:, Weights: tensor([[[[-1.1105, -0.9865, -0.9352],
#           [-0.8721, -1.1352, -1.1738],
#           [-0.7834, -0.9322, -1.0827]],
#
#          [[-0.8810, -0.9254, -1.0950],
#           [-1.1491, -1.0367, -1.0092],
#           [-0.9971, -1.0630, -0.9373]],
#
#          [[-0.9829, -1.0945, -1.0776],
#           [-1.0101, -0.9546, -1.0227],
#           [-1.0981, -1.0111, -0.7534]],
#
#          ...,
#
#          [[-0.9250, -0.8971, -0.9492],
#           [-1.0718, -1.0550, -0.9535],
#           [-1.0430, -1.0337, -1.1825]],
#
#          [[-1.0466, -0.9731, -0.8659],
#           [-0.8813, -0.8629, -0.9175],
#           [-1.2671, -1.2308, -0.8784]],
#
#          [[-1.0551, -1.0992, -0.8904],
#           [-1.0195, -0.9374, -1.2303],
#           [-1.1851, -1.1885, -1.0160]]],
#
#
#         [[[-1.0134, -0.8969, -1.0647],
#           [-0.9949, -0.9982, -0.9998],
#           [-1.0278, -1.1232, -0.8185]],
#
#          [[-1.0440, -0.9474, -1.2077],
#           [-0.8994, -0.8547, -0.7949],
#           [-1.2149, -1.0817, -0.7854]],
#
#          [[-0.9285, -1.1742, -0.9272],
#           [-0.9280, -0.9345, -1.1233],
#           [-1.0503, -0.9954, -1.1175]],
#
#          ...,
#
#          [[-1.0231, -1.0894, -0.9395],
#           [-0.8766, -1.0813, -0.9738],
#           [-0.9619, -1.1361, -1.0754]],
#
#          [[-1.3133, -1.0030, -1.0660],
#           [-0.9552, -0.9556, -1.0122],
#           [-1.0427, -0.9290, -1.2256]],
#
#          [[-0.9606, -0.9335, -1.0009],
#           [-1.0005, -0.9853, -1.0487],
#           [-1.1919, -0.9037, -1.0094]]],
#
#
#         [[[-0.7101, -1.0407, -1.0112],
#           [-1.0528, -0.9620, -0.9880],
#           [-0.8584, -1.0714, -0.9590]],
#
#          [[-0.9450, -1.1393, -1.0710],
#           [-1.1398, -1.0551, -1.0813],
#           [-0.9447, -1.0280, -0.7878]],
#
#          [[-0.9704, -0.7964, -1.0137],
#           [-0.9843, -0.9099, -1.0392],
#           [-0.9494, -0.9793, -0.8799]],
#
#          ...,
#
#          [[-0.8723, -0.9041, -0.9377],
#           [-1.1251, -1.0574, -1.0200],
#           [-0.9496, -1.1216, -1.1287]],
#
#          [[-0.8298, -1.2108, -1.0438],
#           [-0.8236, -0.8690, -1.0191],
#           [-0.8377, -0.8919, -0.9502]],
#
#          [[-1.0042, -1.1100, -1.0818],
#           [-0.9394, -0.9375, -0.9235],
#           [-0.9745, -0.8873, -0.9658]]],
#
#
#         ...,
#
#
#         [[[-1.1470, -1.1179, -0.8315],
#           [-0.9909, -0.9261, -1.0951],
#           [-1.2366, -0.9334, -1.0269]],
#
#          [[-0.8501, -1.1814, -1.1422],
#           [-0.8816, -0.9562, -0.9746],
#           [-1.0883, -1.1397, -1.1284]],
#
#          [[-1.0045, -1.0069, -0.9416],
#           [-0.9926, -1.0080, -1.0855],
#           [-0.9522, -1.0183, -0.7997]],
#
#          ...,
#
#          [[-1.0088, -0.7936, -1.0794],
#           [-0.8735, -1.0228, -0.9241],
#           [-0.9903, -0.9853, -1.0841]],
#
#          [[-1.0935, -1.0216, -0.9893],
#           [-1.0359, -1.1773, -0.9232],
#           [-0.8481, -1.1703, -1.0226]],
#
#          [[-1.0484, -0.9069, -0.8900],
#           [-0.7967, -1.1675, -1.0940],
#           [-0.9132, -0.9663, -0.9310]]],
#
#
#         [[[-0.9619, -1.1848, -0.8325],
#           [-1.1294, -1.0925, -1.0176],
#           [-1.0260, -0.9454, -0.8955]],
#
#          [[-0.9613, -1.2289, -1.1322],
#           [-1.0805, -0.9969, -0.9129],
#           [-1.0928, -0.9658, -1.0109]],
#
#          [[-1.0013, -0.8879, -0.8099],
#           [-0.9628, -0.8316, -0.9388],
#           [-1.1522, -0.8401, -0.9721]],
#
#          ...,
#
#          [[-0.9359, -0.9169, -0.9490],
#           [-0.9983, -0.9814, -0.9690],
#           [-0.8518, -0.8828, -1.0099]],
#
#          [[-0.9674, -1.0454, -1.0218],
#           [-1.0081, -1.1314, -0.9632],
#           [-0.9918, -1.2077, -1.0427]],
#
#          [[-0.8339, -0.9159, -0.9680],
#           [-1.0039, -0.9421, -0.9808],
#           [-1.2168, -0.9358, -1.0980]]],
#
#
#         [[[-1.0326, -0.9086, -0.8678],
#           [-0.9271, -0.9465, -0.7938],
#           [-0.9990, -0.9101, -1.0672]],
#
#          [[-0.8913, -1.0605, -1.1434],
#           [-1.0801, -1.1022, -0.9669],
#           [-0.9669, -1.2301, -0.8761]],
#
#          [[-0.9014, -1.0078, -1.0579],
#           [-0.9446, -1.1462, -1.0090],
#           [-1.0864, -0.9972, -1.0863]],
#
#          ...,
#
#          [[-1.0754, -1.0352, -1.1416],
#           [-0.8857, -0.9743, -0.8718],
#           [-0.9807, -0.9793, -0.9125]],
#
#          [[-1.1770, -1.1951, -1.0214],
#           [-1.0197, -1.0353, -0.9905],
#           [-0.9131, -0.8550, -1.1208]],
#
#          [[-0.9780, -1.1435, -0.9195],
#           [-0.9846, -1.0210, -0.8405],
#           [-0.9419, -0.9440, -0.8615]]]], device='cuda:0')
# Layer: conv_layers.12.bias, Biases: tensor([-0.8469, -0.9926, -0.9083, -1.0938, -1.1044, -1.1605, -0.9700, -0.9534,
#         -1.0190, -0.8907, -1.0582, -1.1579, -1.0062, -1.0029, -0.8889, -0.8769,
#         -0.8889, -1.0105, -1.0244, -1.0831, -1.0125, -1.0457, -1.0179, -1.0481,
#         -0.8952, -1.0548, -0.9349, -0.8217, -0.9572, -1.1797, -0.9913, -1.2166,
#         -1.1081, -0.8616, -0.8560, -1.0778, -0.9477, -0.8834, -1.0155, -1.0732,
#         -1.1077, -0.9088, -1.0348, -1.0933, -0.9744, -1.2360, -1.1117, -1.1384,
#         -1.0437, -1.1328, -0.8253, -1.0987, -1.0019, -0.9450, -0.9976, -0.9165,
#         -1.0758, -1.0018, -0.7557, -1.0835, -0.8168, -0.9157, -0.9200, -1.0040,
#         -0.9789, -1.0369, -0.9320, -0.9511, -0.9512, -0.8277, -0.9911, -0.8351,
#         -1.1085, -1.0687, -1.0380, -0.9813, -1.0258, -1.0518, -0.9755, -0.9991,
#         -0.9043, -0.9280, -1.2786, -0.9143, -1.1795, -1.0286, -0.8427, -0.9864,
#         -1.0759, -1.0356, -0.9983, -0.9930, -0.8563, -1.0251, -0.7905, -0.8316,
#         -0.8500, -1.2363, -0.9488, -0.9410, -0.9806, -0.9053, -1.0991, -1.0665,
#         -1.0325, -0.9481, -1.1363, -0.8667, -0.9738, -1.0125, -0.9270, -1.0458,
#         -1.0207, -1.1865, -1.0979, -1.0357, -1.1497, -0.9479, -0.6984, -0.7555,
#         -1.1535, -1.0275, -1.0193, -1.3180, -1.0895, -1.0647, -1.1055, -1.0003],
#        device='cuda:0')
# Layer: conv_layers.14.weight:, Weights: tensor([[[[-0.9212, -1.1157, -1.0213],
#           [-1.0357, -1.0377, -1.1671],
#           [-0.9795, -0.9660, -0.9231]],
#
#          [[-1.0599, -1.1074, -1.1059],
#           [-0.9474, -1.0092, -0.8046],
#           [-1.0533, -0.9553, -0.9671]],
#
#          [[-0.9943, -0.9903, -0.8141],
#           [-1.0770, -1.1126, -0.8951],
#           [-1.0172, -0.7841, -1.0780]],
#
#          ...,
#
#          [[-0.8772, -1.0039, -0.9830],
#           [-0.9116, -0.8823, -1.0679],
#           [-1.0335, -1.0214, -0.8919]],
#
#          [[-1.0138, -0.9135, -0.9796],
#           [-0.8124, -1.0116, -1.0063],
#           [-1.1292, -1.0381, -0.8211]],
#
#          [[-1.0891, -0.9274, -1.1851],
#           [-1.0793, -0.9464, -1.1613],
#           [-1.2836, -1.0885, -0.8645]]],
#
#
#         [[[-1.0167, -1.1301, -0.8105],
#           [-1.1215, -0.8646, -1.1168],
#           [-1.0236, -1.1371, -1.0465]],
#
#          [[-1.0703, -0.8842, -0.9377],
#           [-0.8678, -1.0662, -1.0197],
#           [-0.9466, -0.9700, -1.1681]],
#
#          [[-0.8909, -0.9514, -1.0728],
#           [-0.9697, -0.8359, -0.9680],
#           [-1.0118, -1.2514, -1.1188]],
#
#          ...,
#
#          [[-1.0514, -1.0551, -1.1512],
#           [-1.1875, -1.0325, -1.0753],
#           [-0.9138, -0.8235, -1.0624]],
#
#          [[-1.1100, -0.9858, -1.2206],
#           [-1.1321, -0.8444, -1.1281],
#           [-0.9607, -0.8230, -1.0235]],
#
#          [[-1.2211, -0.8961, -0.8714],
#           [-0.9949, -1.0581, -0.9269],
#           [-0.8429, -0.8137, -1.0083]]],
#
#
#         [[[-1.0093, -1.2034, -1.0788],
#           [-1.0398, -1.0717, -0.9863],
#           [-0.9861, -1.0103, -1.1573]],
#
#          [[-1.1547, -1.1349, -0.9365],
#           [-1.1489, -0.9196, -0.9821],
#           [-1.0971, -1.2690, -0.9432]],
#
#          [[-1.0192, -1.1201, -0.9393],
#           [-1.0158, -0.9382, -0.8687],
#           [-0.7463, -0.9960, -1.0653]],
#
#          ...,
#
#          [[-1.1056, -0.9489, -1.0478],
#           [-0.9949, -0.9462, -0.9015],
#           [-1.0700, -0.9481, -0.9585]],
#
#          [[-0.9856, -0.8848, -1.1208],
#           [-0.9392, -0.9386, -0.9897],
#           [-0.8788, -1.0419, -0.9407]],
#
#          [[-0.7386, -0.9767, -1.0125],
#           [-0.8673, -1.1730, -0.9988],
#           [-1.0250, -1.0773, -0.9794]]],
#
#
#         ...,
#
#
#         [[[-1.0337, -0.8797, -0.9251],
#           [-0.9885, -0.8240, -1.0540],
#           [-0.9574, -0.9309, -0.8324]],
#
#          [[-1.2053, -1.0053, -1.0071],
#           [-0.9954, -0.8693, -0.9284],
#           [-0.9521, -1.1065, -0.8668]],
#
#          [[-1.1012, -0.9296, -1.0228],
#           [-0.9062, -1.0389, -0.9386],
#           [-0.9019, -0.8732, -0.8597]],
#
#          ...,
#
#          [[-0.8812, -1.0580, -1.0815],
#           [-1.0468, -1.0857, -1.1061],
#           [-1.1775, -0.9752, -0.7669]],
#
#          [[-0.8459, -0.9502, -1.0922],
#           [-0.9470, -0.9277, -1.1487],
#           [-0.8319, -0.8798, -1.1092]],
#
#          [[-0.9702, -0.8716, -1.3623],
#           [-0.7979, -0.8658, -0.9659],
#           [-0.9940, -1.0575, -0.9503]]],
#
#
#         [[[-1.0818, -1.2197, -0.9597],
#           [-0.9448, -0.9883, -1.0452],
#           [-1.0264, -1.0830, -0.8372]],
#
#          [[-0.9853, -0.7840, -1.0111],
#           [-0.9546, -0.9449, -1.0770],
#           [-1.1615, -0.9198, -1.0426]],
#
#          [[-0.9930, -1.0625, -1.1327],
#           [-1.2221, -1.1463, -0.9744],
#           [-1.2297, -0.9471, -1.0592]],
#
#          ...,
#
#          [[-0.9624, -0.9911, -1.0759],
#           [-0.9925, -0.9315, -0.9149],
#           [-1.0102, -1.0361, -1.0753]],
#
#          [[-1.0595, -1.0693, -0.9852],
#           [-0.7589, -1.0069, -1.1520],
#           [-0.9769, -1.0332, -0.7975]],
#
#          [[-1.0317, -1.0622, -0.9518],
#           [-0.9494, -1.0206, -0.9842],
#           [-1.0174, -1.1517, -1.0370]]],
#
#
#         [[[-0.9179, -0.9369, -1.0520],
#           [-0.8969, -0.9623, -0.8583],
#           [-0.9012, -0.9332, -0.8451]],
#
#          [[-1.0601, -0.9989, -0.9651],
#           [-1.0312, -0.8731, -0.9196],
#           [-0.8066, -1.0749, -1.1260]],
#
#          [[-0.9487, -0.9693, -0.8596],
#           [-1.0454, -1.0604, -0.9838],
#           [-1.3033, -1.0709, -1.0318]],
#
#          ...,
#
#          [[-0.9771, -1.0793, -1.1521],
#           [-0.7859, -0.9488, -0.9335],
#           [-1.0411, -0.9202, -0.9450]],
#
#          [[-0.9957, -1.0011, -1.0016],
#           [-0.9315, -0.9738, -0.9331],
#           [-1.1521, -1.1231, -0.8239]],
#
#          [[-0.8520, -0.9574, -1.0161],
#           [-0.9819, -0.9989, -0.9895],
#           [-1.0773, -0.6951, -0.9548]]]], device='cuda:0')
# Layer: conv_layers.14.bias, Biases: tensor([-0.9623, -0.9824, -0.8824, -1.0052, -0.9851, -0.8572, -1.1510, -0.9585,
#         -1.0409, -1.0545, -0.9592, -1.0654, -1.1552, -0.9347, -0.9447, -0.8527,
#         -0.9317, -0.8487, -0.9869, -0.9490, -1.1714, -0.9798, -1.0928, -1.0821,
#         -0.9753, -0.9015, -0.8837, -0.8727, -1.1969, -1.2048, -0.8983, -1.1201,
#         -1.2191, -1.1259, -0.8449, -1.0769, -0.9409, -0.8906, -1.0905, -1.0988,
#         -0.8312, -0.8138, -1.0738, -1.0420, -0.8454, -1.0224, -1.0026, -0.9652,
#         -1.1256, -1.0371, -0.9661, -0.9359, -0.9579, -0.9499, -0.9766, -1.1279,
#         -1.0027, -1.1846, -1.1406, -1.0888, -1.0545, -0.9956, -0.8801, -1.0656,
#         -0.8467, -1.0188, -0.9961, -0.9242, -0.9834, -0.9705, -0.8369, -1.0178,
#         -1.0529, -0.8774, -1.1698, -1.0297, -1.0626, -0.8840, -1.0357, -1.0017,
#         -1.1331, -1.0982, -0.7501, -1.0567, -0.9914, -1.0396, -1.0907, -1.0392,
#         -0.7896, -0.7877, -0.7916, -1.0557, -0.9579, -1.1376, -0.9642, -0.9156,
#         -0.9645, -1.1574, -1.0529, -0.9789, -0.8801, -0.9333, -0.9806, -0.9467,
#         -1.0059, -0.9304, -1.0377, -0.8272, -1.0366, -1.1048, -0.8930, -1.0026,
#         -0.9823, -0.9554, -1.1209, -0.9416, -1.0864, -0.8985, -1.1450, -0.8961,
#         -0.9499, -1.0172, -0.9604, -1.1161, -1.0850, -1.0302, -0.9643, -0.8628],
#        device='cuda:0')
# Layer: fc.0.weight:, Weights: tensor([[-0.9630, -0.9826, -0.9682,  ..., -1.0191, -1.1996, -1.0198],
#         [-0.9107, -1.1283, -1.1484,  ..., -0.9931, -0.8341, -1.0505],
#         [-0.9090, -0.9959, -0.9355,  ..., -1.0019, -1.1283, -0.8567],
#         ...,
#         [-0.9639, -0.9748, -0.9260,  ..., -0.9690, -1.0825, -1.0405],
#         [-1.0059, -0.8319, -0.9190,  ..., -0.9801, -0.9470, -1.1236],
#         [-0.8669, -0.9190, -0.9621,  ..., -1.0709, -1.0453, -1.0651]],
#        device='cuda:0')
# Layer: fc.0.bias, Biases: tensor([-1.0866, -0.9429, -1.0163, -1.0912, -0.9904, -1.0199, -0.9616, -0.8650,
#         -0.9790, -1.0094, -0.9760, -1.1006, -1.0209, -0.9436, -1.0215, -0.8902,
#         -0.9744, -1.0039, -0.9963, -1.0510, -0.9317, -1.0226, -0.8980, -0.9072,
#         -1.0186, -1.1567, -0.8270, -0.8614, -0.8631, -0.9413, -0.9473, -0.8919,
#         -1.0614, -0.8795, -1.0239, -1.0768, -0.8882, -1.2002, -0.9684, -0.8963,
#         -0.9071, -1.0073, -1.1026, -1.0407, -0.8513, -0.8272, -1.0117, -1.0529,
#         -1.1671, -0.9972, -0.9917, -1.0597, -0.9197, -0.7815, -0.8550, -0.9696,
#         -0.9623, -0.9343, -1.0142, -0.8184, -0.9364, -0.9429, -1.0227, -0.8625,
#         -1.0996, -0.8652, -1.0480, -1.0088, -1.2288, -0.9003, -0.9675, -1.0030,
#         -0.9784, -0.8552, -1.1117, -0.9108, -0.9237, -1.1000, -0.9873, -0.8720,
#         -1.0828, -1.1135, -1.0123, -0.9127, -0.9508, -0.9304, -1.1844, -1.1015,
#         -1.0275, -1.0590, -1.0094, -0.9870, -0.9765, -1.0235, -0.9872, -1.0841,
#         -0.9308, -0.9366, -1.0688, -1.0997, -0.8996, -0.9189, -0.9188, -1.0875,
#         -1.0460, -0.9424, -1.1043, -1.2358, -0.9776, -1.0218, -1.1485, -1.1347,
#         -1.0152, -0.9531, -0.9893, -1.0920, -0.9730, -0.9600, -1.0841, -1.1363,
#         -1.1436, -1.0428, -1.0860, -0.9839, -1.0578, -1.1207, -1.0915, -0.9640,
#         -0.9675, -0.9894, -1.0130, -1.0796, -1.0472, -1.0474, -0.9029, -0.9227,
#         -1.1355, -0.9469, -0.9086, -1.0253, -0.9815, -0.9606, -1.0124, -0.9935,
#         -1.1108, -1.0766, -1.0227, -1.1072, -1.0305, -1.2095, -0.9452, -0.7999,
#         -1.0494, -0.9805, -0.9326, -1.0468, -0.8603, -0.9022, -1.0246, -0.9850,
#         -0.8679, -1.1662, -1.0802, -1.1413, -1.1282, -0.9899, -0.9298, -0.8897,
#         -1.1119, -0.9574, -0.9475, -1.0455, -1.0311, -0.8642, -1.0087, -1.1246,
#         -0.9931, -0.8492, -0.9366, -1.0125, -0.9476, -0.7319, -0.9224, -1.0663,
#         -1.0301, -1.0995, -1.1727, -0.9766, -1.0592, -0.9656, -0.9262, -0.8650,
#         -1.1153, -0.8917, -1.0417, -1.0526, -0.8108, -0.9605, -0.9174, -1.0895,
#         -0.8958, -0.9882, -1.0190, -1.1620, -1.1714, -1.0732, -1.0145, -1.0892,
#         -1.2112, -0.9047, -0.9360, -0.8602, -0.9974, -1.0280, -1.0299, -1.0400,
#         -1.0202, -0.7398, -1.0339, -1.0940, -1.0342, -0.9707, -1.0684, -0.9123,
#         -1.0538, -1.1141, -0.9669, -1.1498, -1.0261, -1.0047, -1.0115, -0.9050,
#         -0.9083, -1.1769, -0.7712, -1.1336, -0.9735, -0.9369, -1.0059, -0.9298,
#         -1.0706, -1.0482, -0.9894, -0.9794, -0.9114, -1.0056, -1.1187, -1.0690,
#         -0.9601, -1.0606, -0.9409, -1.0005, -0.8919, -1.1505, -0.9875, -0.8014],
#        device='cuda:0')
# Layer: fc.2.weight:, Weights: tensor([[-1.1169, -0.9604, -1.0316,  ..., -0.9812, -0.9206, -0.8877],
#         [-1.0249, -0.9659, -1.0129,  ..., -0.9204, -1.1108, -0.8108],
#         [-0.8415, -0.9605, -1.0024,  ..., -0.7314, -0.9968, -0.8491],
#         ...,
#         [-0.9831, -1.0148, -0.9980,  ..., -0.9495, -1.0090, -1.0203],
#         [-1.0023, -0.9222, -0.8909,  ..., -1.0159, -0.8690, -0.8386],
#         [-1.0732, -0.9745, -1.0561,  ..., -0.9986, -0.9582, -0.9839]],
#        device='cuda:0')
# Layer: fc.2.bias, Biases: tensor([-1.0004, -1.0765, -1.2098, -1.0977, -0.8950, -0.8723, -1.0948, -0.9561,
#         -1.0965, -0.9362, -0.9419, -1.1623, -1.0532, -1.0026, -1.1687, -1.0327,
#         -1.1392, -1.2369, -1.0203, -1.1075, -0.8437, -0.8689, -1.0479, -0.7882,
#         -0.9235, -1.0591, -1.0681, -1.0335, -1.0310, -0.8661, -0.8383, -0.9946,
#         -0.9276, -1.0519, -1.0336, -1.1355, -0.9250, -1.0498, -1.0477, -0.9636,
#         -0.8751, -1.0493, -0.9847, -0.9066, -1.2767, -1.1385, -0.9349, -0.7990,
#         -0.9841, -1.0550, -0.9692, -0.8439, -0.9659, -0.9363, -0.9130, -1.0051,
#         -1.0045, -0.9637, -1.1340, -1.1492, -1.0080, -0.9514, -1.0763, -1.0642,
#         -1.1143, -0.9482, -0.9429, -1.0357, -1.0101, -0.9642, -0.9916, -1.0301,
#         -1.1921, -1.0310, -1.0264, -1.0210, -1.1006, -0.9722, -0.9247, -1.0683,
#         -1.0235, -0.8536, -1.0806, -0.9830, -1.1305, -1.0747, -0.9809, -0.9886,
#         -0.8784, -0.8544, -0.9965, -1.0066, -0.9999, -1.0811, -1.1312, -0.8475,
#         -1.0888, -1.0017, -1.0416, -0.6580, -0.9495, -1.2020, -0.9537, -0.8566,
#         -1.0950, -0.9814, -1.0961, -1.0577, -1.2479, -0.9723, -0.8089, -1.0521,
#         -1.1528, -1.0687, -0.9493, -1.0264, -0.8725, -0.9707, -1.0549, -0.8305,
#         -1.0691, -0.8675, -0.9032, -1.0956, -0.9997, -0.9308, -0.9420, -1.0592,
#         -1.1433, -1.0608, -1.0684, -1.1132, -0.9790, -1.1850, -1.0403, -1.0065,
#         -0.8265, -1.0894, -0.8812, -0.9148, -1.0757, -1.0360, -0.9179, -1.0389,
#         -1.0803, -1.1165, -0.9963, -0.8912, -1.0458, -0.9672, -0.9870, -1.0871,
#         -1.0064, -0.9463, -0.9595, -0.8543, -1.0299, -1.0854, -0.8711, -0.8281,
#         -0.9055, -1.0062, -0.9764, -0.9791, -0.9274, -1.0046, -1.0981, -1.0858,
#         -1.1607, -0.9215, -1.0163, -0.8865, -1.1593, -0.9331, -0.9806, -0.9895,
#         -1.1304, -0.8969, -0.9840, -1.0034, -1.0732, -1.0892, -0.8916, -0.9325,
#         -1.0162, -0.9971, -0.8332, -1.1963, -1.0107, -0.7973, -1.1829, -0.8635,
#         -1.1642, -0.9038, -0.9256, -0.8682, -0.9653, -1.0521, -0.8818, -0.7880,
#         -0.8008, -0.9802, -1.0501, -1.0081, -0.9553, -1.1118, -1.1244, -0.9875,
#         -1.1457, -1.1042, -1.2213, -0.9432, -1.1641, -1.0946, -1.0843, -1.0114,
#         -0.9274, -1.0660, -0.7938, -0.9681, -1.1882, -1.1428, -1.1792, -0.9575,
#         -0.9041, -0.9400, -1.0168, -0.8653, -0.9379, -1.1238, -0.9173, -0.9580,
#         -0.9561, -1.0715, -0.9557, -0.9633, -1.0896, -1.1239, -1.0466, -0.8960,
#         -0.8490, -1.0147, -1.0354, -0.8491, -1.0762, -1.0955, -1.0117, -0.9243,
#         -0.8562, -0.9712, -1.1264, -1.1767, -0.9673, -1.1386, -0.9305, -0.9771],
#        device='cuda:0')
# Layer: fc.4.weight:, Weights: tensor([[-0.9879, -0.9583, -0.8832,  ..., -1.1059, -0.9827, -1.0825],
#         [-0.9429, -1.0698, -1.0260,  ..., -1.0520, -0.9361, -1.0410],
#         [-0.9876, -0.8446, -1.0514,  ..., -1.0185, -1.1347, -1.0221],
#         ...,
#         [-0.9358, -0.9631, -1.0302,  ..., -1.0071, -1.1059, -0.9684],
#         [-0.9522, -1.1185, -1.0532,  ..., -0.9516, -1.0451, -1.0474],
#         [-0.9988, -0.8819, -0.9959,  ..., -1.1731, -1.0833, -1.0879]],
#        device='cuda:0')
# Layer: fc.4.bias, Biases: tensor([-0.9142, -0.9950, -0.8998, -0.9735, -0.9540, -0.9494, -0.9289, -0.9703,
#         -0.8106, -1.0987], device='cuda:0')

# %% [markdown]
# ## Test Dummy Input

# %%
dummy_input = torch.randn(1, 3, 32, 32).to(device)
model(dummy_input)
# Out:
# tensor([[10.6470, 10.5527, 10.7759, 10.7852, 10.6112, 10.5973, 10.7065, 10.6618,
#          10.7584, 10.5834]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Training and Execution

# %% [markdown]
# ## Setup loss, accuracy, and paramaters

# %% [markdown]
# ## Mathematical Definition of Categorical Cross-Entropy
#
# Categorical Cross-Entropy (CCE) is the standard loss function for multi-class classification. It measures the difference between two probability distributions: the actual ground-truth labels (usually one-hot encoded) and the model's predicted probabilities.
#
# For a single sample, the loss is defined as:
#
# $$f(y_i, \hat{y}_i) = -\sum_{i=1}^{C} y_i \log(\hat{y}_i)$$
#
# When calculating the average loss over a batch of $N$ samples, the formula expands to:
#
# $$f(y_i, \hat{y}_i) = -\frac{1}{N} \sum_{j=1}^{N} \sum_{i=1}^{C} y_{j,i} \log(\hat{y}_{j,i})$$
#
# **Where:**
# * $C$ = Total number of classes
# * $N$ = Total number of samples in the batch
# * $y_i$ (or $y_{j,i}$) = The true label (1 if the sample belongs to class $i$, and 0 for all other classes)
# * $\hat{y}_i$ (or $\hat{y}_{j,i}$) = The model's predicted probability that the sample belongs to class $i$ (typically the output of a Softmax activation function)
#
# > **Note:** Because the true labels $y_i$ are zero for all incorrect classes in one-hot encoding, the formula effectively simplifies to taking the negative log of the predicted probability for the **true** class.

# %%
#Setup Loss Functions, Accuracy function
loss_fn = torch.nn.CrossEntropyLoss(label_smoothing=0.1)

#Define Accuracy Metric
def calculate_accuracy(y_true, y_pred):
  correct = torch.eq(y_true, y_pred).sum().item()
  accuracy = (correct / len(y_pred)) * 100
  return accuracy

##Training Parameters

num_of_epochs = 100
num_loss_steps = 5

# %% [markdown]
# ### Gradient Norm
#
# **Mathematical Definition**: The $\ell^2$ Norm of the Gradient. In real analysis, the small $\ell^2$ norm (standard Euclidean norm) measures the magnitude of a finite-dimensional vector in $\mathbb{R}^n$.Let $\mathbf{w} \in \mathbb{R}^n$ represent the flattened continuous vector of all trainable parameters within the neural network architecture. The gradient of the objective loss function $\mathcal{L}$ with respect to these parameters is a discrete vector composed of partial derivatives:
# $$\nabla_{\mathbf{w}} \mathcal{L} = \left[ \frac{\partial \mathcal{L}}{\partial w_1}, \frac{\partial \mathcal{L}}{\partial w_2}, \dots, \frac{\partial \mathcal{L}}{\partial w_n} \right]^T$$
#
# The $\ell^2$ norm of this gradient vector, denoted as $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_{\ell^2}$ or simply $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2$, is defined as the square root of the sum of its squared coordinate components:$$\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2 = \sqrt{ \sum_{i=1}^{n} \left( \frac{\partial \mathcal{L}}{\partial w_i} \right)^2 }$$In the context of empirical risk minimization, bounding this sequence of finite sums guarantees that gradient updates remain stable and prevents the parameter vector from diverging during optimization.
#
#
# **IMPORTANT NOTE**
#
# In real and functional analysis, the capital $L^p$ spaces denote spaces of measurable functions, where the norm is evaluated via continuous integration, such as $\Vert{}f\Vert{}_{L^2} = \left( \int \vert{}f(x)\vert{}^2 dx \right)^{1/2}$. The lowercase $\ell^p$ spaces apply to discrete sequences or finite-dimensional coordinate vectors, where the norm is evaluated via discrete summation. Since the gradient of a neural network's loss with respect to its parameters, $\nabla_{\mathbf{w}} \mathcal{L}$, is a finite-dimensional vector of discrete scalar derivatives rather than a continuous mathematical function, finding its magnitude requires summing the squares of its individual components. You are completely correct: we use the small $\ell^2$ norm precisely because we are operating on discrete Euclidean vectors, not continuous functions.

# %% [markdown]
# ## Execution and Saving

# %%
torch.manual_seed(143)
activation_dict = {
    "PGELU": PGELU,
    "MP_GELU": partial(MPGELU, s_param=0.0, use_softplus=True),
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}

all_results = {}

for act_name, act_fn in activation_dict.items():
    print(f"\n=======================================================")
    print(f"       TRAINING WITH ACTIVATION: {act_name}")
    print(f"=======================================================")

    model = MyCNN(input_shape=3, output_shape=10, activation=act_fn, params=chosen_model_params).to(device)
    model.apply(init_custom_weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)

    trainer = Trainer(model=model, loss_fn=loss_fn, optimizer=optimizer,
                      calculate_accuracy=calculate_accuracy, device=device, loss_steps=num_loss_steps)

    results = {
        "train_loss": [],
        "train_accu": [],
        "test_loss": [],
        "test_accu": [],
        "activation_params": {},
        "grad_norm": []  # Initialize an empty list to store gradient norms
    }

    start_time = time.perf_counter()

    for epoch in tqdm(range(num_of_epochs), desc=f"Training {act_name}"):
        if epoch % num_loss_steps == 0:
            print(f"Epoch: {epoch} \n =====================================================================")
        train_loss, train_accu, norm = trainer.train(data_loader=train_dataloader, epoch=epoch)
        test_loss, test_accu = trainer.test(data_loader=test_dataloader, epoch=epoch)

        results["train_loss"].append(train_loss)
        results["train_accu"].append(train_accu)
        results["test_loss"].append(test_loss)
        results["test_accu"].append(test_accu)
        results["grad_norm"].append(norm)

        # Track dynamic activation parameters
        for name, param in model.named_parameters():
            if 'alpha_param' in name or 'beta_param' in name or 's_param' in name:
                if name not in results.setdefault("activation_params", {}):
                    results["activation_params"][name] = []
                results["activation_params"][name].append(param.item())

    total_time = time.perf_counter() - start_time
    results["total_runtime"] = total_time
    all_results[act_name] = results

    # Save Model Checkpoint
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'results': results,
        'total_runtime': total_time,
        'activation_name': act_name
    }

    save_dir = "model_trained_params_new"
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir, f"chkpt4_{act_name}.pth")

    torch.save(checkpoint, save_path)
    print(f"Saved model state to {save_path}")
# Out:
# =======================================================
#        TRAINING WITH ACTIVATION: PGELU
# =======================================================
# Training PGELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 3.22673 | Training Accuracy: 9.89570%
# Test Loss 6.48160 | Test Accuracy 10.80894%
# Epoch: 5
#  =====================================================================
# Training Loss: 145.86558 | Training Accuracy: 10.11109%
# Test Loss 3.79671 | Test Accuracy 10.64082%
# Epoch: 10
#  =====================================================================
# Training Loss: 2.35107 | Training Accuracy: 10.33008%
# Test Loss 2.37079 | Test Accuracy 10.65071%
# Epoch: 15
#  =====================================================================
# Training Loss: 2.35510 | Training Accuracy: 10.06154%
# Test Loss 2.36702 | Test Accuracy 8.69264%
# Epoch: 20
#  =====================================================================
# Training Loss: 2.32918 | Training Accuracy: 9.93526%
# Test Loss 2.32573 | Test Accuracy 8.47508%
# Epoch: 25
#  =====================================================================
# Training Loss: 2.34646 | Training Accuracy: 9.85174%
# Test Loss 2.37707 | Test Accuracy 9.19699%
# Epoch: 30
#  =====================================================================
# Training Loss: 2.34890 | Training Accuracy: 9.81058%
# Test Loss 2.34479 | Test Accuracy 9.01899%
# Epoch: 35
#  =====================================================================
# Training Loss: 2.31563 | Training Accuracy: 10.00879%
# Test Loss 2.31914 | Test Accuracy 8.62342%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.30654 | Training Accuracy: 9.92247%
# Test Loss 2.31602 | Test Accuracy 8.23774%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.30470 | Training Accuracy: 10.05754%
# Test Loss 2.31553 | Test Accuracy 8.84098%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.30413 | Training Accuracy: 9.79939%
# Test Loss 2.30585 | Test Accuracy 9.10799%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.30314 | Training Accuracy: 9.91848%
# Test Loss 2.30297 | Test Accuracy 8.95965%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.30265 | Training Accuracy: 9.92128%
# Test Loss 2.30140 | Test Accuracy 10.63093%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.30251 | Training Accuracy: 10.10710%
# Test Loss 2.30032 | Test Accuracy 12.08465%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.30239 | Training Accuracy: 10.29292%
# Test Loss 2.30094 | Test Accuracy 11.14517%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.31904 | Training Accuracy: 9.91528%
# Test Loss 2.30423 | Test Accuracy 10.02769%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.30258 | Training Accuracy: 10.06913%
# Test Loss 2.30084 | Test Accuracy 11.14517%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.30291 | Training Accuracy: 9.93806%
# Test Loss 2.31517 | Test Accuracy 11.50119%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.30293 | Training Accuracy: 9.96723%
# Test Loss 2.34522 | Test Accuracy 11.05617%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.30338 | Training Accuracy: 10.14626%
# Test Loss 2.31260 | Test Accuracy 11.59019%
# Saved model state to model_trained_params_new/chkpt4_PGELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: MP_GELU
# =======================================================
# Training MP_GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.52267 | Training Accuracy: 9.79500%
# Test Loss 2.58953 | Test Accuracy 10.29470%
# Epoch: 5
#  =====================================================================
# Training Loss: 2.31010 | Training Accuracy: 10.11709%
# Test Loss 2.38698 | Test Accuracy 10.66060%
# Epoch: 10
#  =====================================================================
# Training Loss: 2.30291 | Training Accuracy: 9.89530%
# Test Loss 2.30563 | Test Accuracy 10.57160%
# Epoch: 15
#  =====================================================================
# Training Loss: 2.30198 | Training Accuracy: 10.13067%
# Test Loss 2.30316 | Test Accuracy 10.69027%
# Epoch: 20
#  =====================================================================
# Training Loss: 2.30176 | Training Accuracy: 10.02877%
# Test Loss 2.30296 | Test Accuracy 9.76068%
# Epoch: 25
#  =====================================================================
# Training Loss: 2.30178 | Training Accuracy: 10.11909%
# Test Loss 2.30626 | Test Accuracy 9.92880%
# Epoch: 30
#  =====================================================================
# Training Loss: 2.30182 | Training Accuracy: 10.19821%
# Test Loss 2.30375 | Test Accuracy 9.83979%
# Epoch: 35
#  =====================================================================
# Training Loss: 2.30199 | Training Accuracy: 10.06074%
# Test Loss 2.30444 | Test Accuracy 10.09691%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.30213 | Training Accuracy: 10.01359%
# Test Loss 2.30512 | Test Accuracy 9.66179%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.30212 | Training Accuracy: 9.88891%
# Test Loss 2.30402 | Test Accuracy 9.95847%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.30156 | Training Accuracy: 10.21220%
# Test Loss 2.30384 | Test Accuracy 10.50237%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.30181 | Training Accuracy: 10.07193%
# Test Loss 2.30973 | Test Accuracy 9.82002%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.30160 | Training Accuracy: 10.16424%
# Test Loss 2.30815 | Test Accuracy 10.12658%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.30201 | Training Accuracy: 9.99720%
# Test Loss 2.30298 | Test Accuracy 10.19581%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.30187 | Training Accuracy: 9.87092%
# Test Loss 2.30431 | Test Accuracy 9.96835%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.30177 | Training Accuracy: 10.08312%
# Test Loss 2.30441 | Test Accuracy 10.14636%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.30166 | Training Accuracy: 10.01519%
# Test Loss 2.31407 | Test Accuracy 10.18592%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.30209 | Training Accuracy: 9.82177%
# Test Loss 2.30323 | Test Accuracy 10.10680%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.30160 | Training Accuracy: 10.13347%
# Test Loss 2.30461 | Test Accuracy 9.97824%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.30160 | Training Accuracy: 10.12148%
# Test Loss 2.30545 | Test Accuracy 10.37381%
# Saved model state to model_trained_params_new/chkpt4_MP_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: ReLU
# =======================================================
# Training ReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.30469 | Training Accuracy: 9.94365%
# Test Loss 2.30285 | Test Accuracy 9.88924%
# Epoch: 5
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.74145%
# Test Loss 2.30258 | Test Accuracy 10.09691%
# Epoch: 10
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.76822%
# Test Loss 2.30260 | Test Accuracy 9.88924%
# Epoch: 15
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.81218%
# Test Loss 2.30258 | Test Accuracy 10.09691%
# Epoch: 20
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.68031%
# Test Loss 2.30259 | Test Accuracy 9.95847%
# Epoch: 25
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.90169%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 30
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.84295%
# Test Loss 2.30259 | Test Accuracy 10.02769%
# Epoch: 35
#  =====================================================================
# Training Loss: 2.30270 | Training Accuracy: 9.80858%
# Test Loss 2.30260 | Test Accuracy 9.88924%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.70628%
# Test Loss 2.30263 | Test Accuracy 10.09691%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 10.09151%
# Test Loss 2.30262 | Test Accuracy 9.95847%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.81338%
# Test Loss 2.30261 | Test Accuracy 9.88924%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.79100%
# Test Loss 2.30258 | Test Accuracy 10.09691%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.91168%
# Test Loss 2.30259 | Test Accuracy 9.88924%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.89650%
# Test Loss 2.30262 | Test Accuracy 9.88924%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.84135%
# Test Loss 2.30258 | Test Accuracy 9.95847%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.90529%
# Test Loss 2.30262 | Test Accuracy 9.95847%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.62916%
# Test Loss 2.30260 | Test Accuracy 9.95847%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.66272%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.83736%
# Test Loss 2.30261 | Test Accuracy 9.88924%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.66512%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Saved model state to model_trained_params_new/chkpt4_ReLU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: GELU
# =======================================================
# Training GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.55985 | Training Accuracy: 10.06913%
# Test Loss 4.24841 | Test Accuracy 10.85839%
# Epoch: 5
#  =====================================================================
# Training Loss: 2.31473 | Training Accuracy: 10.19461%
# Test Loss 2.44452 | Test Accuracy 10.84850%
# Epoch: 10
#  =====================================================================
# Training Loss: 2.30341 | Training Accuracy: 9.95724%
# Test Loss 2.30157 | Test Accuracy 10.99684%
# Epoch: 15
#  =====================================================================
# Training Loss: 2.30183 | Training Accuracy: 10.00559%
# Test Loss 2.30032 | Test Accuracy 11.14517%
# Epoch: 20
#  =====================================================================
# Training Loss: 2.30177 | Training Accuracy: 10.06793%
# Test Loss 2.30296 | Test Accuracy 11.74842%
# Epoch: 25
#  =====================================================================
# Training Loss: 2.30204 | Training Accuracy: 10.10230%
# Test Loss 2.30120 | Test Accuracy 10.36392%
# Epoch: 30
#  =====================================================================
# Training Loss: 2.30213 | Training Accuracy: 10.06634%
# Test Loss 2.30239 | Test Accuracy 10.95728%
# Epoch: 35
#  =====================================================================
# Training Loss: 2.30217 | Training Accuracy: 10.17583%
# Test Loss 2.30054 | Test Accuracy 10.38370%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.30214 | Training Accuracy: 10.29691%
# Test Loss 2.29957 | Test Accuracy 10.99684%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.30228 | Training Accuracy: 10.05075%
# Test Loss 2.30017 | Test Accuracy 11.06606%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.30205 | Training Accuracy: 10.16584%
# Test Loss 2.29944 | Test Accuracy 11.03639%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.30188 | Training Accuracy: 10.00480%
# Test Loss 2.29943 | Test Accuracy 10.27492%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.30218 | Training Accuracy: 10.12988%
# Test Loss 2.30016 | Test Accuracy 11.76820%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.30201 | Training Accuracy: 10.11389%
# Test Loss 2.29979 | Test Accuracy 10.70016%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.30185 | Training Accuracy: 10.11669%
# Test Loss 2.30013 | Test Accuracy 10.99684%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.30240 | Training Accuracy: 10.14866%
# Test Loss 2.30029 | Test Accuracy 11.66930%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.30182 | Training Accuracy: 10.11749%
# Test Loss 2.30026 | Test Accuracy 11.41218%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.30183 | Training Accuracy: 10.17024%
# Test Loss 2.29981 | Test Accuracy 11.02650%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.30189 | Training Accuracy: 9.99920%
# Test Loss 2.30043 | Test Accuracy 10.75949%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.30218 | Training Accuracy: 10.06474%
# Test Loss 2.30042 | Test Accuracy 10.51226%
# Saved model state to model_trained_params_new/chkpt4_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: LeakyReLU
# =======================================================
# Training LeakyReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 1632373758219.13037 | Training Accuracy: 9.94006%
# Test Loss 341969291704.70886 | Test Accuracy 10.09691%
# Epoch: 5
#  =====================================================================
# Training Loss: 33006785109.11509 | Training Accuracy: 10.03676%
# Test Loss 43968001036.96203 | Test Accuracy 9.88924%
# Epoch: 10
#  =====================================================================
# Training Loss: 6768218739.23274 | Training Accuracy: 10.06074%
# Test Loss 6839964503.49367 | Test Accuracy 10.09691%
# Epoch: 15
#  =====================================================================
# Training Loss: 1812767653.31969 | Training Accuracy: 10.03557%
# Test Loss 1379408495.79747 | Test Accuracy 10.21559%
# Epoch: 20
#  =====================================================================
# Training Loss: 470050107.92839 | Training Accuracy: 9.97922%
# Test Loss 347826137.51899 | Test Accuracy 9.95847%
# Epoch: 25
#  =====================================================================
# Training Loss: 109927950.14834 | Training Accuracy: 10.15945%
# Test Loss 72333941.87342 | Test Accuracy 9.84968%
# Epoch: 30
#  =====================================================================
# Training Loss: 17801098.23913 | Training Accuracy: 10.55667%
# Test Loss 22993899.49367 | Test Accuracy 10.23536%
# Epoch: 35
#  =====================================================================
# Training Loss: 4479004.52398 | Training Accuracy: 11.14290%
# Test Loss 3145986.26582 | Test Accuracy 12.97468%
# Epoch: 40
#  =====================================================================
# Training Loss: 864204.37816 | Training Accuracy: 11.11733%
# Test Loss 1025109.56092 | Test Accuracy 10.69027%
# Epoch: 45
#  =====================================================================
# Training Loss: 304826.92355 | Training Accuracy: 10.84479%
# Test Loss 353773.88568 | Test Accuracy 10.55182%
# Epoch: 50
#  =====================================================================
# Training Loss: 121768.48142 | Training Accuracy: 11.14650%
# Test Loss 107129.62589 | Test Accuracy 10.75949%
# Epoch: 55
#  =====================================================================
# Training Loss: 27507.67966 | Training Accuracy: 11.57449%
# Test Loss 16700.07437 | Test Accuracy 12.89557%
# Epoch: 60
#  =====================================================================
# Training Loss: 5369.68810 | Training Accuracy: 11.70316%
# Test Loss 7741.67470 | Test Accuracy 11.27373%
# Epoch: 65
#  =====================================================================
# Training Loss: 1766.85150 | Training Accuracy: 11.07617%
# Test Loss 923.83212 | Test Accuracy 11.56052%
# Epoch: 70
#  =====================================================================
# Training Loss: 1216.22987 | Training Accuracy: 10.57705%
# Test Loss 1064.17468 | Test Accuracy 10.31448%
# Epoch: 75
#  =====================================================================
# Training Loss: 297.34099 | Training Accuracy: 10.05235%
# Test Loss 11.62654 | Test Accuracy 11.66930%
# Epoch: 80
#  =====================================================================
# Training Loss: 21.97274 | Training Accuracy: 10.82401%
# Test Loss 6.75022 | Test Accuracy 11.74842%
# Epoch: 85
#  =====================================================================
# Training Loss: 10.84013 | Training Accuracy: 10.89114%
# Test Loss 4.49415 | Test Accuracy 10.55182%
# Epoch: 90
#  =====================================================================
# Training Loss: 4.37671 | Training Accuracy: 11.44981%
# Test Loss 9.60087 | Test Accuracy 8.70253%
# Epoch: 95
#  =====================================================================
# Training Loss: 4.90102 | Training Accuracy: 10.50631%
# Test Loss 2.75420 | Test Accuracy 9.97824%
# Saved model state to model_trained_params_new/chkpt4_LeakyReLU.pth

# %% [markdown]
# # Loading the trained model params

# %%
activation_dict = {
    "MP_GELU": MPGELU,
    "PGELU": PGELU,
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}

# activation_dict = {
#     "PGELU": PGELU,
# }

# Initialize LoadedModel with the correct initial_fileName and checkpoint_dir
loader = LoadedModel(
    activation_dict=activation_dict,
    model_params=chosen_model_params,
    initial_fileName="chkpt4",
    checkpoint_dir="model_trained_params_new",
    device=device
)

# Run it
my_models = loader.load_checkpoints()
# Out:
# =======================================================
#        EVALUATING ACTIVATION: MP_GELU
# =======================================================
# Loaded trained model for MP_GELU from model_trained_params_new/chkpt4_MP_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: PGELU
# =======================================================
# Loaded trained model for PGELU from model_trained_params_new/chkpt4_PGELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: ReLU
# =======================================================
# Loaded trained model for ReLU from model_trained_params_new/chkpt4_ReLU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: GELU
# =======================================================
# Loaded trained model for GELU from model_trained_params_new/chkpt4_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: LeakyReLU
# =======================================================
# Loaded trained model for LeakyReLU from model_trained_params_new/chkpt4_LeakyReLU.pth

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Plotting

# %%
to_plot = {
    "MP_GELU":   {"results": my_models["MP_GELU"]["results"],   "linewidth": 3.0, "color": "#000000"}, # Jet Black
    "PGELU":     {"results": my_models["PGELU"]["results"],     "linewidth": 2.0, "color": "#E62937"}, # Strong Red
    "ReLU":      {"results": my_models["ReLU"]["results"],      "linewidth": 2.0, "color": "#009E73"}, # Teal
    "GELU":      {"results": my_models["GELU"]["results"],      "linewidth": 2.0, "color": "#4363D8"}, # Royal Blue
    "LeakyReLU": {"results": my_models["LeakyReLU"]["results"], "linewidth": 2.0, "color": "#F58231"}  # Bright Orange
}

# %% [markdown]
# ### Evolution of Learnable Parameters

# %% [markdown]
# #### $\alpha$ and $\beta$ of PGELU

# %%
alpha = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.alpha_param"]
beta = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.beta_param"]

fig, ax = plt.subplots(1, 2, figsize=(10, 6))

# Alpha Plot
# \n splits the label into two lines
ax[0].plot(alpha, label="Alpha\nParameter", color="#E62937", linewidth=2.5)
ax[0].grid(True, linestyle=':', alpha=0.9)
ax[0].tick_params(axis='x', labelsize=13)
ax[0].legend(loc="center left", bbox_to_anchor=(0.02, 0.5), fontsize=15)

# Beta Plot
# \n splits the label into two lines
ax[1].plot(beta, label="Beta\nParameter", color="#009E73", linewidth=2.5)
ax[1].grid(True, linestyle=':', alpha=0.9)
ax[1].tick_params(axis='x', labelsize=13)
ax[1].legend(loc="center left", bbox_to_anchor=(0.02, 0.5), fontsize=15)

fig.supxlabel("Epochs", fontsize=15)
fig.supylabel("Parameter Value", fontsize=15)
fig.suptitle("Dynamic Activation Parameters Evolution for PGELU", fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### $\lambda$ of MPGELU

# %%
# ============================================================
# MP-GELU LEARNED LAMBDA EVOLUTION
# ============================================================

params_dict = my_models["MP_GELU"]["results"]["activation_params"]

s_vals = params_dict["conv_layers.1.s_param"]

s_values = torch.tensor(
    s_vals,
    dtype=torch.float32,
    device=device
)

# Same formulation used in MPGELU
lam = 1.0 + F.softplus(s_values)

plt.figure(figsize=(11, 7))

plt.plot(
    lam.detach().cpu().numpy(),
    linewidth=2.5,
    color="#000055",
    label=r"Learned $\lambda$"
)

plt.xlabel("Epoch", fontsize=15)
plt.ylabel(r"Learned $\lambda$", fontsize=15)
plt.title(
    r"Evolution of Learned $\lambda$ in MP-GELU During Training",
    fontsize=16
)

# 0–100 axis
plt.xlim(0, 100)
plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

plt.grid(True, linestyle=":", alpha=0.9)
plt.legend(fontsize=14)

plt.tight_layout()
plt.show()

# %%
params_dict = my_models["MP_GELU"]["results"]["activation_params"]
s_vals = params_dict['conv_layers.1.s_param']
s_values = torch.tensor(s_vals, device=device, dtype=torch.float32)
lam = 1.0 + torch.log(1.0 + torch.exp(s_values))

plt.figure(figsize=(9, 6))
plt.plot(lam.detach().cpu().numpy(), linestyle='-', color='#000055')
plt.xlabel("Epoch", fontsize=13)
plt.ylabel(r"Learned $\lambda$", fontsize=13)
plt.title(r"Evolution of $\lambda$ of MPGELU During Training")
plt.grid(True, linestyle=':', alpha=0.9)
plt.yticks(np.arange(1.6, 3.2, 0.2), fontsize=13)

# --- CHANGED FOR 100 EPOCHS ---
plt.xticks(np.arange(0, 105, 10), fontsize=13) # Ticks every 10 epochs
plt.xlim(-2, 102)                             # Bounds slightly padded past 100
# ------------------------------

plt.tight_layout()
# plt.savefig("learned_lambda_evolution.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Train Loss Curves

# %%
# ============================================================
# TRAINING LOSS COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["train_loss"], **arguments)

plt.legend(loc="upper right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

# Keep automatic y-axis
# plt.ylim(0.75, 2.4)

# 0–100
plt.xlim(0, 100)

plt.title(
    "Training Loss Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("train_loss_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["train_loss"], **arguments)

# --- CHANGED LEGEND POSITION ---
plt.legend(loc="lower left", fontsize=14)
# -------------------------------

plt.grid(True,linestyle='--', alpha=0.6)

# --- 100 EPOCHS TIMELINE ---
plt.xticks(np.arange(0, 105, 10), fontsize=12)
plt.xlim(-2, 102)

# --- CHANGED Y-AXIS SPECIFICATIONS ---
plt.yticks(np.arange(1.6, 3.4, 0.2), fontsize=12) # Explicitly labels every 0.2 units (1.6, 1.8... 3.2)
plt.ylim(1.6, 3.2)                                # Clips the view window strictly from 1.6 to 3.2
# --------------------------------------

plt.title("Training Loss Comparison Across Activation Functions", fontsize=16)
# plt.savefig("train_loss_comparison.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Test Loss Curves

# %%
# ============================================================
# TEST LOSS COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["test_loss"], **arguments)

plt.legend(loc="upper right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

plt.xlim(0, 100)

plt.title(
    "Test Loss Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("test_loss_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["test_loss"], **arguments)

# --- CHANGED LEGEND POSITION ---
plt.legend(loc="lower left", fontsize=14)
# -------------------------------

plt.grid(True,linestyle='--', alpha=0.6)

# --- 100 EPOCHS TIMELINE ---
plt.xticks(np.arange(0, 105, 10), fontsize=12)
plt.xlim(-2, 102)

# --- CHANGED Y-AXIS SPECIFICATIONS ---
plt.yticks(np.arange(1.6, 3.4, 0.2), fontsize=12) # Labels every 0.2 units (1.6, 1.8... 3.2)
plt.ylim(1.6, 3.2)                                # Clips the view window strictly from 1.6 to 3.2
# --------------------------------------

plt.title("Test Loss Comparison Across Activation Functions", fontsize=16)
plt.tight_layout()
# plt.savefig("test_loss_comparison.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Training Accuracy

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["train_accu"], **arguments)
plt.legend(loc="upper left", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)

# --- CHANGED FOR 100 EPOCHS & MAGNIFICATION ---
plt.xticks(np.arange(0, 105, 10), fontsize=12) # Labels every 10 epochs: 0, 10, 20...100
plt.xlim(-2, 102)                             # Displays slightly past 100 so the edge isn't cut off
plt.yticks(np.arange(0, 35, 5), fontsize=12)   # Magnified y-axis labels
plt.ylim(0, 30)                               # Magnified y-axis boundaries
# ----------------------------------------------

plt.title("Training Accuracy Comparison Across Activation Functions", fontsize=16)
plt.show()

# %% [markdown]
# ### Test Accuracy

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["test_accu"], **arguments)
plt.legend(loc="upper left", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)

# --- CHANGED FOR 100 EPOCHS & MAGNIFICATION ---
plt.xticks(np.arange(0, 105, 10), fontsize=12) # Labels every 10 epochs: 0, 10, 20...100
plt.xlim(-2, 102)                             # Displays slightly past 100 so the edge isn't cut off
plt.yticks(np.arange(0, 35, 5), fontsize=12)   # Magnified y-axis labels
plt.ylim(0, 30)                               # Magnified y-axis boundaries
# ----------------------------------------------

plt.title("Test Accuracy Comparison Across Activation Functions", fontsize=16)
plt.show()

# %%
plt.plot(my_models["LeakyReLU"]["results"]["grad_norm"])

# %% [markdown]
# # $F_{1}$ Scores
# **Mathematical Definition of the $F_1$ Score**
#
# The $F_1$ score is the harmonic mean of Precision and Recall. It provides a single metric that balances both false positives and false negatives, making it particularly useful for evaluating models on imbalanced datasets.
#
# The general formula is defined as:
#
# $$F_1 = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$$
#
# To calculate the $F_1$ score, you must first calculate **Precision** and **Recall**:
#
# * **Precision** measures the proportion of positive predictions that were actually correct:
#   $$\text{Precision} = \frac{TP}{TP + FP}$$
#
# * **Recall** (also known as Sensitivity) measures the proportion of actual positives that were identified correctly:
#   $$\text{Recall} = \frac{TP}{TP + FN}$$
#
# By substituting Precision and Recall back into the original equation, the $F_1$ score can be expressed directly in terms of prediction outcomes:
#
# $$F_1 = \frac{2 \cdot TP}{2 \cdot TP + FP + FN}$$
#
# **Where:**
# * $TP$ = **True Positives** (Model correctly predicts the positive class)
# * $FP$ = **False Positives** (Model incorrectly predicts the positive class)
# * $FN$ = **False Negatives** (Model incorrectly predicts the negative class)

# %%
f1_results = {}

print("Calculating F1 Scores...")
print("========================")

for act_name, model_data in my_models.items():
    model = model_data["model"]
    model.eval()  # Ensure the model is in evaluation mode

    all_preds = []
    all_targets = []

    with torch.inference_mode():
        # Assuming you have your test_dataloader ready
        for inputs, targets in test_dataloader:
            inputs = inputs.to(device)

            # Get predictions
            outputs = model(inputs)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(targets.numpy())

    f1 = f1_score(all_targets, all_preds, average='macro')
    f1_results[act_name] = f1

    print(f"{act_name: >10}: {f1:.4f}")
# Out:
# Calculating F1 Scores...
# ========================
#    MP_GELU: 0.0275
#      PGELU: 0.0405
#       ReLU: 0.0182
#       GELU: 0.0333
#  LeakyReLU: 0.0199

# %%
import numpy as np
import matplotlib.pyplot as plt

print("=" * 80)
print("GRADIENT L₂ NORMS BY EPOCH")
print("=" * 80)

for act_name, results in all_results.items():

    print(f"\n{'=' * 80}")
    print(f"ACTIVATION: {act_name}")
    print(f"{'=' * 80}")

    grad_norms = np.array(results["grad_norm"], dtype=float)

    # Print gradient norm for every epoch
    for epoch, grad_norm in enumerate(grad_norms, start=1):
        print(
            f"Epoch {epoch:3d}: "
            f"Gradient L₂ Norm = {grad_norm:.6f}"
        )

    # Statistics
    min_grad = np.min(grad_norms)
    max_grad = np.max(grad_norms)
    mean_grad = np.mean(grad_norms)
    std_grad = np.std(grad_norms, ddof=1)

    min_epoch = np.argmin(grad_norms) + 1
    max_epoch = np.argmax(grad_norms) + 1

    print(f"\n{'-' * 80}")
    print(f"SUMMARY — {act_name}")
    print(f"{'-' * 80}")

    print(f"Minimum Gradient L₂ Norm : {min_grad:.6f} "
          f"(Epoch {min_epoch})")

    print(f"Maximum Gradient L₂ Norm : {max_grad:.6f} "
          f"(Epoch {max_epoch})")

    print(f"Mean Gradient L₂ Norm    : {mean_grad:.6f}")

    print(f"Standard Deviation       : {std_grad:.6f}")

    print(f"Mean ± SD                : "
          f"{mean_grad:.6f} ± {std_grad:.6f}")
# Out:
# ================================================================================
# GRADIENT L₂ NORMS BY EPOCH
# ================================================================================
#
# ================================================================================
# ACTIVATION: PGELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 78.188235
# Epoch   2: Gradient L₂ Norm = 126299.738262
# Epoch   3: Gradient L₂ Norm = 519090.701740
# Epoch   4: Gradient L₂ Norm = 295758.128287
# Epoch   5: Gradient L₂ Norm = 195771.568543
# Epoch   6: Gradient L₂ Norm = 26290.191094
# Epoch   7: Gradient L₂ Norm = 608.426386
# Epoch   8: Gradient L₂ Norm = 595.160894
# Epoch   9: Gradient L₂ Norm = 616.735952
# Epoch  10: Gradient L₂ Norm = 636.492022
# Epoch  11: Gradient L₂ Norm = 647.748029
# Epoch  12: Gradient L₂ Norm = 654.622048
# Epoch  13: Gradient L₂ Norm = 672.755430
# Epoch  14: Gradient L₂ Norm = 640.580214
# Epoch  15: Gradient L₂ Norm = 573.703424
# Epoch  16: Gradient L₂ Norm = 492.089643
# Epoch  17: Gradient L₂ Norm = 403.610253
# Epoch  18: Gradient L₂ Norm = 331.026586
# Epoch  19: Gradient L₂ Norm = 267.587128
# Epoch  20: Gradient L₂ Norm = 232.909460
# Epoch  21: Gradient L₂ Norm = 199.661652
# Epoch  22: Gradient L₂ Norm = 173.611328
# Epoch  23: Gradient L₂ Norm = 165.355057
# Epoch  24: Gradient L₂ Norm = 163.508476
# Epoch  25: Gradient L₂ Norm = 155.478714
# Epoch  26: Gradient L₂ Norm = 153.676976
# Epoch  27: Gradient L₂ Norm = 143.248572
# Epoch  28: Gradient L₂ Norm = 137.874556
# Epoch  29: Gradient L₂ Norm = 120.760139
# Epoch  30: Gradient L₂ Norm = 109.176281
# Epoch  31: Gradient L₂ Norm = 104.000329
# Epoch  32: Gradient L₂ Norm = 87.599419
# Epoch  33: Gradient L₂ Norm = 72.908959
# Epoch  34: Gradient L₂ Norm = 54.593816
# Epoch  35: Gradient L₂ Norm = 41.758253
# Epoch  36: Gradient L₂ Norm = 30.175446
# Epoch  37: Gradient L₂ Norm = 21.558799
# Epoch  38: Gradient L₂ Norm = 14.629083
# Epoch  39: Gradient L₂ Norm = 11.365500
# Epoch  40: Gradient L₂ Norm = 13.953198
# Epoch  41: Gradient L₂ Norm = 9.586425
# Epoch  42: Gradient L₂ Norm = 7.441623
# Epoch  43: Gradient L₂ Norm = 5.867663
# Epoch  44: Gradient L₂ Norm = 5.809683
# Epoch  45: Gradient L₂ Norm = 4.391423
# Epoch  46: Gradient L₂ Norm = 5.347108
# Epoch  47: Gradient L₂ Norm = 5.518360
# Epoch  48: Gradient L₂ Norm = 2.995750
# Epoch  49: Gradient L₂ Norm = 2.394207
# Epoch  50: Gradient L₂ Norm = 2.110662
# Epoch  51: Gradient L₂ Norm = 1.915862
# Epoch  52: Gradient L₂ Norm = 3.819394
# Epoch  53: Gradient L₂ Norm = 1.847614
# Epoch  54: Gradient L₂ Norm = 9.977422
# Epoch  55: Gradient L₂ Norm = 1.504524
# Epoch  56: Gradient L₂ Norm = 0.927788
# Epoch  57: Gradient L₂ Norm = 3.385668
# Epoch  58: Gradient L₂ Norm = 6.322767
# Epoch  59: Gradient L₂ Norm = 1.400230
# Epoch  60: Gradient L₂ Norm = 0.190665
# Epoch  61: Gradient L₂ Norm = 0.181328
# Epoch  62: Gradient L₂ Norm = 0.175617
# Epoch  63: Gradient L₂ Norm = 0.168362
# Epoch  64: Gradient L₂ Norm = 0.165550
# Epoch  65: Gradient L₂ Norm = 0.180720
# Epoch  66: Gradient L₂ Norm = 0.156424
# Epoch  67: Gradient L₂ Norm = 0.149422
# Epoch  68: Gradient L₂ Norm = 0.141098
# Epoch  69: Gradient L₂ Norm = 0.137252
# Epoch  70: Gradient L₂ Norm = 0.130588
# Epoch  71: Gradient L₂ Norm = 0.122095
# Epoch  72: Gradient L₂ Norm = 0.120266
# Epoch  73: Gradient L₂ Norm = 0.113222
# Epoch  74: Gradient L₂ Norm = 81339521.785516
# Epoch  75: Gradient L₂ Norm = 11.067225
# Epoch  76: Gradient L₂ Norm = 2.480231
# Epoch  77: Gradient L₂ Norm = 2.343183
# Epoch  78: Gradient L₂ Norm = 2.207318
# Epoch  79: Gradient L₂ Norm = 2.232110
# Epoch  80: Gradient L₂ Norm = 2.217951
# Epoch  81: Gradient L₂ Norm = 2.277557
# Epoch  82: Gradient L₂ Norm = 2.297273
# Epoch  83: Gradient L₂ Norm = 2.400680
# Epoch  84: Gradient L₂ Norm = 2.326802
# Epoch  85: Gradient L₂ Norm = 2.287847
# Epoch  86: Gradient L₂ Norm = 2.323687
# Epoch  87: Gradient L₂ Norm = 2.264914
# Epoch  88: Gradient L₂ Norm = 2.337639
# Epoch  89: Gradient L₂ Norm = 2.417117
# Epoch  90: Gradient L₂ Norm = 2.400242
# Epoch  91: Gradient L₂ Norm = 2.288443
# Epoch  92: Gradient L₂ Norm = 2.395811
# Epoch  93: Gradient L₂ Norm = 2.384830
# Epoch  94: Gradient L₂ Norm = 2.335951
# Epoch  95: Gradient L₂ Norm = 2.367545
# Epoch  96: Gradient L₂ Norm = 2.384479
# Epoch  97: Gradient L₂ Norm = 2.478663
# Epoch  98: Gradient L₂ Norm = 2.411763
# Epoch  99: Gradient L₂ Norm = 2.495283
# Epoch 100: Gradient L₂ Norm = 2.357606
#
# --------------------------------------------------------------------------------
# SUMMARY — PGELU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 0.113222 (Epoch 73)
# Maximum Gradient L₂ Norm : 81339521.785516 (Epoch 74)
# Mean Gradient L₂ Norm    : 825123.131226
# Standard Deviation       : 8133014.703102
# Mean ± SD                : 825123.131226 ± 8133014.703102
#
# ================================================================================
# ACTIVATION: MP_GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 7.286637
# Epoch   2: Gradient L₂ Norm = 5.664749
# Epoch   3: Gradient L₂ Norm = 3.525379
# Epoch   4: Gradient L₂ Norm = 2.536055
# Epoch   5: Gradient L₂ Norm = 1.906754
# Epoch   6: Gradient L₂ Norm = 1.469705
# Epoch   7: Gradient L₂ Norm = 0.974953
# Epoch   8: Gradient L₂ Norm = 0.716655
# Epoch   9: Gradient L₂ Norm = 0.480635
# Epoch  10: Gradient L₂ Norm = 0.297468
# Epoch  11: Gradient L₂ Norm = 0.196246
# Epoch  12: Gradient L₂ Norm = 0.137121
# Epoch  13: Gradient L₂ Norm = 0.102978
# Epoch  14: Gradient L₂ Norm = 0.088414
# Epoch  15: Gradient L₂ Norm = 0.086281
# Epoch  16: Gradient L₂ Norm = 0.086849
# Epoch  17: Gradient L₂ Norm = 0.092423
# Epoch  18: Gradient L₂ Norm = 0.096933
# Epoch  19: Gradient L₂ Norm = 0.099481
# Epoch  20: Gradient L₂ Norm = 0.101063
# Epoch  21: Gradient L₂ Norm = 0.100796
# Epoch  22: Gradient L₂ Norm = 0.103895
# Epoch  23: Gradient L₂ Norm = 0.101440
# Epoch  24: Gradient L₂ Norm = 0.105983
# Epoch  25: Gradient L₂ Norm = 0.104795
# Epoch  26: Gradient L₂ Norm = 0.104786
# Epoch  27: Gradient L₂ Norm = 0.112047
# Epoch  28: Gradient L₂ Norm = 0.107629
# Epoch  29: Gradient L₂ Norm = 0.101188
# Epoch  30: Gradient L₂ Norm = 0.106475
# Epoch  31: Gradient L₂ Norm = 0.110010
# Epoch  32: Gradient L₂ Norm = 0.105566
# Epoch  33: Gradient L₂ Norm = 0.108232
# Epoch  34: Gradient L₂ Norm = 0.117129
# Epoch  35: Gradient L₂ Norm = 0.107716
# Epoch  36: Gradient L₂ Norm = 0.102161
# Epoch  37: Gradient L₂ Norm = 0.107625
# Epoch  38: Gradient L₂ Norm = 0.107353
# Epoch  39: Gradient L₂ Norm = 0.109468
# Epoch  40: Gradient L₂ Norm = 0.115448
# Epoch  41: Gradient L₂ Norm = 0.109058
# Epoch  42: Gradient L₂ Norm = 0.108648
# Epoch  43: Gradient L₂ Norm = 0.111803
# Epoch  44: Gradient L₂ Norm = 0.107017
# Epoch  45: Gradient L₂ Norm = 0.119209
# Epoch  46: Gradient L₂ Norm = 0.111991
# Epoch  47: Gradient L₂ Norm = 0.113764
# Epoch  48: Gradient L₂ Norm = 0.107492
# Epoch  49: Gradient L₂ Norm = 0.120626
# Epoch  50: Gradient L₂ Norm = 0.106768
# Epoch  51: Gradient L₂ Norm = 0.117229
# Epoch  52: Gradient L₂ Norm = 0.105499
# Epoch  53: Gradient L₂ Norm = 0.115693
# Epoch  54: Gradient L₂ Norm = 0.110812
# Epoch  55: Gradient L₂ Norm = 0.104739
# Epoch  56: Gradient L₂ Norm = 0.107133
# Epoch  57: Gradient L₂ Norm = 0.112819
# Epoch  58: Gradient L₂ Norm = 0.115984
# Epoch  59: Gradient L₂ Norm = 0.109408
# Epoch  60: Gradient L₂ Norm = 0.097002
# Epoch  61: Gradient L₂ Norm = 0.107745
# Epoch  62: Gradient L₂ Norm = 0.119199
# Epoch  63: Gradient L₂ Norm = 0.115659
# Epoch  64: Gradient L₂ Norm = 0.105201
# Epoch  65: Gradient L₂ Norm = 0.113999
# Epoch  66: Gradient L₂ Norm = 0.099867
# Epoch  67: Gradient L₂ Norm = 0.101444
# Epoch  68: Gradient L₂ Norm = 0.099123
# Epoch  69: Gradient L₂ Norm = 0.107522
# Epoch  70: Gradient L₂ Norm = 0.094469
# Epoch  71: Gradient L₂ Norm = 0.103239
# Epoch  72: Gradient L₂ Norm = 0.096493
# Epoch  73: Gradient L₂ Norm = 0.097825
# Epoch  74: Gradient L₂ Norm = 0.105361
# Epoch  75: Gradient L₂ Norm = 0.099227
# Epoch  76: Gradient L₂ Norm = 0.102603
# Epoch  77: Gradient L₂ Norm = 0.095375
# Epoch  78: Gradient L₂ Norm = 0.091903
# Epoch  79: Gradient L₂ Norm = 0.101405
# Epoch  80: Gradient L₂ Norm = 0.107567
# Epoch  81: Gradient L₂ Norm = 0.095274
# Epoch  82: Gradient L₂ Norm = 0.098132
# Epoch  83: Gradient L₂ Norm = 0.100211
# Epoch  84: Gradient L₂ Norm = 0.101696
# Epoch  85: Gradient L₂ Norm = 0.099074
# Epoch  86: Gradient L₂ Norm = 0.091085
# Epoch  87: Gradient L₂ Norm = 0.091715
# Epoch  88: Gradient L₂ Norm = 0.090315
# Epoch  89: Gradient L₂ Norm = 0.091380
# Epoch  90: Gradient L₂ Norm = 0.094842
# Epoch  91: Gradient L₂ Norm = 0.095485
# Epoch  92: Gradient L₂ Norm = 0.095272
# Epoch  93: Gradient L₂ Norm = 0.109706
# Epoch  94: Gradient L₂ Norm = 0.110381
# Epoch  95: Gradient L₂ Norm = 0.095541
# Epoch  96: Gradient L₂ Norm = 0.110747
# Epoch  97: Gradient L₂ Norm = 0.095884
# Epoch  98: Gradient L₂ Norm = 0.094063
# Epoch  99: Gradient L₂ Norm = 0.096657
# Epoch 100: Gradient L₂ Norm = 0.095762
#
# --------------------------------------------------------------------------------
# SUMMARY — MP_GELU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 0.086281 (Epoch 15)
# Maximum Gradient L₂ Norm : 7.286637 (Epoch 1)
# Mean Gradient L₂ Norm    : 0.343177
# Standard Deviation       : 1.009329
# Mean ± SD                : 0.343177 ± 1.009329
#
# ================================================================================
# ACTIVATION: ReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.077090
# Epoch   2: Gradient L₂ Norm = 0.074400
# Epoch   3: Gradient L₂ Norm = 0.073251
# Epoch   4: Gradient L₂ Norm = 0.072307
# Epoch   5: Gradient L₂ Norm = 0.073702
# Epoch   6: Gradient L₂ Norm = 0.073029
# Epoch   7: Gradient L₂ Norm = 0.074933
# Epoch   8: Gradient L₂ Norm = 0.072468
# Epoch   9: Gradient L₂ Norm = 0.072837
# Epoch  10: Gradient L₂ Norm = 0.071521
# Epoch  11: Gradient L₂ Norm = 0.072757
# Epoch  12: Gradient L₂ Norm = 0.072839
# Epoch  13: Gradient L₂ Norm = 0.073385
# Epoch  14: Gradient L₂ Norm = 0.072492
# Epoch  15: Gradient L₂ Norm = 0.074823
# Epoch  16: Gradient L₂ Norm = 0.074958
# Epoch  17: Gradient L₂ Norm = 0.073235
# Epoch  18: Gradient L₂ Norm = 0.074564
# Epoch  19: Gradient L₂ Norm = 0.072477
# Epoch  20: Gradient L₂ Norm = 0.073496
# Epoch  21: Gradient L₂ Norm = 0.073362
# Epoch  22: Gradient L₂ Norm = 0.072246
# Epoch  23: Gradient L₂ Norm = 0.074439
# Epoch  24: Gradient L₂ Norm = 0.075152
# Epoch  25: Gradient L₂ Norm = 0.073341
# Epoch  26: Gradient L₂ Norm = 0.072996
# Epoch  27: Gradient L₂ Norm = 0.072924
# Epoch  28: Gradient L₂ Norm = 0.073163
# Epoch  29: Gradient L₂ Norm = 0.073264
# Epoch  30: Gradient L₂ Norm = 0.074159
# Epoch  31: Gradient L₂ Norm = 0.074119
# Epoch  32: Gradient L₂ Norm = 0.073542
# Epoch  33: Gradient L₂ Norm = 0.073375
# Epoch  34: Gradient L₂ Norm = 0.074118
# Epoch  35: Gradient L₂ Norm = 0.072985
# Epoch  36: Gradient L₂ Norm = 0.074240
# Epoch  37: Gradient L₂ Norm = 0.073211
# Epoch  38: Gradient L₂ Norm = 0.074599
# Epoch  39: Gradient L₂ Norm = 0.072120
# Epoch  40: Gradient L₂ Norm = 0.072722
# Epoch  41: Gradient L₂ Norm = 0.072006
# Epoch  42: Gradient L₂ Norm = 0.072860
# Epoch  43: Gradient L₂ Norm = 0.073354
# Epoch  44: Gradient L₂ Norm = 0.072793
# Epoch  45: Gradient L₂ Norm = 0.073400
# Epoch  46: Gradient L₂ Norm = 0.073363
# Epoch  47: Gradient L₂ Norm = 0.072236
# Epoch  48: Gradient L₂ Norm = 0.073392
# Epoch  49: Gradient L₂ Norm = 0.073797
# Epoch  50: Gradient L₂ Norm = 0.073515
# Epoch  51: Gradient L₂ Norm = 0.073828
# Epoch  52: Gradient L₂ Norm = 0.071594
# Epoch  53: Gradient L₂ Norm = 0.072613
# Epoch  54: Gradient L₂ Norm = 0.074475
# Epoch  55: Gradient L₂ Norm = 0.073721
# Epoch  56: Gradient L₂ Norm = 0.073635
# Epoch  57: Gradient L₂ Norm = 0.072062
# Epoch  58: Gradient L₂ Norm = 0.073898
# Epoch  59: Gradient L₂ Norm = 0.073561
# Epoch  60: Gradient L₂ Norm = 0.073887
# Epoch  61: Gradient L₂ Norm = 0.073409
# Epoch  62: Gradient L₂ Norm = 0.073433
# Epoch  63: Gradient L₂ Norm = 0.072899
# Epoch  64: Gradient L₂ Norm = 0.073368
# Epoch  65: Gradient L₂ Norm = 0.073174
# Epoch  66: Gradient L₂ Norm = 0.072158
# Epoch  67: Gradient L₂ Norm = 0.073714
# Epoch  68: Gradient L₂ Norm = 0.074031
# Epoch  69: Gradient L₂ Norm = 0.073353
# Epoch  70: Gradient L₂ Norm = 0.073832
# Epoch  71: Gradient L₂ Norm = 0.074165
# Epoch  72: Gradient L₂ Norm = 0.072222
# Epoch  73: Gradient L₂ Norm = 0.074018
# Epoch  74: Gradient L₂ Norm = 0.073467
# Epoch  75: Gradient L₂ Norm = 0.073289
# Epoch  76: Gradient L₂ Norm = 0.073918
# Epoch  77: Gradient L₂ Norm = 0.073619
# Epoch  78: Gradient L₂ Norm = 0.073781
# Epoch  79: Gradient L₂ Norm = 0.073717
# Epoch  80: Gradient L₂ Norm = 0.073977
# Epoch  81: Gradient L₂ Norm = 0.075142
# Epoch  82: Gradient L₂ Norm = 0.074565
# Epoch  83: Gradient L₂ Norm = 0.073601
# Epoch  84: Gradient L₂ Norm = 0.072985
# Epoch  85: Gradient L₂ Norm = 0.072802
# Epoch  86: Gradient L₂ Norm = 0.073514
# Epoch  87: Gradient L₂ Norm = 0.073982
# Epoch  88: Gradient L₂ Norm = 0.072695
# Epoch  89: Gradient L₂ Norm = 0.074847
# Epoch  90: Gradient L₂ Norm = 0.072707
# Epoch  91: Gradient L₂ Norm = 0.073993
# Epoch  92: Gradient L₂ Norm = 0.074080
# Epoch  93: Gradient L₂ Norm = 0.074955
# Epoch  94: Gradient L₂ Norm = 0.073702
# Epoch  95: Gradient L₂ Norm = 0.073598
# Epoch  96: Gradient L₂ Norm = 0.073447
# Epoch  97: Gradient L₂ Norm = 0.073864
# Epoch  98: Gradient L₂ Norm = 0.073654
# Epoch  99: Gradient L₂ Norm = 0.073157
# Epoch 100: Gradient L₂ Norm = 0.073466
#
# --------------------------------------------------------------------------------
# SUMMARY — ReLU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 0.071521 (Epoch 10)
# Maximum Gradient L₂ Norm : 0.077090 (Epoch 1)
# Mean Gradient L₂ Norm    : 0.073489
# Standard Deviation       : 0.000855
# Mean ± SD                : 0.073489 ± 0.000855
#
# ================================================================================
# ACTIVATION: GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 25.150976
# Epoch   2: Gradient L₂ Norm = 21.504050
# Epoch   3: Gradient L₂ Norm = 14.147837
# Epoch   4: Gradient L₂ Norm = 9.990633
# Epoch   5: Gradient L₂ Norm = 6.379736
# Epoch   6: Gradient L₂ Norm = 3.900488
# Epoch   7: Gradient L₂ Norm = 2.726980
# Epoch   8: Gradient L₂ Norm = 1.524412
# Epoch   9: Gradient L₂ Norm = 0.904091
# Epoch  10: Gradient L₂ Norm = 0.595032
# Epoch  11: Gradient L₂ Norm = 0.264122
# Epoch  12: Gradient L₂ Norm = 0.104412
# Epoch  13: Gradient L₂ Norm = 0.102814
# Epoch  14: Gradient L₂ Norm = 0.101092
# Epoch  15: Gradient L₂ Norm = 0.102186
# Epoch  16: Gradient L₂ Norm = 0.101939
# Epoch  17: Gradient L₂ Norm = 0.103678
# Epoch  18: Gradient L₂ Norm = 0.100773
# Epoch  19: Gradient L₂ Norm = 0.101687
# Epoch  20: Gradient L₂ Norm = 0.102670
# Epoch  21: Gradient L₂ Norm = 0.100152
# Epoch  22: Gradient L₂ Norm = 0.102866
# Epoch  23: Gradient L₂ Norm = 0.100021
# Epoch  24: Gradient L₂ Norm = 0.099846
# Epoch  25: Gradient L₂ Norm = 0.098500
# Epoch  26: Gradient L₂ Norm = 0.098359
# Epoch  27: Gradient L₂ Norm = 0.099513
# Epoch  28: Gradient L₂ Norm = 0.097553
# Epoch  29: Gradient L₂ Norm = 0.097003
# Epoch  30: Gradient L₂ Norm = 0.097495
# Epoch  31: Gradient L₂ Norm = 0.097549
# Epoch  32: Gradient L₂ Norm = 0.099145
# Epoch  33: Gradient L₂ Norm = 7.551408
# Epoch  34: Gradient L₂ Norm = 0.096032
# Epoch  35: Gradient L₂ Norm = 0.094599
# Epoch  36: Gradient L₂ Norm = 0.089273
# Epoch  37: Gradient L₂ Norm = 0.084436
# Epoch  38: Gradient L₂ Norm = 0.085782
# Epoch  39: Gradient L₂ Norm = 0.084645
# Epoch  40: Gradient L₂ Norm = 0.082932
# Epoch  41: Gradient L₂ Norm = 0.082781
# Epoch  42: Gradient L₂ Norm = 0.083424
# Epoch  43: Gradient L₂ Norm = 0.082803
# Epoch  44: Gradient L₂ Norm = 0.083120
# Epoch  45: Gradient L₂ Norm = 0.081232
# Epoch  46: Gradient L₂ Norm = 0.082518
# Epoch  47: Gradient L₂ Norm = 0.082023
# Epoch  48: Gradient L₂ Norm = 0.083179
# Epoch  49: Gradient L₂ Norm = 0.083614
# Epoch  50: Gradient L₂ Norm = 0.082455
# Epoch  51: Gradient L₂ Norm = 0.080530
# Epoch  52: Gradient L₂ Norm = 0.083218
# Epoch  53: Gradient L₂ Norm = 0.082800
# Epoch  54: Gradient L₂ Norm = 0.082448
# Epoch  55: Gradient L₂ Norm = 0.083091
# Epoch  56: Gradient L₂ Norm = 0.081746
# Epoch  57: Gradient L₂ Norm = 0.082343
# Epoch  58: Gradient L₂ Norm = 0.083338
# Epoch  59: Gradient L₂ Norm = 0.082165
# Epoch  60: Gradient L₂ Norm = 0.081987
# Epoch  61: Gradient L₂ Norm = 0.081864
# Epoch  62: Gradient L₂ Norm = 0.080703
# Epoch  63: Gradient L₂ Norm = 0.080503
# Epoch  64: Gradient L₂ Norm = 0.081835
# Epoch  65: Gradient L₂ Norm = 0.083817
# Epoch  66: Gradient L₂ Norm = 0.082474
# Epoch  67: Gradient L₂ Norm = 0.080809
# Epoch  68: Gradient L₂ Norm = 0.081703
# Epoch  69: Gradient L₂ Norm = 0.081797
# Epoch  70: Gradient L₂ Norm = 0.080328
# Epoch  71: Gradient L₂ Norm = 0.082022
# Epoch  72: Gradient L₂ Norm = 0.079623
# Epoch  73: Gradient L₂ Norm = 0.080314
# Epoch  74: Gradient L₂ Norm = 0.080057
# Epoch  75: Gradient L₂ Norm = 69.831847
# Epoch  76: Gradient L₂ Norm = 0.079648
# Epoch  77: Gradient L₂ Norm = 0.080055
# Epoch  78: Gradient L₂ Norm = 0.080990
# Epoch  79: Gradient L₂ Norm = 0.079889
# Epoch  80: Gradient L₂ Norm = 0.081017
# Epoch  81: Gradient L₂ Norm = 0.080669
# Epoch  82: Gradient L₂ Norm = 0.080296
# Epoch  83: Gradient L₂ Norm = 0.078383
# Epoch  84: Gradient L₂ Norm = 0.080658
# Epoch  85: Gradient L₂ Norm = 0.078072
# Epoch  86: Gradient L₂ Norm = 0.080781
# Epoch  87: Gradient L₂ Norm = 0.079582
# Epoch  88: Gradient L₂ Norm = 0.079560
# Epoch  89: Gradient L₂ Norm = 0.078673
# Epoch  90: Gradient L₂ Norm = 0.080507
# Epoch  91: Gradient L₂ Norm = 0.078264
# Epoch  92: Gradient L₂ Norm = 0.079079
# Epoch  93: Gradient L₂ Norm = 0.080458
# Epoch  94: Gradient L₂ Norm = 0.078627
# Epoch  95: Gradient L₂ Norm = 0.080245
# Epoch  96: Gradient L₂ Norm = 0.078681
# Epoch  97: Gradient L₂ Norm = 0.079060
# Epoch  98: Gradient L₂ Norm = 0.079116
# Epoch  99: Gradient L₂ Norm = 0.079448
# Epoch 100: Gradient L₂ Norm = 0.080830
#
# --------------------------------------------------------------------------------
# SUMMARY — GELU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 0.078072 (Epoch 85)
# Maximum Gradient L₂ Norm : 69.831847 (Epoch 75)
# Mean Gradient L₂ Norm    : 1.719798
# Standard Deviation       : 7.849777
# Mean ± SD                : 1.719798 ± 7.849777
#
# ================================================================================
# ACTIVATION: LeakyReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 116280607055645.578125
# Epoch   2: Gradient L₂ Norm = 54668772065444.296875
# Epoch   3: Gradient L₂ Norm = 32131705772229.121094
# Epoch   4: Gradient L₂ Norm = 21453115951674.667969
# Epoch   5: Gradient L₂ Norm = 14757346411266.220703
# Epoch   6: Gradient L₂ Norm = 10800853961506.714844
# Epoch   7: Gradient L₂ Norm = 8117888083690.189453
# Epoch   8: Gradient L₂ Norm = 6318758781294.879883
# Epoch   9: Gradient L₂ Norm = 4922262571298.239258
# Epoch  10: Gradient L₂ Norm = 3850542397574.726562
# Epoch  11: Gradient L₂ Norm = 3041405726143.459961
# Epoch  12: Gradient L₂ Norm = 2412122684113.905273
# Epoch  13: Gradient L₂ Norm = 1918821763777.200684
# Epoch  14: Gradient L₂ Norm = 1510178424645.845215
# Epoch  15: Gradient L₂ Norm = 1220635656025.564941
# Epoch  16: Gradient L₂ Norm = 958691027352.761353
# Epoch  17: Gradient L₂ Norm = 766541877220.166138
# Epoch  18: Gradient L₂ Norm = 610382760838.343506
# Epoch  19: Gradient L₂ Norm = 493985698026.699158
# Epoch  20: Gradient L₂ Norm = 392026462840.342224
# Epoch  21: Gradient L₂ Norm = 308160076248.145142
# Epoch  22: Gradient L₂ Norm = 244849722648.169708
# Epoch  23: Gradient L₂ Norm = 193408986148.710205
# Epoch  24: Gradient L₂ Norm = 154330684514.566650
# Epoch  25: Gradient L₂ Norm = 120378896363.252777
# Epoch  26: Gradient L₂ Norm = 93006517779.418503
# Epoch  27: Gradient L₂ Norm = 72073851599.865326
# Epoch  28: Gradient L₂ Norm = 55312348537.306664
# Epoch  29: Gradient L₂ Norm = 42716606198.177414
# Epoch  30: Gradient L₂ Norm = 32021444585.747822
# Epoch  31: Gradient L₂ Norm = 24504268934.093067
# Epoch  32: Gradient L₂ Norm = 19196822278.721134
# Epoch  33: Gradient L₂ Norm = 15155809177.421154
# Epoch  34: Gradient L₂ Norm = 12066344714.216364
# Epoch  35: Gradient L₂ Norm = 9616252324.813303
# Epoch  36: Gradient L₂ Norm = 7253862672.009208
# Epoch  37: Gradient L₂ Norm = 5437483368.442251
# Epoch  38: Gradient L₂ Norm = 4217338061.895577
# Epoch  39: Gradient L₂ Norm = 3292087856.934741
# Epoch  40: Gradient L₂ Norm = 2506652855.191076
# Epoch  41: Gradient L₂ Norm = 2036886590.285081
# Epoch  42: Gradient L₂ Norm = 1570910047.028908
# Epoch  43: Gradient L₂ Norm = 1279995003.467721
# Epoch  44: Gradient L₂ Norm = 1066763737.272724
# Epoch  45: Gradient L₂ Norm = 872993661.581400
# Epoch  46: Gradient L₂ Norm = 748802859.954445
# Epoch  47: Gradient L₂ Norm = 632207122.049029
# Epoch  48: Gradient L₂ Norm = 530556982.576460
# Epoch  49: Gradient L₂ Norm = 442906700.467009
# Epoch  50: Gradient L₂ Norm = 356130357.266905
# Epoch  51: Gradient L₂ Norm = 282935002.779381
# Epoch  52: Gradient L₂ Norm = 220826138.880750
# Epoch  53: Gradient L₂ Norm = 166693619.480813
# Epoch  54: Gradient L₂ Norm = 131590977.479176
# Epoch  55: Gradient L₂ Norm = 107289651.707744
# Epoch  56: Gradient L₂ Norm = 85771425.786221
# Epoch  57: Gradient L₂ Norm = 69280147.465517
# Epoch  58: Gradient L₂ Norm = 54904685.662086
# Epoch  59: Gradient L₂ Norm = 44009918.990080
# Epoch  60: Gradient L₂ Norm = 36774324.268875
# Epoch  61: Gradient L₂ Norm = 24486918.654698
# Epoch  62: Gradient L₂ Norm = 19665531.575735
# Epoch  63: Gradient L₂ Norm = 15711364.782837
# Epoch  64: Gradient L₂ Norm = 12837413.711337
# Epoch  65: Gradient L₂ Norm = 10878640.441700
# Epoch  66: Gradient L₂ Norm = 8366143.388113
# Epoch  67: Gradient L₂ Norm = 7054703.154114
# Epoch  68: Gradient L₂ Norm = 5883162.790668
# Epoch  69: Gradient L₂ Norm = 4978481.821210
# Epoch  70: Gradient L₂ Norm = 4328502.655830
# Epoch  71: Gradient L₂ Norm = 3858452.627093
# Epoch  72: Gradient L₂ Norm = 3227168.921679
# Epoch  73: Gradient L₂ Norm = 2826805.549709
# Epoch  74: Gradient L₂ Norm = 1220694.063802
# Epoch  75: Gradient L₂ Norm = 502733.961752
# Epoch  76: Gradient L₂ Norm = 688283.398245
# Epoch  77: Gradient L₂ Norm = 176235.107824
# Epoch  78: Gradient L₂ Norm = 251071.958019
# Epoch  79: Gradient L₂ Norm = 217292.634787
# Epoch  80: Gradient L₂ Norm = 177481.667032
# Epoch  81: Gradient L₂ Norm = 134696.227017
# Epoch  82: Gradient L₂ Norm = 171318.429494
# Epoch  83: Gradient L₂ Norm = 102724.435024
# Epoch  84: Gradient L₂ Norm = 139027.277411
# Epoch  85: Gradient L₂ Norm = 80507.641872
# Epoch  86: Gradient L₂ Norm = 62257.709436
# Epoch  87: Gradient L₂ Norm = 147090.055235
# Epoch  88: Gradient L₂ Norm = 32506.257992
# Epoch  89: Gradient L₂ Norm = 56804.682297
# Epoch  90: Gradient L₂ Norm = 17987.156180
# Epoch  91: Gradient L₂ Norm = 18104.880778
# Epoch  92: Gradient L₂ Norm = 23426.506519
# Epoch  93: Gradient L₂ Norm = 21880.305716
# Epoch  94: Gradient L₂ Norm = 8814.112771
# Epoch  95: Gradient L₂ Norm = 13564.715956
# Epoch  96: Gradient L₂ Norm = 9674.962952
# Epoch  97: Gradient L₂ Norm = 48766.440740
# Epoch  98: Gradient L₂ Norm = 3522.987160
# Epoch  99: Gradient L₂ Norm = 4138.029307
# Epoch 100: Gradient L₂ Norm = 4111.622425
#
# --------------------------------------------------------------------------------
# SUMMARY — LeakyReLU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 3522.987160 (Epoch 98)
# Maximum Gradient L₂ Norm : 116280607055645.578125 (Epoch 1)
# Mean Gradient L₂ Norm    : 2880570178564.377930
# Standard Deviation       : 13362520401329.349609
# Mean ± SD                : 2880570178564.377930 ± 13362520401329.349609
