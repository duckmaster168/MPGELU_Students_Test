# %% [markdown]
# # Introduction
#
# <center>
# <h2>
# Computational Experiments with Modern Parametrized Gaussian Error Linear Unit (MPGELU)
# </h2>
# <b>A demonstration by: Jose Aries E. De Los Santos</b>
# </center>

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %% [markdown]
# # Import Libraries

# %%
import os
import sys
from pathlib import Path
from functools import partial

#PyTorch
import torch as torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import time
from torchinfo import summary

import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import random
from typing import Iterable, Callable


#sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

#Import torchvision
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor
from torchinfo import summary

#Import tqdm for a cool progress bar
from tqdm.auto import tqdm

# Measure time
from timeit import default_timer as timer

seed = 143
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)


print(f"PyTorch Version: {torch.__version__}")
print(f"Numpy Version: {np.__version__}")
print(f"Pandas Version: {pd.__version__}")
# print(f"Matplotlib Version: {matplotlib.__version__}")
print(f"SciPy Version: {scipy.__version__}")

# device = "cuda" if torch.cuda.is_available() else "cpu"

if torch.cuda.is_available():
    device = "cuda"
    print(f"Device: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = "mps"
    print(f"Device: {torch.backends.mps.is_available()}")
else:
    device = "cpu"
    print(f"Device: {device}")
# Out:
# PyTorch Version: 2.11.0+cu128
# Numpy Version: 2.1.3
# Pandas Version: 2.2.3
# SciPy Version: 1.16.3
# Device: NVIDIA A100-SXM4-40GB

# %% [markdown]
# # Dynamic Path Modification
#
# * It is a runtime technique used to explicitly tell Python where to look for modules or packages when you run an ``import`` statement.

# %% [markdown]
# ## Import Helper Functions

# %%
### Add the parent directory to the sys.path to import MyCNN and MPGELU
#%reload_ext autoreload
#%autoreload 2
mother_path = Path.cwd()
for folder in ["utility", "act_fns", "models"]:
    path = os.path.join(mother_path , folder)
    if path not in sys.path:
        sys.path.append(path)
from MPGELU import MPGELU
from PGELU import PGELU
from MyCNN import MyCNN
from DataTransforms import DataTransforms
from Trainer import Trainer
from LoadedModel import LoadedModel

# %% [markdown]
# # MP GELU
#
# * Modified Parametric Gaussian Error Linear Unit
# $$
# f(x) = \frac{x}{2} \left[ 1 + \text{erf}\left( \frac{\lambda x}{\sqrt{2}}\right)\right] = \frac{x}{2} + \frac{x}{\sqrt{\pi}}\int_{0}^{\lambda x / \sqrt{2}} e^{-u^{2}}du
# $$
# where $\lambda  = (1 + \ln(1 + e^{s})) \geq 1$   $\forall s \in \mathbb{R}$
#
# * Check MPGELU.py file for the implementation of the MPGELU activation function

# %%
x_np = np.linspace(-4.0, 4.0, 400)
x_tensor = torch.tensor(x_np, dtype=torch.float32)
# s_values = np.arange(-2.0, 2.0, 0.1)
s_values = [-100, 0.0, 100, ]
plt.figure(figsize=(9, 6))

for s_val in s_values:
    activation1 = MPGELU(s_param=s_val)
    activation2 = MPGELU(s_param=s_val, use_softplus=False)
    with torch.inference_mode():
        y_tensor1 = activation1(x_tensor)
        y_tensor2 = activation2(x_tensor)

    lam_val = (1.0 + F.softplus(torch.tensor(s_val, dtype=torch.float32))).item()
    plt.plot(x_np, y_tensor1.numpy(), label=f"s = {s_val}", linewidth=2.5)
    # plt.plot(x_np, y_tensor2.numpy(), label=f"s = {s_val}", linewidth=2)

# 4. Format the plot
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.axvline(0, color='black', linewidth=0.8, linestyle='--')
plt.title("Modified Parametric GELU (MP-GELU) Activation Function", fontsize=15)
xticks = np.arange(-4, 5, 0.8)
plt.xticks(xticks,fontsize=12)
plt.xlabel("Input ($x$)", fontsize=12)
yticks = np.arange(-2, 5, 0.8)
plt.yticks(yticks,fontsize=12)
plt.ylabel("Output ($f(x)$)", fontsize=12)
plt.grid(True, linestyle=':', alpha=0.9)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # Data Processing

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Create the target directory and extract the file from your ModelDatasets folder
# !mkdir -p ./data
# !tar -xzvf "/content/drive/MyDrive/ModelDatasets/cifar-10-python.tar.gz" -C "./data/"

# 3. Your original transformer setup (unaffected)
transformer = DataTransforms(dataset='cifar10', use_augmentation=True, use_stats=False)
train_transform = transformer.get_train_transform()
test_transform = transformer.get_test_transform()

# 4. UPDATED PyTorch dataset loading
# Change download to False so it instantly reads your local extracted files
train_data = datasets.CIFAR10(root='./data', train=True, download=False, transform=train_transform)
test_data = datasets.CIFAR10(root='./data', train=False, download=False, transform=test_transform)

# 5. Your original DataLoaders (unaffected)
train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True, num_workers=10, pin_memory=True, persistent_workers=True)
test_dataloader = DataLoader(test_data, batch_size=128, shuffle=False, num_workers=10, pin_memory=True, persistent_workers=True)
# Out:
# Mounted at /content/drive
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1

# %% [markdown]
# ## Visualize Sample Images

# %%
fig = plt.figure(figsize=(8, 8))
rows, columns = 4, 4

for i in range(1, rows * columns + 1):
    idx = torch.randint(0, len(train_data), size=[1]).item()  # Random index
    img, label = train_data[idx][0], train_data[idx][1]
    fig.add_subplot(rows, columns, i)

    # Display image without converting to grayscale
    plt.imshow(img.permute(1, 2, 0))  # Change channels to last dimension (H, W, C)
    plt.title(train_data.classes[label])
    plt.grid(False)
    plt.axis(False)

plt.axis(False)
# plt.savefig("cifar10_dataset.jpg",dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ## Set its Parameters

# %%
chosen_model_params = [32, 32, 'MaxPool', 64, 64, 'MaxPool', 128, 128, 128, 'MaxPool']

model = MyCNN(input_shape=3,
                  output_shape=10,
                  activation = MPGELU,
                  params = chosen_model_params).to(device)

print(summary(model=model,
        input = torch.randn(size=(3, 32, 32)).unsqueeze(dim=0)))

total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MyCNN                                    --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       896
# │    └─MPGELU: 2-2                       1
# │    └─Conv2d: 2-3                       9,248
# │    └─MPGELU: 2-4                       1
# │    └─MaxPool2d: 2-5                    --
# │    └─Conv2d: 2-6                       18,496
# │    └─MPGELU: 2-7                       1
# │    └─Conv2d: 2-8                       36,928
# │    └─MPGELU: 2-9                       1
# │    └─MaxPool2d: 2-10                   --
# │    └─Conv2d: 2-11                      73,856
# │    └─MPGELU: 2-12                      1
# │    └─Conv2d: 2-13                      147,584
# │    └─MPGELU: 2-14                      1
# │    └─Conv2d: 2-15                      147,584
# │    └─MPGELU: 2-16                      1
# │    └─MaxPool2d: 2-17                   --
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-18                      524,544
# │    └─MPGELU: 2-19                      1
# │    └─Linear: 2-20                      65,792
# │    └─MPGELU: 2-21                      1
# │    └─Linear: 2-22                      2,570
# =================================================================
# Total params: 1,027,507
# Trainable params: 1,027,507
# Non-trainable params: 0
# =================================================================
# Total number of parameters: 1027507

# %% [markdown]
# ## Test Dummy Input

# %%
dummy_input = torch.randn(1, 3, 32, 32).to(device)
model(dummy_input)
# Out:
# tensor([[-0.0472,  0.0603, -0.0531, -0.0600, -0.0494,  0.0707,  0.0160, -0.0226,
#           0.0072, -0.0552]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Training and Execution

# %% [markdown]
# ## Setup loss, accuracy, and paramaters

# %% [markdown]
# ## Mathematical Definition of Categorical Cross-Entropy
#
# Categorical Cross-Entropy (CCE) is the standard loss function for multi-class classification. It measures the difference between two probability distributions: the actual ground-truth labels (usually one-hot encoded) and the model's predicted probabilities.
#
# For a single sample, the loss is defined as:
#
# $$f(y_i, \hat{y}_i) = -\sum_{i=1}^{C} y_i \log(\hat{y}_i)$$
#
# When calculating the average loss over a batch of $N$ samples, the formula expands to:
#
# $$f(y_i, \hat{y}_i) = -\frac{1}{N} \sum_{j=1}^{N} \sum_{i=1}^{C} y_{j,i} \log(\hat{y}_{j,i})$$
#
# **Where:**
# * $C$ = Total number of classes
# * $N$ = Total number of samples in the batch
# * $y_i$ (or $y_{j,i}$) = The true label (1 if the sample belongs to class $i$, and 0 for all other classes)
# * $\hat{y}_i$ (or $\hat{y}_{j,i}$) = The model's predicted probability that the sample belongs to class $i$ (typically the output of a Softmax activation function)
#
# > **Note:** Because the true labels $y_i$ are zero for all incorrect classes in one-hot encoding, the formula effectively simplifies to taking the negative log of the predicted probability for the **true** class.

# %%
#Setup Loss Functions, Accuracy function
loss_fn = torch.nn.CrossEntropyLoss(label_smoothing=0.1)

#Define Accuracy Metric
def calculate_accuracy(y_true, y_pred):
  correct = torch.eq(y_true, y_pred).sum().item()
  accuracy = (correct / len(y_pred)) * 100
  return accuracy

##Training Parameters

num_of_epochs = 100
num_loss_steps = 5

# %% [markdown]
# ### Gradient Norm
#
# **Mathematical Definition**: The $\ell^2$ Norm of the Gradient. In real analysis, the small $\ell^2$ norm (standard Euclidean norm) measures the magnitude of a finite-dimensional vector in $\mathbb{R}^n$.Let $\mathbf{w} \in \mathbb{R}^n$ represent the flattened continuous vector of all trainable parameters within the neural network architecture. The gradient of the objective loss function $\mathcal{L}$ with respect to these parameters is a discrete vector composed of partial derivatives:
# $$\nabla_{\mathbf{w}} \mathcal{L} = \left[ \frac{\partial \mathcal{L}}{\partial w_1}, \frac{\partial \mathcal{L}}{\partial w_2}, \dots, \frac{\partial \mathcal{L}}{\partial w_n} \right]^T$$
#
# The $\ell^2$ norm of this gradient vector, denoted as $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_{\ell^2}$ or simply $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2$, is defined as the square root of the sum of its squared coordinate components:$$\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2 = \sqrt{ \sum_{i=1}^{n} \left( \frac{\partial \mathcal{L}}{\partial w_i} \right)^2 }$$In the context of empirical risk minimization, bounding this sequence of finite sums guarantees that gradient updates remain stable and prevents the parameter vector from diverging during optimization.
#
#
# **IMPORTANT NOTE**
#
# In real and functional analysis, the capital $L^p$ spaces denote spaces of measurable functions, where the norm is evaluated via continuous integration, such as $\Vert{}f\Vert{}_{L^2} = \left( \int \vert{}f(x)\vert{}^2 dx \right)^{1/2}$. The lowercase $\ell^p$ spaces apply to discrete sequences or finite-dimensional coordinate vectors, where the norm is evaluated via discrete summation. Since the gradient of a neural network's loss with respect to its parameters, $\nabla_{\mathbf{w}} \mathcal{L}$, is a finite-dimensional vector of discrete scalar derivatives rather than a continuous mathematical function, finding its magnitude requires summing the squares of its individual components. You are completely correct: we use the small $\ell^2$ norm precisely because we are operating on discrete Euclidean vectors, not continuous functions.

# %% [markdown]
# ## Execution and Saving

# %%
torch.manual_seed(143)
activation_dict = {
    "PGELU": PGELU,
    "MP_GELU": partial(MPGELU, s_param=0.0, use_softplus=True),
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}

all_results = {}

for act_name, act_fn in activation_dict.items():
    print(f"\n=======================================================")
    print(f"       TRAINING WITH ACTIVATION: {act_name}")
    print(f"=======================================================")

    model = MyCNN(input_shape=3, output_shape=10, activation=act_fn, params=chosen_model_params).to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)

    trainer = Trainer(model=model, loss_fn=loss_fn, optimizer=optimizer,
                      calculate_accuracy=calculate_accuracy, device=device, loss_steps=num_loss_steps)

    results = {
        "train_loss": [],
        "train_accu": [],
        "test_loss": [],
        "test_accu": [],
        "activation_params": {},
        "grad_norm": []  # Initialize an empty list to store gradient norms
    }

    start_time = time.perf_counter()

    for epoch in tqdm(range(num_of_epochs), desc=f"Training {act_name}"):
        if epoch % num_loss_steps == 0:
            print(f"Epoch: {epoch} \n =====================================================================")
        train_loss, train_accu, norm = trainer.train(data_loader=train_dataloader, epoch=epoch)
        test_loss, test_accu = trainer.test(data_loader=test_dataloader, epoch=epoch)

        results["train_loss"].append(train_loss)
        results["train_accu"].append(train_accu)
        results["test_loss"].append(test_loss)
        results["test_accu"].append(test_accu)
        results["grad_norm"].append(norm)

        # Track dynamic activation parameters
        for name, param in model.named_parameters():
            if 'alpha_param' in name or 'beta_param' in name or 's_param' in name:
                if name not in results.setdefault("activation_params", {}):
                    results["activation_params"][name] = []
                results["activation_params"][name].append(param.item())

    total_time = time.perf_counter() - start_time
    results["total_runtime"] = total_time
    all_results[act_name] = results

    # Save Model Checkpoint
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'results': results,
        'total_runtime': total_time,
        'activation_name': act_name
    }

    save_dir = "model_trained_params_new"
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir, f"chkpt5_{act_name}.pth")

    torch.save(checkpoint, save_path)
    print(f"Saved model state to {save_path}")
# Out:
# =======================================================
#        TRAINING WITH ACTIVATION: PGELU
# =======================================================
# Training PGELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 1.99493 | Training Accuracy: 28.69206%
# Test Loss 1.75947 | Test Accuracy 42.13805%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.30700 | Training Accuracy: 64.14962%
# Test Loss 1.10755 | Test Accuracy 73.82318%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.18068 | Training Accuracy: 70.10150%
# Test Loss 1.02451 | Test Accuracy 78.04589%
# Epoch: 15
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.86373%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 20
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.76742%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 25
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.87532%
# Test Loss 2.30261 | Test Accuracy 9.88924%
# Epoch: 30
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.87492%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 35
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.91208%
# Test Loss 2.30263 | Test Accuracy 9.88924%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.75424%
# Test Loss 2.30258 | Test Accuracy 10.02769%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.85254%
# Test Loss 2.30259 | Test Accuracy 9.88924%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.92447%
# Test Loss 2.30260 | Test Accuracy 10.02769%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.85054%
# Test Loss 2.30260 | Test Accuracy 9.88924%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.87372%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.67991%
# Test Loss 2.30260 | Test Accuracy 9.88924%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.87652%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.76782%
# Test Loss 2.30260 | Test Accuracy 9.88924%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.30270 | Training Accuracy: 9.77062%
# Test Loss 2.30260 | Test Accuracy 9.88924%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.74425%
# Test Loss 2.30261 | Test Accuracy 9.88924%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.81777%
# Test Loss 2.30260 | Test Accuracy 9.88924%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 10.00759%
# Test Loss 2.30258 | Test Accuracy 10.09691%
# Saved model state to model_trained_params_new/chkpt5_PGELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: MP_GELU
# =======================================================
# Training MP_GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.07794 | Training Accuracy: 24.45133%
# Test Loss 1.82644 | Test Accuracy 36.88687%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.32383 | Training Accuracy: 62.86965%
# Test Loss 1.13162 | Test Accuracy 72.26068%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.12703 | Training Accuracy: 72.17311%
# Test Loss 0.97107 | Test Accuracy 79.67761%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.04600 | Training Accuracy: 75.82481%
# Test Loss 0.93021 | Test Accuracy 81.96203%
# Epoch: 20
#  =====================================================================
# Training Loss: 0.99095 | Training Accuracy: 78.25128%
# Test Loss 0.91986 | Test Accuracy 82.26859%
# Epoch: 25
#  =====================================================================
# Training Loss: 0.95515 | Training Accuracy: 80.06594%
# Test Loss 0.86019 | Test Accuracy 84.83979%
# Epoch: 30
#  =====================================================================
# Training Loss: 0.93346 | Training Accuracy: 81.21403%
# Test Loss 0.86644 | Test Accuracy 84.37500%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.91132 | Training Accuracy: 82.00767%
# Test Loss 0.85566 | Test Accuracy 84.94858%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.89597 | Training Accuracy: 82.82129%
# Test Loss 0.85331 | Test Accuracy 84.86946%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.88724 | Training Accuracy: 83.25847%
# Test Loss 0.84255 | Test Accuracy 85.75949%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.86964 | Training Accuracy: 83.89066%
# Test Loss 0.82758 | Test Accuracy 86.39241%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.86376 | Training Accuracy: 84.18438%
# Test Loss 0.82876 | Test Accuracy 86.45174%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.85342 | Training Accuracy: 84.82137%
# Test Loss 0.81263 | Test Accuracy 87.01543%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.84387 | Training Accuracy: 85.19981%
# Test Loss 0.82626 | Test Accuracy 86.48141%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.83929 | Training Accuracy: 85.45556%
# Test Loss 0.82201 | Test Accuracy 86.80775%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.82786 | Training Accuracy: 86.01902%
# Test Loss 0.81253 | Test Accuracy 87.18354%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.81798 | Training Accuracy: 86.33152%
# Test Loss 0.80374 | Test Accuracy 87.48022%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.81750 | Training Accuracy: 86.34231%
# Test Loss 0.81451 | Test Accuracy 86.86709%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.80526 | Training Accuracy: 86.97051%
# Test Loss 0.80176 | Test Accuracy 87.38133%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.80971 | Training Accuracy: 86.63803%
# Test Loss 0.80960 | Test Accuracy 87.45055%
# Saved model state to model_trained_params_new/chkpt5_MP_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: ReLU
# =======================================================
# Training ReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.11352 | Training Accuracy: 22.35654%
# Test Loss 1.88370 | Test Accuracy 33.32674%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.58922 | Training Accuracy: 49.59039%
# Test Loss 1.43569 | Test Accuracy 56.86313%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.37885 | Training Accuracy: 60.08552%
# Test Loss 1.22837 | Test Accuracy 67.22706%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.26713 | Training Accuracy: 65.46236%
# Test Loss 1.13282 | Test Accuracy 71.98378%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.19894 | Training Accuracy: 68.64610%
# Test Loss 1.08762 | Test Accuracy 74.04074%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.15767 | Training Accuracy: 70.63020%
# Test Loss 1.07969 | Test Accuracy 74.84177%
# Epoch: 30
#  =====================================================================
# Training Loss: 1.11781 | Training Accuracy: 72.21427%
# Test Loss 0.99279 | Test Accuracy 78.87658%
# Epoch: 35
#  =====================================================================
# Training Loss: 1.09757 | Training Accuracy: 73.42871%
# Test Loss 1.00231 | Test Accuracy 77.97666%
# Epoch: 40
#  =====================================================================
# Training Loss: 1.07577 | Training Accuracy: 74.47650%
# Test Loss 0.99294 | Test Accuracy 78.52057%
# Epoch: 45
#  =====================================================================
# Training Loss: 1.05863 | Training Accuracy: 75.37484%
# Test Loss 0.97061 | Test Accuracy 79.84573%
# Epoch: 50
#  =====================================================================
# Training Loss: 1.04287 | Training Accuracy: 75.90153%
# Test Loss 0.97176 | Test Accuracy 79.71717%
# Epoch: 55
#  =====================================================================
# Training Loss: 1.03310 | Training Accuracy: 76.23761%
# Test Loss 0.95711 | Test Accuracy 80.54786%
# Epoch: 60
#  =====================================================================
# Training Loss: 1.02360 | Training Accuracy: 76.78469%
# Test Loss 0.94388 | Test Accuracy 81.01266%
# Epoch: 65
#  =====================================================================
# Training Loss: 1.00425 | Training Accuracy: 77.68942%
# Test Loss 0.96410 | Test Accuracy 80.48853%
# Epoch: 70
#  =====================================================================
# Training Loss: 1.00442 | Training Accuracy: 77.84207%
# Test Loss 0.92396 | Test Accuracy 82.07081%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.99273 | Training Accuracy: 78.42072%
# Test Loss 0.91705 | Test Accuracy 82.19937%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.98436 | Training Accuracy: 78.60214%
# Test Loss 0.90896 | Test Accuracy 82.98062%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.98180 | Training Accuracy: 78.88067%
# Test Loss 0.91821 | Test Accuracy 82.47627%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.97635 | Training Accuracy: 79.04652%
# Test Loss 0.90772 | Test Accuracy 82.49604%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.97348 | Training Accuracy: 79.17719%
# Test Loss 0.91731 | Test Accuracy 82.55538%
# Saved model state to model_trained_params_new/chkpt5_ReLU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: GELU
# =======================================================
# Training GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.10045 | Training Accuracy: 22.72698%
# Test Loss 1.80111 | Test Accuracy 39.51741%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.36682 | Training Accuracy: 61.03541%
# Test Loss 1.16960 | Test Accuracy 71.23220%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.17188 | Training Accuracy: 70.25176%
# Test Loss 1.01507 | Test Accuracy 78.61946%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.08835 | Training Accuracy: 74.29028%
# Test Loss 0.94805 | Test Accuracy 81.05222%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.03957 | Training Accuracy: 76.47179%
# Test Loss 0.93311 | Test Accuracy 81.85324%
# Epoch: 25
#  =====================================================================
# Training Loss: 0.99781 | Training Accuracy: 78.47626%
# Test Loss 0.91558 | Test Accuracy 82.83228%
# Epoch: 30
#  =====================================================================
# Training Loss: 0.97465 | Training Accuracy: 79.48569%
# Test Loss 0.90353 | Test Accuracy 83.32674%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.95014 | Training Accuracy: 80.46116%
# Test Loss 0.88750 | Test Accuracy 84.13766%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.92906 | Training Accuracy: 81.36669%
# Test Loss 0.86679 | Test Accuracy 84.86946%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.90940 | Training Accuracy: 82.53716%
# Test Loss 0.86384 | Test Accuracy 84.73101%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.89831 | Training Accuracy: 82.83128%
# Test Loss 0.86651 | Test Accuracy 85.01780%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.89213 | Training Accuracy: 83.09023%
# Test Loss 0.85567 | Test Accuracy 85.23536%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.87911 | Training Accuracy: 83.68766%
# Test Loss 0.84869 | Test Accuracy 85.82872%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.86660 | Training Accuracy: 84.26910%
# Test Loss 0.83017 | Test Accuracy 86.54074%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.86138 | Training Accuracy: 84.69629%
# Test Loss 0.84649 | Test Accuracy 85.94739%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.85291 | Training Accuracy: 84.88411%
# Test Loss 0.83842 | Test Accuracy 86.07595%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.84172 | Training Accuracy: 85.41520%
# Test Loss 0.81948 | Test Accuracy 86.99565%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.83992 | Training Accuracy: 85.61101%
# Test Loss 0.82171 | Test Accuracy 86.79786%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.83428 | Training Accuracy: 85.93910%
# Test Loss 0.83549 | Test Accuracy 86.44185%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.82700 | Training Accuracy: 86.10973%
# Test Loss 0.80724 | Test Accuracy 87.43078%
# Saved model state to model_trained_params_new/chkpt5_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: LeakyReLU
# =======================================================
# Training LeakyReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.13680 | Training Accuracy: 20.93750%
# Test Loss 1.86777 | Test Accuracy 34.41456%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.46791 | Training Accuracy: 55.62740%
# Test Loss 1.29558 | Test Accuracy 64.73497%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.24987 | Training Accuracy: 66.25759%
# Test Loss 1.11981 | Test Accuracy 72.02334%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.14072 | Training Accuracy: 71.40425%
# Test Loss 1.00869 | Test Accuracy 78.39201%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.07550 | Training Accuracy: 74.28469%
# Test Loss 0.96973 | Test Accuracy 79.80617%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.04097 | Training Accuracy: 76.00144%
# Test Loss 0.94340 | Test Accuracy 80.77532%
# Epoch: 30
#  =====================================================================
# Training Loss: 1.00532 | Training Accuracy: 77.74816%
# Test Loss 0.93282 | Test Accuracy 81.67524%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.98507 | Training Accuracy: 78.61253%
# Test Loss 0.93010 | Test Accuracy 82.12025%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.96352 | Training Accuracy: 79.74425%
# Test Loss 0.88806 | Test Accuracy 83.58386%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.94954 | Training Accuracy: 80.47434%
# Test Loss 0.89489 | Test Accuracy 83.25752%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.93727 | Training Accuracy: 81.05059%
# Test Loss 0.88907 | Test Accuracy 83.89043%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.91980 | Training Accuracy: 81.82585%
# Test Loss 0.88125 | Test Accuracy 84.22666%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.90720 | Training Accuracy: 82.20029%
# Test Loss 0.88941 | Test Accuracy 83.92998%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.90214 | Training Accuracy: 82.63187%
# Test Loss 0.87582 | Test Accuracy 84.21677%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.89105 | Training Accuracy: 83.11901%
# Test Loss 0.85800 | Test Accuracy 85.38370%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.87850 | Training Accuracy: 83.65609%
# Test Loss 0.85533 | Test Accuracy 85.21559%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.87002 | Training Accuracy: 84.17959%
# Test Loss 0.87560 | Test Accuracy 84.82991%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.86323 | Training Accuracy: 84.42535%
# Test Loss 0.86257 | Test Accuracy 85.02769%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.86037 | Training Accuracy: 84.53844%
# Test Loss 0.86765 | Test Accuracy 84.96835%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.85172 | Training Accuracy: 84.95404%
# Test Loss 0.85765 | Test Accuracy 85.48259%
# Saved model state to model_trained_params_new/chkpt5_LeakyReLU.pth

# %% [markdown]
# # Loading the trained model params

# %%
activation_dict = {
    "MP_GELU": MPGELU,
    "PGELU": PGELU,
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}

# activation_dict = {
#     "PGELU": PGELU,
# }

# Initialize LoadedModel with the correct initial_fileName and checkpoint_dir
loader = LoadedModel(
    activation_dict=activation_dict,
    model_params=chosen_model_params,
    initial_fileName="chkpt5",
    checkpoint_dir="model_trained_params_new",
    device=device
)

# Run it
my_models = loader.load_checkpoints()
# Out:
# =======================================================
#        EVALUATING ACTIVATION: MP_GELU
# =======================================================
# Loaded trained model for MP_GELU from model_trained_params_new/chkpt5_MP_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: PGELU
# =======================================================
# Loaded trained model for PGELU from model_trained_params_new/chkpt5_PGELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: ReLU
# =======================================================
# Loaded trained model for ReLU from model_trained_params_new/chkpt5_ReLU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: GELU
# =======================================================
# Loaded trained model for GELU from model_trained_params_new/chkpt5_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: LeakyReLU
# =======================================================
# Loaded trained model for LeakyReLU from model_trained_params_new/chkpt5_LeakyReLU.pth

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Plotting

# %%
to_plot = {
    "MP_GELU":   {"results": my_models["MP_GELU"]["results"],   "linewidth": 3.0, "color": "#000000"}, # Jet Black
    "PGELU":     {"results": my_models["PGELU"]["results"],     "linewidth": 2.0, "color": "#E62937"}, # Strong Red
    "ReLU":      {"results": my_models["ReLU"]["results"],      "linewidth": 2.0, "color": "#009E73"}, # Teal
    "GELU":      {"results": my_models["GELU"]["results"],      "linewidth": 2.0, "color": "#4363D8"}, # Royal Blue
    "LeakyReLU": {"results": my_models["LeakyReLU"]["results"], "linewidth": 2.0, "color": "#F58231"}  # Bright Orange
}

# %% [markdown]
# ### Evolution of Learnable Parameters

# %% [markdown]
# #### $\alpha$ and $\beta$ of PGELU

# %%
alpha = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.alpha_param"]
beta = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.beta_param"]

fig, ax = plt.subplots(1, 2, figsize=(10, 6))

# Alpha Plot
# \n splits the label into two lines
ax[0].plot(alpha, label="Alpha\nParameter", color="#E62937", linewidth=2.5)
ax[0].grid(True, linestyle=':', alpha=0.9)
ax[0].tick_params(axis='x', labelsize=13)
ax[0].legend(loc="center left", bbox_to_anchor=(0.02, 0.5), fontsize=15)

# Beta Plot
# \n splits the label into two lines
ax[1].plot(beta, label="Beta\nParameter", color="#009E73", linewidth=2.5)
ax[1].grid(True, linestyle=':', alpha=0.9)
ax[1].tick_params(axis='x', labelsize=13)
ax[1].legend(loc="center left", bbox_to_anchor=(0.02, 0.5), fontsize=15)

fig.supxlabel("Epochs", fontsize=15)
fig.supylabel("Parameter Value", fontsize=15)
fig.suptitle("Dynamic Activation Parameters Evolution for PGELU", fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### $\lambda$ of MPGELU

# %%
# ============================================================
# MP-GELU LEARNED LAMBDA EVOLUTION
# ============================================================

params_dict = my_models["MP_GELU"]["results"]["activation_params"]

s_vals = params_dict["conv_layers.1.s_param"]

s_values = torch.tensor(
    s_vals,
    dtype=torch.float32,
    device=device
)

# Same formulation used in MPGELU
lam = 1.0 + F.softplus(s_values)

plt.figure(figsize=(11, 7))

plt.plot(
    lam.detach().cpu().numpy(),
    linewidth=2.5,
    color="#000055",
    label=r"Learned $\lambda$"
)

plt.xlabel("Epoch", fontsize=15)
plt.ylabel(r"Learned $\lambda$", fontsize=15)
plt.title(
    r"Evolution of Learned $\lambda$ in MP-GELU During Training",
    fontsize=16
)

# 0–100 axis
plt.xlim(0, 100)
plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

plt.grid(True, linestyle=":", alpha=0.9)
plt.legend(fontsize=14)

plt.tight_layout()
plt.show()

# %%
params_dict = my_models["MP_GELU"]["results"]["activation_params"]
s_vals = params_dict['conv_layers.1.s_param']
s_values = torch.tensor(s_vals, device=device, dtype=torch.float32)
lam = 1.0 + torch.log(1.0 + torch.exp(s_values))

plt.figure(figsize=(9, 6))
plt.plot(lam.detach().cpu().numpy(), linestyle='-', color='#000055')
plt.xlabel("Epoch", fontsize=13)
plt.ylabel(r"Learned $\lambda$", fontsize=13)
plt.title(r"Evolution of $\lambda$ of MPGELU During Training")
plt.grid(True, linestyle=':', alpha=0.9)
plt.yticks(np.arange(1.6, 3.2, 0.2), fontsize=13)

# --- CHANGED FOR 100 EPOCHS ---
plt.xticks(np.arange(0, 105, 10), fontsize=13) # Ticks every 10 epochs
plt.xlim(-2, 102)                             # Bounds slightly padded past 100
# ------------------------------

plt.tight_layout()
# plt.savefig("learned_lambda_evolution.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Train Loss Curves

# %%
# ============================================================
# TRAINING LOSS COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["train_loss"], **arguments)

plt.legend(loc="upper right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

# Keep automatic y-axis
# plt.ylim(0.75, 2.4)

# 0–100
plt.xlim(0, 100)

plt.title(
    "Training Loss Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("train_loss_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["train_loss"], **arguments)

# --- CHANGED LEGEND POSITION ---
plt.legend(loc="lower left", fontsize=14)
# -------------------------------

plt.grid(True,linestyle='--', alpha=0.6)

# --- 100 EPOCHS TIMELINE ---
plt.xticks(np.arange(0, 105, 10), fontsize=12)
plt.xlim(-2, 102)

# --- CHANGED Y-AXIS SPECIFICATIONS ---
plt.yticks(np.arange(1.6, 3.4, 0.2), fontsize=12) # Explicitly labels every 0.2 units (1.6, 1.8... 3.2)
plt.ylim(1.6, 3.2)                                # Clips the view window strictly from 1.6 to 3.2
# --------------------------------------

plt.title("Training Loss Comparison Across Activation Functions", fontsize=16)
# plt.savefig("train_loss_comparison.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Test Loss Curves

# %%
# ============================================================
# TEST LOSS COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["test_loss"], **arguments)

plt.legend(loc="upper right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

plt.xlim(0, 100)

plt.title(
    "Test Loss Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("test_loss_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["test_loss"], **arguments)

# --- CHANGED LEGEND POSITION ---
plt.legend(loc="lower left", fontsize=14)
# -------------------------------

plt.grid(True,linestyle='--', alpha=0.6)

# --- 100 EPOCHS TIMELINE ---
plt.xticks(np.arange(0, 105, 10), fontsize=12)
plt.xlim(-2, 102)

# --- CHANGED Y-AXIS SPECIFICATIONS ---
plt.yticks(np.arange(1.6, 3.4, 0.2), fontsize=12) # Labels every 0.2 units (1.6, 1.8... 3.2)
plt.ylim(1.6, 3.2)                                # Clips the view window strictly from 1.6 to 3.2
# --------------------------------------

plt.title("Test Loss Comparison Across Activation Functions", fontsize=16)
plt.tight_layout()
# plt.savefig("test_loss_comparison.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Training Accuracy

# %%
# ============================================================
# TRAINING ACCURACY COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["train_accu"], **arguments)

plt.legend(loc="lower right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(np.arange(0, 101, 10), fontsize=12)

plt.xlim(0, 100)
plt.ylim(0, 100)

plt.title(
    "Training Accuracy Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("train_accuracy_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test Accuracy

# %%
# ============================================================
# TEST ACCURACY COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["test_accu"], **arguments)

plt.legend(loc="lower right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(np.arange(0, 101, 10), fontsize=12)

plt.xlim(0, 100)
plt.ylim(0, 100)

plt.title(
    "Test Accuracy Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("test_accuracy_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.plot(my_models["LeakyReLU"]["results"]["grad_norm"])

# %% [markdown]
# # $F_{1}$ Scores
# **Mathematical Definition of the $F_1$ Score**
#
# The $F_1$ score is the harmonic mean of Precision and Recall. It provides a single metric that balances both false positives and false negatives, making it particularly useful for evaluating models on imbalanced datasets.
#
# The general formula is defined as:
#
# $$F_1 = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$$
#
# To calculate the $F_1$ score, you must first calculate **Precision** and **Recall**:
#
# * **Precision** measures the proportion of positive predictions that were actually correct:
#   $$\text{Precision} = \frac{TP}{TP + FP}$$
#
# * **Recall** (also known as Sensitivity) measures the proportion of actual positives that were identified correctly:
#   $$\text{Recall} = \frac{TP}{TP + FN}$$
#
# By substituting Precision and Recall back into the original equation, the $F_1$ score can be expressed directly in terms of prediction outcomes:
#
# $$F_1 = \frac{2 \cdot TP}{2 \cdot TP + FP + FN}$$
#
# **Where:**
# * $TP$ = **True Positives** (Model correctly predicts the positive class)
# * $FP$ = **False Positives** (Model incorrectly predicts the positive class)
# * $FN$ = **False Negatives** (Model incorrectly predicts the negative class)

# %%
f1_results = {}

print("Calculating F1 Scores...")
print("========================")

for act_name, model_data in my_models.items():
    model = model_data["model"]
    model.eval()  # Ensure the model is in evaluation mode

    all_preds = []
    all_targets = []

    with torch.inference_mode():
        # Assuming you have your test_dataloader ready
        for inputs, targets in test_dataloader:
            inputs = inputs.to(device)

            # Get predictions
            outputs = model(inputs)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(targets.numpy())

    f1 = f1_score(all_targets, all_preds, average='macro')
    f1_results[act_name] = f1

    print(f"{act_name: >10}: {f1:.4f}")
# Out:
# Calculating F1 Scores...
# ========================
#    MP_GELU: 0.8763
#      PGELU: 0.0182
#       ReLU: 0.8299
#       GELU: 0.8746
#  LeakyReLU: 0.8538

# %%
import numpy as np
import matplotlib.pyplot as plt

print("=" * 80)
print("GRADIENT L₂ NORMS BY EPOCH")
print("=" * 80)

for act_name, results in all_results.items():

    print(f"\n{'=' * 80}")
    print(f"ACTIVATION: {act_name}")
    print(f"{'=' * 80}")

    grad_norms = np.array(results["grad_norm"], dtype=float)

    # Print gradient norm for every epoch
    for epoch, grad_norm in enumerate(grad_norms, start=1):
        print(
            f"Epoch {epoch:3d}: "
            f"Gradient L₂ Norm = {grad_norm:.6f}"
        )

    # Statistics
    min_grad = np.min(grad_norms)
    max_grad = np.max(grad_norms)
    mean_grad = np.mean(grad_norms)
    std_grad = np.std(grad_norms, ddof=1)

    min_epoch = np.argmin(grad_norms) + 1
    max_epoch = np.argmax(grad_norms) + 1

    print(f"\n{'-' * 80}")
    print(f"SUMMARY — {act_name}")
    print(f"{'-' * 80}")

    print(f"Minimum Gradient L₂ Norm : {min_grad:.6f} "
          f"(Epoch {min_epoch})")

    print(f"Maximum Gradient L₂ Norm : {max_grad:.6f} "
          f"(Epoch {max_epoch})")

    print(f"Mean Gradient L₂ Norm    : {mean_grad:.6f}")

    print(f"Standard Deviation       : {std_grad:.6f}")

    print(f"Mean ± SD                : "
          f"{mean_grad:.6f} ± {std_grad:.6f}")
# Out:
# ================================================================================
# GRADIENT L₂ NORMS BY EPOCH
# ================================================================================
#
# ================================================================================
# ACTIVATION: PGELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 4.158905
# Epoch   2: Gradient L₂ Norm = 4.128474
# Epoch   3: Gradient L₂ Norm = 3.852604
# Epoch   4: Gradient L₂ Norm = 3.876674
# Epoch   5: Gradient L₂ Norm = 3.979221
# Epoch   6: Gradient L₂ Norm = 3.898461
# Epoch   7: Gradient L₂ Norm = 3.870161
# Epoch   8: Gradient L₂ Norm = 4.919090
# Epoch   9: Gradient L₂ Norm = 4.224478
# Epoch  10: Gradient L₂ Norm = 4.232341
# Epoch  11: Gradient L₂ Norm = 4.119735
# Epoch  12: Gradient L₂ Norm = 4.534734
# Epoch  13: Gradient L₂ Norm = 90.211469
# Epoch  14: Gradient L₂ Norm = 0.072866
# Epoch  15: Gradient L₂ Norm = 0.073628
# Epoch  16: Gradient L₂ Norm = 0.072354
# Epoch  17: Gradient L₂ Norm = 0.073044
# Epoch  18: Gradient L₂ Norm = 0.073402
# Epoch  19: Gradient L₂ Norm = 0.073627
# Epoch  20: Gradient L₂ Norm = 0.073750
# Epoch  21: Gradient L₂ Norm = 0.073014
# Epoch  22: Gradient L₂ Norm = 0.074088
# Epoch  23: Gradient L₂ Norm = 0.073581
# Epoch  24: Gradient L₂ Norm = 0.074135
# Epoch  25: Gradient L₂ Norm = 0.073343
# Epoch  26: Gradient L₂ Norm = 0.073586
# Epoch  27: Gradient L₂ Norm = 0.074559
# Epoch  28: Gradient L₂ Norm = 0.074357
# Epoch  29: Gradient L₂ Norm = 0.073582
# Epoch  30: Gradient L₂ Norm = 0.072303
# Epoch  31: Gradient L₂ Norm = 0.072775
# Epoch  32: Gradient L₂ Norm = 0.073564
# Epoch  33: Gradient L₂ Norm = 0.072618
# Epoch  34: Gradient L₂ Norm = 0.072473
# Epoch  35: Gradient L₂ Norm = 0.071473
# Epoch  36: Gradient L₂ Norm = 0.073893
# Epoch  37: Gradient L₂ Norm = 0.073081
# Epoch  38: Gradient L₂ Norm = 0.074166
# Epoch  39: Gradient L₂ Norm = 0.073856
# Epoch  40: Gradient L₂ Norm = 0.073016
# Epoch  41: Gradient L₂ Norm = 0.073033
# Epoch  42: Gradient L₂ Norm = 0.073292
# Epoch  43: Gradient L₂ Norm = 0.073962
# Epoch  44: Gradient L₂ Norm = 0.071314
# Epoch  45: Gradient L₂ Norm = 0.073659
# Epoch  46: Gradient L₂ Norm = 0.073249
# Epoch  47: Gradient L₂ Norm = 0.073465
# Epoch  48: Gradient L₂ Norm = 0.072975
# Epoch  49: Gradient L₂ Norm = 0.073476
# Epoch  50: Gradient L₂ Norm = 0.072958
# Epoch  51: Gradient L₂ Norm = 0.074500
# Epoch  52: Gradient L₂ Norm = 0.075529
# Epoch  53: Gradient L₂ Norm = 0.073873
# Epoch  54: Gradient L₂ Norm = 0.074585
# Epoch  55: Gradient L₂ Norm = 0.073056
# Epoch  56: Gradient L₂ Norm = 0.073069
# Epoch  57: Gradient L₂ Norm = 0.073476
# Epoch  58: Gradient L₂ Norm = 0.073566
# Epoch  59: Gradient L₂ Norm = 0.073814
# Epoch  60: Gradient L₂ Norm = 0.073396
# Epoch  61: Gradient L₂ Norm = 0.073535
# Epoch  62: Gradient L₂ Norm = 0.074775
# Epoch  63: Gradient L₂ Norm = 0.072146
# Epoch  64: Gradient L₂ Norm = 0.072732
# Epoch  65: Gradient L₂ Norm = 0.074334
# Epoch  66: Gradient L₂ Norm = 0.073337
# Epoch  67: Gradient L₂ Norm = 0.073215
# Epoch  68: Gradient L₂ Norm = 0.073385
# Epoch  69: Gradient L₂ Norm = 0.075205
# Epoch  70: Gradient L₂ Norm = 0.074901
# Epoch  71: Gradient L₂ Norm = 0.073274
# Epoch  72: Gradient L₂ Norm = 0.075053
# Epoch  73: Gradient L₂ Norm = 0.074777
# Epoch  74: Gradient L₂ Norm = 0.073761
# Epoch  75: Gradient L₂ Norm = 0.073464
# Epoch  76: Gradient L₂ Norm = 0.072408
# Epoch  77: Gradient L₂ Norm = 0.074789
# Epoch  78: Gradient L₂ Norm = 0.072662
# Epoch  79: Gradient L₂ Norm = 0.072948
# Epoch  80: Gradient L₂ Norm = 0.073822
# Epoch  81: Gradient L₂ Norm = 0.074491
# Epoch  82: Gradient L₂ Norm = 0.074182
# Epoch  83: Gradient L₂ Norm = 0.072456
# Epoch  84: Gradient L₂ Norm = 0.074200
# Epoch  85: Gradient L₂ Norm = 0.073342
# Epoch  86: Gradient L₂ Norm = 0.073607
# Epoch  87: Gradient L₂ Norm = 0.072400
# Epoch  88: Gradient L₂ Norm = 0.071515
# Epoch  89: Gradient L₂ Norm = 0.073927
# Epoch  90: Gradient L₂ Norm = 0.073105
# Epoch  91: Gradient L₂ Norm = 0.072829
# Epoch  92: Gradient L₂ Norm = 0.073264
# Epoch  93: Gradient L₂ Norm = 0.074419
# Epoch  94: Gradient L₂ Norm = 0.072329
# Epoch  95: Gradient L₂ Norm = 0.074840
# Epoch  96: Gradient L₂ Norm = 0.073824
# Epoch  97: Gradient L₂ Norm = 0.072965
# Epoch  98: Gradient L₂ Norm = 0.072916
# Epoch  99: Gradient L₂ Norm = 0.074650
# Epoch 100: Gradient L₂ Norm = 0.073385
#
# --------------------------------------------------------------------------------
# SUMMARY — PGELU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 0.071314 (Epoch 44)
# Maximum Gradient L₂ Norm : 90.211469 (Epoch 13)
# Mean Gradient L₂ Norm    : 1.463999
# Standard Deviation       : 9.063170
# Mean ± SD                : 1.463999 ± 9.063170
#
# ================================================================================
# ACTIVATION: MP_GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 3.031189
# Epoch   2: Gradient L₂ Norm = 3.232646
# Epoch   3: Gradient L₂ Norm = 3.196958
# Epoch   4: Gradient L₂ Norm = 2.917434
# Epoch   5: Gradient L₂ Norm = 2.986941
# Epoch   6: Gradient L₂ Norm = 2.774552
# Epoch   7: Gradient L₂ Norm = 2.775324
# Epoch   8: Gradient L₂ Norm = 2.572072
# Epoch   9: Gradient L₂ Norm = 2.688190
# Epoch  10: Gradient L₂ Norm = 2.681622
# Epoch  11: Gradient L₂ Norm = 2.634169
# Epoch  12: Gradient L₂ Norm = 2.648866
# Epoch  13: Gradient L₂ Norm = 2.596871
# Epoch  14: Gradient L₂ Norm = 2.667611
# Epoch  15: Gradient L₂ Norm = 2.652492
# Epoch  16: Gradient L₂ Norm = 2.687076
# Epoch  17: Gradient L₂ Norm = 2.674400
# Epoch  18: Gradient L₂ Norm = 2.664739
# Epoch  19: Gradient L₂ Norm = 2.642286
# Epoch  20: Gradient L₂ Norm = 2.606820
# Epoch  21: Gradient L₂ Norm = 2.639786
# Epoch  22: Gradient L₂ Norm = 2.728989
# Epoch  23: Gradient L₂ Norm = 2.646792
# Epoch  24: Gradient L₂ Norm = 2.681753
# Epoch  25: Gradient L₂ Norm = 2.720239
# Epoch  26: Gradient L₂ Norm = 2.699487
# Epoch  27: Gradient L₂ Norm = 2.723924
# Epoch  28: Gradient L₂ Norm = 2.789284
# Epoch  29: Gradient L₂ Norm = 2.753830
# Epoch  30: Gradient L₂ Norm = 2.713761
# Epoch  31: Gradient L₂ Norm = 2.752081
# Epoch  32: Gradient L₂ Norm = 2.779489
# Epoch  33: Gradient L₂ Norm = 2.803927
# Epoch  34: Gradient L₂ Norm = 2.791438
# Epoch  35: Gradient L₂ Norm = 2.849875
# Epoch  36: Gradient L₂ Norm = 2.883681
# Epoch  37: Gradient L₂ Norm = 2.765474
# Epoch  38: Gradient L₂ Norm = 2.865681
# Epoch  39: Gradient L₂ Norm = 2.891495
# Epoch  40: Gradient L₂ Norm = 2.870864
# Epoch  41: Gradient L₂ Norm = 2.834548
# Epoch  42: Gradient L₂ Norm = 2.886292
# Epoch  43: Gradient L₂ Norm = 2.862008
# Epoch  44: Gradient L₂ Norm = 2.913478
# Epoch  45: Gradient L₂ Norm = 2.947275
# Epoch  46: Gradient L₂ Norm = 2.900782
# Epoch  47: Gradient L₂ Norm = 2.900544
# Epoch  48: Gradient L₂ Norm = 2.885822
# Epoch  49: Gradient L₂ Norm = 2.950509
# Epoch  50: Gradient L₂ Norm = 2.853962
# Epoch  51: Gradient L₂ Norm = 2.909126
# Epoch  52: Gradient L₂ Norm = 2.920030
# Epoch  53: Gradient L₂ Norm = 2.874976
# Epoch  54: Gradient L₂ Norm = 3.031866
# Epoch  55: Gradient L₂ Norm = 2.978705
# Epoch  56: Gradient L₂ Norm = 2.942110
# Epoch  57: Gradient L₂ Norm = 2.960140
# Epoch  58: Gradient L₂ Norm = 2.909071
# Epoch  59: Gradient L₂ Norm = 2.978115
# Epoch  60: Gradient L₂ Norm = 2.944720
# Epoch  61: Gradient L₂ Norm = 2.996623
# Epoch  62: Gradient L₂ Norm = 2.985868
# Epoch  63: Gradient L₂ Norm = 3.147569
# Epoch  64: Gradient L₂ Norm = 2.975163
# Epoch  65: Gradient L₂ Norm = 3.115962
# Epoch  66: Gradient L₂ Norm = 3.038091
# Epoch  67: Gradient L₂ Norm = 2.971633
# Epoch  68: Gradient L₂ Norm = 2.961727
# Epoch  69: Gradient L₂ Norm = 3.019239
# Epoch  70: Gradient L₂ Norm = 3.022187
# Epoch  71: Gradient L₂ Norm = 3.056460
# Epoch  72: Gradient L₂ Norm = 3.063615
# Epoch  73: Gradient L₂ Norm = 3.083009
# Epoch  74: Gradient L₂ Norm = 3.095481
# Epoch  75: Gradient L₂ Norm = 3.142398
# Epoch  76: Gradient L₂ Norm = 3.059440
# Epoch  77: Gradient L₂ Norm = 3.101693
# Epoch  78: Gradient L₂ Norm = 3.076824
# Epoch  79: Gradient L₂ Norm = 3.039384
# Epoch  80: Gradient L₂ Norm = 3.094818
# Epoch  81: Gradient L₂ Norm = 3.046806
# Epoch  82: Gradient L₂ Norm = 3.138300
# Epoch  83: Gradient L₂ Norm = 3.081961
# Epoch  84: Gradient L₂ Norm = 3.060446
# Epoch  85: Gradient L₂ Norm = 3.125432
# Epoch  86: Gradient L₂ Norm = 3.150171
# Epoch  87: Gradient L₂ Norm = 3.179266
# Epoch  88: Gradient L₂ Norm = 3.132498
# Epoch  89: Gradient L₂ Norm = 3.122342
# Epoch  90: Gradient L₂ Norm = 3.154196
# Epoch  91: Gradient L₂ Norm = 3.133427
# Epoch  92: Gradient L₂ Norm = 3.110268
# Epoch  93: Gradient L₂ Norm = 3.165187
# Epoch  94: Gradient L₂ Norm = 3.223892
# Epoch  95: Gradient L₂ Norm = 3.111392
# Epoch  96: Gradient L₂ Norm = 3.275702
# Epoch  97: Gradient L₂ Norm = 3.242948
# Epoch  98: Gradient L₂ Norm = 3.161024
# Epoch  99: Gradient L₂ Norm = 3.186737
# Epoch 100: Gradient L₂ Norm = 3.207139
#
# --------------------------------------------------------------------------------
# SUMMARY — MP_GELU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 2.572072 (Epoch 8)
# Maximum Gradient L₂ Norm : 3.275702 (Epoch 96)
# Mean Gradient L₂ Norm    : 2.931245
# Standard Deviation       : 0.184160
# Mean ± SD                : 2.931245 ± 0.184160
#
# ================================================================================
# ACTIVATION: ReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 3.348030
# Epoch   2: Gradient L₂ Norm = 4.407728
# Epoch   3: Gradient L₂ Norm = 4.039810
# Epoch   4: Gradient L₂ Norm = 4.085012
# Epoch   5: Gradient L₂ Norm = 4.385184
# Epoch   6: Gradient L₂ Norm = 4.470637
# Epoch   7: Gradient L₂ Norm = 4.570997
# Epoch   8: Gradient L₂ Norm = 4.427460
# Epoch   9: Gradient L₂ Norm = 4.331112
# Epoch  10: Gradient L₂ Norm = 4.271668
# Epoch  11: Gradient L₂ Norm = 4.213261
# Epoch  12: Gradient L₂ Norm = 4.113137
# Epoch  13: Gradient L₂ Norm = 4.320021
# Epoch  14: Gradient L₂ Norm = 4.109588
# Epoch  15: Gradient L₂ Norm = 4.034981
# Epoch  16: Gradient L₂ Norm = 4.011873
# Epoch  17: Gradient L₂ Norm = 4.122189
# Epoch  18: Gradient L₂ Norm = 3.960368
# Epoch  19: Gradient L₂ Norm = 3.977681
# Epoch  20: Gradient L₂ Norm = 3.922759
# Epoch  21: Gradient L₂ Norm = 3.900251
# Epoch  22: Gradient L₂ Norm = 3.953495
# Epoch  23: Gradient L₂ Norm = 3.801422
# Epoch  24: Gradient L₂ Norm = 3.792109
# Epoch  25: Gradient L₂ Norm = 3.797125
# Epoch  26: Gradient L₂ Norm = 3.733821
# Epoch  27: Gradient L₂ Norm = 3.746905
# Epoch  28: Gradient L₂ Norm = 3.660124
# Epoch  29: Gradient L₂ Norm = 3.677333
# Epoch  30: Gradient L₂ Norm = 3.777104
# Epoch  31: Gradient L₂ Norm = 3.577091
# Epoch  32: Gradient L₂ Norm = 3.695956
# Epoch  33: Gradient L₂ Norm = 3.652574
# Epoch  34: Gradient L₂ Norm = 3.678103
# Epoch  35: Gradient L₂ Norm = 3.671951
# Epoch  36: Gradient L₂ Norm = 3.703013
# Epoch  37: Gradient L₂ Norm = 3.629053
# Epoch  38: Gradient L₂ Norm = 3.433637
# Epoch  39: Gradient L₂ Norm = 3.646734
# Epoch  40: Gradient L₂ Norm = 3.596426
# Epoch  41: Gradient L₂ Norm = 3.610116
# Epoch  42: Gradient L₂ Norm = 3.575351
# Epoch  43: Gradient L₂ Norm = 3.606347
# Epoch  44: Gradient L₂ Norm = 3.441054
# Epoch  45: Gradient L₂ Norm = 3.511488
# Epoch  46: Gradient L₂ Norm = 3.426002
# Epoch  47: Gradient L₂ Norm = 3.622833
# Epoch  48: Gradient L₂ Norm = 3.564970
# Epoch  49: Gradient L₂ Norm = 3.499293
# Epoch  50: Gradient L₂ Norm = 3.499848
# Epoch  51: Gradient L₂ Norm = 3.548126
# Epoch  52: Gradient L₂ Norm = 3.401020
# Epoch  53: Gradient L₂ Norm = 3.552226
# Epoch  54: Gradient L₂ Norm = 3.454199
# Epoch  55: Gradient L₂ Norm = 3.464304
# Epoch  56: Gradient L₂ Norm = 3.514566
# Epoch  57: Gradient L₂ Norm = 3.483511
# Epoch  58: Gradient L₂ Norm = 3.417045
# Epoch  59: Gradient L₂ Norm = 3.536695
# Epoch  60: Gradient L₂ Norm = 3.533057
# Epoch  61: Gradient L₂ Norm = 3.449464
# Epoch  62: Gradient L₂ Norm = 3.434136
# Epoch  63: Gradient L₂ Norm = 3.450036
# Epoch  64: Gradient L₂ Norm = 3.517874
# Epoch  65: Gradient L₂ Norm = 3.593959
# Epoch  66: Gradient L₂ Norm = 3.404717
# Epoch  67: Gradient L₂ Norm = 3.499262
# Epoch  68: Gradient L₂ Norm = 3.477725
# Epoch  69: Gradient L₂ Norm = 3.621410
# Epoch  70: Gradient L₂ Norm = 3.432073
# Epoch  71: Gradient L₂ Norm = 3.525395
# Epoch  72: Gradient L₂ Norm = 3.452321
# Epoch  73: Gradient L₂ Norm = 3.503928
# Epoch  74: Gradient L₂ Norm = 3.444277
# Epoch  75: Gradient L₂ Norm = 3.452737
# Epoch  76: Gradient L₂ Norm = 3.429519
# Epoch  77: Gradient L₂ Norm = 3.409514
# Epoch  78: Gradient L₂ Norm = 3.452859
# Epoch  79: Gradient L₂ Norm = 3.444739
# Epoch  80: Gradient L₂ Norm = 3.458740
# Epoch  81: Gradient L₂ Norm = 3.497357
# Epoch  82: Gradient L₂ Norm = 3.378219
# Epoch  83: Gradient L₂ Norm = 3.407411
# Epoch  84: Gradient L₂ Norm = 3.530995
# Epoch  85: Gradient L₂ Norm = 3.457330
# Epoch  86: Gradient L₂ Norm = 3.416039
# Epoch  87: Gradient L₂ Norm = 3.423882
# Epoch  88: Gradient L₂ Norm = 3.487405
# Epoch  89: Gradient L₂ Norm = 3.479046
# Epoch  90: Gradient L₂ Norm = 3.412959
# Epoch  91: Gradient L₂ Norm = 3.467727
# Epoch  92: Gradient L₂ Norm = 3.473259
# Epoch  93: Gradient L₂ Norm = 3.399846
# Epoch  94: Gradient L₂ Norm = 3.348090
# Epoch  95: Gradient L₂ Norm = 3.382208
# Epoch  96: Gradient L₂ Norm = 3.447153
# Epoch  97: Gradient L₂ Norm = 3.430585
# Epoch  98: Gradient L₂ Norm = 3.436065
# Epoch  99: Gradient L₂ Norm = 3.455977
# Epoch 100: Gradient L₂ Norm = 3.464947
#
# --------------------------------------------------------------------------------
# SUMMARY — ReLU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 3.348030 (Epoch 1)
# Maximum Gradient L₂ Norm : 4.570997 (Epoch 7)
# Mean Gradient L₂ Norm    : 3.657610
# Standard Deviation       : 0.299371
# Mean ± SD                : 3.657610 ± 0.299371
#
# ================================================================================
# ACTIVATION: GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 2.506721
# Epoch   2: Gradient L₂ Norm = 2.902747
# Epoch   3: Gradient L₂ Norm = 2.864723
# Epoch   4: Gradient L₂ Norm = 2.831580
# Epoch   5: Gradient L₂ Norm = 2.864595
# Epoch   6: Gradient L₂ Norm = 2.771175
# Epoch   7: Gradient L₂ Norm = 2.706735
# Epoch   8: Gradient L₂ Norm = 2.617048
# Epoch   9: Gradient L₂ Norm = 2.743989
# Epoch  10: Gradient L₂ Norm = 2.690164
# Epoch  11: Gradient L₂ Norm = 2.598322
# Epoch  12: Gradient L₂ Norm = 2.582084
# Epoch  13: Gradient L₂ Norm = 2.594119
# Epoch  14: Gradient L₂ Norm = 2.709537
# Epoch  15: Gradient L₂ Norm = 2.715309
# Epoch  16: Gradient L₂ Norm = 2.628495
# Epoch  17: Gradient L₂ Norm = 2.574978
# Epoch  18: Gradient L₂ Norm = 2.673167
# Epoch  19: Gradient L₂ Norm = 2.636855
# Epoch  20: Gradient L₂ Norm = 2.524118
# Epoch  21: Gradient L₂ Norm = 2.644514
# Epoch  22: Gradient L₂ Norm = 2.693145
# Epoch  23: Gradient L₂ Norm = 2.586833
# Epoch  24: Gradient L₂ Norm = 2.637054
# Epoch  25: Gradient L₂ Norm = 2.576580
# Epoch  26: Gradient L₂ Norm = 2.652851
# Epoch  27: Gradient L₂ Norm = 2.638084
# Epoch  28: Gradient L₂ Norm = 2.744593
# Epoch  29: Gradient L₂ Norm = 2.635675
# Epoch  30: Gradient L₂ Norm = 2.633317
# Epoch  31: Gradient L₂ Norm = 2.717822
# Epoch  32: Gradient L₂ Norm = 2.620969
# Epoch  33: Gradient L₂ Norm = 2.708567
# Epoch  34: Gradient L₂ Norm = 2.705013
# Epoch  35: Gradient L₂ Norm = 2.700193
# Epoch  36: Gradient L₂ Norm = 2.615687
# Epoch  37: Gradient L₂ Norm = 2.671522
# Epoch  38: Gradient L₂ Norm = 2.571214
# Epoch  39: Gradient L₂ Norm = 2.698700
# Epoch  40: Gradient L₂ Norm = 2.605789
# Epoch  41: Gradient L₂ Norm = 2.671756
# Epoch  42: Gradient L₂ Norm = 2.696623
# Epoch  43: Gradient L₂ Norm = 2.712581
# Epoch  44: Gradient L₂ Norm = 2.662427
# Epoch  45: Gradient L₂ Norm = 2.695171
# Epoch  46: Gradient L₂ Norm = 2.615383
# Epoch  47: Gradient L₂ Norm = 2.674239
# Epoch  48: Gradient L₂ Norm = 2.755181
# Epoch  49: Gradient L₂ Norm = 2.699772
# Epoch  50: Gradient L₂ Norm = 2.695781
# Epoch  51: Gradient L₂ Norm = 2.785020
# Epoch  52: Gradient L₂ Norm = 2.803836
# Epoch  53: Gradient L₂ Norm = 2.737516
# Epoch  54: Gradient L₂ Norm = 2.763589
# Epoch  55: Gradient L₂ Norm = 2.800125
# Epoch  56: Gradient L₂ Norm = 2.831768
# Epoch  57: Gradient L₂ Norm = 2.752291
# Epoch  58: Gradient L₂ Norm = 2.780228
# Epoch  59: Gradient L₂ Norm = 2.891951
# Epoch  60: Gradient L₂ Norm = 2.779997
# Epoch  61: Gradient L₂ Norm = 2.911289
# Epoch  62: Gradient L₂ Norm = 2.870490
# Epoch  63: Gradient L₂ Norm = 2.843484
# Epoch  64: Gradient L₂ Norm = 2.886505
# Epoch  65: Gradient L₂ Norm = 2.892197
# Epoch  66: Gradient L₂ Norm = 2.836555
# Epoch  67: Gradient L₂ Norm = 2.889665
# Epoch  68: Gradient L₂ Norm = 2.864332
# Epoch  69: Gradient L₂ Norm = 2.907837
# Epoch  70: Gradient L₂ Norm = 2.881371
# Epoch  71: Gradient L₂ Norm = 2.955963
# Epoch  72: Gradient L₂ Norm = 2.893481
# Epoch  73: Gradient L₂ Norm = 2.924980
# Epoch  74: Gradient L₂ Norm = 2.952376
# Epoch  75: Gradient L₂ Norm = 2.861130
# Epoch  76: Gradient L₂ Norm = 2.935782
# Epoch  77: Gradient L₂ Norm = 2.971403
# Epoch  78: Gradient L₂ Norm = 2.934867
# Epoch  79: Gradient L₂ Norm = 2.990195
# Epoch  80: Gradient L₂ Norm = 2.979462
# Epoch  81: Gradient L₂ Norm = 3.008074
# Epoch  82: Gradient L₂ Norm = 3.104403
# Epoch  83: Gradient L₂ Norm = 3.120915
# Epoch  84: Gradient L₂ Norm = 2.980116
# Epoch  85: Gradient L₂ Norm = 3.007220
# Epoch  86: Gradient L₂ Norm = 3.052761
# Epoch  87: Gradient L₂ Norm = 3.006314
# Epoch  88: Gradient L₂ Norm = 3.041275
# Epoch  89: Gradient L₂ Norm = 3.053885
# Epoch  90: Gradient L₂ Norm = 3.093548
# Epoch  91: Gradient L₂ Norm = 3.129433
# Epoch  92: Gradient L₂ Norm = 3.093793
# Epoch  93: Gradient L₂ Norm = 3.115004
# Epoch  94: Gradient L₂ Norm = 3.116907
# Epoch  95: Gradient L₂ Norm = 3.073204
# Epoch  96: Gradient L₂ Norm = 3.110455
# Epoch  97: Gradient L₂ Norm = 3.172972
# Epoch  98: Gradient L₂ Norm = 3.118978
# Epoch  99: Gradient L₂ Norm = 3.161745
# Epoch 100: Gradient L₂ Norm = 3.196616
#
# --------------------------------------------------------------------------------
# SUMMARY — GELU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 2.506721 (Epoch 1)
# Maximum Gradient L₂ Norm : 3.196616 (Epoch 100)
# Mean Gradient L₂ Norm    : 2.815408
# Standard Deviation       : 0.177582
# Mean ± SD                : 2.815408 ± 0.177582
#
# ================================================================================
# ACTIVATION: LeakyReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 2.440463
# Epoch   2: Gradient L₂ Norm = 3.607204
# Epoch   3: Gradient L₂ Norm = 4.083914
# Epoch   4: Gradient L₂ Norm = 4.237519
# Epoch   5: Gradient L₂ Norm = 4.398298
# Epoch   6: Gradient L₂ Norm = 4.347599
# Epoch   7: Gradient L₂ Norm = 4.158585
# Epoch   8: Gradient L₂ Norm = 4.137318
# Epoch   9: Gradient L₂ Norm = 3.914537
# Epoch  10: Gradient L₂ Norm = 3.967783
# Epoch  11: Gradient L₂ Norm = 3.962019
# Epoch  12: Gradient L₂ Norm = 3.795467
# Epoch  13: Gradient L₂ Norm = 3.782348
# Epoch  14: Gradient L₂ Norm = 3.804590
# Epoch  15: Gradient L₂ Norm = 3.765759
# Epoch  16: Gradient L₂ Norm = 3.612197
# Epoch  17: Gradient L₂ Norm = 3.622615
# Epoch  18: Gradient L₂ Norm = 3.593171
# Epoch  19: Gradient L₂ Norm = 3.552023
# Epoch  20: Gradient L₂ Norm = 3.658344
# Epoch  21: Gradient L₂ Norm = 3.491662
# Epoch  22: Gradient L₂ Norm = 3.524497
# Epoch  23: Gradient L₂ Norm = 3.506045
# Epoch  24: Gradient L₂ Norm = 3.563133
# Epoch  25: Gradient L₂ Norm = 3.505498
# Epoch  26: Gradient L₂ Norm = 3.477374
# Epoch  27: Gradient L₂ Norm = 3.423143
# Epoch  28: Gradient L₂ Norm = 3.447480
# Epoch  29: Gradient L₂ Norm = 3.396038
# Epoch  30: Gradient L₂ Norm = 3.432060
# Epoch  31: Gradient L₂ Norm = 3.374581
# Epoch  32: Gradient L₂ Norm = 3.430601
# Epoch  33: Gradient L₂ Norm = 3.381782
# Epoch  34: Gradient L₂ Norm = 3.375256
# Epoch  35: Gradient L₂ Norm = 3.342066
# Epoch  36: Gradient L₂ Norm = 3.433248
# Epoch  37: Gradient L₂ Norm = 3.347710
# Epoch  38: Gradient L₂ Norm = 3.405234
# Epoch  39: Gradient L₂ Norm = 3.330790
# Epoch  40: Gradient L₂ Norm = 3.351497
# Epoch  41: Gradient L₂ Norm = 3.282032
# Epoch  42: Gradient L₂ Norm = 3.400052
# Epoch  43: Gradient L₂ Norm = 3.335468
# Epoch  44: Gradient L₂ Norm = 3.256963
# Epoch  45: Gradient L₂ Norm = 3.323490
# Epoch  46: Gradient L₂ Norm = 3.309776
# Epoch  47: Gradient L₂ Norm = 3.326933
# Epoch  48: Gradient L₂ Norm = 3.309955
# Epoch  49: Gradient L₂ Norm = 3.307567
# Epoch  50: Gradient L₂ Norm = 3.278067
# Epoch  51: Gradient L₂ Norm = 3.377147
# Epoch  52: Gradient L₂ Norm = 3.297984
# Epoch  53: Gradient L₂ Norm = 3.290144
# Epoch  54: Gradient L₂ Norm = 3.411443
# Epoch  55: Gradient L₂ Norm = 3.409080
# Epoch  56: Gradient L₂ Norm = 3.339776
# Epoch  57: Gradient L₂ Norm = 3.297947
# Epoch  58: Gradient L₂ Norm = 3.338013
# Epoch  59: Gradient L₂ Norm = 3.405598
# Epoch  60: Gradient L₂ Norm = 3.413405
# Epoch  61: Gradient L₂ Norm = 3.357108
# Epoch  62: Gradient L₂ Norm = 3.364972
# Epoch  63: Gradient L₂ Norm = 3.270026
# Epoch  64: Gradient L₂ Norm = 3.409349
# Epoch  65: Gradient L₂ Norm = 3.372372
# Epoch  66: Gradient L₂ Norm = 3.413286
# Epoch  67: Gradient L₂ Norm = 3.262247
# Epoch  68: Gradient L₂ Norm = 3.343882
# Epoch  69: Gradient L₂ Norm = 3.401443
# Epoch  70: Gradient L₂ Norm = 3.453586
# Epoch  71: Gradient L₂ Norm = 3.476038
# Epoch  72: Gradient L₂ Norm = 3.391112
# Epoch  73: Gradient L₂ Norm = 3.394738
# Epoch  74: Gradient L₂ Norm = 3.459536
# Epoch  75: Gradient L₂ Norm = 3.394230
# Epoch  76: Gradient L₂ Norm = 3.336837
# Epoch  77: Gradient L₂ Norm = 3.333726
# Epoch  78: Gradient L₂ Norm = 3.526259
# Epoch  79: Gradient L₂ Norm = 3.380893
# Epoch  80: Gradient L₂ Norm = 3.330033
# Epoch  81: Gradient L₂ Norm = 3.394509
# Epoch  82: Gradient L₂ Norm = 3.514599
# Epoch  83: Gradient L₂ Norm = 3.525627
# Epoch  84: Gradient L₂ Norm = 3.422621
# Epoch  85: Gradient L₂ Norm = 3.535254
# Epoch  86: Gradient L₂ Norm = 3.463119
# Epoch  87: Gradient L₂ Norm = 3.412154
# Epoch  88: Gradient L₂ Norm = 3.441331
# Epoch  89: Gradient L₂ Norm = 3.527031
# Epoch  90: Gradient L₂ Norm = 3.481617
# Epoch  91: Gradient L₂ Norm = 3.459959
# Epoch  92: Gradient L₂ Norm = 3.434085
# Epoch  93: Gradient L₂ Norm = 3.495874
# Epoch  94: Gradient L₂ Norm = 3.479987
# Epoch  95: Gradient L₂ Norm = 3.563126
# Epoch  96: Gradient L₂ Norm = 3.490990
# Epoch  97: Gradient L₂ Norm = 3.550292
# Epoch  98: Gradient L₂ Norm = 3.503940
# Epoch  99: Gradient L₂ Norm = 3.636141
# Epoch 100: Gradient L₂ Norm = 3.483959
#
# --------------------------------------------------------------------------------
# SUMMARY — LeakyReLU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 2.440463 (Epoch 1)
# Maximum Gradient L₂ Norm : 4.398298 (Epoch 5)
# Mean Gradient L₂ Norm    : 3.491802
# Standard Deviation       : 0.257644
# Mean ± SD                : 3.491802 ± 0.257644

# %%
# ============================================================
# GRADIENT L2 NORM VS EPOCH
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, properties in to_plot.items():

    plot_results = properties["results"]

    epochs = np.arange(1, len(plot_results["grad_norm"]) + 1)

    plt.plot(
        epochs,
        plot_results["grad_norm"],
        linewidth=properties["linewidth"],
        linestyle="-",
        label=act_name,
        color=properties["color"]
    )

plt.xlabel("Epoch", fontsize=13)
plt.ylabel("Gradient L₂ Norm", fontsize=13)

plt.title(
    "Gradient L₂ Norm vs Epoch",
    fontsize=16
)

plt.legend(
    loc="upper right",
    fontsize=12
)

plt.grid(
    True,
    linestyle="--",
    alpha=0.6
)

plt.xticks(
    np.arange(0, 101, 5),
    fontsize=12
)

plt.yticks(fontsize=12)

plt.xlim(1, 100)

plt.tight_layout()
plt.show()
