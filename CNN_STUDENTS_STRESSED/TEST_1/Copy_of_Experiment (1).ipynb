# %% [markdown]
# # Introduction
#
# <center>
# <h2>
# Computational Experiments with Modern Parametrized Gaussian Error Linear Unit (MPGELU)
# </h2>
# <b>A demonstration by: Jose Aries E. De Los Santos</b>
# </center>

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %% [markdown]
# # Import Libraries

# %%
import os
import sys
from pathlib import Path
from functools import partial

#PyTorch
import torch as torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import time
from torchinfo import summary

import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import random
from typing import Iterable, Callable


#sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

#Import torchvision
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor
from torchinfo import summary

#Import tqdm for a cool progress bar
from tqdm.auto import tqdm

# Measure time
from timeit import default_timer as timer

seed = 143
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)


print(f"PyTorch Version: {torch.__version__}")
print(f"Numpy Version: {np.__version__}")
print(f"Pandas Version: {pd.__version__}")
# print(f"Matplotlib Version: {matplotlib.__version__}")
print(f"SciPy Version: {scipy.__version__}")

# device = "cuda" if torch.cuda.is_available() else "cpu"

if torch.cuda.is_available():
    device = "cuda"
    print(f"Device: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = "mps"
    print(f"Device: {torch.backends.mps.is_available()}")
else:
    device = "cpu"
    print(f"Device: {device}")
# Out:
# PyTorch Version: 2.11.0+cu128
# Numpy Version: 2.1.3
# Pandas Version: 2.2.3
# SciPy Version: 1.16.3
# Device: NVIDIA A100-SXM4-40GB

# %% [markdown]
# # Dynamic Path Modification
#
# * It is a runtime technique used to explicitly tell Python where to look for modules or packages when you run an ``import`` statement.

# %% [markdown]
# ## Import Helper Functions

# %%
### Add the parent directory to the sys.path to import MyCNN and MPGELU
#%reload_ext autoreload
#%autoreload 2
mother_path = Path.cwd()
for folder in ["utility", "act_fns", "models"]:
    path = os.path.join(mother_path , folder)
    if path not in sys.path:
        sys.path.append(path)
from MPGELU import MPGELU
from PGELU import PGELU
from MyCNN import MyCNN
from DataTransforms import DataTransforms
from Trainer import Trainer
from LoadedModel import LoadedModel

# %% [markdown]
# # MP GELU
#
# * Modified Parametric Gaussian Error Linear Unit
# $$
# f(x) = \frac{x}{2} \left[ 1 + \text{erf}\left( \frac{\lambda x}{\sqrt{2}}\right)\right] = \frac{x}{2} + \frac{x}{\sqrt{\pi}}\int_{0}^{\lambda x / \sqrt{2}} e^{-u^{2}}du
# $$
# where $\lambda  = (1 + \ln(1 + e^{s})) \geq 1$   $\forall s \in \mathbb{R}$
#
# * Check MPGELU.py file for the implementation of the MPGELU activation function

# %%
x_np = np.linspace(-4.0, 4.0, 400)
x_tensor = torch.tensor(x_np, dtype=torch.float32)
# s_values = np.arange(-2.0, 2.0, 0.1)
s_values = [-100, 0.0, 100, ]
plt.figure(figsize=(9, 6))

for s_val in s_values:
    activation1 = MPGELU(s_param=s_val)
    activation2 = MPGELU(s_param=s_val, use_softplus=False)
    with torch.inference_mode():
        y_tensor1 = activation1(x_tensor)
        y_tensor2 = activation2(x_tensor)

    lam_val = (1.0 + F.softplus(torch.tensor(s_val, dtype=torch.float32))).item()
    plt.plot(x_np, y_tensor1.numpy(), label=f"s = {s_val}", linewidth=2.5)
    # plt.plot(x_np, y_tensor2.numpy(), label=f"s = {s_val}", linewidth=2)

# 4. Format the plot
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.axvline(0, color='black', linewidth=0.8, linestyle='--')
plt.title("Modified Parametric GELU (MP-GELU) Activation Function", fontsize=15)
xticks = np.arange(-4, 5, 0.8)
plt.xticks(xticks,fontsize=12)
plt.xlabel("Input ($x$)", fontsize=12)
yticks = np.arange(-2, 5, 0.8)
plt.yticks(yticks,fontsize=12)
plt.ylabel("Output ($f(x)$)", fontsize=12)
plt.grid(True, linestyle=':', alpha=0.9)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # Data Processing

# %%
transformer = DataTransforms(dataset='cifar10', use_augmentation=True, use_stats=False)
train_transform = transformer.get_train_transform()
test_transform = transformer.get_test_transform()


train_data = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
test_data = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)


train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True, num_workers=10, pin_memory=True, persistent_workers=True)
test_dataloader = DataLoader(test_data, batch_size=128, shuffle=False, num_workers=10, pin_memory=True, persistent_workers=True)

# %% [markdown]
# ## Visualize Sample Images

# %%
fig = plt.figure(figsize=(8, 8))
rows, columns = 4, 4

for i in range(1, rows * columns + 1):
    idx = torch.randint(0, len(train_data), size=[1]).item()  # Random index
    img, label = train_data[idx][0], train_data[idx][1]
    fig.add_subplot(rows, columns, i)

    # Display image without converting to grayscale
    plt.imshow(img.permute(1, 2, 0))  # Change channels to last dimension (H, W, C)
    plt.title(train_data.classes[label])
    plt.grid(False)
    plt.axis(False)

plt.axis(False)
# plt.savefig("cifar10_dataset.jpg",dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Model

# %%
def init_custom_weights(m):
    if isinstance(m, (nn.Linear, nn.Conv2d)):
        nn.init.normal_(m.weight, mean=-1, std=0.1)
        # nn.init.constant_(m.weight, 0.0)
        if m.bias is not None:
            # nn.init.constant_(m.bias, 0.0)
            nn.init.normal_(m.weight, mean=-1, std=0.1)

# %% [markdown]
# ## Set its Parameters

# %%
chosen_model_params = [32, 32, 'MaxPool', 64, 64, 'MaxPool', 128, 128, 128, 'MaxPool']

model = MyCNN(input_shape=3,
                  output_shape=10,
                  activation = MPGELU,
                  params = chosen_model_params).to(device)

print(summary(model=model,
        input = torch.randn(size=(3, 32, 32)).unsqueeze(dim=0)))

total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MyCNN                                    --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       896
# │    └─MPGELU: 2-2                       1
# │    └─Conv2d: 2-3                       9,248
# │    └─MPGELU: 2-4                       1
# │    └─MaxPool2d: 2-5                    --
# │    └─Conv2d: 2-6                       18,496
# │    └─MPGELU: 2-7                       1
# │    └─Conv2d: 2-8                       36,928
# │    └─MPGELU: 2-9                       1
# │    └─MaxPool2d: 2-10                   --
# │    └─Conv2d: 2-11                      73,856
# │    └─MPGELU: 2-12                      1
# │    └─Conv2d: 2-13                      147,584
# │    └─MPGELU: 2-14                      1
# │    └─Conv2d: 2-15                      147,584
# │    └─MPGELU: 2-16                      1
# │    └─MaxPool2d: 2-17                   --
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-18                      524,544
# │    └─MPGELU: 2-19                      1
# │    └─Linear: 2-20                      65,792
# │    └─MPGELU: 2-21                      1
# │    └─Linear: 2-22                      2,570
# =================================================================
# Total params: 1,027,507
# Trainable params: 1,027,507
# Non-trainable params: 0
# =================================================================
# Total number of parameters: 1027507

# %%
model.apply(init_custom_weights)
for name, param in model.named_parameters():
  if "weight" in name:
    print(f"Layer: {name}:, Weights: {param.data}")
  elif "bias" in name:
    print(f"Layer: {name}, Biases: {param.data}")
# Out:
# Layer: conv_layers.0.weight:, Weights: tensor([[[[-0.9282, -1.0105, -0.9556],
#           [-0.9534, -0.9668, -0.9092],
#           [-1.0745, -0.9940, -1.0132]],
#
#          [[-1.0405, -1.0187, -1.1812],
#           [-0.9370, -0.7344, -1.0595],
#           [-0.8914, -1.0909, -1.1709]],
#
#          [[-1.0648, -0.9168, -0.8241],
#           [-0.8306, -0.9082, -1.0156],
#           [-0.9965, -1.0429, -0.9388]]],
#
#
#         [[[-0.9564, -1.0188, -0.9722],
#           [-0.8658, -1.0397, -1.0330],
#           [-0.9517, -1.0243, -0.9851]],
#
#          [[-1.0611, -1.1027, -0.8697],
#           [-1.0053, -0.8955, -0.8529],
#           [-1.0957, -0.9436, -1.0740]],
#
#          [[-1.0753, -1.0377, -0.7794],
#           [-0.9740, -1.0230, -0.9458],
#           [-0.8463, -1.0386, -0.9121]]],
#
#
#         [[[-1.0201, -1.0192, -1.0809],
#           [-0.9771, -0.8196, -1.0218],
#           [-1.1460, -1.0076, -1.0464]],
#
#          [[-0.8964, -0.8717, -1.0461],
#           [-0.9964, -0.8318, -1.0042],
#           [-1.0584, -1.1152, -0.7975]],
#
#          [[-1.0168, -0.9827, -0.9406],
#           [-1.0186, -0.8857, -1.0051],
#           [-1.1652, -1.0287, -1.0510]]],
#
#
#         [[[-1.0376, -1.0508, -0.9014],
#           [-1.0259, -0.9590, -0.9231],
#           [-1.1613, -1.0331, -0.9395]],
#
#          [[-0.8907, -0.9507, -0.9192],
#           [-1.0655, -0.8399, -1.0413],
#           [-1.0675, -1.0145, -1.1345]],
#
#          [[-1.0030, -1.1790, -0.8951],
#           [-1.1035, -0.9815, -0.8963],
#           [-1.1889, -0.9435, -1.0612]]],
#
#
#         [[[-0.8312, -0.9759, -0.8371],
#           [-0.9391, -1.2270, -1.0498],
#           [-1.1511, -1.0558, -1.0237]],
#
#          [[-1.0351, -0.9766, -1.0076],
#           [-1.0205, -1.0094, -1.0227],
#           [-0.9683, -1.1042, -0.9657]],
#
#          [[-1.0399, -0.9624, -1.1163],
#           [-0.9382, -1.0331, -1.0216],
#           [-1.1625, -1.0971, -1.1085]]],
#
#
#         [[[-1.3143, -0.9301, -1.1230],
#           [-1.0812, -1.0014, -0.9658],
#           [-1.1804, -1.1430, -1.0873]],
#
#          [[-1.0781, -0.9388, -0.9344],
#           [-0.8672, -0.8790, -0.9711],
#           [-0.9178, -0.9291, -1.1839]],
#
#          [[-1.0910, -1.0166, -1.0489],
#           [-0.9658, -0.9449, -1.0777],
#           [-1.1448, -0.9142, -0.7554]]],
#
#
#         [[[-1.1159, -1.0504, -1.0317],
#           [-0.8854, -1.0238, -0.9232],
#           [-0.9000, -1.1712, -0.9121]],
#
#          [[-0.8991, -0.8612, -0.9603],
#           [-0.7123, -1.1014, -0.9422],
#           [-1.1586, -0.8925, -1.0204]],
#
#          [[-1.0616, -0.9691, -0.9657],
#           [-1.0446, -1.1345, -0.9403],
#           [-1.0847, -1.0856, -1.0040]]],
#
#
#         [[[-1.1189, -0.9213, -0.9634],
#           [-1.0359, -0.8834, -1.0556],
#           [-0.9038, -0.8896, -1.0096]],
#
#          [[-1.1043, -1.1862, -1.0556],
#           [-1.0529, -0.9321, -1.0770],
#           [-1.0729, -0.9698, -0.8314]],
#
#          [[-1.0983, -0.9283, -0.8805],
#           [-1.0309, -0.9804, -1.0305],
#           [-0.9756, -0.9714, -0.8343]]],
#
#
#         [[[-1.0962, -1.0008, -0.9022],
#           [-0.9119, -0.9813, -1.1103],
#           [-1.1167, -1.0302, -0.9136]],
#
#          [[-0.8955, -0.8761, -1.0037],
#           [-1.1534, -1.0288, -0.8520],
#           [-1.0461, -0.8938, -0.9507]],
#
#          [[-1.1432, -0.9912, -0.9939],
#           [-1.0101, -1.0337, -0.9600],
#           [-1.1134, -0.8506, -1.0874]]],
#
#
#         [[[-0.7738, -0.9596, -1.0134],
#           [-0.8824, -0.9674, -1.0491],
#           [-1.1179, -0.9504, -0.9962]],
#
#          [[-0.9996, -0.8362, -1.0162],
#           [-1.0494, -1.0788, -0.9554],
#           [-0.9596, -1.0721, -1.0230]],
#
#          [[-1.0321, -1.1453, -0.9706],
#           [-0.9933, -0.9552, -1.1378],
#           [-0.9347, -1.0344, -0.9178]]],
#
#
#         [[[-0.9768, -0.9744, -0.9647],
#           [-0.9138, -1.1979, -0.9838],
#           [-0.8002, -0.9862, -1.1654]],
#
#          [[-0.9324, -1.0540, -0.9056],
#           [-0.8425, -1.0289, -0.8825],
#           [-1.0087, -1.0284, -0.9788]],
#
#          [[-0.9055, -1.0279, -0.8712],
#           [-0.9276, -1.0717, -1.0035],
#           [-1.0077, -0.8664, -1.0007]]],
#
#
#         [[[-1.0089, -0.9715, -0.9795],
#           [-1.1981, -1.1218, -1.1173],
#           [-1.0336, -1.0371, -1.0500]],
#
#          [[-0.9784, -1.1601, -1.0852],
#           [-1.0959, -0.9879, -1.0043],
#           [-0.9154, -1.0264, -1.1586]],
#
#          [[-1.0795, -0.9292, -1.2448],
#           [-1.0660, -1.0412, -1.0943],
#           [-1.0753, -1.1067, -0.7631]]],
#
#
#         [[[-1.0384, -1.0450, -1.0294],
#           [-1.0299, -0.8968, -1.1984],
#           [-0.9642, -1.1904, -0.9933]],
#
#          [[-1.0247, -1.0451, -1.0977],
#           [-1.0841, -0.9340, -0.9921],
#           [-1.0516, -0.8994, -1.0066]],
#
#          [[-1.0492, -1.0224, -0.9928],
#           [-1.0969, -1.0627, -0.9755],
#           [-1.0708, -1.0195, -0.9120]]],
#
#
#         [[[-1.0590, -0.8851, -1.0614],
#           [-0.9025, -0.9596, -1.1180],
#           [-0.9154, -0.9137, -1.0879]],
#
#          [[-1.0132, -0.9225, -1.1626],
#           [-0.9500, -1.0091, -1.0399],
#           [-1.1432, -0.8385, -0.9720]],
#
#          [[-1.0346, -1.0251, -1.0586],
#           [-0.9953, -0.7896, -0.9883],
#           [-0.9892, -0.8683, -0.9924]]],
#
#
#         [[[-1.0153, -1.0324, -0.9667],
#           [-1.0614, -1.0368, -1.1251],
#           [-1.1013, -1.0048, -1.0458]],
#
#          [[-0.9210, -0.8757, -1.1036],
#           [-0.9949, -0.9433, -0.9267],
#           [-0.9638, -1.1592, -0.9894]],
#
#          [[-0.7885, -1.1097, -1.1463],
#           [-1.1123, -1.1448, -1.2075],
#           [-1.1890, -1.0930, -1.1203]]],
#
#
#         [[[-1.1551, -0.9905, -1.0801],
#           [-0.9398, -1.0811, -0.9595],
#           [-1.0769, -1.0663, -1.0657]],
#
#          [[-1.0075, -1.0316, -0.9943],
#           [-0.8628, -1.1323, -0.9919],
#           [-1.1007, -0.8810, -0.9958]],
#
#          [[-1.0070, -0.9075, -1.0594],
#           [-1.1686, -1.0366, -0.9868],
#           [-0.8418, -0.9658, -1.0709]]],
#
#
#         [[[-0.9935, -1.0884, -0.9304],
#           [-0.8592, -1.0142, -1.0799],
#           [-1.1112, -1.0239, -0.9994]],
#
#          [[-0.9909, -0.8749, -1.1335],
#           [-1.1800, -0.8912, -0.9205],
#           [-1.0038, -1.1898, -0.9387]],
#
#          [[-1.1363, -0.9251, -1.2042],
#           [-1.0085, -1.0460, -1.0075],
#           [-1.0967, -1.1198, -0.8798]]],
#
#
#         [[[-1.0341, -1.0757, -1.2578],
#           [-0.9131, -1.0285, -1.1030],
#           [-0.9509, -0.9354, -0.9556]],
#
#          [[-1.0873, -0.9986, -0.9096],
#           [-0.9475, -1.1801, -1.0937],
#           [-0.9782, -1.2091, -1.0070]],
#
#          [[-0.9032, -1.0055, -1.0061],
#           [-0.9957, -0.9317, -1.0310],
#           [-0.8988, -1.1788, -1.0346]]],
#
#
#         [[[-1.0087, -1.0850, -0.8828],
#           [-1.1167, -0.8606, -1.1210],
#           [-1.0154, -0.9715, -1.1070]],
#
#          [[-1.0698, -1.1358, -0.9186],
#           [-1.0207, -0.9416, -1.0117],
#           [-1.0660, -1.0499, -0.7472]],
#
#          [[-0.9153, -0.9164, -0.9429],
#           [-0.9270, -0.8610, -1.0946],
#           [-1.0350, -0.9820, -1.0801]]],
#
#
#         [[[-0.9516, -1.1054, -0.9248],
#           [-1.0140, -0.8113, -0.9468],
#           [-0.7629, -1.0826, -0.9332]],
#
#          [[-1.0390, -1.0323, -1.2075],
#           [-1.1655, -0.8626, -1.0833],
#           [-0.8979, -1.0655, -0.9920]],
#
#          [[-1.0747, -0.9647, -1.0651],
#           [-1.0321, -1.0468, -0.9355],
#           [-0.8578, -1.0031, -1.0649]]],
#
#
#         [[[-0.9969, -0.8111, -1.0864],
#           [-1.0706, -1.1379, -0.9583],
#           [-0.9050, -0.9190, -1.0759]],
#
#          [[-1.0757, -0.8081, -0.9041],
#           [-1.0349, -1.0154, -1.1233],
#           [-0.9078, -1.1891, -0.9231]],
#
#          [[-1.1908, -1.2122, -0.9550],
#           [-0.8723, -1.0794, -0.9949],
#           [-0.9180, -1.1668, -0.9418]]],
#
#
#         [[[-0.9602, -1.1064, -0.8205],
#           [-0.9711, -1.0269, -0.9159],
#           [-0.8819, -0.8858, -0.9067]],
#
#          [[-1.0924, -0.8834, -0.8961],
#           [-0.9968, -1.0704, -0.9611],
#           [-1.2512, -0.8620, -1.0970]],
#
#          [[-1.0003, -0.9695, -1.0007],
#           [-1.1556, -1.0815, -1.1855],
#           [-0.9767, -0.9273, -0.8228]]],
#
#
#         [[[-0.8799, -1.0074, -0.9911],
#           [-1.1995, -0.8470, -1.1581],
#           [-0.8614, -0.9964, -0.9933]],
#
#          [[-0.8887, -0.9642, -1.0381],
#           [-0.9793, -1.0040, -0.9099],
#           [-0.9034, -1.0950, -0.9949]],
#
#          [[-0.9769, -1.0091, -0.9571],
#           [-1.0728, -0.8990, -1.0502],
#           [-0.9013, -1.0870, -1.1432]]],
#
#
#         [[[-1.0236, -1.1062, -1.0165],
#           [-0.9793, -1.0410, -1.0672],
#           [-1.1647, -1.2235, -1.0591]],
#
#          [[-0.9847, -0.8732, -0.8906],
#           [-1.0799, -0.9819, -0.8479],
#           [-1.0573, -0.9494, -0.9807]],
#
#          [[-0.9554, -1.2014, -1.1159],
#           [-0.8735, -1.0313, -1.0342],
#           [-0.7965, -0.9751, -0.8586]]],
#
#
#         [[[-1.0819, -0.9917, -0.7312],
#           [-0.9096, -0.9297, -1.0591],
#           [-1.0216, -0.9705, -1.0197]],
#
#          [[-0.9506, -0.9642, -1.0439],
#           [-1.0450, -0.9371, -1.0750],
#           [-1.1083, -0.9145, -1.1059]],
#
#          [[-0.9413, -1.0726, -1.0040],
#           [-0.8938, -1.2548, -1.0659],
#           [-0.9764, -0.9925, -0.8887]]],
#
#
#         [[[-1.0075, -0.9499, -0.9498],
#           [-0.9810, -0.8698, -1.0197],
#           [-1.0212, -1.0123, -0.8799]],
#
#          [[-1.1637, -0.8749, -0.8695],
#           [-1.0908, -1.1674, -1.0666],
#           [-0.9351, -1.0869, -0.8664]],
#
#          [[-1.0088, -0.9903, -0.9441],
#           [-1.0543, -1.2239, -1.1268],
#           [-0.8799, -1.0728, -0.8991]]],
#
#
#         [[[-1.0566, -0.8596, -1.0457],
#           [-0.9651, -0.9715, -0.9895],
#           [-1.0087, -0.9027, -1.1317]],
#
#          [[-0.9044, -1.0213, -0.9283],
#           [-0.9705, -1.1168, -0.9127],
#           [-1.0558, -1.2159, -0.9256]],
#
#          [[-1.0462, -1.1187, -1.0673],
#           [-1.1217, -1.1301, -1.1163],
#           [-0.8694, -0.9563, -0.8367]]],
#
#
#         [[[-0.9186, -0.9667, -0.9372],
#           [-1.1096, -1.0514, -1.1017],
#           [-0.9129, -0.9697, -0.9069]],
#
#          [[-0.9086, -1.0461, -0.9841],
#           [-1.1050, -1.1466, -0.9082],
#           [-1.1272, -0.8098, -0.9864]],
#
#          [[-0.8379, -0.9938, -1.1018],
#           [-0.8929, -0.9017, -0.8372],
#           [-0.9860, -0.9769, -1.0669]]],
#
#
#         [[[-1.1008, -1.0917, -0.9636],
#           [-1.1536, -0.9413, -1.0317],
#           [-0.9001, -0.9116, -0.9170]],
#
#          [[-1.1075, -0.8882, -0.9889],
#           [-1.0481, -1.0160, -1.1617],
#           [-0.9269, -1.0238, -0.9892]],
#
#          [[-0.8169, -1.0147, -0.9212],
#           [-1.1360, -1.1044, -0.8864],
#           [-0.9265, -0.9937, -0.9697]]],
#
#
#         [[[-0.8876, -1.0163, -1.0098],
#           [-1.1128, -1.0269, -1.1004],
#           [-0.7944, -0.9014, -0.9349]],
#
#          [[-0.9405, -0.9926, -1.0556],
#           [-0.8858, -0.9898, -1.0518],
#           [-0.9843, -0.9260, -1.0817]],
#
#          [[-0.9661, -0.9274, -1.1579],
#           [-1.0432, -0.9716, -0.9955],
#           [-1.0794, -1.0575, -1.0791]]],
#
#
#         [[[-1.0254, -1.0521, -1.0505],
#           [-1.1150, -1.0602, -0.9864],
#           [-0.9664, -0.7416, -1.0762]],
#
#          [[-0.9547, -1.0785, -1.1112],
#           [-1.1145, -0.9616, -0.9048],
#           [-0.8842, -0.9710, -1.0387]],
#
#          [[-0.9028, -1.1710, -1.0414],
#           [-1.0649, -0.9515, -0.9562],
#           [-1.1314, -1.0854, -0.7796]]],
#
#
#         [[[-1.0103, -0.8333, -1.0247],
#           [-1.0855, -1.0516, -0.9299],
#           [-1.0610, -0.9453, -0.8928]],
#
#          [[-1.0317, -1.0319, -0.9716],
#           [-0.9860, -1.0084, -1.0659],
#           [-1.0959, -0.9655, -0.9122]],
#
#          [[-1.0856, -1.0071, -1.2048],
#           [-1.1556, -1.0820, -1.0464],
#           [-1.1319, -1.0429, -0.9826]]]], device='cuda:0')
# Layer: conv_layers.0.bias, Biases: tensor([ 0.1434, -0.0241,  0.1077, -0.0882, -0.1870, -0.1816, -0.0839, -0.0105,
#         -0.0054, -0.1545, -0.1457, -0.0421,  0.1246, -0.0680,  0.0035, -0.0656,
#         -0.0540,  0.1781,  0.1288, -0.0697,  0.1500, -0.0558,  0.0109, -0.1238,
#         -0.1217, -0.1566,  0.0456, -0.0036, -0.0969, -0.0104,  0.0839,  0.0715],
#        device='cuda:0')
# Layer: conv_layers.2.weight:, Weights: tensor([[[[-0.8878, -0.9249, -1.0883],
#           [-0.8897, -0.8911, -0.8905],
#           [-1.0108, -0.9349, -0.9588]],
#
#          [[-1.0634, -0.9935, -0.9143],
#           [-0.9858, -1.0694, -0.9593],
#           [-0.8150, -1.0134, -0.9489]],
#
#          [[-1.0240, -1.1371, -1.0516],
#           [-0.9266, -1.1369, -1.1066],
#           [-1.0981, -0.9494, -0.9847]],
#
#          ...,
#
#          [[-0.9416, -1.1061, -1.0224],
#           [-0.9393, -1.1530, -0.8734],
#           [-0.9360, -1.1535, -1.1116]],
#
#          [[-1.0207, -1.2007, -0.9540],
#           [-1.0482, -1.1630, -0.9541],
#           [-1.0690, -0.9065, -1.1184]],
#
#          [[-0.8523, -1.0285, -1.0149],
#           [-0.8793, -0.9111, -1.0921],
#           [-0.9770, -1.1054, -0.8833]]],
#
#
#         [[[-0.7572, -1.0522, -0.9995],
#           [-0.9854, -0.9612, -1.2331],
#           [-1.0134, -1.1293, -1.0744]],
#
#          [[-1.0011, -1.0643, -0.9518],
#           [-1.0702, -0.9994, -1.0474],
#           [-1.1115, -1.0632, -1.0966]],
#
#          [[-1.0049, -0.9358, -0.8970],
#           [-0.8906, -1.0271, -0.9994],
#           [-1.1384, -0.9245, -0.9011]],
#
#          ...,
#
#          [[-1.0524, -1.1551, -0.8915],
#           [-0.9929, -1.0334, -1.1061],
#           [-0.9362, -0.9818, -0.9655]],
#
#          [[-1.1664, -1.0814, -1.1204],
#           [-1.0470, -0.8638, -1.0657],
#           [-1.1853, -1.0495, -0.9040]],
#
#          [[-0.9289, -0.9543, -0.9815],
#           [-1.0916, -1.0016, -0.9686],
#           [-1.0362, -1.0546, -0.9759]]],
#
#
#         [[[-0.8873, -1.0418, -1.0084],
#           [-1.1533, -0.9770, -1.0471],
#           [-0.9360, -0.7349, -0.8876]],
#
#          [[-0.9586, -0.8325, -0.8859],
#           [-0.9773, -0.9505, -0.9633],
#           [-1.0251, -0.9214, -0.9914]],
#
#          [[-0.9279, -1.1208, -0.9975],
#           [-0.8698, -0.8589, -0.8946],
#           [-0.7787, -0.9266, -0.9378]],
#
#          ...,
#
#          [[-1.0083, -1.0031, -1.0780],
#           [-1.1329, -1.0759, -1.1802],
#           [-1.0117, -1.0516, -0.9241]],
#
#          [[-0.9767, -1.2221, -0.9777],
#           [-1.0551, -1.1549, -0.9499],
#           [-1.0326, -1.1166, -0.9401]],
#
#          [[-0.8349, -0.9008, -1.0478],
#           [-1.0320, -1.0887, -0.9489],
#           [-1.0134, -0.9755, -0.7285]]],
#
#
#         ...,
#
#
#         [[[-1.0425, -1.0960, -1.0085],
#           [-1.0421, -1.1026, -0.9697],
#           [-0.8755, -1.1136, -1.0861]],
#
#          [[-1.0908, -0.9157, -1.0330],
#           [-1.0843, -0.9168, -1.1140],
#           [-1.0358, -0.8424, -0.9373]],
#
#          [[-1.3706, -1.0442, -1.0159],
#           [-0.9251, -0.9616, -1.0725],
#           [-1.0253, -1.0887, -0.9272]],
#
#          ...,
#
#          [[-1.1749, -0.9913, -0.9484],
#           [-1.0240, -0.9842, -0.8380],
#           [-1.0253, -1.0810, -0.9815]],
#
#          [[-1.1657, -0.8352, -1.0563],
#           [-0.9352, -0.9121, -0.7841],
#           [-0.9321, -0.9799, -1.2232]],
#
#          [[-0.9903, -0.9979, -0.7667],
#           [-0.9605, -0.9644, -0.9224],
#           [-1.0615, -0.8464, -1.0361]]],
#
#
#         [[[-0.8903, -0.9222, -1.1334],
#           [-1.0252, -0.9719, -0.8173],
#           [-1.1126, -0.8605, -0.9694]],
#
#          [[-0.9699, -0.9838, -1.0640],
#           [-1.0128, -1.1508, -1.0658],
#           [-0.9325, -0.9573, -0.9854]],
#
#          [[-0.9291, -1.1599, -0.9950],
#           [-1.0006, -1.1032, -0.9286],
#           [-1.0994, -1.0395, -0.9877]],
#
#          ...,
#
#          [[-1.0449, -0.9910, -1.2420],
#           [-1.0116, -1.0210, -0.8712],
#           [-0.8358, -1.0182, -1.1038]],
#
#          [[-1.1920, -0.9770, -0.8680],
#           [-0.9917, -1.0666, -1.1541],
#           [-1.0818, -0.8845, -1.0497]],
#
#          [[-1.0878, -0.8533, -0.9896],
#           [-1.0003, -1.0923, -1.0750],
#           [-1.0271, -1.1010, -1.0434]]],
#
#
#         [[[-1.0132, -1.0314, -0.9889],
#           [-0.9732, -1.2544, -1.0778],
#           [-0.8806, -0.9602, -0.9025]],
#
#          [[-0.9192, -0.9840, -1.0602],
#           [-0.9557, -0.9623, -0.9360],
#           [-1.0982, -1.0877, -0.9617]],
#
#          [[-0.8807, -0.9615, -1.0392],
#           [-0.9591, -1.0896, -1.1224],
#           [-1.0089, -0.8199, -0.9197]],
#
#          ...,
#
#          [[-1.0929, -0.9606, -0.8476],
#           [-0.9841, -0.9361, -0.8911],
#           [-1.0218, -0.9847, -0.9480]],
#
#          [[-0.8875, -0.9023, -1.1358],
#           [-1.2848, -0.8432, -0.8576],
#           [-0.9141, -1.0541, -0.9914]],
#
#          [[-0.8563, -0.9594, -1.1225],
#           [-0.9894, -1.1331, -0.9996],
#           [-0.9281, -0.9338, -1.0955]]]], device='cuda:0')
# Layer: conv_layers.2.bias, Biases: tensor([-5.4298e-02,  2.1162e-02,  3.3046e-02,  1.3889e-02,  5.0343e-02,
#          6.6919e-03, -1.4754e-02, -1.1502e-02, -8.6278e-03, -2.3893e-02,
#         -4.3342e-02,  4.4835e-02, -5.2028e-02, -3.7404e-02, -1.1571e-02,
#         -1.4272e-02, -2.9049e-02, -5.3087e-02, -5.1089e-02,  5.3132e-03,
#          2.0574e-03,  4.8447e-02, -5.0759e-02,  1.7222e-02, -6.1240e-03,
#         -1.4131e-02,  3.0203e-02, -8.1237e-03,  5.8451e-05,  5.5154e-02,
#          3.4970e-02, -1.0003e-02], device='cuda:0')
# Layer: conv_layers.5.weight:, Weights: tensor([[[[-1.0409, -0.9394, -0.9814],
#           [-1.1303, -1.0531, -1.0144],
#           [-1.0360, -1.1413, -1.0076]],
#
#          [[-1.0894, -1.0249, -0.9736],
#           [-0.9028, -0.9493, -1.0655],
#           [-0.8383, -1.0011, -0.9945]],
#
#          [[-0.9699, -0.9367, -0.8086],
#           [-1.2300, -0.9916, -1.0533],
#           [-1.0855, -0.9662, -1.1474]],
#
#          ...,
#
#          [[-1.0815, -1.0294, -1.0362],
#           [-1.0979, -1.0123, -1.0230],
#           [-0.9472, -0.8588, -0.8061]],
#
#          [[-0.8148, -0.8470, -1.0543],
#           [-0.9217, -0.8875, -0.9232],
#           [-1.0242, -1.1549, -1.0517]],
#
#          [[-0.9443, -1.0332, -0.8840],
#           [-0.7252, -1.0779, -1.1243],
#           [-0.9899, -1.0200, -0.8822]]],
#
#
#         [[[-1.1510, -1.0752, -0.9192],
#           [-0.9773, -0.8941, -0.9794],
#           [-0.9213, -1.0087, -0.9443]],
#
#          [[-1.0289, -1.1091, -1.1363],
#           [-0.7266, -1.0499, -1.0504],
#           [-0.9646, -0.9636, -0.9954]],
#
#          [[-0.9573, -1.0288, -1.1115],
#           [-0.9916, -1.0202, -0.9266],
#           [-0.8710, -0.9850, -0.8023]],
#
#          ...,
#
#          [[-1.0254, -1.0899, -1.0661],
#           [-1.0707, -0.9092, -1.0725],
#           [-1.0463, -1.0252, -1.0916]],
#
#          [[-1.1961, -0.8637, -1.0707],
#           [-0.9917, -0.9810, -0.8922],
#           [-1.0639, -1.0972, -1.0173]],
#
#          [[-0.9060, -0.9792, -1.0415],
#           [-0.9833, -0.9608, -0.8908],
#           [-1.0502, -0.9293, -0.8619]]],
#
#
#         [[[-1.0754, -0.9085, -1.0120],
#           [-1.0806, -1.0143, -0.9765],
#           [-0.9362, -1.0337, -1.1415]],
#
#          [[-0.9699, -1.2029, -0.9469],
#           [-1.0920, -1.1668, -1.0285],
#           [-0.9955, -0.9778, -1.0201]],
#
#          [[-0.8688, -0.9819, -0.9362],
#           [-0.8221, -0.8711, -0.9934],
#           [-1.0119, -0.9964, -1.0602]],
#
#          ...,
#
#          [[-1.0025, -1.1596, -1.0242],
#           [-1.0993, -0.8383, -0.9774],
#           [-0.9549, -0.8290, -0.8595]],
#
#          [[-1.0806, -1.0284, -0.9831],
#           [-0.9641, -1.0734, -1.1188],
#           [-1.1870, -1.0873, -0.9527]],
#
#          [[-1.1229, -1.1120, -1.0822],
#           [-1.1036, -1.0226, -0.9972],
#           [-0.9524, -1.0025, -1.0005]]],
#
#
#         ...,
#
#
#         [[[-0.9045, -0.9565, -0.9680],
#           [-1.1192, -1.0145, -0.8529],
#           [-1.0060, -0.8841, -1.1252]],
#
#          [[-1.0125, -1.0055, -1.0330],
#           [-0.9191, -1.0206, -0.9520],
#           [-0.8017, -1.0264, -0.9186]],
#
#          [[-1.0222, -0.9322, -0.9304],
#           [-1.1367, -1.1619, -1.0244],
#           [-0.8253, -1.0179, -1.0158]],
#
#          ...,
#
#          [[-1.1542, -1.0384, -1.0926],
#           [-0.9885, -1.0549, -0.8958],
#           [-1.0104, -0.8992, -0.8794]],
#
#          [[-0.8301, -1.0574, -0.9776],
#           [-0.8754, -0.9942, -0.8591],
#           [-0.9605, -0.9351, -0.9189]],
#
#          [[-1.0797, -1.1512, -0.9610],
#           [-0.8986, -0.9875, -0.9458],
#           [-0.9460, -0.9274, -1.0429]]],
#
#
#         [[[-1.0140, -1.0154, -1.0422],
#           [-0.9423, -0.9415, -0.8766],
#           [-0.8831, -0.9563, -0.9418]],
#
#          [[-0.9295, -0.7203, -0.9426],
#           [-0.8859, -0.9806, -1.0088],
#           [-0.8692, -1.0317, -1.0398]],
#
#          [[-0.8996, -0.8685, -0.9774],
#           [-1.0213, -0.9415, -1.0353],
#           [-0.9363, -0.8487, -1.0008]],
#
#          ...,
#
#          [[-1.0072, -0.9373, -0.9713],
#           [-1.1254, -1.1113, -1.2150],
#           [-0.9275, -0.9503, -0.8517]],
#
#          [[-1.1589, -0.9827, -1.0341],
#           [-0.9566, -1.0041, -0.9158],
#           [-0.9455, -0.9649, -0.8735]],
#
#          [[-1.0023, -1.0987, -0.8833],
#           [-1.0035, -0.8943, -1.0092],
#           [-1.1439, -0.9432, -0.9936]]],
#
#
#         [[[-1.0038, -1.0506, -1.0170],
#           [-0.9996, -1.0098, -1.1487],
#           [-1.0116, -0.8800, -0.9626]],
#
#          [[-0.8648, -1.0075, -1.0832],
#           [-0.8696, -0.8171, -0.8960],
#           [-0.8936, -1.0380, -0.9694]],
#
#          [[-1.0825, -0.8791, -1.0875],
#           [-0.9899, -1.0949, -1.0743],
#           [-0.9592, -1.0073, -0.7969]],
#
#          ...,
#
#          [[-1.1016, -1.0608, -1.1767],
#           [-0.9250, -0.9908, -1.0188],
#           [-0.8893, -1.0456, -0.9021]],
#
#          [[-0.9925, -1.0611, -0.7243],
#           [-1.0692, -1.0177, -1.0194],
#           [-0.9672, -0.9041, -0.9937]],
#
#          [[-1.1267, -1.1069, -0.9612],
#           [-0.9538, -1.1536, -0.9461],
#           [-1.0423, -0.9372, -0.9366]]]], device='cuda:0')
# Layer: conv_layers.5.bias, Biases: tensor([-0.0300,  0.0305, -0.0500,  0.0130,  0.0219,  0.0513,  0.0253,  0.0176,
#         -0.0371, -0.0044,  0.0268,  0.0377,  0.0031,  0.0344,  0.0342,  0.0196,
#          0.0100,  0.0543,  0.0175, -0.0032,  0.0226,  0.0123,  0.0302,  0.0546,
#         -0.0143, -0.0246,  0.0507,  0.0509,  0.0164,  0.0046, -0.0556, -0.0585,
#          0.0139, -0.0243,  0.0145,  0.0364,  0.0049, -0.0075, -0.0156, -0.0579,
#          0.0029,  0.0373, -0.0273,  0.0489,  0.0025,  0.0524,  0.0421, -0.0105,
#         -0.0247, -0.0316,  0.0417,  0.0278, -0.0461,  0.0204,  0.0084,  0.0207,
#         -0.0359, -0.0024,  0.0545,  0.0335, -0.0321, -0.0006, -0.0128, -0.0057],
#        device='cuda:0')
# Layer: conv_layers.7.weight:, Weights: tensor([[[[-1.1379, -0.9344, -0.9430],
#           [-0.8956, -1.0249, -1.0726],
#           [-1.0866, -0.9583, -0.8894]],
#
#          [[-1.1434, -0.9700, -0.9599],
#           [-0.9251, -0.8621, -1.1207],
#           [-0.9742, -0.9462, -0.9300]],
#
#          [[-0.8896, -1.0911, -1.0162],
#           [-1.0254, -1.1823, -0.9510],
#           [-0.8473, -0.9436, -1.0276]],
#
#          ...,
#
#          [[-0.8552, -1.0917, -0.9248],
#           [-1.0876, -1.0252, -1.1447],
#           [-0.9286, -1.1739, -0.7897]],
#
#          [[-1.0571, -1.0777, -1.1825],
#           [-0.9966, -0.9736, -1.1552],
#           [-1.0593, -1.1020, -1.2339]],
#
#          [[-1.1661, -1.1238, -0.9765],
#           [-0.9254, -1.0833, -0.9207],
#           [-1.0143, -0.8680, -1.0535]]],
#
#
#         [[[-0.9485, -1.0503, -1.0210],
#           [-1.0062, -0.9756, -0.9054],
#           [-0.8487, -1.1575, -0.8831]],
#
#          [[-1.0706, -0.9441, -0.8304],
#           [-1.0193, -1.0490, -0.9605],
#           [-0.9906, -0.7764, -1.2141]],
#
#          [[-0.9276, -1.1592, -0.9630],
#           [-0.9706, -0.8732, -0.9823],
#           [-0.7756, -0.7722, -1.0113]],
#
#          ...,
#
#          [[-1.0353, -1.0419, -0.8859],
#           [-1.0994, -1.1339, -1.0576],
#           [-1.0715, -0.9863, -1.0249]],
#
#          [[-0.9278, -0.9253, -0.7767],
#           [-1.0482, -0.9555, -0.8443],
#           [-0.9831, -0.9241, -0.9925]],
#
#          [[-1.0411, -0.9595, -1.0337],
#           [-0.8346, -1.0428, -0.9355],
#           [-0.9379, -0.7817, -0.9487]]],
#
#
#         [[[-0.7913, -0.8974, -0.9467],
#           [-0.8992, -0.9812, -1.0102],
#           [-1.0051, -0.7299, -0.9268]],
#
#          [[-1.0994, -1.0804, -0.9595],
#           [-1.0480, -1.0501, -0.9025],
#           [-0.9533, -0.9358, -1.2036]],
#
#          [[-0.9848, -0.9007, -1.0535],
#           [-1.1282, -0.8191, -1.0185],
#           [-1.1078, -1.1489, -1.0209]],
#
#          ...,
#
#          [[-1.1820, -1.1890, -1.0704],
#           [-0.9735, -1.0413, -1.1978],
#           [-0.8992, -0.9296, -0.9584]],
#
#          [[-0.9726, -1.0765, -0.9984],
#           [-0.9149, -0.8711, -0.9540],
#           [-0.9666, -0.9672, -1.0228]],
#
#          [[-1.0080, -1.0320, -0.9316],
#           [-0.9515, -0.9003, -0.9307],
#           [-0.9690, -0.9999, -1.0751]]],
#
#
#         ...,
#
#
#         [[[-0.8535, -0.8020, -1.1119],
#           [-0.8738, -0.8689, -1.0030],
#           [-1.1932, -1.1109, -0.8926]],
#
#          [[-1.1565, -1.0046, -0.8886],
#           [-1.0048, -0.9700, -1.0160],
#           [-1.0766, -0.9575, -0.8670]],
#
#          [[-1.0638, -1.0901, -1.0707],
#           [-1.0418, -1.0771, -0.9342],
#           [-0.8062, -1.0401, -0.9045]],
#
#          ...,
#
#          [[-0.8350, -1.1209, -0.8785],
#           [-1.1328, -1.0034, -0.9973],
#           [-0.9718, -1.0843, -0.9198]],
#
#          [[-1.0857, -1.1202, -1.0429],
#           [-1.0202, -0.9881, -1.0549],
#           [-0.8569, -1.0292, -0.9163]],
#
#          [[-1.0365, -1.0189, -0.9648],
#           [-0.9317, -1.0547, -1.1429],
#           [-0.9648, -0.9664, -1.0367]]],
#
#
#         [[[-1.0404, -1.0076, -0.8732],
#           [-1.0042, -0.9192, -0.9752],
#           [-0.8994, -0.9294, -1.0711]],
#
#          [[-1.2700, -0.9134, -1.0054],
#           [-0.8224, -0.8954, -1.1300],
#           [-1.1082, -1.0547, -1.0080]],
#
#          [[-0.9801, -1.0696, -1.0755],
#           [-1.0020, -0.8367, -0.9448],
#           [-1.0177, -1.1367, -0.8699]],
#
#          ...,
#
#          [[-1.2265, -0.9897, -0.8961],
#           [-1.0013, -0.9899, -1.1513],
#           [-1.1037, -0.9165, -0.8580]],
#
#          [[-1.1138, -0.9016, -1.0326],
#           [-1.0796, -0.8570, -1.0359],
#           [-1.0160, -1.0631, -1.1500]],
#
#          [[-0.9356, -1.0747, -1.0582],
#           [-1.1124, -0.9227, -0.9542],
#           [-1.0169, -1.0683, -1.1558]]],
#
#
#         [[[-0.9349, -1.0036, -1.0802],
#           [-0.9526, -0.9263, -0.8876],
#           [-0.7498, -0.9584, -0.9795]],
#
#          [[-0.9303, -0.7905, -0.9723],
#           [-1.0241, -1.1099, -0.8920],
#           [-0.9513, -0.9472, -0.8974]],
#
#          [[-0.9223, -1.1841, -1.1371],
#           [-1.1596, -0.9855, -0.9835],
#           [-1.0003, -0.9168, -0.9474]],
#
#          ...,
#
#          [[-0.9951, -0.9680, -1.0466],
#           [-0.9778, -0.9970, -0.9001],
#           [-0.9781, -1.0258, -1.0480]],
#
#          [[-1.0144, -0.8360, -0.9712],
#           [-0.9310, -1.0824, -0.8503],
#           [-0.9305, -0.8515, -1.0503]],
#
#          [[-1.0364, -0.9735, -1.1103],
#           [-0.9962, -1.1080, -0.9072],
#           [-0.9895, -0.7040, -0.9766]]]], device='cuda:0')
# Layer: conv_layers.7.bias, Biases: tensor([ 0.0302,  0.0127,  0.0383,  0.0255,  0.0150,  0.0186, -0.0257, -0.0348,
#         -0.0341, -0.0103, -0.0215,  0.0277, -0.0066, -0.0371,  0.0282, -0.0378,
#         -0.0027,  0.0249, -0.0359,  0.0121, -0.0174, -0.0177, -0.0249,  0.0218,
#         -0.0123, -0.0225,  0.0072,  0.0254, -0.0095,  0.0212,  0.0049,  0.0095,
#          0.0164, -0.0188,  0.0260,  0.0211, -0.0133, -0.0001, -0.0333,  0.0288,
#          0.0398,  0.0233,  0.0242, -0.0181,  0.0114, -0.0039, -0.0002,  0.0093,
#          0.0061, -0.0083,  0.0416, -0.0328,  0.0296,  0.0231,  0.0079, -0.0298,
#         -0.0064, -0.0070,  0.0256,  0.0333,  0.0373, -0.0398, -0.0368,  0.0108],
#        device='cuda:0')
# Layer: conv_layers.10.weight:, Weights: tensor([[[[-0.9346, -0.9117, -0.9532],
#           [-1.1497, -0.9555, -0.9279],
#           [-0.8560, -0.9137, -0.9816]],
#
#          [[-1.0691, -0.7397, -1.0444],
#           [-1.1567, -1.0069, -1.0153],
#           [-0.9689, -1.1031, -0.9261]],
#
#          [[-1.0700, -0.9387, -1.0312],
#           [-0.8803, -1.1459, -1.0296],
#           [-0.9257, -0.8121, -1.0655]],
#
#          ...,
#
#          [[-0.9341, -1.0186, -1.1124],
#           [-0.8595, -0.9342, -0.9983],
#           [-0.7924, -1.0050, -0.9929]],
#
#          [[-0.9447, -1.1126, -0.8318],
#           [-0.9259, -0.8572, -0.8619],
#           [-1.0654, -1.0684, -0.9638]],
#
#          [[-1.1844, -0.9559, -1.1321],
#           [-1.0163, -0.9505, -1.0167],
#           [-0.8932, -1.0110, -1.0069]]],
#
#
#         [[[-1.1251, -0.9166, -1.0215],
#           [-1.0006, -0.8219, -0.9866],
#           [-1.0366, -0.9979, -1.0996]],
#
#          [[-0.9436, -0.9821, -1.0582],
#           [-0.9812, -1.0390, -1.1024],
#           [-0.9669, -1.0173, -0.9802]],
#
#          [[-1.0532, -0.9485, -0.9385],
#           [-1.0260, -1.0363, -1.1297],
#           [-1.0568, -0.9621, -1.0504]],
#
#          ...,
#
#          [[-1.0362, -1.0212, -1.0525],
#           [-0.9023, -0.9481, -1.0965],
#           [-0.8986, -1.0454, -0.8888]],
#
#          [[-0.9027, -0.9196, -0.9792],
#           [-0.9891, -1.0494, -1.0980],
#           [-0.9469, -1.1156, -0.9829]],
#
#          [[-1.0381, -1.1716, -1.1049],
#           [-0.9857, -0.9885, -0.9775],
#           [-0.8309, -0.8534, -0.9700]]],
#
#
#         [[[-0.9837, -0.9047, -1.1039],
#           [-1.1157, -0.9037, -0.7878],
#           [-0.9556, -0.8987, -0.9729]],
#
#          [[-0.9560, -1.0970, -1.0145],
#           [-1.0048, -1.1026, -1.1195],
#           [-0.9163, -0.9362, -1.0622]],
#
#          [[-0.9666, -0.9148, -0.9635],
#           [-1.0155, -1.1314, -0.9812],
#           [-0.8836, -1.0300, -1.0603]],
#
#          ...,
#
#          [[-1.1800, -0.9591, -0.8604],
#           [-1.0993, -0.9256, -1.0415],
#           [-0.9058, -1.0590, -1.0436]],
#
#          [[-1.0088, -0.9246, -0.9926],
#           [-1.1300, -1.0297, -1.1960],
#           [-1.0146, -0.8691, -1.0831]],
#
#          [[-0.8632, -0.8472, -1.2696],
#           [-0.9353, -0.9276, -0.8532],
#           [-0.8028, -0.7919, -1.0763]]],
#
#
#         ...,
#
#
#         [[[-0.8397, -1.2580, -1.0282],
#           [-1.0640, -1.1494, -0.9779],
#           [-1.0211, -0.9043, -0.8793]],
#
#          [[-0.9258, -0.9153, -0.9413],
#           [-1.0106, -1.0999, -1.0587],
#           [-1.0151, -0.9678, -1.1141]],
#
#          [[-1.1162, -1.0012, -0.8937],
#           [-0.9804, -0.9628, -1.0787],
#           [-1.0248, -0.9348, -1.1028]],
#
#          ...,
#
#          [[-0.9224, -1.1050, -0.9657],
#           [-0.9939, -0.7887, -1.0340],
#           [-1.0793, -0.8551, -0.9499]],
#
#          [[-0.8409, -1.0868, -0.8801],
#           [-1.0461, -1.1122, -1.2065],
#           [-1.0455, -0.9329, -1.0100]],
#
#          [[-1.0539, -0.9118, -1.0603],
#           [-0.9654, -1.0778, -0.9216],
#           [-1.0232, -1.0094, -0.9684]]],
#
#
#         [[[-1.2619, -1.0716, -0.9612],
#           [-0.8554, -0.9529, -1.0793],
#           [-0.7255, -0.9723, -1.1777]],
#
#          [[-0.7983, -1.0300, -0.8064],
#           [-0.9629, -1.1566, -1.0779],
#           [-1.0068, -1.1028, -0.9301]],
#
#          [[-1.0253, -1.0598, -0.8822],
#           [-0.9578, -0.7546, -0.9992],
#           [-1.0129, -0.9998, -1.1227]],
#
#          ...,
#
#          [[-1.0065, -1.0587, -1.0922],
#           [-1.2300, -0.9813, -1.0031],
#           [-0.8349, -1.0018, -0.7796]],
#
#          [[-0.9461, -1.0457, -0.9023],
#           [-0.8878, -1.0456, -1.0417],
#           [-1.0248, -0.9694, -0.9771]],
#
#          [[-0.9853, -1.1536, -0.9617],
#           [-0.8849, -0.9766, -1.0398],
#           [-1.0060, -0.9736, -1.0856]]],
#
#
#         [[[-1.2586, -1.0047, -1.0733],
#           [-0.9875, -1.0647, -1.0820],
#           [-1.1570, -1.0000, -0.8459]],
#
#          [[-1.0791, -0.9438, -1.0518],
#           [-1.1887, -0.9916, -0.9832],
#           [-1.1054, -1.1171, -0.8546]],
#
#          [[-1.0348, -0.9393, -1.1195],
#           [-0.8644, -1.0117, -0.9862],
#           [-0.8712, -0.9420, -1.0217]],
#
#          ...,
#
#          [[-0.8778, -1.0413, -1.0724],
#           [-0.9683, -1.1697, -1.0148],
#           [-0.8783, -1.0153, -0.9278]],
#
#          [[-0.9092, -1.0775, -0.9118],
#           [-0.8247, -0.9600, -0.8823],
#           [-1.1431, -0.9904, -1.1059]],
#
#          [[-0.8271, -1.0701, -0.8525],
#           [-1.0444, -1.0358, -1.0047],
#           [-0.8648, -0.9663, -1.0502]]]], device='cuda:0')
# Layer: conv_layers.10.bias, Biases: tensor([-0.0168,  0.0088, -0.0276, -0.0097, -0.0270, -0.0403,  0.0064,  0.0313,
#         -0.0335, -0.0080,  0.0373,  0.0218,  0.0382, -0.0354, -0.0360, -0.0012,
#          0.0167,  0.0368,  0.0137, -0.0183, -0.0065,  0.0396, -0.0042, -0.0224,
#          0.0146,  0.0388, -0.0096, -0.0091, -0.0414,  0.0133,  0.0014,  0.0066,
#         -0.0381,  0.0396, -0.0148, -0.0018, -0.0292, -0.0079,  0.0252, -0.0358,
#          0.0273,  0.0186, -0.0302,  0.0323,  0.0330, -0.0355, -0.0079, -0.0361,
#          0.0234, -0.0194, -0.0243, -0.0270,  0.0190, -0.0059, -0.0324, -0.0357,
#          0.0044, -0.0314, -0.0171, -0.0255, -0.0125,  0.0389, -0.0121,  0.0075,
#          0.0369,  0.0042,  0.0067, -0.0071,  0.0135,  0.0252, -0.0241, -0.0044,
#          0.0315,  0.0291,  0.0160,  0.0326, -0.0340,  0.0133, -0.0388,  0.0019,
#         -0.0292,  0.0040, -0.0033,  0.0347,  0.0100,  0.0344, -0.0019, -0.0405,
#         -0.0198, -0.0308, -0.0127,  0.0129, -0.0122, -0.0394, -0.0220,  0.0238,
#          0.0098, -0.0046,  0.0205,  0.0333,  0.0220,  0.0187, -0.0021,  0.0023,
#         -0.0080,  0.0339,  0.0270, -0.0253,  0.0143,  0.0402,  0.0388, -0.0289,
#          0.0014, -0.0348,  0.0253, -0.0414, -0.0284,  0.0283, -0.0220, -0.0346,
#         -0.0162,  0.0064,  0.0395,  0.0134,  0.0198,  0.0280, -0.0098, -0.0390],
#        device='cuda:0')
# Layer: conv_layers.12.weight:, Weights: tensor([[[[-0.8469, -0.9926, -0.9083],
#           [-1.0938, -1.1044, -1.1605],
#           [-0.9700, -0.9534, -1.0190]],
#
#          [[-0.8907, -1.0582, -1.1579],
#           [-1.0062, -1.0029, -0.8889],
#           [-0.8769, -0.8889, -1.0105]],
#
#          [[-1.0244, -1.0831, -1.0125],
#           [-1.0457, -1.0179, -1.0481],
#           [-0.8952, -1.0548, -0.9349]],
#
#          ...,
#
#          [[-1.1012, -0.9604, -0.9388],
#           [-1.1824, -0.9505, -0.8676],
#           [-1.1107, -1.0094, -0.8635]],
#
#          [[-1.1438, -1.0645, -0.8120],
#           [-1.0943, -0.9374, -0.8886],
#           [-0.8206, -0.8849, -1.3407]],
#
#          [[-0.9850, -1.0405, -0.9809],
#           [-1.0358, -0.8814, -1.0575],
#           [-1.0774, -1.0044, -1.0267]]],
#
#
#         [[[-0.9966, -0.9639, -0.8996],
#           [-0.9238, -1.0645, -0.9169],
#           [-0.7910, -1.0723, -1.0594]],
#
#          [[-0.8754, -1.0383, -0.9094],
#           [-1.1049, -1.0525, -1.0495],
#           [-0.8966, -0.9557, -1.1721]],
#
#          [[-0.8926, -1.1266, -0.9131],
#           [-1.0499, -1.0543, -0.9698],
#           [-1.0076, -1.0654, -1.0931]],
#
#          ...,
#
#          [[-1.1105, -0.8913, -0.9388],
#           [-1.0151, -0.9297, -0.9389],
#           [-1.0568, -0.8247, -0.9130]],
#
#          [[-0.9633, -1.0068, -1.0826],
#           [-1.1116, -0.8616, -1.1368],
#           [-1.0319, -1.0208, -0.9716]],
#
#          [[-1.0127, -0.9561, -1.0352],
#           [-0.9199, -1.1758, -1.0048],
#           [-0.9374, -0.8558, -1.1484]]],
#
#
#         [[[-0.9328, -0.8339, -0.9552],
#           [-1.0557, -0.9895, -0.9722],
#           [-0.9387, -0.9777, -0.8863]],
#
#          [[-0.8567, -1.0685, -1.0542],
#           [-0.9745, -1.1572, -1.0321],
#           [-0.9238, -0.9245, -1.0459]],
#
#          [[-1.0732, -1.1463, -1.0783],
#           [-1.1290, -0.9232, -1.0682],
#           [-1.1988, -1.1683, -1.0021]],
#
#          ...,
#
#          [[-0.9427, -0.9111, -1.1535],
#           [-1.0172, -0.9412, -0.9081],
#           [-0.8860, -1.1248, -1.0673]],
#
#          [[-0.9909, -0.9685, -0.8813],
#           [-0.7985, -0.9361, -0.9180],
#           [-0.9597, -1.1646, -0.9414]],
#
#          [[-1.0000, -0.9616, -1.0009],
#           [-0.9393, -1.1898, -1.0133],
#           [-1.1335, -1.1244, -1.1051]]],
#
#
#         ...,
#
#
#         [[[-1.1308, -0.8931, -0.9171],
#           [-0.9301, -0.9445, -1.0458],
#           [-1.1982, -0.9959, -1.1099]],
#
#          [[-0.9687, -1.0263, -0.8570],
#           [-1.1594, -1.0979, -0.9102],
#           [-1.1819, -1.0318, -1.0275]],
#
#          [[-1.0695, -1.0562, -1.0933],
#           [-1.0129, -1.1736, -0.7721],
#           [-0.9960, -1.0896, -1.0147]],
#
#          ...,
#
#          [[-0.9503, -0.9843, -0.7685],
#           [-1.1172, -0.9742, -0.9161],
#           [-1.0944, -1.0115, -0.9482]],
#
#          [[-0.9122, -1.0063, -0.9020],
#           [-1.0517, -1.0336, -1.0990],
#           [-0.8894, -0.9901, -0.8795]],
#
#          [[-1.1933, -0.9566, -1.1298],
#           [-0.9547, -1.0953, -1.0740],
#           [-1.0307, -0.8888, -1.1723]]],
#
#
#         [[[-0.8600, -1.0743, -0.9037],
#           [-0.9959, -1.0707, -0.9913],
#           [-1.0206, -1.0272, -1.0053]],
#
#          [[-1.1138, -0.8962, -0.7756],
#           [-0.9510, -0.9626, -1.0246],
#           [-1.0055, -0.9136, -0.9274]],
#
#          [[-1.2268, -0.9587, -0.8947],
#           [-0.9526, -1.0712, -1.0374],
#           [-1.0815, -0.9314, -1.0019]],
#
#          ...,
#
#          [[-1.0688, -0.9873, -1.0113],
#           [-1.0271, -0.9247, -1.1064],
#           [-0.8490, -1.0236, -1.0805]],
#
#          [[-0.9842, -0.8453, -0.9435],
#           [-1.0606, -0.9764, -1.1525],
#           [-0.9614, -1.0725, -0.9213]],
#
#          [[-1.0516, -1.0694, -0.9798],
#           [-1.1508, -0.8802, -1.0459],
#           [-1.1182, -1.0075, -0.9213]]],
#
#
#         [[[-0.9625, -1.0252, -0.8792],
#           [-0.8372, -0.9683, -0.9149],
#           [-1.0221, -0.9361, -0.9320]],
#
#          [[-1.0851, -1.0697, -1.0842],
#           [-1.0386, -0.9366, -0.9779],
#           [-0.9080, -1.0602, -0.9733]],
#
#          [[-1.1335, -1.0588, -1.2095],
#           [-1.0137, -0.9733, -1.0024],
#           [-0.9254, -0.9454, -0.9438]],
#
#          ...,
#
#          [[-0.9188, -0.8827, -0.9337],
#           [-1.0594, -1.0319, -0.9367],
#           [-0.9945, -1.0288, -0.9325]],
#
#          [[-0.9196, -0.9296, -0.9862],
#           [-0.9282, -1.0662, -1.0481],
#           [-0.9861, -1.0224, -1.0346]],
#
#          [[-1.0628, -0.9657, -1.0158],
#           [-0.9588, -1.0736, -1.2192],
#           [-0.9236, -0.9385, -0.9048]]]], device='cuda:0')
# Layer: conv_layers.12.bias, Biases: tensor([ 0.0168, -0.0255,  0.0258,  0.0123, -0.0192,  0.0193,  0.0087,  0.0291,
#          0.0236, -0.0222, -0.0222,  0.0248, -0.0018, -0.0146,  0.0209,  0.0190,
#          0.0104,  0.0163,  0.0180, -0.0222, -0.0189, -0.0281,  0.0106,  0.0017,
#          0.0184,  0.0155, -0.0145,  0.0007,  0.0053,  0.0039,  0.0090, -0.0235,
#          0.0083, -0.0129, -0.0159, -0.0242,  0.0010, -0.0218, -0.0142,  0.0141,
#         -0.0283,  0.0220, -0.0220,  0.0142,  0.0023, -0.0172, -0.0010, -0.0231,
#         -0.0019,  0.0009,  0.0218, -0.0220, -0.0291,  0.0114,  0.0086, -0.0285,
#         -0.0061, -0.0290,  0.0100,  0.0049, -0.0196, -0.0144,  0.0229,  0.0044,
#          0.0129, -0.0004, -0.0257,  0.0288, -0.0082,  0.0196,  0.0293,  0.0072,
#         -0.0080,  0.0020, -0.0053, -0.0167, -0.0287, -0.0190, -0.0155,  0.0023,
#         -0.0057, -0.0219, -0.0225, -0.0191, -0.0240,  0.0103, -0.0106, -0.0192,
#          0.0175, -0.0290, -0.0172,  0.0011, -0.0166, -0.0130, -0.0161, -0.0120,
#         -0.0003, -0.0239, -0.0123,  0.0008, -0.0177,  0.0263, -0.0095, -0.0174,
#          0.0294, -0.0079, -0.0071,  0.0237,  0.0049,  0.0123, -0.0202,  0.0083,
#         -0.0149,  0.0146,  0.0135, -0.0229, -0.0216, -0.0254,  0.0002,  0.0256,
#         -0.0156,  0.0148,  0.0038, -0.0115,  0.0001, -0.0227,  0.0227,  0.0283],
#        device='cuda:0')
# Layer: conv_layers.14.weight:, Weights: tensor([[[[-0.9623, -0.9824, -0.8824],
#           [-1.0052, -0.9851, -0.8572],
#           [-1.1510, -0.9585, -1.0409]],
#
#          [[-1.0545, -0.9592, -1.0654],
#           [-1.1552, -0.9347, -0.9447],
#           [-0.8527, -0.9317, -0.8487]],
#
#          [[-0.9869, -0.9490, -1.1714],
#           [-0.9798, -1.0928, -1.0821],
#           [-0.9753, -0.9015, -0.8837]],
#
#          ...,
#
#          [[-0.7457, -1.0629, -0.9967],
#           [-0.9667, -1.0369, -1.3488],
#           [-1.0070, -1.0351, -1.0624]],
#
#          [[-1.0628, -0.9706, -1.0637],
#           [-1.0679, -1.0179, -1.0282],
#           [-1.0185, -0.8293, -0.9609]],
#
#          [[-1.0220, -1.0021, -1.1665],
#           [-0.9289, -0.9188, -0.9235],
#           [-0.7899, -0.8250, -1.1588]]],
#
#
#         [[[-1.0260, -1.0747, -1.0183],
#           [-0.9373, -0.9036, -1.1508],
#           [-1.1104, -1.0128, -0.8661]],
#
#          [[-1.1667, -0.9690, -0.8844],
#           [-0.9712, -1.2132, -1.0893],
#           [-0.9839, -1.1373, -0.9874]],
#
#          [[-0.9848, -1.1474, -0.8196],
#           [-0.7992, -1.1113, -0.9546],
#           [-0.9926, -0.9497, -1.0183]],
#
#          ...,
#
#          [[-1.0197, -1.0599, -0.9833],
#           [-1.1350, -0.9026, -0.9748],
#           [-0.7780, -1.0532, -0.7513]],
#
#          [[-1.0418, -1.1207, -0.9221],
#           [-0.9972, -0.9880, -1.0337],
#           [-1.0011, -0.9038, -0.9622]],
#
#          [[-1.0408, -0.8354, -0.9700],
#           [-1.0322, -1.1326, -1.0352],
#           [-0.8625, -0.9847, -0.9103]]],
#
#
#         [[[-0.7939, -1.0558, -1.1318],
#           [-1.0789, -0.9178, -0.9349],
#           [-0.9227, -0.9407, -1.0265]],
#
#          [[-0.8949, -1.1578, -0.8805],
#           [-0.8875, -0.8800, -1.0951],
#           [-1.0461, -0.8648, -1.0691]],
#
#          [[-0.8639, -0.8767, -1.0861],
#           [-1.0916, -0.9538, -0.8231],
#           [-1.0525, -1.1962, -0.9594]],
#
#          ...,
#
#          [[-0.8772, -0.8657, -0.9855],
#           [-0.9059, -1.2034, -1.1035],
#           [-1.1256, -0.7993, -1.0130]],
#
#          [[-0.9498, -0.8927, -1.0929],
#           [-1.0716, -0.9422, -0.8525],
#           [-0.8768, -1.1322, -0.9142]],
#
#          [[-0.9870, -0.9571, -0.9723],
#           [-1.0315, -1.0990, -0.9492],
#           [-0.9755, -0.9827, -1.2031]]],
#
#
#         ...,
#
#
#         [[[-1.0764, -1.0116, -1.2045],
#           [-1.1414, -0.9999, -0.9935],
#           [-0.9762, -1.0240, -0.8901]],
#
#          [[-0.9926, -0.8603, -0.9957],
#           [-0.9610, -1.0464, -0.8432],
#           [-1.1135, -1.0761, -0.9526]],
#
#          [[-0.9595, -0.9400, -0.9977],
#           [-1.0207, -0.9555, -0.9570],
#           [-1.0958, -1.0278, -0.9898]],
#
#          ...,
#
#          [[-0.8454, -0.9166, -0.8514],
#           [-0.8927, -0.9517, -1.0686],
#           [-1.0827, -1.0494, -0.8853]],
#
#          [[-0.8342, -1.1824, -1.0555],
#           [-1.0210, -0.9548, -0.9472],
#           [-0.9654, -1.1391, -1.0139]],
#
#          [[-1.0303, -1.0198, -0.8475],
#           [-1.0835, -1.0710, -1.0207],
#           [-0.9513, -1.1085, -0.9200]]],
#
#
#         [[[-0.9628, -1.0046, -0.9671],
#           [-0.9510, -1.0324, -0.8512],
#           [-1.0666, -0.8951, -0.8670]],
#
#          [[-1.1293, -1.0039, -0.9757],
#           [-0.9655, -1.0046, -0.9372],
#           [-0.8465, -0.9750, -1.0469]],
#
#          [[-0.9690, -1.0484, -1.2152],
#           [-1.0869, -0.9293, -0.9591],
#           [-0.9460, -1.1629, -0.9249]],
#
#          ...,
#
#          [[-0.9333, -1.0440, -1.0207],
#           [-1.1686, -0.9768, -0.9497],
#           [-1.1565, -0.8103, -0.8336]],
#
#          [[-1.1573, -0.9631, -1.0472],
#           [-1.1002, -1.0010, -0.8725],
#           [-1.1204, -1.0897, -0.9506]],
#
#          [[-0.8937, -0.8383, -0.9275],
#           [-0.9832, -0.8346, -1.0957],
#           [-1.0912, -0.8937, -0.9211]]],
#
#
#         [[[-0.9548, -1.0751, -1.1983],
#           [-1.2338, -1.0901, -1.1424],
#           [-0.9641, -0.8796, -1.0977]],
#
#          [[-1.2535, -0.8571, -0.9611],
#           [-0.9126, -1.1436, -0.8280],
#           [-0.9431, -0.9521, -0.9127]],
#
#          [[-1.2116, -0.9876, -1.1191],
#           [-0.9808, -0.9278, -1.0081],
#           [-0.9804, -1.1201, -0.7718]],
#
#          ...,
#
#          [[-1.0170, -1.0166, -1.1902],
#           [-1.0056, -0.8467, -0.9824],
#           [-0.9487, -0.9562, -1.2073]],
#
#          [[-0.8434, -1.0070, -0.8563],
#           [-1.0737, -1.1080, -0.9515],
#           [-1.0790, -0.8303, -1.0253]],
#
#          [[-0.9949, -1.0998, -0.9297],
#           [-1.0696, -1.0212, -1.1248],
#           [-0.9036, -0.9853, -0.9438]]]], device='cuda:0')
# Layer: conv_layers.14.bias, Biases: tensor([ 0.0111,  0.0131, -0.0042,  0.0245, -0.0038,  0.0270,  0.0228, -0.0162,
#         -0.0273, -0.0052, -0.0181,  0.0111, -0.0055,  0.0265,  0.0091, -0.0174,
#         -0.0114,  0.0252, -0.0163,  0.0006,  0.0099, -0.0082,  0.0004,  0.0099,
#         -0.0145, -0.0186,  0.0153,  0.0256, -0.0284, -0.0085,  0.0105,  0.0142,
#         -0.0244, -0.0060,  0.0121, -0.0040, -0.0030,  0.0032, -0.0147,  0.0192,
#          0.0179, -0.0237, -0.0223, -0.0128,  0.0006, -0.0263,  0.0237,  0.0266,
#          0.0054,  0.0063,  0.0053,  0.0240,  0.0216, -0.0044, -0.0141,  0.0149,
#         -0.0263,  0.0145, -0.0016,  0.0253, -0.0031,  0.0126, -0.0173, -0.0158,
#          0.0136,  0.0060, -0.0219, -0.0210,  0.0238, -0.0034,  0.0040,  0.0051,
#         -0.0293,  0.0039,  0.0103, -0.0293,  0.0220, -0.0135,  0.0105,  0.0153,
#         -0.0192, -0.0209,  0.0140,  0.0257, -0.0011, -0.0046, -0.0048,  0.0161,
#         -0.0167, -0.0142,  0.0014,  0.0031,  0.0143, -0.0158, -0.0199,  0.0275,
#         -0.0188,  0.0171, -0.0229,  0.0008,  0.0167,  0.0077,  0.0275,  0.0178,
#         -0.0117, -0.0263,  0.0183,  0.0142,  0.0249,  0.0062, -0.0274, -0.0181,
#          0.0085, -0.0184, -0.0223,  0.0010,  0.0283,  0.0183, -0.0219,  0.0240,
#         -0.0091, -0.0033, -0.0121,  0.0179, -0.0283,  0.0056,  0.0202,  0.0053],
#        device='cuda:0')
# Layer: fc.0.weight:, Weights: tensor([[-1.0866, -0.9429, -1.0163,  ..., -1.0644, -0.8683, -0.9964],
#         [-1.0968, -1.0312, -0.7885,  ..., -0.9490, -1.1535, -0.7899],
#         [-0.8620, -1.0149, -1.0172,  ..., -0.9985, -1.0316, -0.8734],
#         ...,
#         [-1.0793, -0.9542, -0.9317,  ..., -1.0975, -1.0928, -1.0823],
#         [-0.9482, -1.2073, -0.8818,  ..., -1.0678, -1.0132, -1.1008],
#         [-0.9927, -1.3076, -1.0765,  ..., -1.0392, -0.9261, -0.9520]],
#        device='cuda:0')
# Layer: fc.0.bias, Biases: tensor([ 5.9642e-03,  2.0589e-02, -3.7557e-03, -7.1326e-03,  7.3435e-03,
#         -4.9253e-03,  1.2142e-02,  4.1905e-04,  8.7218e-03, -1.9633e-02,
#          3.0351e-03,  1.0849e-02,  1.9718e-03, -1.0522e-02, -2.7806e-03,
#         -1.2627e-02, -1.5149e-02, -2.5640e-03, -9.6489e-03, -1.2307e-02,
#         -2.3780e-03,  1.1390e-02,  2.0543e-02,  1.1642e-02,  1.9543e-02,
#         -2.1883e-02, -1.7272e-02,  7.7105e-04,  2.0958e-02,  4.3962e-03,
#          1.4528e-02, -2.2007e-02,  4.6767e-03,  6.0166e-04,  1.2807e-02,
#          1.4573e-02, -1.3243e-02,  5.2316e-03, -1.1907e-02,  1.1055e-03,
#          1.1068e-02, -1.9699e-02,  4.6200e-03, -1.3906e-02,  5.2212e-04,
#         -1.0118e-02,  2.0540e-02, -2.1594e-02, -1.0465e-02,  2.0548e-02,
#         -2.1512e-02,  1.4439e-02,  5.5160e-03, -1.9491e-02, -1.8219e-02,
#          1.6142e-02, -5.3133e-03,  1.5272e-04, -1.1119e-02, -7.5099e-03,
#          2.1290e-02, -1.2111e-02,  1.7312e-02,  1.6549e-02, -1.9514e-02,
#          5.0882e-03, -5.7657e-03,  2.1173e-02,  1.1667e-02,  1.1553e-02,
#          1.5585e-02,  1.7419e-02, -1.1942e-02, -1.9937e-02,  5.9814e-03,
#         -1.6218e-02, -1.9699e-02,  5.7140e-03, -1.8061e-02,  7.1333e-03,
#         -2.1701e-02,  2.0346e-02, -1.6413e-02,  5.5115e-03,  1.8230e-03,
#          6.5200e-03,  1.6280e-02,  1.6442e-02,  1.1842e-02,  6.3545e-03,
#          1.7925e-03, -1.3044e-03, -3.6085e-03, -1.4316e-02,  7.2839e-03,
#         -1.5612e-02, -1.8308e-02, -6.7557e-03, -1.1178e-02,  2.0880e-02,
#         -2.1268e-02, -1.8808e-02, -4.7705e-03, -8.8327e-03,  1.7615e-02,
#         -2.1626e-02, -1.2520e-02, -9.9179e-03,  1.9922e-02,  4.1476e-03,
#          6.4282e-03,  1.5351e-02, -2.0942e-02,  5.7727e-03, -9.9320e-03,
#          1.8385e-03,  1.8185e-02,  2.1993e-02, -6.0438e-03, -4.4368e-03,
#         -7.8937e-03, -1.3680e-02,  5.1852e-03,  2.1940e-03, -3.9196e-03,
#         -9.6038e-03, -8.0683e-03,  1.3206e-02,  1.1974e-02,  1.3558e-02,
#          2.1391e-02,  1.1588e-02,  6.6187e-03, -1.8669e-02,  1.2836e-02,
#         -1.1209e-03, -2.8447e-03, -6.6454e-03, -8.4933e-03,  6.9035e-03,
#          1.7136e-02, -6.2164e-03,  1.6569e-02,  1.9385e-02, -1.9620e-02,
#         -5.1352e-03, -1.2230e-03,  1.6730e-02,  1.3462e-03,  1.8998e-04,
#         -1.9236e-02, -1.9863e-02, -1.2443e-02, -1.8754e-02, -1.3135e-02,
#          7.1754e-03,  7.6224e-04,  5.9616e-04, -1.4216e-02,  1.2494e-02,
#          3.2766e-03,  1.3708e-02, -2.1484e-02, -1.9497e-02, -1.8367e-02,
#          1.5228e-02,  1.8522e-02, -1.1457e-02,  3.2027e-03,  5.6614e-03,
#         -8.5279e-03, -1.8345e-02,  1.4511e-02, -2.0170e-02,  1.1413e-02,
#         -1.9049e-02,  1.6348e-02, -8.4057e-03, -8.6598e-03, -1.0912e-02,
#         -1.9392e-02,  1.0640e-03,  3.3541e-03,  1.9768e-02,  1.2133e-02,
#         -1.7526e-02, -4.0345e-03,  1.7873e-02,  3.4628e-03,  1.3865e-03,
#          1.5448e-02,  3.0710e-03,  1.6454e-02,  1.7537e-03,  1.3549e-02,
#         -6.2914e-03, -1.2334e-02,  1.1603e-02,  4.3682e-04,  1.9880e-02,
#          1.9771e-04, -1.7675e-02, -1.2812e-02, -1.1443e-02, -1.5455e-02,
#          1.1584e-03, -4.4206e-03,  6.4195e-04, -1.8604e-02,  1.9637e-02,
#         -1.9816e-02,  1.5819e-02,  2.1061e-04,  1.7532e-02, -1.6986e-02,
#         -4.7353e-04,  1.1030e-03,  1.9823e-02,  1.5100e-02,  1.3306e-02,
#         -4.0981e-03, -1.9848e-02,  1.2495e-02, -1.6750e-02,  1.8423e-02,
#          1.0019e-02,  1.6698e-02, -2.1087e-02, -2.2026e-02, -1.6027e-03,
#          1.5643e-03,  9.5876e-03,  6.2190e-03,  1.9527e-02,  9.1844e-03,
#         -2.1518e-03,  1.5889e-02, -6.1244e-03, -1.9782e-02, -1.3639e-02,
#         -3.9136e-05,  1.5852e-02,  1.9687e-02, -1.3440e-02,  1.8193e-02,
#          3.7923e-03,  2.0459e-02,  1.1706e-02,  1.9021e-03, -1.1359e-03,
#         -8.3962e-04,  1.2130e-02,  6.7112e-03,  4.6386e-03,  7.9495e-03,
#         -2.2522e-03], device='cuda:0')
# Layer: fc.2.weight:, Weights: tensor([[-1.0004, -1.0765, -1.2098,  ..., -1.1386, -0.9305, -0.9771],
#         [-1.1331, -1.0848, -0.8336,  ..., -0.9277, -1.0731, -1.1420],
#         [-1.1546, -0.8967, -0.9691,  ..., -1.0852, -0.9963, -0.9273],
#         ...,
#         [-0.9830, -1.0078, -1.1250,  ..., -1.0010, -0.9975, -1.1001],
#         [-0.8425, -1.0429, -0.8339,  ..., -1.0603, -0.8300, -0.9303],
#         [-0.8394, -0.9043, -0.9874,  ..., -0.8862, -0.9236, -1.1535]],
#        device='cuda:0')
# Layer: fc.2.bias, Biases: tensor([ 0.0076,  0.0238,  0.0045, -0.0135, -0.0221,  0.0402,  0.0124, -0.0100,
#          0.0531, -0.0175,  0.0422, -0.0031, -0.0520,  0.0116,  0.0193, -0.0429,
#         -0.0122, -0.0116, -0.0497,  0.0282,  0.0490,  0.0108, -0.0594, -0.0510,
#          0.0203,  0.0115, -0.0049,  0.0072, -0.0389, -0.0389, -0.0075,  0.0527,
#         -0.0199, -0.0369, -0.0494, -0.0614, -0.0436, -0.0199, -0.0579, -0.0227,
#          0.0544,  0.0061, -0.0037,  0.0077, -0.0098, -0.0226, -0.0040,  0.0086,
#         -0.0132, -0.0468,  0.0064,  0.0167, -0.0575,  0.0361, -0.0558, -0.0328,
#         -0.0530, -0.0619, -0.0613,  0.0427, -0.0315, -0.0390,  0.0252, -0.0599,
#          0.0042,  0.0378, -0.0170,  0.0568,  0.0058, -0.0053, -0.0599, -0.0073,
#          0.0227,  0.0492,  0.0439, -0.0483, -0.0162,  0.0406,  0.0597,  0.0529,
#          0.0353, -0.0020,  0.0561, -0.0378,  0.0531, -0.0545,  0.0067, -0.0041,
#         -0.0601,  0.0079, -0.0460, -0.0512, -0.0127,  0.0186, -0.0025, -0.0528,
#          0.0114,  0.0027, -0.0059, -0.0258,  0.0606, -0.0048, -0.0027,  0.0145,
#         -0.0203,  0.0571, -0.0076,  0.0179, -0.0393, -0.0303,  0.0619, -0.0021,
#          0.0067,  0.0621, -0.0485,  0.0142,  0.0239, -0.0360, -0.0249, -0.0245,
#         -0.0242, -0.0326,  0.0612,  0.0614,  0.0074,  0.0605, -0.0176, -0.0484,
#          0.0090, -0.0090,  0.0157, -0.0086,  0.0516,  0.0171, -0.0370, -0.0605,
#         -0.0549,  0.0560,  0.0364,  0.0418,  0.0458, -0.0447, -0.0370, -0.0498,
#          0.0126, -0.0392, -0.0280, -0.0349, -0.0188, -0.0003, -0.0388, -0.0593,
#         -0.0127, -0.0194,  0.0024, -0.0060, -0.0316, -0.0508, -0.0080, -0.0440,
#         -0.0083,  0.0317,  0.0201,  0.0372, -0.0158, -0.0028, -0.0067,  0.0400,
#         -0.0400, -0.0103,  0.0351,  0.0197, -0.0222, -0.0165, -0.0619,  0.0417,
#         -0.0381, -0.0260, -0.0283,  0.0534, -0.0036, -0.0527, -0.0446, -0.0476,
#         -0.0009, -0.0424, -0.0587,  0.0511, -0.0550,  0.0614, -0.0213, -0.0224,
#          0.0029, -0.0359,  0.0214, -0.0107, -0.0532, -0.0448,  0.0593, -0.0318,
#         -0.0489,  0.0431,  0.0091, -0.0214,  0.0279,  0.0264, -0.0459,  0.0477,
#          0.0434, -0.0208, -0.0154, -0.0373, -0.0207,  0.0055, -0.0013, -0.0143,
#          0.0383,  0.0570, -0.0329, -0.0570,  0.0167,  0.0137, -0.0041, -0.0012,
#          0.0252,  0.0076,  0.0506, -0.0566, -0.0566, -0.0265, -0.0038,  0.0196,
#         -0.0289, -0.0114,  0.0350, -0.0321, -0.0549,  0.0223, -0.0598,  0.0031,
#          0.0400, -0.0314,  0.0168,  0.0508,  0.0492,  0.0531, -0.0218, -0.0486,
#         -0.0582, -0.0154, -0.0322,  0.0203,  0.0092, -0.0270,  0.0481, -0.0068],
#        device='cuda:0')
# Layer: fc.4.weight:, Weights: tensor([[-0.9142, -0.9950, -0.8998,  ..., -1.1161, -0.9649, -1.0076],
#         [-1.0998, -1.0283, -0.9968,  ..., -1.0842, -0.9407, -0.7649],
#         [-1.2123, -0.9956, -1.0914,  ..., -0.8853, -0.9380, -1.0599],
#         ...,
#         [-0.9492, -1.2064, -1.0953,  ..., -1.0302, -0.9561, -1.1879],
#         [-1.0643, -0.9448, -1.2005,  ..., -0.9149, -0.9212, -1.0956],
#         [-1.0574, -1.0792, -0.8706,  ..., -1.1470, -0.8534, -0.9416]],
#        device='cuda:0')
# Layer: fc.4.bias, Biases: tensor([-0.0491,  0.0563, -0.0452, -0.0550, -0.0351,  0.0573,  0.0397, -0.0306,
#          0.0254, -0.0594], device='cuda:0')

# %% [markdown]
# ## Test Dummy Input

# %%
dummy_input = torch.randn(1, 3, 32, 32).to(device)
model(dummy_input)
# Out:
# tensor([[0.3784, 0.5655, 0.4087, 0.3522, 0.4480, 0.4991, 0.5006, 0.3983, 0.4785,
#          0.3713]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Training and Execution

# %% [markdown]
# ## Setup loss, accuracy, and paramaters

# %% [markdown]
# ## Mathematical Definition of Categorical Cross-Entropy
#
# Categorical Cross-Entropy (CCE) is the standard loss function for multi-class classification. It measures the difference between two probability distributions: the actual ground-truth labels (usually one-hot encoded) and the model's predicted probabilities.
#
# For a single sample, the loss is defined as:
#
# $$f(y_i, \hat{y}_i) = -\sum_{i=1}^{C} y_i \log(\hat{y}_i)$$
#
# When calculating the average loss over a batch of $N$ samples, the formula expands to:
#
# $$f(y_i, \hat{y}_i) = -\frac{1}{N} \sum_{j=1}^{N} \sum_{i=1}^{C} y_{j,i} \log(\hat{y}_{j,i})$$
#
# **Where:**
# * $C$ = Total number of classes
# * $N$ = Total number of samples in the batch
# * $y_i$ (or $y_{j,i}$) = The true label (1 if the sample belongs to class $i$, and 0 for all other classes)
# * $\hat{y}_i$ (or $\hat{y}_{j,i}$) = The model's predicted probability that the sample belongs to class $i$ (typically the output of a Softmax activation function)
#
# > **Note:** Because the true labels $y_i$ are zero for all incorrect classes in one-hot encoding, the formula effectively simplifies to taking the negative log of the predicted probability for the **true** class.

# %%
#Setup Loss Functions, Accuracy function
loss_fn = torch.nn.CrossEntropyLoss(label_smoothing=0.1)

#Define Accuracy Metric
def calculate_accuracy(y_true, y_pred):
  correct = torch.eq(y_true, y_pred).sum().item()
  accuracy = (correct / len(y_pred)) * 100
  return accuracy

##Training Parameters

num_of_epochs = 100
num_loss_steps = 5

# %% [markdown]
# ### Gradient Norm
#
# **Mathematical Definition**: The $\ell^2$ Norm of the Gradient. In real analysis, the small $\ell^2$ norm (standard Euclidean norm) measures the magnitude of a finite-dimensional vector in $\mathbb{R}^n$.Let $\mathbf{w} \in \mathbb{R}^n$ represent the flattened continuous vector of all trainable parameters within the neural network architecture. The gradient of the objective loss function $\mathcal{L}$ with respect to these parameters is a discrete vector composed of partial derivatives:
# $$\nabla_{\mathbf{w}} \mathcal{L} = \left[ \frac{\partial \mathcal{L}}{\partial w_1}, \frac{\partial \mathcal{L}}{\partial w_2}, \dots, \frac{\partial \mathcal{L}}{\partial w_n} \right]^T$$
#
# The $\ell^2$ norm of this gradient vector, denoted as $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_{\ell^2}$ or simply $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2$, is defined as the square root of the sum of its squared coordinate components:$$\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2 = \sqrt{ \sum_{i=1}^{n} \left( \frac{\partial \mathcal{L}}{\partial w_i} \right)^2 }$$In the context of empirical risk minimization, bounding this sequence of finite sums guarantees that gradient updates remain stable and prevents the parameter vector from diverging during optimization.
#
#
# **IMPORTANT NOTE**
#
# In real and functional analysis, the capital $L^p$ spaces denote spaces of measurable functions, where the norm is evaluated via continuous integration, such as $\Vert{}f\Vert{}_{L^2} = \left( \int \vert{}f(x)\vert{}^2 dx \right)^{1/2}$. The lowercase $\ell^p$ spaces apply to discrete sequences or finite-dimensional coordinate vectors, where the norm is evaluated via discrete summation. Since the gradient of a neural network's loss with respect to its parameters, $\nabla_{\mathbf{w}} \mathcal{L}$, is a finite-dimensional vector of discrete scalar derivatives rather than a continuous mathematical function, finding its magnitude requires summing the squares of its individual components. You are completely correct: we use the small $\ell^2$ norm precisely because we are operating on discrete Euclidean vectors, not continuous functions.

# %% [markdown]
# ## Execution and Saving

# %%
torch.manual_seed(143)
activation_dict = {
    #"PGELU": PGELU,
    "MP_GELU":  partial(MPGELU, s_param=0.5, use_softplus=True),
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}

all_results = {}

for act_name, act_fn in activation_dict.items():
    print(f"\n=======================================================")
    print(f"       TRAINING WITH ACTIVATION: {act_name}")
    print(f"=======================================================")

    model = MyCNN(input_shape=3, output_shape=10, activation=act_fn, params=chosen_model_params).to(device)
    model.apply(init_custom_weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)

    trainer = Trainer(model=model, loss_fn=loss_fn, optimizer=optimizer,
                      calculate_accuracy=calculate_accuracy, device=device, loss_steps=num_loss_steps)

    results = {
        "train_loss": [],
        "train_accu": [],
        "test_loss": [],
        "test_accu": [],
        "activation_params": {},
        "grad_norm": []  # Initialize an empty list to store gradient norms
    }

    start_time = time.perf_counter()

    for epoch in tqdm(range(num_of_epochs), desc=f"Training {act_name}"):
        if epoch % num_loss_steps == 0:
            print(f"Epoch: {epoch} \n =====================================================================")
        train_loss, train_accu, norm = trainer.train(data_loader=train_dataloader, epoch=epoch)
        test_loss, test_accu = trainer.test(data_loader=test_dataloader, epoch=epoch)

        results["train_loss"].append(train_loss)
        results["train_accu"].append(train_accu)
        results["test_loss"].append(test_loss)
        results["test_accu"].append(test_accu)
        results["grad_norm"].append(norm)

        # Track dynamic activation parameters
        for name, param in model.named_parameters():
            if 'alpha_param' in name or 'beta_param' in name or 's_param' in name:
                if name not in results.setdefault("activation_params", {}):
                    results["activation_params"][name] = []
                results["activation_params"][name].append(param.item())

    total_time = time.perf_counter() - start_time
    results["total_runtime"] = total_time
    all_results[act_name] = results

    # Save Model Checkpoint
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'results': results,
        'total_runtime': total_time,
        'activation_name': act_name
    }

    save_dir = "model_trained_params_new"
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir, f"chkpt3_{act_name}.pth")

    torch.save(checkpoint, save_path)
    print(f"Saved model state to {save_path}")
# Out:
# =======================================================
#        TRAINING WITH ACTIVATION: MP_GELU
# =======================================================
# Training MP_GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.33566 | Training Accuracy: 10.79723%
# Test Loss 2.29839 | Test Accuracy 11.13528%
# Epoch: 5
#  =====================================================================
# Training Loss: 2.29885 | Training Accuracy: 11.71276%
# Test Loss 2.29931 | Test Accuracy 11.60997%
# Epoch: 10
#  =====================================================================
# Training Loss: 2.29545 | Training Accuracy: 12.28700%
# Test Loss 2.29536 | Test Accuracy 11.92642%
# Epoch: 15
#  =====================================================================
# Training Loss: 2.29535 | Training Accuracy: 12.30299%
# Test Loss 2.29580 | Test Accuracy 11.91653%
# Epoch: 20
#  =====================================================================
# Training Loss: 2.29539 | Training Accuracy: 12.14874%
# Test Loss 2.29535 | Test Accuracy 11.92642%
# Epoch: 25
#  =====================================================================
# Training Loss: 2.29470 | Training Accuracy: 12.26742%
# Test Loss 2.29551 | Test Accuracy 11.92642%
# Epoch: 30
#  =====================================================================
# Training Loss: 2.29445 | Training Accuracy: 12.41328%
# Test Loss 2.29597 | Test Accuracy 11.92642%
# Epoch: 35
#  =====================================================================
# Training Loss: 2.29501 | Training Accuracy: 12.21387%
# Test Loss 2.29584 | Test Accuracy 11.92642%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.29452 | Training Accuracy: 12.36853%
# Test Loss 2.29570 | Test Accuracy 11.92642%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.29497 | Training Accuracy: 12.31378%
# Test Loss 2.29629 | Test Accuracy 11.00672%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.29484 | Training Accuracy: 12.35814%
# Test Loss 2.29576 | Test Accuracy 11.92642%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.29469 | Training Accuracy: 12.38891%
# Test Loss 2.29534 | Test Accuracy 11.92642%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.29546 | Training Accuracy: 12.25344%
# Test Loss 2.29694 | Test Accuracy 11.92642%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.29537 | Training Accuracy: 12.36293%
# Test Loss 2.29657 | Test Accuracy 11.92642%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.29461 | Training Accuracy: 12.38051%
# Test Loss 2.29506 | Test Accuracy 11.92642%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.29479 | Training Accuracy: 12.28820%
# Test Loss 2.29566 | Test Accuracy 11.92642%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.29500 | Training Accuracy: 12.30699%
# Test Loss 2.29565 | Test Accuracy 11.92642%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.29446 | Training Accuracy: 12.43127%
# Test Loss 2.29626 | Test Accuracy 11.92642%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.29487 | Training Accuracy: 12.47802%
# Test Loss 2.29591 | Test Accuracy 11.92642%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.29504 | Training Accuracy: 12.25863%
# Test Loss 2.29701 | Test Accuracy 11.92642%
# Saved model state to model_trained_params_new/chkpt3_MP_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: ReLU
# =======================================================
# Training ReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.30195 | Training Accuracy: 9.94086%
# Test Loss 2.30277 | Test Accuracy 9.90902%
# Epoch: 5
#  =====================================================================
# Training Loss: 2.30149 | Training Accuracy: 10.14986%
# Test Loss 2.30263 | Test Accuracy 10.03758%
# Epoch: 10
#  =====================================================================
# Training Loss: 2.30139 | Training Accuracy: 9.94605%
# Test Loss 2.30272 | Test Accuracy 10.03758%
# Epoch: 15
#  =====================================================================
# Training Loss: 2.30144 | Training Accuracy: 10.02558%
# Test Loss 2.30267 | Test Accuracy 9.90902%
# Epoch: 20
#  =====================================================================
# Training Loss: 2.30168 | Training Accuracy: 9.95804%
# Test Loss 2.30266 | Test Accuracy 9.91891%
# Epoch: 25
#  =====================================================================
# Training Loss: 2.30144 | Training Accuracy: 10.08792%
# Test Loss 2.30268 | Test Accuracy 10.12658%
# Epoch: 30
#  =====================================================================
# Training Loss: 2.30188 | Training Accuracy: 10.04276%
# Test Loss 2.30262 | Test Accuracy 10.03758%
# Epoch: 35
#  =====================================================================
# Training Loss: 2.30142 | Training Accuracy: 9.96883%
# Test Loss 2.30271 | Test Accuracy 9.95847%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.30118 | Training Accuracy: 10.07353%
# Test Loss 2.30280 | Test Accuracy 10.03758%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.30158 | Training Accuracy: 10.04915%
# Test Loss 2.30268 | Test Accuracy 9.88924%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.30145 | Training Accuracy: 9.83616%
# Test Loss 2.30271 | Test Accuracy 9.91891%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.30141 | Training Accuracy: 10.05555%
# Test Loss 2.30269 | Test Accuracy 9.91891%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.30133 | Training Accuracy: 10.14706%
# Test Loss 2.30277 | Test Accuracy 10.03758%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.30161 | Training Accuracy: 9.80818%
# Test Loss 2.30267 | Test Accuracy 9.91891%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.30151 | Training Accuracy: 9.91688%
# Test Loss 2.30267 | Test Accuracy 9.95847%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.30144 | Training Accuracy: 10.17144%
# Test Loss 2.30266 | Test Accuracy 9.91891%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.30168 | Training Accuracy: 9.96124%
# Test Loss 2.30268 | Test Accuracy 10.03758%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.30149 | Training Accuracy: 9.94805%
# Test Loss 2.30270 | Test Accuracy 9.91891%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.30138 | Training Accuracy: 10.07872%
# Test Loss 2.30267 | Test Accuracy 10.03758%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.30129 | Training Accuracy: 10.03477%
# Test Loss 2.30269 | Test Accuracy 10.03758%
# Saved model state to model_trained_params_new/chkpt3_ReLU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: GELU
# =======================================================
# Training GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.31023 | Training Accuracy: 9.80938%
# Test Loss 2.31684 | Test Accuracy 10.07714%
# Epoch: 5
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.71148%
# Test Loss 2.30260 | Test Accuracy 9.88924%
# Epoch: 10
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.72387%
# Test Loss 2.30260 | Test Accuracy 10.09691%
# Epoch: 15
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.95604%
# Test Loss 2.30258 | Test Accuracy 10.02769%
# Epoch: 20
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.51846%
# Test Loss 2.30260 | Test Accuracy 10.02769%
# Epoch: 25
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.91688%
# Test Loss 2.30262 | Test Accuracy 9.95847%
# Epoch: 30
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.86053%
# Test Loss 2.30259 | Test Accuracy 9.95847%
# Epoch: 35
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.92967%
# Test Loss 2.30260 | Test Accuracy 9.95847%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.68830%
# Test Loss 2.30260 | Test Accuracy 10.09691%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.78700%
# Test Loss 2.30261 | Test Accuracy 9.95847%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.72946%
# Test Loss 2.30259 | Test Accuracy 10.02769%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.64194%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.30268 | Training Accuracy: 9.75983%
# Test Loss 2.30259 | Test Accuracy 10.09691%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.78660%
# Test Loss 2.30260 | Test Accuracy 10.09691%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.30269 | Training Accuracy: 9.71228%
# Test Loss 2.30259 | Test Accuracy 9.95847%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.70588%
# Test Loss 2.30258 | Test Accuracy 10.09691%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.74864%
# Test Loss 2.30259 | Test Accuracy 9.95847%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.30266 | Training Accuracy: 9.78501%
# Test Loss 2.30258 | Test Accuracy 9.95847%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.30267 | Training Accuracy: 9.97922%
# Test Loss 2.30257 | Test Accuracy 10.02769%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.30266 | Training Accuracy: 9.95484%
# Test Loss 2.30259 | Test Accuracy 9.88924%
# Saved model state to model_trained_params_new/chkpt3_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: LeakyReLU
# =======================================================
# Training LeakyReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 1376872568973.42188 | Training Accuracy: 10.01519%
# Test Loss 582829991028.65820 | Test Accuracy 9.88924%
# Epoch: 5
#  =====================================================================
# Training Loss: 28813181658.68031 | Training Accuracy: 10.05075%
# Test Loss 18467408896.00000 | Test Accuracy 10.11669%
# Epoch: 10
#  =====================================================================
# Training Loss: 5912683172.01023 | Training Accuracy: 10.10390%
# Test Loss 5667489234.63291 | Test Accuracy 9.97824%
# Epoch: 15
#  =====================================================================
# Training Loss: 1555518528.65473 | Training Accuracy: 9.88811%
# Test Loss 2480469894.48101 | Test Accuracy 9.82991%
# Epoch: 20
#  =====================================================================
# Training Loss: 449826788.21483 | Training Accuracy: 10.07393%
# Test Loss 411440194.02532 | Test Accuracy 10.18592%
# Epoch: 25
#  =====================================================================
# Training Loss: 111127350.90537 | Training Accuracy: 10.24856%
# Test Loss 99221525.36709 | Test Accuracy 9.95847%
# Epoch: 30
#  =====================================================================
# Training Loss: 31301761.54987 | Training Accuracy: 10.43598%
# Test Loss 32815659.67089 | Test Accuracy 9.92880%
# Epoch: 35
#  =====================================================================
# Training Loss: 9758510.05754 | Training Accuracy: 10.79364%
# Test Loss 6233379.93038 | Test Accuracy 12.16377%
# Epoch: 40
#  =====================================================================
# Training Loss: 3809354.36317 | Training Accuracy: 11.00743%
# Test Loss 3541659.90823 | Test Accuracy 10.54193%
# Epoch: 45
#  =====================================================================
# Training Loss: 725044.53916 | Training Accuracy: 11.02462%
# Test Loss 1306573.41060 | Test Accuracy 10.83861%
# Epoch: 50
#  =====================================================================
# Training Loss: 174488.79119 | Training Accuracy: 10.89714%
# Test Loss 112136.62787 | Test Accuracy 9.83979%
# Epoch: 55
#  =====================================================================
# Training Loss: 34401.71331 | Training Accuracy: 11.07257%
# Test Loss 22492.35370 | Test Accuracy 10.49248%
# Epoch: 60
#  =====================================================================
# Training Loss: 3032.40962 | Training Accuracy: 11.50975%
# Test Loss 2128.56601 | Test Accuracy 11.06606%
# Epoch: 65
#  =====================================================================
# Training Loss: 182.41521 | Training Accuracy: 11.38827%
# Test Loss 82.39087 | Test Accuracy 13.44937%
# Epoch: 70
#  =====================================================================
# Training Loss: 21.92601 | Training Accuracy: 11.57289%
# Test Loss 9.49938 | Test Accuracy 11.76820%
# Epoch: 75
#  =====================================================================
# Training Loss: 18.64180 | Training Accuracy: 10.62900%
# Test Loss 17.89563 | Test Accuracy 10.38370%
# Epoch: 80
#  =====================================================================
# Training Loss: 7.41922 | Training Accuracy: 11.45860%
# Test Loss 5.08724 | Test Accuracy 12.47033%
# Epoch: 85
#  =====================================================================
# Training Loss: 3.46621 | Training Accuracy: 11.75711%
# Test Loss 4.92336 | Test Accuracy 12.12421%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.82552 | Training Accuracy: 11.95612%
# Test Loss 2.35304 | Test Accuracy 13.66693%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.95160 | Training Accuracy: 12.63267%
# Test Loss 2.37049 | Test Accuracy 14.57674%
# Saved model state to model_trained_params_new/chkpt3_LeakyReLU.pth

# %% [markdown]
# # Loading the trained model params

# %%
activation_dict = {
    "MP_GELU": partial(MPGELU, s_param=0.5, use_softplus=True),
    "PGELU": PGELU,
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}


# Initialize LoadedModel with the correct initial_fileName and checkpoint_dir
loader = LoadedModel(
    activation_dict=activation_dict,
    model_params=chosen_model_params,
    initial_fileName="chkpt3",
    checkpoint_dir="model_trained_params_new",
    device=device
)
# Out:
# =======================================================
#        EVALUATING ACTIVATION: MP_GELU
# =======================================================
# Loaded trained model for MP_GELU from model_trained_params_new/chkpt3_MP_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: PGELU
# =======================================================
# Loaded trained model for PGELU from model_trained_params_new/chkpt3_PGELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: ReLU
# =======================================================
# Loaded trained model for ReLU from model_trained_params_new/chkpt3_ReLU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: GELU
# =======================================================
# Loaded trained model for GELU from model_trained_params_new/chkpt3_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: LeakyReLU
# =======================================================
# Loaded trained model for LeakyReLU from model_trained_params_new/chkpt3_LeakyReLU.pth

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Plotting

# %%
to_plot = {
    "MP_GELU":   {"results": my_models["MP_GELU"]["results"],   "linewidth": 3.0, "color": "#000000"}, # Jet Black
    "PGELU":     {"results": my_models["PGELU"]["results"],     "linewidth": 2.0, "color": "#E62937"}, # Strong Red
    "ReLU":      {"results": my_models["ReLU"]["results"],      "linewidth": 2.0, "color": "#009E73"}, # Teal
    "GELU":      {"results": my_models["GELU"]["results"],      "linewidth": 2.0, "color": "#4363D8"}, # Royal Blue
    "LeakyReLU": {"results": my_models["LeakyReLU"]["results"], "linewidth": 2.0, "color": "#F58231"}  # Bright Orange
}

# %% [markdown]
# ### Evolution of Learnable Parameters

# %% [markdown]
# #### $\alpha$ and $\beta$ of PGELU

# %%
alpha = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.alpha_param"]
beta = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.beta_param"]

fig, ax = plt.subplots(1, 2, figsize=(10, 6))
# Alpha Plot
ax[0].plot(alpha, label="Alpha Parameter", color="#E62937", linewidth=2.5)
# ax[0].set_title("Alpha Parameter Evolution", fontsize=14)
ax[0].grid(True, linestyle=':', alpha=0.9)
ax[0].tick_params(axis='x', labelsize=13)
ax[0].legend(fontsize=15)
# Beta Plot
ax[1].plot(beta, label="Beta Parameter", color="#009E73", linewidth=2.5)
# ax[1].set_title("Beta Parameter Evolution", fontsize=14)
ax[1].grid(True, linestyle=':', alpha=0.9)
ax[1].tick_params(axis='x', labelsize=13)
ax[1].legend(fontsize=15)


fig.supxlabel("Epochs", fontsize=15)
fig.supylabel("Parameter Value", fontsize=15)
fig.suptitle("Dynamic Activation Parameters Evolution for PGELU", fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### $\lambda$ of MPGELU

# %%
# ============================================================
# MP-GELU LEARNED LAMBDA EVOLUTION
# ============================================================

params_dict = my_models["MP_GELU"]["results"]["activation_params"]

s_vals = params_dict["conv_layers.1.s_param"]

s_values = torch.tensor(
    s_vals,
    dtype=torch.float32,
    device=device
)

# Same formulation used in MPGELU
lam = 1.0 + F.softplus(s_values)

plt.figure(figsize=(11, 7))

plt.plot(
    lam.detach().cpu().numpy(),
    linewidth=2.5,
    color="#000055",
    label=r"Learned $\lambda$"
)

plt.xlabel("Epoch", fontsize=15)
plt.ylabel(r"Learned $\lambda$", fontsize=15)
plt.title(
    r"Evolution of Learned $\lambda$ in MP-GELU During Training",
    fontsize=16
)

# 0–100 axis
plt.xlim(0, 100)
plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

plt.grid(True, linestyle=":", alpha=0.9)
plt.legend(fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Train Loss Curves

# %%
# ============================================================
# TRAINING LOSS COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["train_loss"], **arguments)

plt.legend(loc="upper right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

# Keep automatic y-axis
# plt.ylim(0.75, 2.4)

# 0–100
plt.xlim(0, 100)

plt.title(
    "Training Loss Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("train_loss_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test Loss Curves

# %%
# ============================================================
# TEST LOSS COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["test_loss"], **arguments)

plt.legend(loc="upper right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(fontsize=12)

plt.xlim(0, 100)

plt.title(
    "Test Loss Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("test_loss_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Training Accuracy

# %%
# ============================================================
# TRAINING ACCURACY COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["train_accu"], **arguments)

plt.legend(loc="lower right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(np.arange(0, 101, 10), fontsize=12)

plt.xlim(0, 100)
plt.ylim(0, 100)

plt.title(
    "Training Accuracy Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("train_accuracy_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test Accuracy

# %%
# ============================================================
# TEST ACCURACY COMPARISON
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]

    arguments = {
        "linewidth": property.get("linewidth", 1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }

    plt.plot(plot_results["test_accu"], **arguments)

plt.legend(loc="lower right", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.yticks(np.arange(0, 101, 10), fontsize=12)

plt.xlim(0, 100)
plt.ylim(0, 100)

plt.title(
    "Test Accuracy Comparison Across Activation Functions",
    fontsize=16
)

# plt.savefig("test_accuracy_comparison.jpg", dpi=800, bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.plot(my_models["ReLU"]["results"]["grad_norm"])

# %% [markdown]
# ### Print the Gradient Norms

# %%
import numpy as np
import matplotlib.pyplot as plt

print("=" * 80)
print("GRADIENT L₂ NORMS BY EPOCH")
print("=" * 80)

for act_name, results in all_results.items():

    print(f"\n{'=' * 80}")
    print(f"ACTIVATION: {act_name}")
    print(f"{'=' * 80}")

    grad_norms = np.array(results["grad_norm"], dtype=float)

    # Print gradient norm for every epoch
    for epoch, grad_norm in enumerate(grad_norms, start=1):
        print(
            f"Epoch {epoch:3d}: "
            f"Gradient L₂ Norm = {grad_norm:.6f}"
        )

    # Statistics
    min_grad = np.min(grad_norms)
    max_grad = np.max(grad_norms)
    mean_grad = np.mean(grad_norms)
    std_grad = np.std(grad_norms, ddof=1)

    min_epoch = np.argmin(grad_norms) + 1
    max_epoch = np.argmax(grad_norms) + 1

    print(f"\n{'-' * 80}")
    print(f"SUMMARY — {act_name}")
    print(f"{'-' * 80}")

    print(f"Minimum Gradient L₂ Norm : {min_grad:.6f} "
          f"(Epoch {min_epoch})")

    print(f"Maximum Gradient L₂ Norm : {max_grad:.6f} "
          f"(Epoch {max_epoch})")

    print(f"Mean Gradient L₂ Norm    : {mean_grad:.6f}")

    print(f"Standard Deviation       : {std_grad:.6f}")

    print(f"Mean ± SD                : "
          f"{mean_grad:.6f} ± {std_grad:.6f}")
# Out:
# ================================================================================
# GRADIENT L₂ NORMS BY EPOCH
# ================================================================================
#
# ================================================================================
# ACTIVATION: MP_GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 128.797865
# Epoch   2: Gradient L₂ Norm = 0.107452
# Epoch   3: Gradient L₂ Norm = 0.097316
# Epoch   4: Gradient L₂ Norm = 0.091152
# Epoch   5: Gradient L₂ Norm = 0.088851
# Epoch   6: Gradient L₂ Norm = 0.088204
# Epoch   7: Gradient L₂ Norm = 47.321571
# Epoch   8: Gradient L₂ Norm = 47.800277
# Epoch   9: Gradient L₂ Norm = 0.085742
# Epoch  10: Gradient L₂ Norm = 0.086394
# Epoch  11: Gradient L₂ Norm = 0.338265
# Epoch  12: Gradient L₂ Norm = 0.085842
# Epoch  13: Gradient L₂ Norm = 0.085162
# Epoch  14: Gradient L₂ Norm = 0.085300
# Epoch  15: Gradient L₂ Norm = 0.088809
# Epoch  16: Gradient L₂ Norm = 0.083776
# Epoch  17: Gradient L₂ Norm = 0.088660
# Epoch  18: Gradient L₂ Norm = 0.084038
# Epoch  19: Gradient L₂ Norm = 0.083251
# Epoch  20: Gradient L₂ Norm = 0.083788
# Epoch  21: Gradient L₂ Norm = 0.083938
# Epoch  22: Gradient L₂ Norm = 0.083353
# Epoch  23: Gradient L₂ Norm = 0.082762
# Epoch  24: Gradient L₂ Norm = 0.083369
# Epoch  25: Gradient L₂ Norm = 0.082597
# Epoch  26: Gradient L₂ Norm = 0.083390
# Epoch  27: Gradient L₂ Norm = 0.082303
# Epoch  28: Gradient L₂ Norm = 0.082287
# Epoch  29: Gradient L₂ Norm = 0.091559
# Epoch  30: Gradient L₂ Norm = 0.082499
# Epoch  31: Gradient L₂ Norm = 0.081264
# Epoch  32: Gradient L₂ Norm = 0.079557
# Epoch  33: Gradient L₂ Norm = 0.080015
# Epoch  34: Gradient L₂ Norm = 0.080617
# Epoch  35: Gradient L₂ Norm = 0.079730
# Epoch  36: Gradient L₂ Norm = 0.079181
# Epoch  37: Gradient L₂ Norm = 0.077621
# Epoch  38: Gradient L₂ Norm = 0.080422
# Epoch  39: Gradient L₂ Norm = 0.079313
# Epoch  40: Gradient L₂ Norm = 0.079809
# Epoch  41: Gradient L₂ Norm = 0.079436
# Epoch  42: Gradient L₂ Norm = 0.078883
# Epoch  43: Gradient L₂ Norm = 0.078432
# Epoch  44: Gradient L₂ Norm = 0.078377
# Epoch  45: Gradient L₂ Norm = 0.079310
# Epoch  46: Gradient L₂ Norm = 0.076732
# Epoch  47: Gradient L₂ Norm = 0.078883
# Epoch  48: Gradient L₂ Norm = 0.078234
# Epoch  49: Gradient L₂ Norm = 0.078370
# Epoch  50: Gradient L₂ Norm = 0.077626
# Epoch  51: Gradient L₂ Norm = 0.078359
# Epoch  52: Gradient L₂ Norm = 0.077752
# Epoch  53: Gradient L₂ Norm = 0.079356
# Epoch  54: Gradient L₂ Norm = 0.080094
# Epoch  55: Gradient L₂ Norm = 0.078581
# Epoch  56: Gradient L₂ Norm = 0.079240
# Epoch  57: Gradient L₂ Norm = 0.077810
# Epoch  58: Gradient L₂ Norm = 0.077771
# Epoch  59: Gradient L₂ Norm = 0.077955
# Epoch  60: Gradient L₂ Norm = 0.077846
# Epoch  61: Gradient L₂ Norm = 0.078465
# Epoch  62: Gradient L₂ Norm = 0.077765
# Epoch  63: Gradient L₂ Norm = 0.078135
# Epoch  64: Gradient L₂ Norm = 0.079306
# Epoch  65: Gradient L₂ Norm = 0.076226
# Epoch  66: Gradient L₂ Norm = 0.076664
# Epoch  67: Gradient L₂ Norm = 0.078654
# Epoch  68: Gradient L₂ Norm = 0.077369
# Epoch  69: Gradient L₂ Norm = 0.077379
# Epoch  70: Gradient L₂ Norm = 0.077826
# Epoch  71: Gradient L₂ Norm = 0.079294
# Epoch  72: Gradient L₂ Norm = 0.079088
# Epoch  73: Gradient L₂ Norm = 0.077332
# Epoch  74: Gradient L₂ Norm = 0.079457
# Epoch  75: Gradient L₂ Norm = 0.078646
# Epoch  76: Gradient L₂ Norm = 0.077663
# Epoch  77: Gradient L₂ Norm = 0.077322
# Epoch  78: Gradient L₂ Norm = 0.076376
# Epoch  79: Gradient L₂ Norm = 0.078726
# Epoch  80: Gradient L₂ Norm = 0.076785
# Epoch  81: Gradient L₂ Norm = 0.077077
# Epoch  82: Gradient L₂ Norm = 0.077542
# Epoch  83: Gradient L₂ Norm = 0.078642
# Epoch  84: Gradient L₂ Norm = 0.078162
# Epoch  85: Gradient L₂ Norm = 0.076609
# Epoch  86: Gradient L₂ Norm = 0.078085
# Epoch  87: Gradient L₂ Norm = 0.077030
# Epoch  88: Gradient L₂ Norm = 0.077710
# Epoch  89: Gradient L₂ Norm = 0.076187
# Epoch  90: Gradient L₂ Norm = 0.075214
# Epoch  91: Gradient L₂ Norm = 0.077665
# Epoch  92: Gradient L₂ Norm = 0.076686
# Epoch  93: Gradient L₂ Norm = 0.076634
# Epoch  94: Gradient L₂ Norm = 0.076802
# Epoch  95: Gradient L₂ Norm = 0.077947
# Epoch  96: Gradient L₂ Norm = 0.076036
# Epoch  97: Gradient L₂ Norm = 0.078919
# Epoch  98: Gradient L₂ Norm = 0.077589
# Epoch  99: Gradient L₂ Norm = 0.076761
# Epoch 100: Gradient L₂ Norm = 0.076389
#
# --------------------------------------------------------------------------------
# SUMMARY — MP_GELU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 0.075214 (Epoch 90)
# Maximum Gradient L₂ Norm : 128.797865 (Epoch 1)
# Mean Gradient L₂ Norm    : 2.319785
# Standard Deviation       : 14.416491
# Mean ± SD                : 2.319785 ± 14.416491
#
# ================================================================================
# ACTIVATION: ReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.075317
# Epoch   2: Gradient L₂ Norm = 0.075067
# Epoch   3: Gradient L₂ Norm = 0.073285
# Epoch   4: Gradient L₂ Norm = 0.075948
# Epoch   5: Gradient L₂ Norm = 0.073835
# Epoch   6: Gradient L₂ Norm = 0.075405
# Epoch   7: Gradient L₂ Norm = 0.074429
# Epoch   8: Gradient L₂ Norm = 0.074678
# Epoch   9: Gradient L₂ Norm = 0.073269
# Epoch  10: Gradient L₂ Norm = 0.073640
# Epoch  11: Gradient L₂ Norm = 0.074813
# Epoch  12: Gradient L₂ Norm = 0.074851
# Epoch  13: Gradient L₂ Norm = 0.075215
# Epoch  14: Gradient L₂ Norm = 0.074173
# Epoch  15: Gradient L₂ Norm = 0.074832
# Epoch  16: Gradient L₂ Norm = 0.074609
# Epoch  17: Gradient L₂ Norm = 0.074704
# Epoch  18: Gradient L₂ Norm = 0.073996
# Epoch  19: Gradient L₂ Norm = 0.075773
# Epoch  20: Gradient L₂ Norm = 0.074730
# Epoch  21: Gradient L₂ Norm = 0.074084
# Epoch  22: Gradient L₂ Norm = 0.074121
# Epoch  23: Gradient L₂ Norm = 0.072550
# Epoch  24: Gradient L₂ Norm = 0.075667
# Epoch  25: Gradient L₂ Norm = 0.074822
# Epoch  26: Gradient L₂ Norm = 0.074394
# Epoch  27: Gradient L₂ Norm = 0.074362
# Epoch  28: Gradient L₂ Norm = 0.073105
# Epoch  29: Gradient L₂ Norm = 0.076659
# Epoch  30: Gradient L₂ Norm = 0.074438
# Epoch  31: Gradient L₂ Norm = 0.074257
# Epoch  32: Gradient L₂ Norm = 0.075152
# Epoch  33: Gradient L₂ Norm = 0.073814
# Epoch  34: Gradient L₂ Norm = 0.074760
# Epoch  35: Gradient L₂ Norm = 0.074945
# Epoch  36: Gradient L₂ Norm = 0.075033
# Epoch  37: Gradient L₂ Norm = 0.074568
# Epoch  38: Gradient L₂ Norm = 0.073755
# Epoch  39: Gradient L₂ Norm = 0.075433
# Epoch  40: Gradient L₂ Norm = 0.074371
# Epoch  41: Gradient L₂ Norm = 0.073766
# Epoch  42: Gradient L₂ Norm = 0.074286
# Epoch  43: Gradient L₂ Norm = 0.075071
# Epoch  44: Gradient L₂ Norm = 0.074566
# Epoch  45: Gradient L₂ Norm = 0.074108
# Epoch  46: Gradient L₂ Norm = 0.073124
# Epoch  47: Gradient L₂ Norm = 0.074157
# Epoch  48: Gradient L₂ Norm = 0.074625
# Epoch  49: Gradient L₂ Norm = 0.074685
# Epoch  50: Gradient L₂ Norm = 0.075576
# Epoch  51: Gradient L₂ Norm = 0.073656
# Epoch  52: Gradient L₂ Norm = 0.073883
# Epoch  53: Gradient L₂ Norm = 0.075681
# Epoch  54: Gradient L₂ Norm = 0.073178
# Epoch  55: Gradient L₂ Norm = 0.074826
# Epoch  56: Gradient L₂ Norm = 0.075332
# Epoch  57: Gradient L₂ Norm = 0.073123
# Epoch  58: Gradient L₂ Norm = 0.072768
# Epoch  59: Gradient L₂ Norm = 0.074553
# Epoch  60: Gradient L₂ Norm = 0.073425
# Epoch  61: Gradient L₂ Norm = 0.074690
# Epoch  62: Gradient L₂ Norm = 0.073835
# Epoch  63: Gradient L₂ Norm = 0.074432
# Epoch  64: Gradient L₂ Norm = 0.074389
# Epoch  65: Gradient L₂ Norm = 0.073675
# Epoch  66: Gradient L₂ Norm = 0.073886
# Epoch  67: Gradient L₂ Norm = 0.074015
# Epoch  68: Gradient L₂ Norm = 0.074342
# Epoch  69: Gradient L₂ Norm = 0.072632
# Epoch  70: Gradient L₂ Norm = 0.075389
# Epoch  71: Gradient L₂ Norm = 0.072969
# Epoch  72: Gradient L₂ Norm = 0.072369
# Epoch  73: Gradient L₂ Norm = 0.074431
# Epoch  74: Gradient L₂ Norm = 0.073651
# Epoch  75: Gradient L₂ Norm = 0.073989
# Epoch  76: Gradient L₂ Norm = 0.074771
# Epoch  77: Gradient L₂ Norm = 0.074437
# Epoch  78: Gradient L₂ Norm = 0.073138
# Epoch  79: Gradient L₂ Norm = 0.072798
# Epoch  80: Gradient L₂ Norm = 0.076689
# Epoch  81: Gradient L₂ Norm = 0.075057
# Epoch  82: Gradient L₂ Norm = 0.073831
# Epoch  83: Gradient L₂ Norm = 0.074183
# Epoch  84: Gradient L₂ Norm = 0.074281
# Epoch  85: Gradient L₂ Norm = 0.075091
# Epoch  86: Gradient L₂ Norm = 0.075216
# Epoch  87: Gradient L₂ Norm = 0.073822
# Epoch  88: Gradient L₂ Norm = 0.073618
# Epoch  89: Gradient L₂ Norm = 0.074156
# Epoch  90: Gradient L₂ Norm = 0.073674
# Epoch  91: Gradient L₂ Norm = 0.074209
# Epoch  92: Gradient L₂ Norm = 0.073403
# Epoch  93: Gradient L₂ Norm = 0.073111
# Epoch  94: Gradient L₂ Norm = 0.074433
# Epoch  95: Gradient L₂ Norm = 0.073260
# Epoch  96: Gradient L₂ Norm = 0.073288
# Epoch  97: Gradient L₂ Norm = 0.073821
# Epoch  98: Gradient L₂ Norm = 0.073779
# Epoch  99: Gradient L₂ Norm = 0.074770
# Epoch 100: Gradient L₂ Norm = 0.073371
#
# --------------------------------------------------------------------------------
# SUMMARY — ReLU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 0.072369 (Epoch 72)
# Maximum Gradient L₂ Norm : 0.076689 (Epoch 80)
# Mean Gradient L₂ Norm    : 0.074281
# Standard Deviation       : 0.000857
# Mean ± SD                : 0.074281 ± 0.000857
#
# ================================================================================
# ACTIVATION: GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 3.293381
# Epoch   2: Gradient L₂ Norm = 1028.735348
# Epoch   3: Gradient L₂ Norm = 0.074511
# Epoch   4: Gradient L₂ Norm = 0.074285
# Epoch   5: Gradient L₂ Norm = 0.073250
# Epoch   6: Gradient L₂ Norm = 0.072308
# Epoch   7: Gradient L₂ Norm = 0.074539
# Epoch   8: Gradient L₂ Norm = 0.073029
# Epoch   9: Gradient L₂ Norm = 0.074933
# Epoch  10: Gradient L₂ Norm = 0.072469
# Epoch  11: Gradient L₂ Norm = 0.072838
# Epoch  12: Gradient L₂ Norm = 143906.647904
# Epoch  13: Gradient L₂ Norm = 0.072757
# Epoch  14: Gradient L₂ Norm = 0.072839
# Epoch  15: Gradient L₂ Norm = 0.073385
# Epoch  16: Gradient L₂ Norm = 0.072492
# Epoch  17: Gradient L₂ Norm = 0.074823
# Epoch  18: Gradient L₂ Norm = 0.074958
# Epoch  19: Gradient L₂ Norm = 0.073235
# Epoch  20: Gradient L₂ Norm = 0.074564
# Epoch  21: Gradient L₂ Norm = 0.072477
# Epoch  22: Gradient L₂ Norm = 0.073496
# Epoch  23: Gradient L₂ Norm = 0.073362
# Epoch  24: Gradient L₂ Norm = 0.072246
# Epoch  25: Gradient L₂ Norm = 0.074439
# Epoch  26: Gradient L₂ Norm = 0.075152
# Epoch  27: Gradient L₂ Norm = 0.073341
# Epoch  28: Gradient L₂ Norm = 0.072996
# Epoch  29: Gradient L₂ Norm = 0.072924
# Epoch  30: Gradient L₂ Norm = 0.073163
# Epoch  31: Gradient L₂ Norm = 0.073264
# Epoch  32: Gradient L₂ Norm = 0.074159
# Epoch  33: Gradient L₂ Norm = 0.074119
# Epoch  34: Gradient L₂ Norm = 0.073542
# Epoch  35: Gradient L₂ Norm = 0.073375
# Epoch  36: Gradient L₂ Norm = 0.074118
# Epoch  37: Gradient L₂ Norm = 0.072985
# Epoch  38: Gradient L₂ Norm = 0.074240
# Epoch  39: Gradient L₂ Norm = 0.073211
# Epoch  40: Gradient L₂ Norm = 0.074599
# Epoch  41: Gradient L₂ Norm = 0.072120
# Epoch  42: Gradient L₂ Norm = 0.072722
# Epoch  43: Gradient L₂ Norm = 0.072006
# Epoch  44: Gradient L₂ Norm = 0.072860
# Epoch  45: Gradient L₂ Norm = 0.073354
# Epoch  46: Gradient L₂ Norm = 0.072793
# Epoch  47: Gradient L₂ Norm = 0.073400
# Epoch  48: Gradient L₂ Norm = 0.073363
# Epoch  49: Gradient L₂ Norm = 0.072236
# Epoch  50: Gradient L₂ Norm = 0.073392
# Epoch  51: Gradient L₂ Norm = 0.073797
# Epoch  52: Gradient L₂ Norm = 0.073515
# Epoch  53: Gradient L₂ Norm = 0.073828
# Epoch  54: Gradient L₂ Norm = 0.071594
# Epoch  55: Gradient L₂ Norm = 0.072613
# Epoch  56: Gradient L₂ Norm = 0.074475
# Epoch  57: Gradient L₂ Norm = 0.073721
# Epoch  58: Gradient L₂ Norm = 0.073635
# Epoch  59: Gradient L₂ Norm = 0.072062
# Epoch  60: Gradient L₂ Norm = 0.073898
# Epoch  61: Gradient L₂ Norm = 0.073561
# Epoch  62: Gradient L₂ Norm = 0.073887
# Epoch  63: Gradient L₂ Norm = 0.073409
# Epoch  64: Gradient L₂ Norm = 0.073433
# Epoch  65: Gradient L₂ Norm = 0.072899
# Epoch  66: Gradient L₂ Norm = 0.073368
# Epoch  67: Gradient L₂ Norm = 0.073174
# Epoch  68: Gradient L₂ Norm = 0.072158
# Epoch  69: Gradient L₂ Norm = 0.073714
# Epoch  70: Gradient L₂ Norm = 0.074031
# Epoch  71: Gradient L₂ Norm = 0.073353
# Epoch  72: Gradient L₂ Norm = 0.073832
# Epoch  73: Gradient L₂ Norm = 0.074165
# Epoch  74: Gradient L₂ Norm = 0.072222
# Epoch  75: Gradient L₂ Norm = 0.074018
# Epoch  76: Gradient L₂ Norm = 0.073467
# Epoch  77: Gradient L₂ Norm = 0.073289
# Epoch  78: Gradient L₂ Norm = 0.073918
# Epoch  79: Gradient L₂ Norm = 0.073619
# Epoch  80: Gradient L₂ Norm = 0.073781
# Epoch  81: Gradient L₂ Norm = 0.073717
# Epoch  82: Gradient L₂ Norm = 0.073977
# Epoch  83: Gradient L₂ Norm = 0.075142
# Epoch  84: Gradient L₂ Norm = 0.074565
# Epoch  85: Gradient L₂ Norm = 0.073601
# Epoch  86: Gradient L₂ Norm = 0.072985
# Epoch  87: Gradient L₂ Norm = 0.072802
# Epoch  88: Gradient L₂ Norm = 0.073514
# Epoch  89: Gradient L₂ Norm = 0.073982
# Epoch  90: Gradient L₂ Norm = 0.072695
# Epoch  91: Gradient L₂ Norm = 0.074847
# Epoch  92: Gradient L₂ Norm = 0.072707
# Epoch  93: Gradient L₂ Norm = 0.073993
# Epoch  94: Gradient L₂ Norm = 0.074080
# Epoch  95: Gradient L₂ Norm = 0.074955
# Epoch  96: Gradient L₂ Norm = 0.073702
# Epoch  97: Gradient L₂ Norm = 0.073598
# Epoch  98: Gradient L₂ Norm = 0.073447
# Epoch  99: Gradient L₂ Norm = 0.073864
# Epoch 100: Gradient L₂ Norm = 0.073654
#
# --------------------------------------------------------------------------------
# SUMMARY — GELU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 0.071594 (Epoch 54)
# Maximum Gradient L₂ Norm : 143906.647904 (Epoch 12)
# Mean Gradient L₂ Norm    : 1449.458056
# Standard Deviation       : 14389.982751
# Mean ± SD                : 1449.458056 ± 14389.982751
#
# ================================================================================
# ACTIVATION: LeakyReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 112922717557026.890625
# Epoch   2: Gradient L₂ Norm = 52186443640622.453125
# Epoch   3: Gradient L₂ Norm = 30426271183771.058594
# Epoch   4: Gradient L₂ Norm = 19984010123673.875000
# Epoch   5: Gradient L₂ Norm = 14141491509750.609375
# Epoch   6: Gradient L₂ Norm = 10424468851945.210938
# Epoch   7: Gradient L₂ Norm = 7873111326235.069336
# Epoch   8: Gradient L₂ Norm = 6052574174503.755859
# Epoch   9: Gradient L₂ Norm = 4662676180055.867188
# Epoch  10: Gradient L₂ Norm = 3649388321131.872559
# Epoch  11: Gradient L₂ Norm = 2915778582015.712891
# Epoch  12: Gradient L₂ Norm = 2328972705842.827148
# Epoch  13: Gradient L₂ Norm = 1818179154055.782959
# Epoch  14: Gradient L₂ Norm = 1415262492297.835449
# Epoch  15: Gradient L₂ Norm = 1151668469659.448730
# Epoch  16: Gradient L₂ Norm = 911936261079.241333
# Epoch  17: Gradient L₂ Norm = 732871067499.472778
# Epoch  18: Gradient L₂ Norm = 582322982229.908813
# Epoch  19: Gradient L₂ Norm = 465176868417.239990
# Epoch  20: Gradient L₂ Norm = 371714576572.139282
# Epoch  21: Gradient L₂ Norm = 299625578718.718262
# Epoch  22: Gradient L₂ Norm = 238321501951.976776
# Epoch  23: Gradient L₂ Norm = 189255340989.990967
# Epoch  24: Gradient L₂ Norm = 151849798965.326355
# Epoch  25: Gradient L₂ Norm = 120158254328.648514
# Epoch  26: Gradient L₂ Norm = 95719380557.976761
# Epoch  27: Gradient L₂ Norm = 75268284221.378220
# Epoch  28: Gradient L₂ Norm = 59143173845.801003
# Epoch  29: Gradient L₂ Norm = 47131106647.531212
# Epoch  30: Gradient L₂ Norm = 37552884455.904724
# Epoch  31: Gradient L₂ Norm = 30559882348.839649
# Epoch  32: Gradient L₂ Norm = 24596554595.679543
# Epoch  33: Gradient L₂ Norm = 19332167128.970749
# Epoch  34: Gradient L₂ Norm = 15631914250.274754
# Epoch  35: Gradient L₂ Norm = 13029546029.866440
# Epoch  36: Gradient L₂ Norm = 10805035616.479248
# Epoch  37: Gradient L₂ Norm = 8861399813.941111
# Epoch  38: Gradient L₂ Norm = 7439338749.606845
# Epoch  39: Gradient L₂ Norm = 6146825913.414475
# Epoch  40: Gradient L₂ Norm = 4792509238.590836
# Epoch  41: Gradient L₂ Norm = 4146332869.270226
# Epoch  42: Gradient L₂ Norm = 3327136556.471992
# Epoch  43: Gradient L₂ Norm = 2418746925.007599
# Epoch  44: Gradient L₂ Norm = 1896425016.711924
# Epoch  45: Gradient L₂ Norm = 1520692176.570760
# Epoch  46: Gradient L₂ Norm = 1195692612.892510
# Epoch  47: Gradient L₂ Norm = 956080846.083976
# Epoch  48: Gradient L₂ Norm = 747006596.850374
# Epoch  49: Gradient L₂ Norm = 568300477.463085
# Epoch  50: Gradient L₂ Norm = 445422666.027143
# Epoch  51: Gradient L₂ Norm = 350923682.953417
# Epoch  52: Gradient L₂ Norm = 276434646.004040
# Epoch  53: Gradient L₂ Norm = 211593030.133529
# Epoch  54: Gradient L₂ Norm = 162527608.715381
# Epoch  55: Gradient L₂ Norm = 124837551.891584
# Epoch  56: Gradient L₂ Norm = 88679697.259002
# Epoch  57: Gradient L₂ Norm = 63609095.196925
# Epoch  58: Gradient L₂ Norm = 46791237.144635
# Epoch  59: Gradient L₂ Norm = 32287156.223922
# Epoch  60: Gradient L₂ Norm = 20462340.579941
# Epoch  61: Gradient L₂ Norm = 13671677.448462
# Epoch  62: Gradient L₂ Norm = 9030561.006715
# Epoch  63: Gradient L₂ Norm = 5833058.946976
# Epoch  64: Gradient L₂ Norm = 3701728.103862
# Epoch  65: Gradient L₂ Norm = 2529546.250167
# Epoch  66: Gradient L₂ Norm = 1564606.050621
# Epoch  67: Gradient L₂ Norm = 1110911.263183
# Epoch  68: Gradient L₂ Norm = 746159.709357
# Epoch  69: Gradient L₂ Norm = 552243.983611
# Epoch  70: Gradient L₂ Norm = 483145.807300
# Epoch  71: Gradient L₂ Norm = 476288.894428
# Epoch  72: Gradient L₂ Norm = 444420.030943
# Epoch  73: Gradient L₂ Norm = 417834.389942
# Epoch  74: Gradient L₂ Norm = 426881.995223
# Epoch  75: Gradient L₂ Norm = 380486.764110
# Epoch  76: Gradient L₂ Norm = 314676.375910
# Epoch  77: Gradient L₂ Norm = 281515.598787
# Epoch  78: Gradient L₂ Norm = 254693.418958
# Epoch  79: Gradient L₂ Norm = 199864.611309
# Epoch  80: Gradient L₂ Norm = 173969.687348
# Epoch  81: Gradient L₂ Norm = 123384.038289
# Epoch  82: Gradient L₂ Norm = 87054.667841
# Epoch  83: Gradient L₂ Norm = 80890.838048
# Epoch  84: Gradient L₂ Norm = 72240.531934
# Epoch  85: Gradient L₂ Norm = 40384.167624
# Epoch  86: Gradient L₂ Norm = 40373.533150
# Epoch  87: Gradient L₂ Norm = 32227.041495
# Epoch  88: Gradient L₂ Norm = 22690.912883
# Epoch  89: Gradient L₂ Norm = 19079.538498
# Epoch  90: Gradient L₂ Norm = 14711.411361
# Epoch  91: Gradient L₂ Norm = 18226.314957
# Epoch  92: Gradient L₂ Norm = 11830.023655
# Epoch  93: Gradient L₂ Norm = 13247.276870
# Epoch  94: Gradient L₂ Norm = 8732.886208
# Epoch  95: Gradient L₂ Norm = 9959.495577
# Epoch  96: Gradient L₂ Norm = 9182.111757
# Epoch  97: Gradient L₂ Norm = 6113.840909
# Epoch  98: Gradient L₂ Norm = 4885.029821
# Epoch  99: Gradient L₂ Norm = 4727.383414
# Epoch 100: Gradient L₂ Norm = 3638.666567
#
# --------------------------------------------------------------------------------
# SUMMARY — LeakyReLU
# --------------------------------------------------------------------------------
# Minimum Gradient L₂ Norm : 3638.666567 (Epoch 100)
# Maximum Gradient L₂ Norm : 112922717557026.890625 (Epoch 1)
# Mean Gradient L₂ Norm    : 2764908997073.946777
# Standard Deviation       : 12910260907365.710938
# Mean ± SD                : 2764908997073.946777 ± 12910260907365.710938

# %% [markdown]
# ### Graphing the Gradient Norms

# %%
plt.figure(figsize=(10, 6))

for act_name, results in all_results.items():

    grad_norms = results["grad_norm"]

    plt.plot(
        grad_norms,
        label=act_name,
        linewidth=2
    )

plt.xlabel("Epoch", fontsize=13)
plt.ylabel(r"Gradient L$_2$ Norm", fontsize=13)
plt.title("Gradient L₂ Norm vs. Epoch", fontsize=14)

plt.xticks(np.arange(0, 101, 5), fontsize=12)
plt.xlim(0, 100)

plt.grid(True, linestyle=':', alpha=0.9)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # $F_{1}$ Scores
# **Mathematical Definition of the $F_1$ Score**
#
# The $F_1$ score is the harmonic mean of Precision and Recall. It provides a single metric that balances both false positives and false negatives, making it particularly useful for evaluating models on imbalanced datasets.
#
# The general formula is defined as:
#
# $$F_1 = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$$
#
# To calculate the $F_1$ score, you must first calculate **Precision** and **Recall**:
#
# * **Precision** measures the proportion of positive predictions that were actually correct:
#   $$\text{Precision} = \frac{TP}{TP + FP}$$
#
# * **Recall** (also known as Sensitivity) measures the proportion of actual positives that were identified correctly:
#   $$\text{Recall} = \frac{TP}{TP + FN}$$
#
# By substituting Precision and Recall back into the original equation, the $F_1$ score can be expressed directly in terms of prediction outcomes:
#
# $$F_1 = \frac{2 \cdot TP}{2 \cdot TP + FP + FN}$$
#
# **Where:**
# * $TP$ = **True Positives** (Model correctly predicts the positive class)
# * $FP$ = **False Positives** (Model incorrectly predicts the positive class)
# * $FN$ = **False Negatives** (Model incorrectly predicts the negative class)

# %%
f1_results = {}

print("Calculating F1 Scores...")
print("========================")

for act_name, model_data in my_models.items():
    model = model_data["model"]
    model.eval()  # Ensure the model is in evaluation mode

    all_preds = []
    all_targets = []

    with torch.inference_mode():
        # Assuming you have your test_dataloader ready
        for inputs, targets in test_dataloader:
            inputs = inputs.to(device)

            # Get predictions
            outputs = model(inputs)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(targets.numpy())

    f1 = f1_score(all_targets, all_preds, average='macro')
    f1_results[act_name] = f1

    print(f"{act_name: >10}: {f1:.4f}")
