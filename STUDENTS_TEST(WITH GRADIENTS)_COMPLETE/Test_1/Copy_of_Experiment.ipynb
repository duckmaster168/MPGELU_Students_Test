# %% [markdown]
# # Introduction
#
# <center>
# <h2>
# Computational Experiments with Modern Parametrized Gaussian Error Linear Unit (MPGELU)
# </h2>
# <b>A demonstration by: Jose Aries E. De Los Santos</b>
# </center>

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.13/dist-packages (1.8.0)

# %% [markdown]
# # Import Libraries

# %%
import os
import sys
from pathlib import Path

#PyTorch
import torch as torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import time
from torchinfo import summary

import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import random
from typing import Iterable, Callable


#sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

#Import torchvision
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor
from torchinfo import summary

#Import tqdm for a cool progress bar
from tqdm.auto import tqdm

# Measure time
from timeit import default_timer as timer

seed = 143
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)


print(f"PyTorch Version: {torch.__version__}")
print(f"Numpy Version: {np.__version__}")
print(f"Pandas Version: {pd.__version__}")
# print(f"Matplotlib Version: {matplotlib.__version__}")
print(f"SciPy Version: {scipy.__version__}")

# device = "cuda" if torch.cuda.is_available() else "cpu"

if torch.cuda.is_available():
    device = "cuda"
    print(f"Device: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = "mps"
    print(f"Device: {torch.backends.mps.is_available()}")
else:
    device = "cpu"
    print(f"Device: {device}")
# Out:
# PyTorch Version: 2.11.0+cu128
# Numpy Version: 2.1.3
# Pandas Version: 2.2.3
# SciPy Version: 1.16.3
# Device: NVIDIA A100-SXM4-40GB

# %% [markdown]
# # Dynamic Path Modification
#
# * It is a runtime technique used to explicitly tell Python where to look for modules or packages when you run an ``import`` statement.

# %% [markdown]
# ## Import Helper Functions

# %%
### Add the parent directory to the sys.path to import MyCNN and MPGELU
#%reload_ext autoreload
#%autoreload 2
mother_path = Path.cwd()
for folder in ["utility", "act_fns", "models"]:
    path = os.path.join(mother_path , folder)
    if path not in sys.path:
        sys.path.append(path)
from MPGELU import MPGELU
from PGELU import PGELU
from MyCNN import MyCNN
from DataTransforms import DataTransforms
from Trainer import Trainer
from LoadedModel import LoadedModel

# %% [markdown]
# # MP GELU
#
# * Modified Parametric Gaussian Error Linear Unit
# $$
# f(x) = \frac{x}{2} \left[ 1 + \text{erf}\left( \frac{\lambda x}{\sqrt{2}}\right)\right] = \frac{x}{2} + \frac{x}{\sqrt{\pi}}\int_{0}^{\lambda x / \sqrt{2}} e^{-u^{2}}du
# $$
# where $\lambda  = (1 + \ln(1 + e^{s})) \geq 1$   $\forall s \in \mathbb{R}$
#
# * Check MPGELU.py file for the implementation of the MPGELU activation function

# %%
x_np = np.linspace(-4.0, 4.0, 400)
x_tensor = torch.tensor(x_np, dtype=torch.float32)
# s_values = np.arange(-2.0, 2.0, 0.1)
s_values = [-100, 0.0, 100, ]
plt.figure(figsize=(9, 6))

for s_val in s_values:
    activation1 = MPGELU(s_param=s_val)
    activation2 = MPGELU(s_param=s_val, use_softplus=False)
    with torch.no_grad():
        y_tensor1 = activation1(x_tensor)
        y_tensor2 = activation2(x_tensor)

    lam_val = (1.0 + F.softplus(torch.tensor(s_val, dtype=torch.float32))).item()
    plt.plot(x_np, y_tensor1.numpy(), label=f"s = {s_val}", linewidth=2.5)
    # plt.plot(x_np, y_tensor2.numpy(), label=f"s = {s_val}", linewidth=2)

# 4. Format the plot
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.axvline(0, color='black', linewidth=0.8, linestyle='--')
plt.title("Modified Parametric GELU (MP-GELU) Activation Function", fontsize=15)
xticks = np.arange(-4, 5, 0.8)
plt.xticks(xticks,fontsize=12)
plt.xlabel("Input ($x$)", fontsize=12)
yticks = np.arange(-2, 5, 0.8)
plt.yticks(yticks,fontsize=12)
plt.ylabel("Output ($f(x)$)", fontsize=12)
plt.grid(True, linestyle=':', alpha=0.9)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # Data Processing

# %%
transformer = DataTransforms(dataset='cifar10', use_augmentation=True, use_stats=False)
train_transform = transformer.get_train_transform()
test_transform = transformer.get_test_transform()


train_data = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
test_data = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)


train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True, num_workers=10, pin_memory=True, persistent_workers=True)
test_dataloader = DataLoader(test_data, batch_size=128, shuffle=False, num_workers=10, pin_memory=True, persistent_workers=True)

# %% [markdown]
# ## Visualize Sample Images

# %%
fig = plt.figure(figsize=(8, 8))
rows, columns = 4, 4

for i in range(1, rows * columns + 1):
    idx = torch.randint(0, len(train_data), size=[1]).item()  # Random index
    img, label = train_data[idx][0], train_data[idx][1]
    fig.add_subplot(rows, columns, i)

    # Display image without converting to grayscale
    plt.imshow(img.permute(1, 2, 0))  # Change channels to last dimension (H, W, C)
    plt.title(train_data.classes[label])
    plt.grid(False)
    plt.axis(False)

plt.axis(False)
# plt.savefig("cifar10_dataset.jpg",dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ## Set its Parameters

# %%
chosen_model_params = [32, 32, 'MaxPool', 64, 64, 'MaxPool', 128, 128, 128, 'MaxPool']

model = MyCNN(input_shape=3,
                  output_shape=10,
                  activation = MPGELU,
                  params = chosen_model_params).to(device)

print(summary(model=model,
        input = torch.randn(size=(3, 32, 32)).unsqueeze(dim=0)))

total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MyCNN                                    --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       896
# │    └─MPGELU: 2-2                       1
# │    └─Conv2d: 2-3                       9,248
# │    └─MPGELU: 2-4                       1
# │    └─MaxPool2d: 2-5                    --
# │    └─Conv2d: 2-6                       18,496
# │    └─MPGELU: 2-7                       1
# │    └─Conv2d: 2-8                       36,928
# │    └─MPGELU: 2-9                       1
# │    └─MaxPool2d: 2-10                   --
# │    └─Conv2d: 2-11                      73,856
# │    └─MPGELU: 2-12                      1
# │    └─Conv2d: 2-13                      147,584
# │    └─MPGELU: 2-14                      1
# │    └─Conv2d: 2-15                      147,584
# │    └─MPGELU: 2-16                      1
# │    └─MaxPool2d: 2-17                   --
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-18                      524,544
# │    └─MPGELU: 2-19                      1
# │    └─Linear: 2-20                      65,792
# │    └─MPGELU: 2-21                      1
# │    └─Linear: 2-22                      2,570
# =================================================================
# Total params: 1,027,507
# Trainable params: 1,027,507
# Non-trainable params: 0
# =================================================================
# Total number of parameters: 1027507

# %% [markdown]
# ## Test Dummy Input

# %%
dummy_input = torch.randn(1, 3, 32, 32).to(device)
model(dummy_input)
# Out:
# tensor([[-0.0472,  0.0603, -0.0531, -0.0600, -0.0494,  0.0707,  0.0160, -0.0226,
#           0.0072, -0.0552]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Training and Execution

# %% [markdown]
# ## Setup loss, accuracy, and paramaters

# %% [markdown]
# ## Mathematical Definition of Categorical Cross-Entropy
#
# Categorical Cross-Entropy (CCE) is the standard loss function for multi-class classification. It measures the difference between two probability distributions: the actual ground-truth labels (usually one-hot encoded) and the model's predicted probabilities.
#
# For a single sample, the loss is defined as:
#
# $$f(y_i, \hat{y}_i) = -\sum_{i=1}^{C} y_i \log(\hat{y}_i)$$
#
# When calculating the average loss over a batch of $N$ samples, the formula expands to:
#
# $$f(y_i, \hat{y}_i) = -\frac{1}{N} \sum_{j=1}^{N} \sum_{i=1}^{C} y_{j,i} \log(\hat{y}_{j,i})$$
#
# **Where:**
# * $C$ = Total number of classes
# * $N$ = Total number of samples in the batch
# * $y_i$ (or $y_{j,i}$) = The true label (1 if the sample belongs to class $i$, and 0 for all other classes)
# * $\hat{y}_i$ (or $\hat{y}_{j,i}$) = The model's predicted probability that the sample belongs to class $i$ (typically the output of a Softmax activation function)
#
# > **Note:** Because the true labels $y_i$ are zero for all incorrect classes in one-hot encoding, the formula effectively simplifies to taking the negative log of the predicted probability for the **true** class.

# %%
#Setup Loss Functions, Accuracy function
loss_fn = torch.nn.CrossEntropyLoss(label_smoothing=0.1)

#Define Accuracy Metric
def calculate_accuracy(y_true, y_pred):
  correct = torch.eq(y_true, y_pred).sum().item()
  accuracy = (correct / len(y_pred)) * 100
  return accuracy

##Training Parameters

num_of_epochs = 100
num_loss_steps = 5

# %% [markdown]
# ### Gradient Norm
#
# **Mathematical Definition**: The $\ell^2$ Norm of the Gradient. In real analysis, the small $\ell^2$ norm (standard Euclidean norm) measures the magnitude of a finite-dimensional vector in $\mathbb{R}^n$.Let $\mathbf{w} \in \mathbb{R}^n$ represent the flattened continuous vector of all trainable parameters within the neural network architecture. The gradient of the objective loss function $\mathcal{L}$ with respect to these parameters is a discrete vector composed of partial derivatives:
# $$\nabla_{\mathbf{w}} \mathcal{L} = \left[ \frac{\partial \mathcal{L}}{\partial w_1}, \frac{\partial \mathcal{L}}{\partial w_2}, \dots, \frac{\partial \mathcal{L}}{\partial w_n} \right]^T$$
#
# The $\ell^2$ norm of this gradient vector, denoted as $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_{\ell^2}$ or simply $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2$, is defined as the square root of the sum of its squared coordinate components:$$\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2 = \sqrt{ \sum_{i=1}^{n} \left( \frac{\partial \mathcal{L}}{\partial w_i} \right)^2 }$$In the context of empirical risk minimization, bounding this sequence of finite sums guarantees that gradient updates remain stable and prevents the parameter vector from diverging during optimization.
#
#
# **IMPORTANT NOTE**
#
# In real and functional analysis, the capital $L^p$ spaces denote spaces of measurable functions, where the norm is evaluated via continuous integration, such as $\Vert{}f\Vert{}_{L^2} = \left( \int \vert{}f(x)\vert{}^2 dx \right)^{1/2}$. The lowercase $\ell^p$ spaces apply to discrete sequences or finite-dimensional coordinate vectors, where the norm is evaluated via discrete summation. Since the gradient of a neural network's loss with respect to its parameters, $\nabla_{\mathbf{w}} \mathcal{L}$, is a finite-dimensional vector of discrete scalar derivatives rather than a continuous mathematical function, finding its magnitude requires summing the squares of its individual components. You are completely correct: we use the small $\ell^2$ norm precisely because we are operating on discrete Euclidean vectors, not continuous functions.

# %% [markdown]
# ## Execution and Saving

# %%
torch.manual_seed(143)
activation_dict = {
    "PGELU": PGELU,
    "MP_GELU": MPGELU,
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}

all_results = {}

for act_name, act_fn in activation_dict.items():
    print(f"\n=======================================================")
    print(f"       TRAINING WITH ACTIVATION: {act_name}")
    print(f"=======================================================")

    model = MyCNN(input_shape=3, output_shape=10, activation=act_fn, params=chosen_model_params).to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)

    trainer = Trainer(model=model, loss_fn=loss_fn, optimizer=optimizer,
                      calculate_accuracy=calculate_accuracy, device=device, loss_steps=num_loss_steps)

    results = {
        "train_loss": [],
        "train_accu": [],
        "test_loss": [],
        "test_accu": [],
        "activation_params": {},
        "grad_norm": []  # Initialize an empty list to store gradient norms
    }

    start_time = time.perf_counter()

    for epoch in tqdm(range(num_of_epochs), desc=f"Training {act_name}"):
        if epoch % num_loss_steps == 0:
            print(f"Epoch: {epoch} \n =====================================================================")
        train_loss, train_accu, norm = trainer.train(data_loader=train_dataloader, epoch=epoch)
        test_loss, test_accu = trainer.test(data_loader=test_dataloader, epoch=epoch)

        results["train_loss"].append(train_loss)
        results["train_accu"].append(train_accu)
        results["test_loss"].append(test_loss)
        results["test_accu"].append(test_accu)
        results["grad_norm"].append(norm)

        # Track dynamic activation parameters
        for name, param in model.named_parameters():
            if 'alpha_param' in name or 'beta_param' in name or 's_param' in name:
                if name not in results.setdefault("activation_params", {}):
                    results["activation_params"][name] = []
                results["activation_params"][name].append(param.item())

    total_time = time.perf_counter() - start_time
    results["total_runtime"] = total_time
    all_results[act_name] = results

    # Save Model Checkpoint
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'results': results,
        'total_runtime': total_time,
        'activation_name': act_name
    }

    save_dir = "model_trained_params_new"
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir, f"chkpt2_{act_name}.pth")

    torch.save(checkpoint, save_path)
    print(f"Saved model state to {save_path}")
# Out:
# =======================================================
#        TRAINING WITH ACTIVATION: PGELU
# =======================================================
# Training PGELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 1.99017 | Training Accuracy: 29.06969%
# Test Loss 1.62783 | Test Accuracy 47.68592%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.30925 | Training Accuracy: 64.17279%
# Test Loss 1.13287 | Test Accuracy 72.91337%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.17913 | Training Accuracy: 70.01399%
# Test Loss 1.00768 | Test Accuracy 78.56013%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.11485 | Training Accuracy: 73.10822%
# Test Loss 0.97492 | Test Accuracy 80.31052%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.08388 | Training Accuracy: 74.68390%
# Test Loss 0.95731 | Test Accuracy 81.03244%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.05084 | Training Accuracy: 76.17687%
# Test Loss 0.93199 | Test Accuracy 82.02136%
# Epoch: 30
#  =====================================================================
# Training Loss: 1.02912 | Training Accuracy: 77.26463%
# Test Loss 0.91587 | Test Accuracy 83.21796%
# Epoch: 35
#  =====================================================================
# Training Loss: 1.00700 | Training Accuracy: 78.20492%
# Test Loss 0.89822 | Test Accuracy 83.96954%
# Epoch: 40
#  =====================================================================
# Training Loss: 2.30369 | Training Accuracy: 9.80619%
# Test Loss 2.30340 | Test Accuracy 10.02769%
# Epoch: 45
#  =====================================================================
# Training Loss: 2.30431 | Training Accuracy: 9.96124%
# Test Loss 2.30373 | Test Accuracy 10.09691%
# Epoch: 50
#  =====================================================================
# Training Loss: 2.30462 | Training Accuracy: 9.88811%
# Test Loss 2.30280 | Test Accuracy 10.09691%
# Epoch: 55
#  =====================================================================
# Training Loss: 2.30407 | Training Accuracy: 10.21180%
# Test Loss 2.30770 | Test Accuracy 10.09691%
# Epoch: 60
#  =====================================================================
# Training Loss: 2.30388 | Training Accuracy: 10.03676%
# Test Loss 2.30404 | Test Accuracy 10.09691%
# Epoch: 65
#  =====================================================================
# Training Loss: 2.30340 | Training Accuracy: 9.79380%
# Test Loss 2.30279 | Test Accuracy 9.88924%
# Epoch: 70
#  =====================================================================
# Training Loss: 2.30291 | Training Accuracy: 9.98881%
# Test Loss 2.30286 | Test Accuracy 9.95847%
# Epoch: 75
#  =====================================================================
# Training Loss: 2.30299 | Training Accuracy: 9.88651%
# Test Loss 2.30262 | Test Accuracy 9.95847%
# Epoch: 80
#  =====================================================================
# Training Loss: 2.30299 | Training Accuracy: 9.96803%
# Test Loss 2.30277 | Test Accuracy 10.09691%
# Epoch: 85
#  =====================================================================
# Training Loss: 2.30284 | Training Accuracy: 10.17983%
# Test Loss 2.30263 | Test Accuracy 9.88924%
# Epoch: 90
#  =====================================================================
# Training Loss: 2.30286 | Training Accuracy: 9.99760%
# Test Loss 2.30269 | Test Accuracy 9.88924%
# Epoch: 95
#  =====================================================================
# Training Loss: 2.30294 | Training Accuracy: 10.05994%
# Test Loss 2.30277 | Test Accuracy 10.02769%
# Saved model state to model_trained_params_new/chkpt2_PGELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: MP_GELU
# =======================================================
# Training MP_GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.09466 | Training Accuracy: 23.73961%
# Test Loss 1.81719 | Test Accuracy 37.27255%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.33455 | Training Accuracy: 62.54276%
# Test Loss 1.13602 | Test Accuracy 72.74525%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.12933 | Training Accuracy: 71.89298%
# Test Loss 0.97341 | Test Accuracy 79.75672%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.05150 | Training Accuracy: 75.75408%
# Test Loss 0.91856 | Test Accuracy 82.26859%
# Epoch: 20
#  =====================================================================
# Training Loss: 0.99461 | Training Accuracy: 78.19933%
# Test Loss 0.91944 | Test Accuracy 81.87302%
# Epoch: 25
#  =====================================================================
# Training Loss: 0.95799 | Training Accuracy: 80.15265%
# Test Loss 0.87315 | Test Accuracy 84.54312%
# Epoch: 30
#  =====================================================================
# Training Loss: 0.93251 | Training Accuracy: 81.20964%
# Test Loss 0.87337 | Test Accuracy 83.95965%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.90728 | Training Accuracy: 82.28980%
# Test Loss 0.86133 | Test Accuracy 84.47389%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.89163 | Training Accuracy: 83.10022%
# Test Loss 0.85304 | Test Accuracy 85.11669%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.88571 | Training Accuracy: 83.25527%
# Test Loss 0.82136 | Test Accuracy 86.58030%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.87172 | Training Accuracy: 83.95301%
# Test Loss 0.82533 | Test Accuracy 86.31329%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.85631 | Training Accuracy: 84.66232%
# Test Loss 0.82973 | Test Accuracy 86.49130%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.85133 | Training Accuracy: 84.78860%
# Test Loss 0.81970 | Test Accuracy 86.74842%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.83931 | Training Accuracy: 85.35166%
# Test Loss 0.81740 | Test Accuracy 86.65941%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.82986 | Training Accuracy: 85.93071%
# Test Loss 0.81660 | Test Accuracy 86.72864%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.82737 | Training Accuracy: 85.95668%
# Test Loss 0.81925 | Test Accuracy 86.83742%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.81905 | Training Accuracy: 86.24520%
# Test Loss 0.84044 | Test Accuracy 86.04628%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.81706 | Training Accuracy: 86.41304%
# Test Loss 0.81165 | Test Accuracy 87.31210%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.80738 | Training Accuracy: 86.80587%
# Test Loss 0.81757 | Test Accuracy 87.05498%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.80539 | Training Accuracy: 86.95133%
# Test Loss 0.81145 | Test Accuracy 87.35166%
# Saved model state to model_trained_params_new/chkpt2_MP_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: ReLU
# =======================================================
# Training ReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.11594 | Training Accuracy: 22.56993%
# Test Loss 1.88666 | Test Accuracy 34.40467%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.60218 | Training Accuracy: 49.03533%
# Test Loss 1.41792 | Test Accuracy 58.03995%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.35924 | Training Accuracy: 61.01263%
# Test Loss 1.18182 | Test Accuracy 69.72903%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.24557 | Training Accuracy: 66.35110%
# Test Loss 1.08646 | Test Accuracy 74.03085%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.18543 | Training Accuracy: 69.34863%
# Test Loss 1.06799 | Test Accuracy 75.35601%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.13615 | Training Accuracy: 71.61085%
# Test Loss 1.00943 | Test Accuracy 77.65032%
# Epoch: 30
#  =====================================================================
# Training Loss: 1.11232 | Training Accuracy: 72.74616%
# Test Loss 1.00694 | Test Accuracy 78.11511%
# Epoch: 35
#  =====================================================================
# Training Loss: 1.08581 | Training Accuracy: 73.88227%
# Test Loss 0.97727 | Test Accuracy 79.58861%
# Epoch: 40
#  =====================================================================
# Training Loss: 1.06326 | Training Accuracy: 75.24616%
# Test Loss 0.96402 | Test Accuracy 80.11274%
# Epoch: 45
#  =====================================================================
# Training Loss: 1.04914 | Training Accuracy: 75.82960%
# Test Loss 0.95373 | Test Accuracy 80.53797%
# Epoch: 50
#  =====================================================================
# Training Loss: 1.03391 | Training Accuracy: 76.45740%
# Test Loss 0.93714 | Test Accuracy 81.57634%
# Epoch: 55
#  =====================================================================
# Training Loss: 1.03048 | Training Accuracy: 76.52254%
# Test Loss 0.92677 | Test Accuracy 81.73457%
# Epoch: 60
#  =====================================================================
# Training Loss: 1.01420 | Training Accuracy: 77.39370%
# Test Loss 0.93367 | Test Accuracy 81.85324%
# Epoch: 65
#  =====================================================================
# Training Loss: 1.00079 | Training Accuracy: 78.04108%
# Test Loss 0.95414 | Test Accuracy 80.98299%
# Epoch: 70
#  =====================================================================
# Training Loss: 1.00068 | Training Accuracy: 77.87524%
# Test Loss 0.92159 | Test Accuracy 82.07081%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.99031 | Training Accuracy: 78.57497%
# Test Loss 0.91193 | Test Accuracy 82.14992%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.97517 | Training Accuracy: 79.29148%
# Test Loss 0.90178 | Test Accuracy 83.10918%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.97732 | Training Accuracy: 79.02374%
# Test Loss 0.91837 | Test Accuracy 82.17959%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.97137 | Training Accuracy: 79.41216%
# Test Loss 0.91837 | Test Accuracy 82.68394%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.96663 | Training Accuracy: 79.70828%
# Test Loss 0.89694 | Test Accuracy 83.29707%
# Saved model state to model_trained_params_new/chkpt2_ReLU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: GELU
# =======================================================
# Training GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.11243 | Training Accuracy: 22.17112%
# Test Loss 1.84796 | Test Accuracy 37.68790%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.36821 | Training Accuracy: 61.04979%
# Test Loss 1.17442 | Test Accuracy 70.55973%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.17073 | Training Accuracy: 70.20460%
# Test Loss 1.01286 | Test Accuracy 78.49090%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.09526 | Training Accuracy: 73.76159%
# Test Loss 0.95065 | Test Accuracy 80.96321%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.04528 | Training Accuracy: 76.32393%
# Test Loss 0.92349 | Test Accuracy 82.68394%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.00073 | Training Accuracy: 78.32201%
# Test Loss 0.92367 | Test Accuracy 83.10918%
# Epoch: 30
#  =====================================================================
# Training Loss: 0.97296 | Training Accuracy: 79.49329%
# Test Loss 0.90068 | Test Accuracy 83.36630%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.95541 | Training Accuracy: 80.25535%
# Test Loss 0.88256 | Test Accuracy 84.22666%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.93843 | Training Accuracy: 81.28357%
# Test Loss 0.87629 | Test Accuracy 84.54312%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.91886 | Training Accuracy: 82.01247%
# Test Loss 0.85123 | Test Accuracy 85.50237%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.90549 | Training Accuracy: 82.76175%
# Test Loss 0.85756 | Test Accuracy 85.76938%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.89285 | Training Accuracy: 83.11421%
# Test Loss 0.84048 | Test Accuracy 86.27373%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.88229 | Training Accuracy: 83.71164%
# Test Loss 0.83949 | Test Accuracy 86.24407%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.86879 | Training Accuracy: 84.25192%
# Test Loss 0.82828 | Test Accuracy 86.52097%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.86496 | Training Accuracy: 84.31066%
# Test Loss 0.84637 | Test Accuracy 85.76938%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.85540 | Training Accuracy: 84.66312%
# Test Loss 0.84974 | Test Accuracy 85.88805%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.84881 | Training Accuracy: 85.20740%
# Test Loss 0.83056 | Test Accuracy 86.70886%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.83751 | Training Accuracy: 85.56945%
# Test Loss 0.85163 | Test Accuracy 86.00672%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.82878 | Training Accuracy: 85.95628%
# Test Loss 0.83835 | Test Accuracy 86.17484%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.83013 | Training Accuracy: 85.95348%
# Test Loss 0.82516 | Test Accuracy 86.53085%
# Saved model state to model_trained_params_new/chkpt2_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: LeakyReLU
# =======================================================
# Training LeakyReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.18937 | Training Accuracy: 17.95596%
# Test Loss 1.96623 | Test Accuracy 28.90625%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.59435 | Training Accuracy: 49.41776%
# Test Loss 1.40875 | Test Accuracy 59.03877%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.30691 | Training Accuracy: 63.38115%
# Test Loss 1.16061 | Test Accuracy 70.53995%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.17362 | Training Accuracy: 69.94725%
# Test Loss 1.04591 | Test Accuracy 76.38449%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.10893 | Training Accuracy: 72.83568%
# Test Loss 1.00438 | Test Accuracy 78.46123%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.06659 | Training Accuracy: 74.83176%
# Test Loss 0.93780 | Test Accuracy 81.22033%
# Epoch: 30
#  =====================================================================
# Training Loss: 1.02589 | Training Accuracy: 76.58288%
# Test Loss 0.94072 | Test Accuracy 81.71479%
# Epoch: 35
#  =====================================================================
# Training Loss: 1.00269 | Training Accuracy: 77.75895%
# Test Loss 0.92610 | Test Accuracy 81.80380%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.97740 | Training Accuracy: 79.24512%
# Test Loss 0.90939 | Test Accuracy 82.97073%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.95862 | Training Accuracy: 79.89770%
# Test Loss 0.88456 | Test Accuracy 84.10799%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.94464 | Training Accuracy: 80.82601%
# Test Loss 0.88985 | Test Accuracy 83.14873%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.92706 | Training Accuracy: 81.49576%
# Test Loss 0.87991 | Test Accuracy 84.20688%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.91754 | Training Accuracy: 81.88539%
# Test Loss 0.87783 | Test Accuracy 84.01899%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.90543 | Training Accuracy: 82.33336%
# Test Loss 0.88767 | Test Accuracy 83.84098%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.89493 | Training Accuracy: 82.91200%
# Test Loss 0.84816 | Test Accuracy 85.45293%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.88804 | Training Accuracy: 83.21651%
# Test Loss 0.84587 | Test Accuracy 85.51226%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.87970 | Training Accuracy: 83.61453%
# Test Loss 0.87493 | Test Accuracy 84.63212%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.86548 | Training Accuracy: 84.24233%
# Test Loss 0.85599 | Test Accuracy 84.90902%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.86993 | Training Accuracy: 84.14882%
# Test Loss 0.84792 | Test Accuracy 85.79905%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.85492 | Training Accuracy: 84.73226%
# Test Loss 0.85258 | Test Accuracy 85.44304%
# Saved model state to model_trained_params_new/chkpt2_LeakyReLU.pth

# %% [markdown]
# # Loading the trained model params

# %%
activation_dict = {
    "MP_GELU": MPGELU,
    "PGELU": PGELU,
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}


# Initialize LoadedModel with the correct initial_fileName and checkpoint_dir
loader = LoadedModel(
    activation_dict=activation_dict,
    model_params=chosen_model_params,
    initial_fileName="chkpt2",
    checkpoint_dir="model_trained_params_new",
    device=device
)

# Run it
my_models = loader.load_checkpoints()
# Out:
# =======================================================
#        EVALUATING ACTIVATION: MP_GELU
# =======================================================
# Loaded trained model for MP_GELU from model_trained_params_new/chkpt2_MP_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: PGELU
# =======================================================
# Loaded trained model for PGELU from model_trained_params_new/chkpt2_PGELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: ReLU
# =======================================================
# Loaded trained model for ReLU from model_trained_params_new/chkpt2_ReLU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: GELU
# =======================================================
# Loaded trained model for GELU from model_trained_params_new/chkpt2_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: LeakyReLU
# =======================================================
# Loaded trained model for LeakyReLU from model_trained_params_new/chkpt2_LeakyReLU.pth

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Plotting

# %%
to_plot = {
    "MP_GELU":   {"results": my_models["MP_GELU"]["results"],   "linewidth": 3.0, "color": "#000000"}, # Jet Black
    "PGELU":     {"results": my_models["PGELU"]["results"],     "linewidth": 2.0, "color": "#E62937"}, # Strong Red
    "ReLU":      {"results": my_models["ReLU"]["results"],      "linewidth": 2.0, "color": "#009E73"}, # Teal
    "GELU":      {"results": my_models["GELU"]["results"],      "linewidth": 2.0, "color": "#4363D8"}, # Royal Blue
    "LeakyReLU": {"results": my_models["LeakyReLU"]["results"], "linewidth": 2.0, "color": "#F58231"}  # Bright Orange
}

# %% [markdown]
# ### Evolution of Learnable Parameters

# %% [markdown]
# #### $\alpha$ and $\beta$ of PGELU

# %%
alpha = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.alpha_param"]
beta = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.beta_param"]

fig, ax = plt.subplots(1, 2, figsize=(10, 6))
# Alpha Plot
ax[0].plot(alpha, label="Alpha Parameter", color="#E62937", linewidth=2.5)
# ax[0].set_title("Alpha Parameter Evolution", fontsize=14)
ax[0].grid(True, linestyle=':', alpha=0.9)
ax[0].tick_params(axis='x', labelsize=13)
ax[0].legend(fontsize=15)
# Beta Plot
ax[1].plot(beta, label="Beta Parameter", color="#009E73", linewidth=2.5)
# ax[1].set_title("Beta Parameter Evolution", fontsize=14)
ax[1].grid(True, linestyle=':', alpha=0.9)
ax[1].tick_params(axis='x', labelsize=13)
ax[1].legend(fontsize=15)


fig.supxlabel("Epochs", fontsize=15)
fig.supylabel("Parameter Value", fontsize=15)
fig.suptitle("Dynamic Activation Parameters Evolution for PGELU", fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### $\lambda$ of MPGELU

# %%
params_dict = my_models["MP_GELU"]["results"]["activation_params"]
s_vals = params_dict['conv_layers.1.s_param']
s_values = torch.tensor(s_vals, device=device, dtype=torch.float32)
lam = 1.0 + torch.log(1.0 + torch.exp(s_values))
plt.figure(figsize=(9, 6))
plt.plot(lam.detach().cpu().numpy(), linestyle='-', color='#000055')
plt.xlabel("Epoch", fontsize=13)
plt.ylabel(r"Learned $\lambda$", fontsize=13)
plt.title(r"Evolution of $\lambda$ of MPGELU During Training")
plt.grid(True, linestyle=':', alpha=0.9)
plt.yticks(np.arange(1.6, 3.2, 0.2), fontsize=13)
plt.xticks(np.arange(0, 65, 5), fontsize=13)
plt.tight_layout()
# plt.savefig("learned_lambda_evolution.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Train Loss Curves

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["train_loss"], **arguments)
plt.legend(loc="upper right", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)
plt.xticks(np.arange(-10,65,5), fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(0.75,2.4)
plt.xlim(-2,60)
plt.title("Training Loss Comparison Across Activation Functions", fontsize=16)
# plt.savefig("train_loss_comparison.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Test Loss Curves

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["test_loss"], **arguments)
plt.legend(loc="upper right", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)
plt.xticks(np.arange(-10,65,5), fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(0.75,2.4)
plt.xlim(-2,60)
plt.title("Test Loss Comparison Across Activation Functions", fontsize=16)
plt.tight_layout()
# plt.savefig("test_loss_comparison.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Training Accuracy

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["train_accu"], **arguments)
plt.legend(loc="lower right", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)
plt.xticks(np.arange(-5,65,5), fontsize=12)
plt.yticks(np.arange(0,110,10), fontsize=12)
plt.ylim(5,100)
plt.xlim(-2,60)
plt.title("Training Accuracy Comparison Across Activation Functions", fontsize=16)
plt.show()

# %% [markdown]
# ### Test Accuracy

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["test_accu"], **arguments)
plt.legend(loc="lower right", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)
plt.xticks(np.arange(-5,65,5), fontsize=12)
plt.yticks(np.arange(0,110,10), fontsize=12)
plt.ylim(5,100)
plt.xlim(-2,60)
plt.title("Test Accuracy Comparison Across Activation Functions", fontsize=16)
plt.show()

# %% [markdown]
# # $F_{1}$ Scores
# **Mathematical Definition of the $F_1$ Score**
#
# The $F_1$ score is the harmonic mean of Precision and Recall. It provides a single metric that balances both false positives and false negatives, making it particularly useful for evaluating models on imbalanced datasets.
#
# The general formula is defined as:
#
# $$F_1 = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$$
#
# To calculate the $F_1$ score, you must first calculate **Precision** and **Recall**:
#
# * **Precision** measures the proportion of positive predictions that were actually correct:
#   $$\text{Precision} = \frac{TP}{TP + FP}$$
#
# * **Recall** (also known as Sensitivity) measures the proportion of actual positives that were identified correctly:
#   $$\text{Recall} = \frac{TP}{TP + FN}$$
#
# By substituting Precision and Recall back into the original equation, the $F_1$ score can be expressed directly in terms of prediction outcomes:
#
# $$F_1 = \frac{2 \cdot TP}{2 \cdot TP + FP + FN}$$
#
# **Where:**
# * $TP$ = **True Positives** (Model correctly predicts the positive class)
# * $FP$ = **False Positives** (Model incorrectly predicts the positive class)
# * $FN$ = **False Negatives** (Model incorrectly predicts the negative class)

# %%
f1_results = {}

print("Calculating F1 Scores...")
print("========================")

for act_name, model_data in my_models.items():
    model = model_data["model"]
    model.eval()  # Ensure the model is in evaluation mode

    all_preds = []
    all_targets = []

    with torch.inference_mode():
        # Assuming you have your test_dataloader ready
        for inputs, targets in test_dataloader:
            inputs = inputs.to(device)

            # Get predictions
            outputs = model(inputs)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(targets.numpy())

    f1 = f1_score(all_targets, all_preds, average='macro')
    f1_results[act_name] = f1

    print(f"{act_name: >10}: {f1:.4f}")
# Out:
# Calculating F1 Scores...
# ========================
#    MP_GELU: 0.8725
#      PGELU: 0.0182
#       ReLU: 0.8353
#       GELU: 0.8714
#  LeakyReLU: 0.8583

# %%
# ============================================================
# GRADIENT L2 NORM VS EPOCH
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, properties in to_plot.items():

    plot_results = properties["results"]

    epochs = np.arange(1, len(plot_results["grad_norm"]) + 1)

    plt.plot(
        epochs,
        plot_results["grad_norm"],
        linewidth=properties["linewidth"],
        linestyle="-",
        label=act_name,
        color=properties["color"]
    )

plt.xlabel("Epoch", fontsize=13)
plt.ylabel("Gradient L₂ Norm", fontsize=13)

plt.title(
    "Gradient L₂ Norm vs Epoch",
    fontsize=16
)

plt.legend(
    loc="upper right",
    fontsize=12
)

plt.grid(
    True,
    linestyle="--",
    alpha=0.6
)

plt.xticks(
    np.arange(0, 101, 5),
    fontsize=12
)

plt.yticks(fontsize=12)

plt.xlim(1, 100)

plt.tight_layout()
plt.show()

# %%
import numpy as np

print("=" * 80)
print("Gradient L₂ Norms by Epoch")
print("=" * 80)

for act_name, results in all_results.items():
    print(f"\n{'=' * 80}")
    print(f"ACTIVATION: {act_name}")
    print(f"{'=' * 80}")

    grad_norms = np.array(results["grad_norm"], dtype=float)

    # Print every epoch
    for epoch, grad_norm in enumerate(grad_norms, start=1):
        print(f"Epoch {epoch:3d}: Gradient L₂ Norm = {grad_norm:.6f}")

    # Calculate statistics
    mean_grad = np.mean(grad_norms)
    std_grad = np.std(grad_norms, ddof=1)
    min_grad = np.min(grad_norms)
    max_grad = np.max(grad_norms)

    print(f"\n{'-' * 80}")
    print(f"SUMMARY — {act_name}")
    print(f"{'-' * 80}")
    print(f"Average Gradient L₂ Norm : {mean_grad:.6f} ± {std_grad:.6f}")
    print(f"Minimum Gradient L₂ Norm : {min_grad:.6f}")
    print(f"Maximum Gradient L₂ Norm : {max_grad:.6f}")
# Out:
# ================================================================================
# Gradient L₂ Norms by Epoch
# ================================================================================
#
# ================================================================================
# ACTIVATION: PGELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.011886
# Epoch   2: Gradient L₂ Norm = 0.008462
# Epoch   3: Gradient L₂ Norm = 0.007447
# Epoch   4: Gradient L₂ Norm = 0.010647
# Epoch   5: Gradient L₂ Norm = 0.010490
# Epoch   6: Gradient L₂ Norm = 0.011429
# Epoch   7: Gradient L₂ Norm = 0.009725
# Epoch   8: Gradient L₂ Norm = 0.010139
# Epoch   9: Gradient L₂ Norm = 0.014300
# Epoch  10: Gradient L₂ Norm = 0.009362
# Epoch  11: Gradient L₂ Norm = 0.014255
# Epoch  12: Gradient L₂ Norm = 0.011649
# Epoch  13: Gradient L₂ Norm = 0.013049
# Epoch  14: Gradient L₂ Norm = 0.012684
# Epoch  15: Gradient L₂ Norm = 0.018953
# Epoch  16: Gradient L₂ Norm = 0.014570
# Epoch  17: Gradient L₂ Norm = 0.020378
# Epoch  18: Gradient L₂ Norm = 0.012031
# Epoch  19: Gradient L₂ Norm = 0.019039
# Epoch  20: Gradient L₂ Norm = 0.015234
# Epoch  21: Gradient L₂ Norm = 0.017003
# Epoch  22: Gradient L₂ Norm = 0.013182
# Epoch  23: Gradient L₂ Norm = 0.014232
# Epoch  24: Gradient L₂ Norm = 0.085966
# Epoch  25: Gradient L₂ Norm = 0.012951
# Epoch  26: Gradient L₂ Norm = 0.014530
# Epoch  27: Gradient L₂ Norm = 0.011302
# Epoch  28: Gradient L₂ Norm = 0.015733
# Epoch  29: Gradient L₂ Norm = 0.013084
# Epoch  30: Gradient L₂ Norm = 0.013219
# Epoch  31: Gradient L₂ Norm = 0.019681
# Epoch  32: Gradient L₂ Norm = 0.013294
# Epoch  33: Gradient L₂ Norm = 0.015863
# Epoch  34: Gradient L₂ Norm = 0.020780
# Epoch  35: Gradient L₂ Norm = 0.013053
# Epoch  36: Gradient L₂ Norm = 0.017112
# Epoch  37: Gradient L₂ Norm = 0.001617
# Epoch  38: Gradient L₂ Norm = 0.001313
# Epoch  39: Gradient L₂ Norm = 0.001152
# Epoch  40: Gradient L₂ Norm = 0.002167
# Epoch  41: Gradient L₂ Norm = 0.001546
# Epoch  42: Gradient L₂ Norm = 0.001951
# Epoch  43: Gradient L₂ Norm = 0.000713
# Epoch  44: Gradient L₂ Norm = 0.000841
# Epoch  45: Gradient L₂ Norm = 0.001055
# Epoch  46: Gradient L₂ Norm = 0.001623
# Epoch  47: Gradient L₂ Norm = 0.000997
# Epoch  48: Gradient L₂ Norm = 0.002527
# Epoch  49: Gradient L₂ Norm = 0.000663
# Epoch  50: Gradient L₂ Norm = 0.000762
# Epoch  51: Gradient L₂ Norm = 0.001356
# Epoch  52: Gradient L₂ Norm = 0.001069
# Epoch  53: Gradient L₂ Norm = 0.000617
# Epoch  54: Gradient L₂ Norm = 0.001041
# Epoch  55: Gradient L₂ Norm = 0.001347
# Epoch  56: Gradient L₂ Norm = 0.000664
# Epoch  57: Gradient L₂ Norm = 0.000558
# Epoch  58: Gradient L₂ Norm = 0.000598
# Epoch  59: Gradient L₂ Norm = 0.001039
# Epoch  60: Gradient L₂ Norm = 0.000543
# Epoch  61: Gradient L₂ Norm = 0.000316
# Epoch  62: Gradient L₂ Norm = 0.000652
# Epoch  63: Gradient L₂ Norm = 0.000735
# Epoch  64: Gradient L₂ Norm = 0.000457
# Epoch  65: Gradient L₂ Norm = 0.000340
# Epoch  66: Gradient L₂ Norm = 0.000284
# Epoch  67: Gradient L₂ Norm = 0.000249
# Epoch  68: Gradient L₂ Norm = 0.000432
# Epoch  69: Gradient L₂ Norm = 0.000162
# Epoch  70: Gradient L₂ Norm = 0.000171
# Epoch  71: Gradient L₂ Norm = 0.000449
# Epoch  72: Gradient L₂ Norm = 0.000222
# Epoch  73: Gradient L₂ Norm = 0.000321
# Epoch  74: Gradient L₂ Norm = 0.000246
# Epoch  75: Gradient L₂ Norm = 0.000204
# Epoch  76: Gradient L₂ Norm = 0.000228
# Epoch  77: Gradient L₂ Norm = 0.000256
# Epoch  78: Gradient L₂ Norm = 0.000238
# Epoch  79: Gradient L₂ Norm = 0.000260
# Epoch  80: Gradient L₂ Norm = 0.000266
# Epoch  81: Gradient L₂ Norm = 0.000269
# Epoch  82: Gradient L₂ Norm = 0.000264
# Epoch  83: Gradient L₂ Norm = 0.000306
# Epoch  84: Gradient L₂ Norm = 0.000202
# Epoch  85: Gradient L₂ Norm = 0.000222
# Epoch  86: Gradient L₂ Norm = 0.000118
# Epoch  87: Gradient L₂ Norm = 0.000288
# Epoch  88: Gradient L₂ Norm = 0.000277
# Epoch  89: Gradient L₂ Norm = 0.000291
# Epoch  90: Gradient L₂ Norm = 0.000150
# Epoch  91: Gradient L₂ Norm = 0.000223
# Epoch  92: Gradient L₂ Norm = 0.000167
# Epoch  93: Gradient L₂ Norm = 0.000117
# Epoch  94: Gradient L₂ Norm = 0.000209
# Epoch  95: Gradient L₂ Norm = 0.000327
# Epoch  96: Gradient L₂ Norm = 0.000261
# Epoch  97: Gradient L₂ Norm = 0.000139
# Epoch  98: Gradient L₂ Norm = 0.000192
# Epoch  99: Gradient L₂ Norm = 0.000334
# Epoch 100: Gradient L₂ Norm = 0.000252
#
# --------------------------------------------------------------------------------
# SUMMARY — PGELU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.006056 ± 0.010420
# Minimum Gradient L₂ Norm : 0.000117
# Maximum Gradient L₂ Norm : 0.085966
#
# ================================================================================
# ACTIVATION: MP_GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.004380
# Epoch   2: Gradient L₂ Norm = 0.016823
# Epoch   3: Gradient L₂ Norm = 0.006711
# Epoch   4: Gradient L₂ Norm = 0.007072
# Epoch   5: Gradient L₂ Norm = 0.016488
# Epoch   6: Gradient L₂ Norm = 0.006779
# Epoch   7: Gradient L₂ Norm = 0.005799
# Epoch   8: Gradient L₂ Norm = 0.008462
# Epoch   9: Gradient L₂ Norm = 0.006549
# Epoch  10: Gradient L₂ Norm = 0.008491
# Epoch  11: Gradient L₂ Norm = 0.007097
# Epoch  12: Gradient L₂ Norm = 0.008672
# Epoch  13: Gradient L₂ Norm = 0.008494
# Epoch  14: Gradient L₂ Norm = 0.007635
# Epoch  15: Gradient L₂ Norm = 0.007759
# Epoch  16: Gradient L₂ Norm = 0.008727
# Epoch  17: Gradient L₂ Norm = 0.008824
# Epoch  18: Gradient L₂ Norm = 0.016582
# Epoch  19: Gradient L₂ Norm = 0.008254
# Epoch  20: Gradient L₂ Norm = 0.007936
# Epoch  21: Gradient L₂ Norm = 0.008786
# Epoch  22: Gradient L₂ Norm = 0.010226
# Epoch  23: Gradient L₂ Norm = 0.007554
# Epoch  24: Gradient L₂ Norm = 0.010798
# Epoch  25: Gradient L₂ Norm = 0.006946
# Epoch  26: Gradient L₂ Norm = 0.006788
# Epoch  27: Gradient L₂ Norm = 0.009183
# Epoch  28: Gradient L₂ Norm = 0.009932
# Epoch  29: Gradient L₂ Norm = 0.011672
# Epoch  30: Gradient L₂ Norm = 0.008516
# Epoch  31: Gradient L₂ Norm = 0.007686
# Epoch  32: Gradient L₂ Norm = 0.011293
# Epoch  33: Gradient L₂ Norm = 0.009979
# Epoch  34: Gradient L₂ Norm = 0.009382
# Epoch  35: Gradient L₂ Norm = 0.009276
# Epoch  36: Gradient L₂ Norm = 0.007633
# Epoch  37: Gradient L₂ Norm = 0.011083
# Epoch  38: Gradient L₂ Norm = 0.008897
# Epoch  39: Gradient L₂ Norm = 0.013509
# Epoch  40: Gradient L₂ Norm = 0.008153
# Epoch  41: Gradient L₂ Norm = 0.010839
# Epoch  42: Gradient L₂ Norm = 0.008034
# Epoch  43: Gradient L₂ Norm = 0.010189
# Epoch  44: Gradient L₂ Norm = 0.012873
# Epoch  45: Gradient L₂ Norm = 0.008016
# Epoch  46: Gradient L₂ Norm = 0.012237
# Epoch  47: Gradient L₂ Norm = 0.007537
# Epoch  48: Gradient L₂ Norm = 0.012270
# Epoch  49: Gradient L₂ Norm = 0.008218
# Epoch  50: Gradient L₂ Norm = 0.010257
# Epoch  51: Gradient L₂ Norm = 0.008796
# Epoch  52: Gradient L₂ Norm = 0.009920
# Epoch  53: Gradient L₂ Norm = 0.008012
# Epoch  54: Gradient L₂ Norm = 0.010952
# Epoch  55: Gradient L₂ Norm = 0.007275
# Epoch  56: Gradient L₂ Norm = 0.007506
# Epoch  57: Gradient L₂ Norm = 0.009923
# Epoch  58: Gradient L₂ Norm = 0.010288
# Epoch  59: Gradient L₂ Norm = 0.006522
# Epoch  60: Gradient L₂ Norm = 0.011538
# Epoch  61: Gradient L₂ Norm = 0.008978
# Epoch  62: Gradient L₂ Norm = 0.007254
# Epoch  63: Gradient L₂ Norm = 0.011075
# Epoch  64: Gradient L₂ Norm = 0.007202
# Epoch  65: Gradient L₂ Norm = 0.009823
# Epoch  66: Gradient L₂ Norm = 0.012520
# Epoch  67: Gradient L₂ Norm = 0.007522
# Epoch  68: Gradient L₂ Norm = 0.010950
# Epoch  69: Gradient L₂ Norm = 0.008764
# Epoch  70: Gradient L₂ Norm = 0.007636
# Epoch  71: Gradient L₂ Norm = 0.008410
# Epoch  72: Gradient L₂ Norm = 0.006805
# Epoch  73: Gradient L₂ Norm = 0.012210
# Epoch  74: Gradient L₂ Norm = 0.007907
# Epoch  75: Gradient L₂ Norm = 0.011164
# Epoch  76: Gradient L₂ Norm = 0.007197
# Epoch  77: Gradient L₂ Norm = 0.015470
# Epoch  78: Gradient L₂ Norm = 0.011531
# Epoch  79: Gradient L₂ Norm = 0.009818
# Epoch  80: Gradient L₂ Norm = 0.006729
# Epoch  81: Gradient L₂ Norm = 0.008273
# Epoch  82: Gradient L₂ Norm = 0.008838
# Epoch  83: Gradient L₂ Norm = 0.011203
# Epoch  84: Gradient L₂ Norm = 0.010739
# Epoch  85: Gradient L₂ Norm = 0.009414
# Epoch  86: Gradient L₂ Norm = 0.008254
# Epoch  87: Gradient L₂ Norm = 0.011254
# Epoch  88: Gradient L₂ Norm = 0.006821
# Epoch  89: Gradient L₂ Norm = 0.012395
# Epoch  90: Gradient L₂ Norm = 0.010641
# Epoch  91: Gradient L₂ Norm = 0.012566
# Epoch  92: Gradient L₂ Norm = 0.007708
# Epoch  93: Gradient L₂ Norm = 0.015070
# Epoch  94: Gradient L₂ Norm = 0.010418
# Epoch  95: Gradient L₂ Norm = 0.018234
# Epoch  96: Gradient L₂ Norm = 0.011951
# Epoch  97: Gradient L₂ Norm = 0.011753
# Epoch  98: Gradient L₂ Norm = 0.011087
# Epoch  99: Gradient L₂ Norm = 0.008255
# Epoch 100: Gradient L₂ Norm = 0.013669
#
# --------------------------------------------------------------------------------
# SUMMARY — MP_GELU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.009635 ± 0.002569
# Minimum Gradient L₂ Norm : 0.004380
# Maximum Gradient L₂ Norm : 0.018234
#
# ================================================================================
# ACTIVATION: ReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.005608
# Epoch   2: Gradient L₂ Norm = 0.007516
# Epoch   3: Gradient L₂ Norm = 0.010020
# Epoch   4: Gradient L₂ Norm = 0.010219
# Epoch   5: Gradient L₂ Norm = 0.017327
# Epoch   6: Gradient L₂ Norm = 0.017985
# Epoch   7: Gradient L₂ Norm = 0.013235
# Epoch   8: Gradient L₂ Norm = 0.016702
# Epoch   9: Gradient L₂ Norm = 0.007594
# Epoch  10: Gradient L₂ Norm = 0.017247
# Epoch  11: Gradient L₂ Norm = 0.014115
# Epoch  12: Gradient L₂ Norm = 0.012300
# Epoch  13: Gradient L₂ Norm = 0.010333
# Epoch  14: Gradient L₂ Norm = 0.017608
# Epoch  15: Gradient L₂ Norm = 0.013748
# Epoch  16: Gradient L₂ Norm = 0.012969
# Epoch  17: Gradient L₂ Norm = 0.017430
# Epoch  18: Gradient L₂ Norm = 0.010679
# Epoch  19: Gradient L₂ Norm = 0.010775
# Epoch  20: Gradient L₂ Norm = 0.007318
# Epoch  21: Gradient L₂ Norm = 0.012436
# Epoch  22: Gradient L₂ Norm = 0.013522
# Epoch  23: Gradient L₂ Norm = 0.009784
# Epoch  24: Gradient L₂ Norm = 0.017604
# Epoch  25: Gradient L₂ Norm = 0.010714
# Epoch  26: Gradient L₂ Norm = 0.010195
# Epoch  27: Gradient L₂ Norm = 0.008758
# Epoch  28: Gradient L₂ Norm = 0.019865
# Epoch  29: Gradient L₂ Norm = 0.010863
# Epoch  30: Gradient L₂ Norm = 0.012716
# Epoch  31: Gradient L₂ Norm = 0.010482
# Epoch  32: Gradient L₂ Norm = 0.014788
# Epoch  33: Gradient L₂ Norm = 0.013009
# Epoch  34: Gradient L₂ Norm = 0.005446
# Epoch  35: Gradient L₂ Norm = 0.013326
# Epoch  36: Gradient L₂ Norm = 0.020179
# Epoch  37: Gradient L₂ Norm = 0.007486
# Epoch  38: Gradient L₂ Norm = 0.010241
# Epoch  39: Gradient L₂ Norm = 0.015255
# Epoch  40: Gradient L₂ Norm = 0.016309
# Epoch  41: Gradient L₂ Norm = 0.014830
# Epoch  42: Gradient L₂ Norm = 0.012858
# Epoch  43: Gradient L₂ Norm = 0.009496
# Epoch  44: Gradient L₂ Norm = 0.014058
# Epoch  45: Gradient L₂ Norm = 0.009455
# Epoch  46: Gradient L₂ Norm = 0.011171
# Epoch  47: Gradient L₂ Norm = 0.009998
# Epoch  48: Gradient L₂ Norm = 0.011890
# Epoch  49: Gradient L₂ Norm = 0.010377
# Epoch  50: Gradient L₂ Norm = 0.009111
# Epoch  51: Gradient L₂ Norm = 0.011432
# Epoch  52: Gradient L₂ Norm = 0.009508
# Epoch  53: Gradient L₂ Norm = 0.013227
# Epoch  54: Gradient L₂ Norm = 0.009233
# Epoch  55: Gradient L₂ Norm = 0.008716
# Epoch  56: Gradient L₂ Norm = 0.008744
# Epoch  57: Gradient L₂ Norm = 0.011449
# Epoch  58: Gradient L₂ Norm = 0.006682
# Epoch  59: Gradient L₂ Norm = 0.007562
# Epoch  60: Gradient L₂ Norm = 0.017517
# Epoch  61: Gradient L₂ Norm = 0.008423
# Epoch  62: Gradient L₂ Norm = 0.011189
# Epoch  63: Gradient L₂ Norm = 0.012594
# Epoch  64: Gradient L₂ Norm = 0.008870
# Epoch  65: Gradient L₂ Norm = 0.010931
# Epoch  66: Gradient L₂ Norm = 0.015852
# Epoch  67: Gradient L₂ Norm = 0.011040
# Epoch  68: Gradient L₂ Norm = 0.009924
# Epoch  69: Gradient L₂ Norm = 0.009279
# Epoch  70: Gradient L₂ Norm = 0.009046
# Epoch  71: Gradient L₂ Norm = 0.010701
# Epoch  72: Gradient L₂ Norm = 0.011371
# Epoch  73: Gradient L₂ Norm = 0.010983
# Epoch  74: Gradient L₂ Norm = 0.010210
# Epoch  75: Gradient L₂ Norm = 0.011963
# Epoch  76: Gradient L₂ Norm = 0.014573
# Epoch  77: Gradient L₂ Norm = 0.013798
# Epoch  78: Gradient L₂ Norm = 0.010332
# Epoch  79: Gradient L₂ Norm = 0.011321
# Epoch  80: Gradient L₂ Norm = 0.014698
# Epoch  81: Gradient L₂ Norm = 0.007871
# Epoch  82: Gradient L₂ Norm = 0.011567
# Epoch  83: Gradient L₂ Norm = 0.011891
# Epoch  84: Gradient L₂ Norm = 0.012770
# Epoch  85: Gradient L₂ Norm = 0.010429
# Epoch  86: Gradient L₂ Norm = 0.010137
# Epoch  87: Gradient L₂ Norm = 0.010941
# Epoch  88: Gradient L₂ Norm = 0.010023
# Epoch  89: Gradient L₂ Norm = 0.010749
# Epoch  90: Gradient L₂ Norm = 0.010812
# Epoch  91: Gradient L₂ Norm = 0.008039
# Epoch  92: Gradient L₂ Norm = 0.009703
# Epoch  93: Gradient L₂ Norm = 0.013762
# Epoch  94: Gradient L₂ Norm = 0.013367
# Epoch  95: Gradient L₂ Norm = 0.010551
# Epoch  96: Gradient L₂ Norm = 0.014739
# Epoch  97: Gradient L₂ Norm = 0.014033
# Epoch  98: Gradient L₂ Norm = 0.012321
# Epoch  99: Gradient L₂ Norm = 0.010450
# Epoch 100: Gradient L₂ Norm = 0.010794
#
# --------------------------------------------------------------------------------
# SUMMARY — ReLU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.011731 ± 0.003026
# Minimum Gradient L₂ Norm : 0.005446
# Maximum Gradient L₂ Norm : 0.020179
#
# ================================================================================
# ACTIVATION: GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.007574
# Epoch   2: Gradient L₂ Norm = 0.004161
# Epoch   3: Gradient L₂ Norm = 0.008192
# Epoch   4: Gradient L₂ Norm = 0.006168
# Epoch   5: Gradient L₂ Norm = 0.006145
# Epoch   6: Gradient L₂ Norm = 0.009231
# Epoch   7: Gradient L₂ Norm = 0.011051
# Epoch   8: Gradient L₂ Norm = 0.010171
# Epoch   9: Gradient L₂ Norm = 0.008931
# Epoch  10: Gradient L₂ Norm = 0.006888
# Epoch  11: Gradient L₂ Norm = 0.009800
# Epoch  12: Gradient L₂ Norm = 0.012161
# Epoch  13: Gradient L₂ Norm = 0.006210
# Epoch  14: Gradient L₂ Norm = 0.008354
# Epoch  15: Gradient L₂ Norm = 0.004737
# Epoch  16: Gradient L₂ Norm = 0.005827
# Epoch  17: Gradient L₂ Norm = 0.008750
# Epoch  18: Gradient L₂ Norm = 0.006432
# Epoch  19: Gradient L₂ Norm = 0.006188
# Epoch  20: Gradient L₂ Norm = 0.008692
# Epoch  21: Gradient L₂ Norm = 0.005771
# Epoch  22: Gradient L₂ Norm = 0.011436
# Epoch  23: Gradient L₂ Norm = 0.005582
# Epoch  24: Gradient L₂ Norm = 0.006188
# Epoch  25: Gradient L₂ Norm = 0.008045
# Epoch  26: Gradient L₂ Norm = 0.005567
# Epoch  27: Gradient L₂ Norm = 0.012897
# Epoch  28: Gradient L₂ Norm = 0.009290
# Epoch  29: Gradient L₂ Norm = 0.010743
# Epoch  30: Gradient L₂ Norm = 0.009914
# Epoch  31: Gradient L₂ Norm = 0.008972
# Epoch  32: Gradient L₂ Norm = 0.012430
# Epoch  33: Gradient L₂ Norm = 0.007021
# Epoch  34: Gradient L₂ Norm = 0.010221
# Epoch  35: Gradient L₂ Norm = 0.009692
# Epoch  36: Gradient L₂ Norm = 0.007158
# Epoch  37: Gradient L₂ Norm = 0.005930
# Epoch  38: Gradient L₂ Norm = 0.007804
# Epoch  39: Gradient L₂ Norm = 0.007923
# Epoch  40: Gradient L₂ Norm = 0.008905
# Epoch  41: Gradient L₂ Norm = 0.006841
# Epoch  42: Gradient L₂ Norm = 0.006295
# Epoch  43: Gradient L₂ Norm = 0.008136
# Epoch  44: Gradient L₂ Norm = 0.008520
# Epoch  45: Gradient L₂ Norm = 0.007202
# Epoch  46: Gradient L₂ Norm = 0.005928
# Epoch  47: Gradient L₂ Norm = 0.005481
# Epoch  48: Gradient L₂ Norm = 0.007807
# Epoch  49: Gradient L₂ Norm = 0.009030
# Epoch  50: Gradient L₂ Norm = 0.006940
# Epoch  51: Gradient L₂ Norm = 0.008302
# Epoch  52: Gradient L₂ Norm = 0.012407
# Epoch  53: Gradient L₂ Norm = 0.006345
# Epoch  54: Gradient L₂ Norm = 0.006035
# Epoch  55: Gradient L₂ Norm = 0.007263
# Epoch  56: Gradient L₂ Norm = 0.010303
# Epoch  57: Gradient L₂ Norm = 0.006771
# Epoch  58: Gradient L₂ Norm = 0.008391
# Epoch  59: Gradient L₂ Norm = 0.007976
# Epoch  60: Gradient L₂ Norm = 0.011404
# Epoch  61: Gradient L₂ Norm = 0.012431
# Epoch  62: Gradient L₂ Norm = 0.007880
# Epoch  63: Gradient L₂ Norm = 0.008709
# Epoch  64: Gradient L₂ Norm = 0.010141
# Epoch  65: Gradient L₂ Norm = 0.008322
# Epoch  66: Gradient L₂ Norm = 0.006049
# Epoch  67: Gradient L₂ Norm = 0.007255
# Epoch  68: Gradient L₂ Norm = 0.012091
# Epoch  69: Gradient L₂ Norm = 0.008798
# Epoch  70: Gradient L₂ Norm = 0.006901
# Epoch  71: Gradient L₂ Norm = 0.010138
# Epoch  72: Gradient L₂ Norm = 0.011072
# Epoch  73: Gradient L₂ Norm = 0.012414
# Epoch  74: Gradient L₂ Norm = 0.007135
# Epoch  75: Gradient L₂ Norm = 0.006588
# Epoch  76: Gradient L₂ Norm = 0.008748
# Epoch  77: Gradient L₂ Norm = 0.008767
# Epoch  78: Gradient L₂ Norm = 0.011008
# Epoch  79: Gradient L₂ Norm = 0.007515
# Epoch  80: Gradient L₂ Norm = 0.010624
# Epoch  81: Gradient L₂ Norm = 0.009111
# Epoch  82: Gradient L₂ Norm = 0.009370
# Epoch  83: Gradient L₂ Norm = 0.008650
# Epoch  84: Gradient L₂ Norm = 0.006765
# Epoch  85: Gradient L₂ Norm = 0.009205
# Epoch  86: Gradient L₂ Norm = 0.010506
# Epoch  87: Gradient L₂ Norm = 0.011376
# Epoch  88: Gradient L₂ Norm = 0.006368
# Epoch  89: Gradient L₂ Norm = 0.014390
# Epoch  90: Gradient L₂ Norm = 0.010384
# Epoch  91: Gradient L₂ Norm = 0.005222
# Epoch  92: Gradient L₂ Norm = 0.010451
# Epoch  93: Gradient L₂ Norm = 0.011754
# Epoch  94: Gradient L₂ Norm = 0.011450
# Epoch  95: Gradient L₂ Norm = 0.009224
# Epoch  96: Gradient L₂ Norm = 0.007890
# Epoch  97: Gradient L₂ Norm = 0.009839
# Epoch  98: Gradient L₂ Norm = 0.009339
# Epoch  99: Gradient L₂ Norm = 0.008464
# Epoch 100: Gradient L₂ Norm = 0.012900
#
# --------------------------------------------------------------------------------
# SUMMARY — GELU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.008598 ± 0.002160
# Minimum Gradient L₂ Norm : 0.004161
# Maximum Gradient L₂ Norm : 0.014390
#
# ================================================================================
# ACTIVATION: LeakyReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.003802
# Epoch   2: Gradient L₂ Norm = 0.025233
# Epoch   3: Gradient L₂ Norm = 0.006049
# Epoch   4: Gradient L₂ Norm = 0.020139
# Epoch   5: Gradient L₂ Norm = 0.012244
# Epoch   6: Gradient L₂ Norm = 0.015230
# Epoch   7: Gradient L₂ Norm = 0.019687
# Epoch   8: Gradient L₂ Norm = 0.021484
# Epoch   9: Gradient L₂ Norm = 0.014517
# Epoch  10: Gradient L₂ Norm = 0.015012
# Epoch  11: Gradient L₂ Norm = 0.015526
# Epoch  12: Gradient L₂ Norm = 0.015261
# Epoch  13: Gradient L₂ Norm = 0.013651
# Epoch  14: Gradient L₂ Norm = 0.013313
# Epoch  15: Gradient L₂ Norm = 0.012390
# Epoch  16: Gradient L₂ Norm = 0.010310
# Epoch  17: Gradient L₂ Norm = 0.009485
# Epoch  18: Gradient L₂ Norm = 0.013795
# Epoch  19: Gradient L₂ Norm = 0.010851
# Epoch  20: Gradient L₂ Norm = 0.015247
# Epoch  21: Gradient L₂ Norm = 0.024603
# Epoch  22: Gradient L₂ Norm = 0.006929
# Epoch  23: Gradient L₂ Norm = 0.009064
# Epoch  24: Gradient L₂ Norm = 0.011365
# Epoch  25: Gradient L₂ Norm = 0.010580
# Epoch  26: Gradient L₂ Norm = 0.010647
# Epoch  27: Gradient L₂ Norm = 0.013181
# Epoch  28: Gradient L₂ Norm = 0.015649
# Epoch  29: Gradient L₂ Norm = 0.012487
# Epoch  30: Gradient L₂ Norm = 0.013580
# Epoch  31: Gradient L₂ Norm = 0.008470
# Epoch  32: Gradient L₂ Norm = 0.007846
# Epoch  33: Gradient L₂ Norm = 0.008724
# Epoch  34: Gradient L₂ Norm = 0.013792
# Epoch  35: Gradient L₂ Norm = 0.013247
# Epoch  36: Gradient L₂ Norm = 0.009372
# Epoch  37: Gradient L₂ Norm = 0.010774
# Epoch  38: Gradient L₂ Norm = 0.012461
# Epoch  39: Gradient L₂ Norm = 0.011064
# Epoch  40: Gradient L₂ Norm = 0.012024
# Epoch  41: Gradient L₂ Norm = 0.011046
# Epoch  42: Gradient L₂ Norm = 0.010388
# Epoch  43: Gradient L₂ Norm = 0.014945
# Epoch  44: Gradient L₂ Norm = 0.009316
# Epoch  45: Gradient L₂ Norm = 0.014313
# Epoch  46: Gradient L₂ Norm = 0.009193
# Epoch  47: Gradient L₂ Norm = 0.008463
# Epoch  48: Gradient L₂ Norm = 0.012780
# Epoch  49: Gradient L₂ Norm = 0.009386
# Epoch  50: Gradient L₂ Norm = 0.008015
# Epoch  51: Gradient L₂ Norm = 0.010988
# Epoch  52: Gradient L₂ Norm = 0.008208
# Epoch  53: Gradient L₂ Norm = 0.011804
# Epoch  54: Gradient L₂ Norm = 0.014683
# Epoch  55: Gradient L₂ Norm = 0.010835
# Epoch  56: Gradient L₂ Norm = 0.008404
# Epoch  57: Gradient L₂ Norm = 0.012525
# Epoch  58: Gradient L₂ Norm = 0.010225
# Epoch  59: Gradient L₂ Norm = 0.012876
# Epoch  60: Gradient L₂ Norm = 0.021338
# Epoch  61: Gradient L₂ Norm = 0.009333
# Epoch  62: Gradient L₂ Norm = 0.009603
# Epoch  63: Gradient L₂ Norm = 0.010098
# Epoch  64: Gradient L₂ Norm = 0.015035
# Epoch  65: Gradient L₂ Norm = 0.010945
# Epoch  66: Gradient L₂ Norm = 0.009609
# Epoch  67: Gradient L₂ Norm = 0.009082
# Epoch  68: Gradient L₂ Norm = 0.010035
# Epoch  69: Gradient L₂ Norm = 0.010705
# Epoch  70: Gradient L₂ Norm = 0.009714
# Epoch  71: Gradient L₂ Norm = 0.014221
# Epoch  72: Gradient L₂ Norm = 0.011538
# Epoch  73: Gradient L₂ Norm = 0.010647
# Epoch  74: Gradient L₂ Norm = 0.009272
# Epoch  75: Gradient L₂ Norm = 0.008910
# Epoch  76: Gradient L₂ Norm = 0.009721
# Epoch  77: Gradient L₂ Norm = 0.012679
# Epoch  78: Gradient L₂ Norm = 0.009348
# Epoch  79: Gradient L₂ Norm = 0.009254
# Epoch  80: Gradient L₂ Norm = 0.011032
# Epoch  81: Gradient L₂ Norm = 0.009307
# Epoch  82: Gradient L₂ Norm = 0.010565
# Epoch  83: Gradient L₂ Norm = 0.010254
# Epoch  84: Gradient L₂ Norm = 0.014685
# Epoch  85: Gradient L₂ Norm = 0.012558
# Epoch  86: Gradient L₂ Norm = 0.008969
# Epoch  87: Gradient L₂ Norm = 0.010575
# Epoch  88: Gradient L₂ Norm = 0.009329
# Epoch  89: Gradient L₂ Norm = 0.011861
# Epoch  90: Gradient L₂ Norm = 0.010426
# Epoch  91: Gradient L₂ Norm = 0.015929
# Epoch  92: Gradient L₂ Norm = 0.008880
# Epoch  93: Gradient L₂ Norm = 0.010975
# Epoch  94: Gradient L₂ Norm = 0.010333
# Epoch  95: Gradient L₂ Norm = 0.008493
# Epoch  96: Gradient L₂ Norm = 0.013640
# Epoch  97: Gradient L₂ Norm = 0.010056
# Epoch  98: Gradient L₂ Norm = 0.009666
# Epoch  99: Gradient L₂ Norm = 0.010059
# Epoch 100: Gradient L₂ Norm = 0.014430
#
# --------------------------------------------------------------------------------
# SUMMARY — LeakyReLU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.011806 ± 0.003530
# Minimum Gradient L₂ Norm : 0.003802
# Maximum Gradient L₂ Norm : 0.025233
