# %% [markdown]
# # Introduction
#
# <center>
# <h2>
# Computational Experiments with Modern Parametrized Gaussian Error Linear Unit (MPGELU)
# </h2>
# <b>A demonstration by: Jose Aries E. De Los Santos</b>
# </center>

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %% [markdown]
# # Import Libraries

# %%
import os
import sys
from pathlib import Path

#PyTorch
import torch as torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
import time
from torchinfo import summary

import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import random
from typing import Iterable, Callable


#sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

#Import torchvision
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor
from torchinfo import summary

#Import tqdm for a cool progress bar
from tqdm.auto import tqdm

# Measure time
from timeit import default_timer as timer

seed = 143
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)


print(f"PyTorch Version: {torch.__version__}")
print(f"Numpy Version: {np.__version__}")
print(f"Pandas Version: {pd.__version__}")
# print(f"Matplotlib Version: {matplotlib.__version__}")
print(f"SciPy Version: {scipy.__version__}")

# device = "cuda" if torch.cuda.is_available() else "cpu"

if torch.cuda.is_available():
    device = "cuda"
    print(f"Device: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = "mps"
    print(f"Device: {torch.backends.mps.is_available()}")
else:
    device = "cpu"
    print(f"Device: {device}")
# Out:
# PyTorch Version: 2.11.0+cu128
# Numpy Version: 2.1.3
# Pandas Version: 2.2.3
# SciPy Version: 1.16.3
# Device: NVIDIA A100-SXM4-40GB

# %% [markdown]
# # Dynamic Path Modification
#
# * It is a runtime technique used to explicitly tell Python where to look for modules or packages when you run an ``import`` statement.

# %% [markdown]
# ## Import Helper Functions

# %%
### Add the parent directory to the sys.path to import MyCNN and MPGELU
#%reload_ext autoreload
#%autoreload 2
mother_path = Path.cwd()
for folder in ["utility", "act_fns", "models"]:
    path = os.path.join(mother_path , folder)
    if path not in sys.path:
        sys.path.append(path)
from MPGELU import MPGELU
from PGELU import PGELU
from MyCNN import MyCNN
from DataTransforms import DataTransforms
from Trainer import Trainer
from LoadedModel import LoadedModel

# %% [markdown]
# # MP GELU
#
# * Modified Parametric Gaussian Error Linear Unit
# $$
# f(x) = \frac{x}{2} \left[ 1 + \text{erf}\left( \frac{\lambda x}{\sqrt{2}}\right)\right] = \frac{x}{2} + \frac{x}{\sqrt{\pi}}\int_{0}^{\lambda x / \sqrt{2}} e^{-u^{2}}du
# $$
# where $\lambda  = (1 + \ln(1 + e^{s})) \geq 1$   $\forall s \in \mathbb{R}$
#
# * Check MPGELU.py file for the implementation of the MPGELU activation function

# %%
x_np = np.linspace(-4.0, 4.0, 400)
x_tensor = torch.tensor(x_np, dtype=torch.float32)
# s_values = np.arange(-2.0, 2.0, 0.1)
s_values = [-100, 0.0, 100, ]
plt.figure(figsize=(9, 6))

for s_val in s_values:
    activation1 = MPGELU(s_param=s_val)
    activation2 = MPGELU(s_param=s_val, use_softplus=False)
    with torch.no_grad():
        y_tensor1 = activation1(x_tensor)
        y_tensor2 = activation2(x_tensor)

    lam_val = (1.0 + F.softplus(torch.tensor(s_val, dtype=torch.float32))).item()
    plt.plot(x_np, y_tensor1.numpy(), label=f"s = {s_val}", linewidth=2.5)
    # plt.plot(x_np, y_tensor2.numpy(), label=f"s = {s_val}", linewidth=2)

# 4. Format the plot
plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
plt.axvline(0, color='black', linewidth=0.8, linestyle='--')
plt.title("Modified Parametric GELU (MP-GELU) Activation Function", fontsize=15)
xticks = np.arange(-4, 5, 0.8)
plt.xticks(xticks,fontsize=12)
plt.xlabel("Input ($x$)", fontsize=12)
yticks = np.arange(-2, 5, 0.8)
plt.yticks(yticks,fontsize=12)
plt.ylabel("Output ($f(x)$)", fontsize=12)
plt.grid(True, linestyle=':', alpha=0.9)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# # Data Processing

# %%
transformer = DataTransforms(dataset='cifar10', use_augmentation=True, use_stats=False)
train_transform = transformer.get_train_transform()
test_transform = transformer.get_test_transform()


train_data = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
test_data = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)


train_dataloader = DataLoader(train_data, batch_size=128, shuffle=True, num_workers=10, pin_memory=True, persistent_workers=True)
test_dataloader = DataLoader(test_data, batch_size=128, shuffle=False, num_workers=10, pin_memory=True, persistent_workers=True)
# Out:
# 100%|██████████| 170M/170M [00:15<00:00, 11.0MB/s]

# %% [markdown]
# ## Visualize Sample Images

# %%
fig = plt.figure(figsize=(8, 8))
rows, columns = 4, 4

for i in range(1, rows * columns + 1):
    idx = torch.randint(0, len(train_data), size=[1]).item()  # Random index
    img, label = train_data[idx][0], train_data[idx][1]
    fig.add_subplot(rows, columns, i)

    # Display image without converting to grayscale
    plt.imshow(img.permute(1, 2, 0))  # Change channels to last dimension (H, W, C)
    plt.title(train_data.classes[label])
    plt.grid(False)
    plt.axis(False)

plt.axis(False)
# plt.savefig("cifar10_dataset.jpg",dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ## Set its Parameters

# %%
chosen_model_params = [32, 32, 'MaxPool', 64, 64, 'MaxPool', 128, 128, 128, 'MaxPool']

model = MyCNN(input_shape=3,
                  output_shape=10,
                  activation = MPGELU,
                  params = chosen_model_params).to(device)

print(summary(model=model,
        input = torch.randn(size=(3, 32, 32)).unsqueeze(dim=0)))

total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MyCNN                                    --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       896
# │    └─MPGELU: 2-2                       1
# │    └─Conv2d: 2-3                       9,248
# │    └─MPGELU: 2-4                       1
# │    └─MaxPool2d: 2-5                    --
# │    └─Conv2d: 2-6                       18,496
# │    └─MPGELU: 2-7                       1
# │    └─Conv2d: 2-8                       36,928
# │    └─MPGELU: 2-9                       1
# │    └─MaxPool2d: 2-10                   --
# │    └─Conv2d: 2-11                      73,856
# │    └─MPGELU: 2-12                      1
# │    └─Conv2d: 2-13                      147,584
# │    └─MPGELU: 2-14                      1
# │    └─Conv2d: 2-15                      147,584
# │    └─MPGELU: 2-16                      1
# │    └─MaxPool2d: 2-17                   --
# ├─Sequential: 1-2                        --
# │    └─Linear: 2-18                      524,544
# │    └─MPGELU: 2-19                      1
# │    └─Linear: 2-20                      65,792
# │    └─MPGELU: 2-21                      1
# │    └─Linear: 2-22                      2,570
# =================================================================
# Total params: 1,027,507
# Trainable params: 1,027,507
# Non-trainable params: 0
# =================================================================
# Total number of parameters: 1027507

# %% [markdown]
# ## Test Dummy Input

# %%
dummy_input = torch.randn(1, 3, 32, 32).to(device)
model(dummy_input)
# Out:
# tensor([[-0.0472,  0.0603, -0.0531, -0.0600, -0.0494,  0.0707,  0.0160, -0.0226,
#           0.0072, -0.0552]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Training and Execution

# %% [markdown]
# ## Setup loss, accuracy, and paramaters

# %% [markdown]
# ## Mathematical Definition of Categorical Cross-Entropy
#
# Categorical Cross-Entropy (CCE) is the standard loss function for multi-class classification. It measures the difference between two probability distributions: the actual ground-truth labels (usually one-hot encoded) and the model's predicted probabilities.
#
# For a single sample, the loss is defined as:
#
# $$f(y_i, \hat{y}_i) = -\sum_{i=1}^{C} y_i \log(\hat{y}_i)$$
#
# When calculating the average loss over a batch of $N$ samples, the formula expands to:
#
# $$f(y_i, \hat{y}_i) = -\frac{1}{N} \sum_{j=1}^{N} \sum_{i=1}^{C} y_{j,i} \log(\hat{y}_{j,i})$$
#
# **Where:**
# * $C$ = Total number of classes
# * $N$ = Total number of samples in the batch
# * $y_i$ (or $y_{j,i}$) = The true label (1 if the sample belongs to class $i$, and 0 for all other classes)
# * $\hat{y}_i$ (or $\hat{y}_{j,i}$) = The model's predicted probability that the sample belongs to class $i$ (typically the output of a Softmax activation function)
#
# > **Note:** Because the true labels $y_i$ are zero for all incorrect classes in one-hot encoding, the formula effectively simplifies to taking the negative log of the predicted probability for the **true** class.

# %%
#Setup Loss Functions, Accuracy function
loss_fn = torch.nn.CrossEntropyLoss(label_smoothing=0.1)

#Define Accuracy Metric
def calculate_accuracy(y_true, y_pred):
  correct = torch.eq(y_true, y_pred).sum().item()
  accuracy = (correct / len(y_pred)) * 100
  return accuracy

##Training Parameters

num_of_epochs = 100
num_loss_steps = 5

# %% [markdown]
# ### Gradient Norm
#
# **Mathematical Definition**: The $\ell^2$ Norm of the Gradient. In real analysis, the small $\ell^2$ norm (standard Euclidean norm) measures the magnitude of a finite-dimensional vector in $\mathbb{R}^n$.Let $\mathbf{w} \in \mathbb{R}^n$ represent the flattened continuous vector of all trainable parameters within the neural network architecture. The gradient of the objective loss function $\mathcal{L}$ with respect to these parameters is a discrete vector composed of partial derivatives:
# $$\nabla_{\mathbf{w}} \mathcal{L} = \left[ \frac{\partial \mathcal{L}}{\partial w_1}, \frac{\partial \mathcal{L}}{\partial w_2}, \dots, \frac{\partial \mathcal{L}}{\partial w_n} \right]^T$$
#
# The $\ell^2$ norm of this gradient vector, denoted as $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_{\ell^2}$ or simply $\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2$, is defined as the square root of the sum of its squared coordinate components:$$\Vert{} \nabla_{\mathbf{w}} \mathcal{L} \Vert{}_2 = \sqrt{ \sum_{i=1}^{n} \left( \frac{\partial \mathcal{L}}{\partial w_i} \right)^2 }$$In the context of empirical risk minimization, bounding this sequence of finite sums guarantees that gradient updates remain stable and prevents the parameter vector from diverging during optimization.
#
#
# **IMPORTANT NOTE**
#
# In real and functional analysis, the capital $L^p$ spaces denote spaces of measurable functions, where the norm is evaluated via continuous integration, such as $\Vert{}f\Vert{}_{L^2} = \left( \int \vert{}f(x)\vert{}^2 dx \right)^{1/2}$. The lowercase $\ell^p$ spaces apply to discrete sequences or finite-dimensional coordinate vectors, where the norm is evaluated via discrete summation. Since the gradient of a neural network's loss with respect to its parameters, $\nabla_{\mathbf{w}} \mathcal{L}$, is a finite-dimensional vector of discrete scalar derivatives rather than a continuous mathematical function, finding its magnitude requires summing the squares of its individual components. You are completely correct: we use the small $\ell^2$ norm precisely because we are operating on discrete Euclidean vectors, not continuous functions.

# %% [markdown]
# ## Execution and Saving

# %%
torch.manual_seed(143)
activation_dict = {
    "PGELU": PGELU,
    "MP_GELU": MPGELU,
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}

all_results = {}

for act_name, act_fn in activation_dict.items():
    print(f"\n=======================================================")
    print(f"       TRAINING WITH ACTIVATION: {act_name}")
    print(f"=======================================================")

    model = MyCNN(input_shape=3, output_shape=10, activation=act_fn, params=chosen_model_params).to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)

    trainer = Trainer(model=model, loss_fn=loss_fn, optimizer=optimizer,
                      calculate_accuracy=calculate_accuracy, device=device, loss_steps=num_loss_steps)

    results = {
        "train_loss": [],
        "train_accu": [],
        "test_loss": [],
        "test_accu": [],
        "activation_params": {},
        "grad_norm": []  # Initialize an empty list to store gradient norms
    }

    start_time = time.perf_counter()

    for epoch in tqdm(range(num_of_epochs), desc=f"Training {act_name}"):
        if epoch % num_loss_steps == 0:
            print(f"Epoch: {epoch} \n =====================================================================")
        train_loss, train_accu, norm = trainer.train(data_loader=train_dataloader, epoch=epoch)
        test_loss, test_accu = trainer.test(data_loader=test_dataloader, epoch=epoch)

        results["train_loss"].append(train_loss)
        results["train_accu"].append(train_accu)
        results["test_loss"].append(test_loss)
        results["test_accu"].append(test_accu)
        results["grad_norm"].append(norm)

        # Track dynamic activation parameters
        for name, param in model.named_parameters():
            if 'alpha_param' in name or 'beta_param' in name or 's_param' in name:
                if name not in results.setdefault("activation_params", {}):
                    results["activation_params"][name] = []
                results["activation_params"][name].append(param.item())

    total_time = time.perf_counter() - start_time
    results["total_runtime"] = total_time
    all_results[act_name] = results

    # Save Model Checkpoint
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'results': results,
        'total_runtime': total_time,
        'activation_name': act_name
    }

    save_dir = "model_trained_params_new"
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir, f"chkpt2_{act_name}.pth")

    torch.save(checkpoint, save_path)
    print(f"Saved model state to {save_path}")
# Out:
# =======================================================
#        TRAINING WITH ACTIVATION: PGELU
# =======================================================
# Training PGELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 1.99738 | Training Accuracy: 28.61973%
# Test Loss 1.68541 | Test Accuracy 44.77848%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.30528 | Training Accuracy: 64.23713%
# Test Loss 1.14899 | Test Accuracy 71.57832%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.18211 | Training Accuracy: 70.00280%
# Test Loss 1.01567 | Test Accuracy 78.09533%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.12959 | Training Accuracy: 72.67943%
# Test Loss 0.98855 | Test Accuracy 79.83584%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.08156 | Training Accuracy: 74.83256%
# Test Loss 0.95807 | Test Accuracy 80.98299%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.04809 | Training Accuracy: 76.21244%
# Test Loss 0.91303 | Test Accuracy 82.57516%
# Epoch: 30
#  =====================================================================
# Training Loss: 1.01819 | Training Accuracy: 77.63187%
# Test Loss 0.88928 | Test Accuracy 83.56408%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.99497 | Training Accuracy: 78.85750%
# Test Loss 0.89752 | Test Accuracy 83.87065%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.98498 | Training Accuracy: 79.15321%
# Test Loss 0.89178 | Test Accuracy 84.05854%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.99072 | Training Accuracy: 79.21795%
# Test Loss 0.89433 | Test Accuracy 84.43434%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.95810 | Training Accuracy: 80.44597%
# Test Loss 0.87033 | Test Accuracy 85.02769%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.94720 | Training Accuracy: 81.04979%
# Test Loss 0.86132 | Test Accuracy 85.04747%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.94046 | Training Accuracy: 81.28317%
# Test Loss 0.88001 | Test Accuracy 84.33544%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.93614 | Training Accuracy: 81.65801%
# Test Loss 0.88864 | Test Accuracy 84.55301%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.92615 | Training Accuracy: 82.06282%
# Test Loss 0.86055 | Test Accuracy 85.74960%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.91127 | Training Accuracy: 82.71020%
# Test Loss 0.84990 | Test Accuracy 86.13528%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.90543 | Training Accuracy: 82.91760%
# Test Loss 0.86426 | Test Accuracy 86.16495%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.91383 | Training Accuracy: 82.75935%
# Test Loss 0.84065 | Test Accuracy 86.52097%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.89884 | Training Accuracy: 83.42072%
# Test Loss 0.84111 | Test Accuracy 86.42207%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.90101 | Training Accuracy: 83.38635%
# Test Loss 0.86189 | Test Accuracy 86.22429%
# Saved model state to model_trained_params_new/chkpt2_PGELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: MP_GELU
# =======================================================
# Training MP_GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.10557 | Training Accuracy: 23.34399%
# Test Loss 1.89018 | Test Accuracy 34.25633%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.32167 | Training Accuracy: 63.04508%
# Test Loss 1.12596 | Test Accuracy 72.99248%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.12840 | Training Accuracy: 72.30619%
# Test Loss 0.98687 | Test Accuracy 79.11392%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.04823 | Training Accuracy: 75.92191%
# Test Loss 0.92337 | Test Accuracy 82.17959%
# Epoch: 20
#  =====================================================================
# Training Loss: 0.99347 | Training Accuracy: 78.49984%
# Test Loss 0.89417 | Test Accuracy 83.37619%
# Epoch: 25
#  =====================================================================
# Training Loss: 0.95714 | Training Accuracy: 80.02438%
# Test Loss 0.87982 | Test Accuracy 83.86076%
# Epoch: 30
#  =====================================================================
# Training Loss: 0.92849 | Training Accuracy: 81.39066%
# Test Loss 0.87356 | Test Accuracy 84.60245%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.90646 | Training Accuracy: 82.35134%
# Test Loss 0.86013 | Test Accuracy 85.26503%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.89269 | Training Accuracy: 82.98394%
# Test Loss 0.84483 | Test Accuracy 85.47271%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.88282 | Training Accuracy: 83.54979%
# Test Loss 0.84232 | Test Accuracy 85.59138%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.86569 | Training Accuracy: 84.19837%
# Test Loss 0.83762 | Test Accuracy 85.98695%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.85785 | Training Accuracy: 84.61077%
# Test Loss 0.82253 | Test Accuracy 86.77809%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.85134 | Training Accuracy: 84.87132%
# Test Loss 0.81558 | Test Accuracy 87.21321%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.83610 | Training Accuracy: 85.40082%
# Test Loss 0.84261 | Test Accuracy 85.52215%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.82905 | Training Accuracy: 85.92471%
# Test Loss 0.81111 | Test Accuracy 86.95609%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.82030 | Training Accuracy: 86.35550%
# Test Loss 0.81389 | Test Accuracy 87.20332%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.81751 | Training Accuracy: 86.38587%
# Test Loss 0.81515 | Test Accuracy 87.23299%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.81381 | Training Accuracy: 86.47538%
# Test Loss 0.80794 | Test Accuracy 87.26266%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.80669 | Training Accuracy: 86.76111%
# Test Loss 0.80433 | Test Accuracy 87.50000%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.80466 | Training Accuracy: 87.10318%
# Test Loss 0.81321 | Test Accuracy 87.21321%
# Saved model state to model_trained_params_new/chkpt2_MP_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: ReLU
# =======================================================
# Training ReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.10477 | Training Accuracy: 23.28165%
# Test Loss 1.86824 | Test Accuracy 35.67049%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.57711 | Training Accuracy: 50.26055%
# Test Loss 1.43189 | Test Accuracy 56.96203%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.37182 | Training Accuracy: 60.26415%
# Test Loss 1.22301 | Test Accuracy 67.79074%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.26109 | Training Accuracy: 65.86877%
# Test Loss 1.12138 | Test Accuracy 72.74525%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.18811 | Training Accuracy: 69.26311%
# Test Loss 1.05574 | Test Accuracy 75.79114%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.14818 | Training Accuracy: 71.13491%
# Test Loss 1.02991 | Test Accuracy 76.98774%
# Epoch: 30
#  =====================================================================
# Training Loss: 1.11596 | Training Accuracy: 72.55994%
# Test Loss 1.01502 | Test Accuracy 77.64043%
# Epoch: 35
#  =====================================================================
# Training Loss: 1.08483 | Training Accuracy: 73.90066%
# Test Loss 1.00023 | Test Accuracy 78.14478%
# Epoch: 40
#  =====================================================================
# Training Loss: 1.06766 | Training Accuracy: 74.80778%
# Test Loss 0.99557 | Test Accuracy 78.50079%
# Epoch: 45
#  =====================================================================
# Training Loss: 1.04536 | Training Accuracy: 76.01742%
# Test Loss 0.95394 | Test Accuracy 80.35997%
# Epoch: 50
#  =====================================================================
# Training Loss: 1.03530 | Training Accuracy: 76.34950%
# Test Loss 0.94705 | Test Accuracy 80.84454%
# Epoch: 55
#  =====================================================================
# Training Loss: 1.03129 | Training Accuracy: 76.52214%
# Test Loss 0.94069 | Test Accuracy 80.87421%
# Epoch: 60
#  =====================================================================
# Training Loss: 1.01165 | Training Accuracy: 77.45964%
# Test Loss 0.92051 | Test Accuracy 81.95214%
# Epoch: 65
#  =====================================================================
# Training Loss: 1.00161 | Training Accuracy: 77.92160%
# Test Loss 0.92277 | Test Accuracy 82.21915%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.99889 | Training Accuracy: 77.87924%
# Test Loss 0.91815 | Test Accuracy 82.23892%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.98362 | Training Accuracy: 78.76798%
# Test Loss 0.90937 | Test Accuracy 82.82239%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.97561 | Training Accuracy: 79.15201%
# Test Loss 0.90474 | Test Accuracy 82.70372%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.97146 | Training Accuracy: 79.44853%
# Test Loss 0.91612 | Test Accuracy 82.54549%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.96612 | Training Accuracy: 79.54723%
# Test Loss 0.91099 | Test Accuracy 82.73339%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.96373 | Training Accuracy: 79.67711%
# Test Loss 0.91705 | Test Accuracy 82.88172%
# Saved model state to model_trained_params_new/chkpt2_ReLU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: GELU
# =======================================================
# Training GELU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.10547 | Training Accuracy: 22.45724%
# Test Loss 1.82529 | Test Accuracy 38.45926%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.37241 | Training Accuracy: 60.87516%
# Test Loss 1.16514 | Test Accuracy 71.17286%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.17055 | Training Accuracy: 70.30730%
# Test Loss 1.01334 | Test Accuracy 78.25356%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.09305 | Training Accuracy: 73.99936%
# Test Loss 0.95514 | Test Accuracy 81.03244%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.04222 | Training Accuracy: 76.28597%
# Test Loss 0.92851 | Test Accuracy 82.14003%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.00708 | Training Accuracy: 77.84247%
# Test Loss 0.91386 | Test Accuracy 82.82239%
# Epoch: 30
#  =====================================================================
# Training Loss: 0.98058 | Training Accuracy: 79.18398%
# Test Loss 0.90732 | Test Accuracy 83.31685%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.95732 | Training Accuracy: 80.44637%
# Test Loss 0.88609 | Test Accuracy 83.99921%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.93962 | Training Accuracy: 81.05059%
# Test Loss 0.88494 | Test Accuracy 84.23655%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.91915 | Training Accuracy: 81.92935%
# Test Loss 0.85457 | Test Accuracy 85.18592%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.90695 | Training Accuracy: 82.53517%
# Test Loss 0.86385 | Test Accuracy 84.88924%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.89630 | Training Accuracy: 83.07665%
# Test Loss 0.84003 | Test Accuracy 85.93750%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.88639 | Training Accuracy: 83.30123%
# Test Loss 0.84757 | Test Accuracy 85.82872%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.87688 | Training Accuracy: 83.78956%
# Test Loss 0.83877 | Test Accuracy 85.71994%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.86411 | Training Accuracy: 84.55483%
# Test Loss 0.83431 | Test Accuracy 86.28362%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.85903 | Training Accuracy: 84.68870%
# Test Loss 0.83213 | Test Accuracy 86.17484%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.84950 | Training Accuracy: 85.07393%
# Test Loss 0.84002 | Test Accuracy 86.89676%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.84945 | Training Accuracy: 85.18302%
# Test Loss 0.82304 | Test Accuracy 86.94620%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.83673 | Training Accuracy: 85.67415%
# Test Loss 0.82075 | Test Accuracy 87.07476%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.83664 | Training Accuracy: 85.62020%
# Test Loss 0.83349 | Test Accuracy 86.42207%
# Saved model state to model_trained_params_new/chkpt2_GELU.pth
#
# =======================================================
#        TRAINING WITH ACTIVATION: LeakyReLU
# =======================================================
# Training LeakyReLU:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
#  =====================================================================
# Training Loss: 2.11014 | Training Accuracy: 22.19110%
# Test Loss 1.83521 | Test Accuracy 36.50119%
# Epoch: 5
#  =====================================================================
# Training Loss: 1.46718 | Training Accuracy: 55.63899%
# Test Loss 1.28774 | Test Accuracy 64.33940%
# Epoch: 10
#  =====================================================================
# Training Loss: 1.24626 | Training Accuracy: 66.48697%
# Test Loss 1.15976 | Test Accuracy 70.79707%
# Epoch: 15
#  =====================================================================
# Training Loss: 1.13670 | Training Accuracy: 71.62604%
# Test Loss 1.02962 | Test Accuracy 77.12619%
# Epoch: 20
#  =====================================================================
# Training Loss: 1.07769 | Training Accuracy: 74.33264%
# Test Loss 0.96963 | Test Accuracy 79.59850%
# Epoch: 25
#  =====================================================================
# Training Loss: 1.04059 | Training Accuracy: 76.12532%
# Test Loss 0.96052 | Test Accuracy 80.39953%
# Epoch: 30
#  =====================================================================
# Training Loss: 1.00687 | Training Accuracy: 77.63027%
# Test Loss 0.93169 | Test Accuracy 81.89280%
# Epoch: 35
#  =====================================================================
# Training Loss: 0.98692 | Training Accuracy: 78.64650%
# Test Loss 0.91458 | Test Accuracy 82.36748%
# Epoch: 40
#  =====================================================================
# Training Loss: 0.96799 | Training Accuracy: 79.58760%
# Test Loss 0.89633 | Test Accuracy 83.45530%
# Epoch: 45
#  =====================================================================
# Training Loss: 0.94916 | Training Accuracy: 80.39003%
# Test Loss 0.89149 | Test Accuracy 83.70253%
# Epoch: 50
#  =====================================================================
# Training Loss: 0.93421 | Training Accuracy: 81.09095%
# Test Loss 0.88963 | Test Accuracy 83.48497%
# Epoch: 55
#  =====================================================================
# Training Loss: 0.91807 | Training Accuracy: 81.83024%
# Test Loss 0.89300 | Test Accuracy 83.37619%
# Epoch: 60
#  =====================================================================
# Training Loss: 0.90862 | Training Accuracy: 82.31937%
# Test Loss 0.88778 | Test Accuracy 83.86076%
# Epoch: 65
#  =====================================================================
# Training Loss: 0.90047 | Training Accuracy: 82.72259%
# Test Loss 0.87709 | Test Accuracy 84.14755%
# Epoch: 70
#  =====================================================================
# Training Loss: 0.88810 | Training Accuracy: 83.14418%
# Test Loss 0.85586 | Test Accuracy 85.06725%
# Epoch: 75
#  =====================================================================
# Training Loss: 0.88232 | Training Accuracy: 83.52941%
# Test Loss 0.85571 | Test Accuracy 85.37381%
# Epoch: 80
#  =====================================================================
# Training Loss: 0.87679 | Training Accuracy: 83.73322%
# Test Loss 0.85996 | Test Accuracy 85.67049%
# Epoch: 85
#  =====================================================================
# Training Loss: 0.86299 | Training Accuracy: 84.37620%
# Test Loss 0.85589 | Test Accuracy 85.47271%
# Epoch: 90
#  =====================================================================
# Training Loss: 0.86288 | Training Accuracy: 84.41656%
# Test Loss 0.87112 | Test Accuracy 84.66179%
# Epoch: 95
#  =====================================================================
# Training Loss: 0.85208 | Training Accuracy: 84.92927%
# Test Loss 0.85741 | Test Accuracy 85.64082%
# Saved model state to model_trained_params_new/chkpt2_LeakyReLU.pth

# %% [markdown]
# # Loading the trained model params

# %%
activation_dict = {
    "MP_GELU": MPGELU,
    "PGELU": PGELU,
    "ReLU": torch.nn.ReLU,
    "GELU": torch.nn.GELU,
    "LeakyReLU": torch.nn.LeakyReLU
}


# Initialize LoadedModel with the correct initial_fileName and checkpoint_dir
loader = LoadedModel(
    activation_dict=activation_dict,
    model_params=chosen_model_params,
    initial_fileName="chkpt2",
    checkpoint_dir="model_trained_params_new",
    device=device
)

# Run it
my_models = loader.load_checkpoints()
# Out:
# =======================================================
#        EVALUATING ACTIVATION: MP_GELU
# =======================================================
# Loaded trained model for MP_GELU from model_trained_params_new/chkpt2_MP_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: PGELU
# =======================================================
# Loaded trained model for PGELU from model_trained_params_new/chkpt2_PGELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: ReLU
# =======================================================
# Loaded trained model for ReLU from model_trained_params_new/chkpt2_ReLU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: GELU
# =======================================================
# Loaded trained model for GELU from model_trained_params_new/chkpt2_GELU.pth
#
# =======================================================
#        EVALUATING ACTIVATION: LeakyReLU
# =======================================================
# Loaded trained model for LeakyReLU from model_trained_params_new/chkpt2_LeakyReLU.pth

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Plotting

# %%
to_plot = {
    "MP_GELU":   {"results": my_models["MP_GELU"]["results"],   "linewidth": 3.0, "color": "#000000"}, # Jet Black
    "PGELU":     {"results": my_models["PGELU"]["results"],     "linewidth": 2.0, "color": "#E62937"}, # Strong Red
    "ReLU":      {"results": my_models["ReLU"]["results"],      "linewidth": 2.0, "color": "#009E73"}, # Teal
    "GELU":      {"results": my_models["GELU"]["results"],      "linewidth": 2.0, "color": "#4363D8"}, # Royal Blue
    "LeakyReLU": {"results": my_models["LeakyReLU"]["results"], "linewidth": 2.0, "color": "#F58231"}  # Bright Orange
}

# %% [markdown]
# ### Evolution of Learnable Parameters

# %% [markdown]
# #### $\alpha$ and $\beta$ of PGELU

# %%
alpha = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.alpha_param"]
beta = my_models["PGELU"]["results"]["activation_params"]["conv_layers.1.beta_param"]

fig, ax = plt.subplots(1, 2, figsize=(10, 6))
# Alpha Plot
ax[0].plot(alpha, label="Alpha Parameter", color="#E62937", linewidth=2.5)
# ax[0].set_title("Alpha Parameter Evolution", fontsize=14)
ax[0].grid(True, linestyle=':', alpha=0.9)
ax[0].tick_params(axis='x', labelsize=13)
ax[0].legend(fontsize=15)
# Beta Plot
ax[1].plot(beta, label="Beta Parameter", color="#009E73", linewidth=2.5)
# ax[1].set_title("Beta Parameter Evolution", fontsize=14)
ax[1].grid(True, linestyle=':', alpha=0.9)
ax[1].tick_params(axis='x', labelsize=13)
ax[1].legend(fontsize=15)


fig.supxlabel("Epochs", fontsize=15)
fig.supylabel("Parameter Value", fontsize=15)
fig.suptitle("Dynamic Activation Parameters Evolution for PGELU", fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### $\lambda$ of MPGELU

# %%
params_dict = my_models["MP_GELU"]["results"]["activation_params"]
s_vals = params_dict['conv_layers.1.s_param']
s_values = torch.tensor(s_vals, device=device, dtype=torch.float32)
lam = 1.0 + torch.log(1.0 + torch.exp(s_values))
plt.figure(figsize=(9, 6))
plt.plot(lam.detach().cpu().numpy(), linestyle='-', color='#000055')
plt.xlabel("Epoch", fontsize=13)
plt.ylabel(r"Learned $\lambda$", fontsize=13)
plt.title(r"Evolution of $\lambda$ of MPGELU During Training")
plt.grid(True, linestyle=':', alpha=0.9)
plt.yticks(np.arange(1.6, 3.2, 0.2), fontsize=13)
plt.xticks(np.arange(0, 65, 5), fontsize=13)
plt.tight_layout()
# plt.savefig("learned_lambda_evolution.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Train Loss Curves

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["train_loss"], **arguments)
plt.legend(loc="upper right", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)
plt.xticks(np.arange(-10,65,5), fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(0.75,2.4)
plt.xlim(-2,60)
plt.title("Training Loss Comparison Across Activation Functions", fontsize=16)
# plt.savefig("train_loss_comparison.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Test Loss Curves

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["test_loss"], **arguments)
plt.legend(loc="upper right", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)
plt.xticks(np.arange(-10,65,5), fontsize=12)
plt.yticks(fontsize=12)
plt.ylim(0.75,2.4)
plt.xlim(-2,60)
plt.title("Test Loss Comparison Across Activation Functions", fontsize=16)
plt.tight_layout()
# plt.savefig("test_loss_comparison.jpg", dpi=800, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Training Accuracy

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["train_accu"], **arguments)
plt.legend(loc="lower right", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)
plt.xticks(np.arange(-5,65,5), fontsize=12)
plt.yticks(np.arange(0,110,10), fontsize=12)
plt.ylim(5,100)
plt.xlim(-2,60)
plt.title("Training Accuracy Comparison Across Activation Functions", fontsize=16)
plt.show()

# %% [markdown]
# ### Test Accuracy

# %%
plt.figure(figsize=(11, 7))

for act_name, property in to_plot.items():
    plot_results = property["results"]
    arguments = {
        "linewidth" : property.get("linewidth",1.0),
        "linestyle": property.get("linestyle"),
        "label": act_name,
        "color": property["color"]
    }
    plt.plot(plot_results["test_accu"], **arguments)
plt.legend(loc="lower right", fontsize=14)
plt.grid(True,linestyle='--', alpha=0.6)
plt.xticks(np.arange(-5,65,5), fontsize=12)
plt.yticks(np.arange(0,110,10), fontsize=12)
plt.ylim(5,100)
plt.xlim(-2,60)
plt.title("Test Accuracy Comparison Across Activation Functions", fontsize=16)
plt.show()

# %% [markdown]
# # $F_{1}$ Scores
# **Mathematical Definition of the $F_1$ Score**
#
# The $F_1$ score is the harmonic mean of Precision and Recall. It provides a single metric that balances both false positives and false negatives, making it particularly useful for evaluating models on imbalanced datasets.
#
# The general formula is defined as:
#
# $$F_1 = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$$
#
# To calculate the $F_1$ score, you must first calculate **Precision** and **Recall**:
#
# * **Precision** measures the proportion of positive predictions that were actually correct:
#   $$\text{Precision} = \frac{TP}{TP + FP}$$
#
# * **Recall** (also known as Sensitivity) measures the proportion of actual positives that were identified correctly:
#   $$\text{Recall} = \frac{TP}{TP + FN}$$
#
# By substituting Precision and Recall back into the original equation, the $F_1$ score can be expressed directly in terms of prediction outcomes:
#
# $$F_1 = \frac{2 \cdot TP}{2 \cdot TP + FP + FN}$$
#
# **Where:**
# * $TP$ = **True Positives** (Model correctly predicts the positive class)
# * $FP$ = **False Positives** (Model incorrectly predicts the positive class)
# * $FN$ = **False Negatives** (Model incorrectly predicts the negative class)

# %%
f1_results = {}

print("Calculating F1 Scores...")
print("========================")

for act_name, model_data in my_models.items():
    model = model_data["model"]
    model.eval()  # Ensure the model is in evaluation mode

    all_preds = []
    all_targets = []

    with torch.inference_mode():
        # Assuming you have your test_dataloader ready
        for inputs, targets in test_dataloader:
            inputs = inputs.to(device)

            # Get predictions
            outputs = model(inputs)
            _, preds = torch.max(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(targets.numpy())

    f1 = f1_score(all_targets, all_preds, average='macro')
    f1_results[act_name] = f1

    print(f"{act_name: >10}: {f1:.4f}")
# Out:
# Calculating F1 Scores...
# ========================
#    MP_GELU: 0.8764
#      PGELU: 0.8679
#       ReLU: 0.8329
#       GELU: 0.8708
#  LeakyReLU: 0.8555

# %%
# ============================================================
# GRADIENT L2 NORM VS EPOCH
# ============================================================

plt.figure(figsize=(11, 7))

for act_name, properties in to_plot.items():

    plot_results = properties["results"]

    epochs = np.arange(1, len(plot_results["grad_norm"]) + 1)

    plt.plot(
        epochs,
        plot_results["grad_norm"],
        linewidth=properties["linewidth"],
        linestyle="-",
        label=act_name,
        color=properties["color"]
    )

plt.xlabel("Epoch", fontsize=13)
plt.ylabel("Gradient L₂ Norm", fontsize=13)

plt.title(
    "Gradient L₂ Norm vs Epoch",
    fontsize=16
)

plt.legend(
    loc="upper right",
    fontsize=12
)

plt.grid(
    True,
    linestyle="--",
    alpha=0.6
)

plt.xticks(
    np.arange(0, 101, 5),
    fontsize=12
)

plt.yticks(fontsize=12)

plt.xlim(1, 100)

plt.tight_layout()
plt.show()

# %%
import numpy as np

print("=" * 80)
print("Gradient L₂ Norms by Epoch")
print("=" * 80)

for act_name, results in all_results.items():
    print(f"\n{'=' * 80}")
    print(f"ACTIVATION: {act_name}")
    print(f"{'=' * 80}")

    grad_norms = np.array(results["grad_norm"], dtype=float)

    # Print every epoch
    for epoch, grad_norm in enumerate(grad_norms, start=1):
        print(f"Epoch {epoch:3d}: Gradient L₂ Norm = {grad_norm:.6f}")

    # Calculate statistics
    mean_grad = np.mean(grad_norms)
    std_grad = np.std(grad_norms, ddof=1)
    min_grad = np.min(grad_norms)
    max_grad = np.max(grad_norms)

    print(f"\n{'-' * 80}")
    print(f"SUMMARY — {act_name}")
    print(f"{'-' * 80}")
    print(f"Average Gradient L₂ Norm : {mean_grad:.6f} ± {std_grad:.6f}")
    print(f"Minimum Gradient L₂ Norm : {min_grad:.6f}")
    print(f"Maximum Gradient L₂ Norm : {max_grad:.6f}")
# Out:
# ================================================================================
# Gradient L₂ Norms by Epoch
# ================================================================================
#
# ================================================================================
# ACTIVATION: PGELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.015675
# Epoch   2: Gradient L₂ Norm = 0.013710
# Epoch   3: Gradient L₂ Norm = 0.007768
# Epoch   4: Gradient L₂ Norm = 0.012854
# Epoch   5: Gradient L₂ Norm = 0.012732
# Epoch   6: Gradient L₂ Norm = 0.010193
# Epoch   7: Gradient L₂ Norm = 0.009043
# Epoch   8: Gradient L₂ Norm = 0.012325
# Epoch   9: Gradient L₂ Norm = 0.009251
# Epoch  10: Gradient L₂ Norm = 0.010583
# Epoch  11: Gradient L₂ Norm = 0.021749
# Epoch  12: Gradient L₂ Norm = 0.012489
# Epoch  13: Gradient L₂ Norm = 0.011824
# Epoch  14: Gradient L₂ Norm = 0.011770
# Epoch  15: Gradient L₂ Norm = 0.011971
# Epoch  16: Gradient L₂ Norm = 0.009957
# Epoch  17: Gradient L₂ Norm = 0.012890
# Epoch  18: Gradient L₂ Norm = 0.013167
# Epoch  19: Gradient L₂ Norm = 0.013876
# Epoch  20: Gradient L₂ Norm = 0.015881
# Epoch  21: Gradient L₂ Norm = 0.014783
# Epoch  22: Gradient L₂ Norm = 0.022671
# Epoch  23: Gradient L₂ Norm = 0.023954
# Epoch  24: Gradient L₂ Norm = 0.016041
# Epoch  25: Gradient L₂ Norm = 0.020933
# Epoch  26: Gradient L₂ Norm = 0.013968
# Epoch  27: Gradient L₂ Norm = 0.017428
# Epoch  28: Gradient L₂ Norm = 0.022537
# Epoch  29: Gradient L₂ Norm = 0.061822
# Epoch  30: Gradient L₂ Norm = 0.018267
# Epoch  31: Gradient L₂ Norm = 0.032512
# Epoch  32: Gradient L₂ Norm = 0.018568
# Epoch  33: Gradient L₂ Norm = 0.026964
# Epoch  34: Gradient L₂ Norm = 0.021441
# Epoch  35: Gradient L₂ Norm = 0.013457
# Epoch  36: Gradient L₂ Norm = 0.018093
# Epoch  37: Gradient L₂ Norm = 0.013739
# Epoch  38: Gradient L₂ Norm = 0.023691
# Epoch  39: Gradient L₂ Norm = 0.016770
# Epoch  40: Gradient L₂ Norm = 0.013739
# Epoch  41: Gradient L₂ Norm = 0.018762
# Epoch  42: Gradient L₂ Norm = 0.019465
# Epoch  43: Gradient L₂ Norm = 0.018825
# Epoch  44: Gradient L₂ Norm = 0.015324
# Epoch  45: Gradient L₂ Norm = 0.023821
# Epoch  46: Gradient L₂ Norm = 0.019749
# Epoch  47: Gradient L₂ Norm = 0.023014
# Epoch  48: Gradient L₂ Norm = 0.022756
# Epoch  49: Gradient L₂ Norm = 0.020668
# Epoch  50: Gradient L₂ Norm = 0.020247
# Epoch  51: Gradient L₂ Norm = 0.019753
# Epoch  52: Gradient L₂ Norm = 0.021171
# Epoch  53: Gradient L₂ Norm = 0.016687
# Epoch  54: Gradient L₂ Norm = 0.022531
# Epoch  55: Gradient L₂ Norm = 0.023973
# Epoch  56: Gradient L₂ Norm = 0.020077
# Epoch  57: Gradient L₂ Norm = 0.019808
# Epoch  58: Gradient L₂ Norm = 0.021895
# Epoch  59: Gradient L₂ Norm = 0.022741
# Epoch  60: Gradient L₂ Norm = 0.017585
# Epoch  61: Gradient L₂ Norm = 0.021142
# Epoch  62: Gradient L₂ Norm = 0.018133
# Epoch  63: Gradient L₂ Norm = 0.018489
# Epoch  64: Gradient L₂ Norm = 0.026394
# Epoch  65: Gradient L₂ Norm = 0.023906
# Epoch  66: Gradient L₂ Norm = 0.017104
# Epoch  67: Gradient L₂ Norm = 0.032539
# Epoch  68: Gradient L₂ Norm = 0.022002
# Epoch  69: Gradient L₂ Norm = 0.018143
# Epoch  70: Gradient L₂ Norm = 0.014243
# Epoch  71: Gradient L₂ Norm = 0.027886
# Epoch  72: Gradient L₂ Norm = 0.019054
# Epoch  73: Gradient L₂ Norm = 0.021320
# Epoch  74: Gradient L₂ Norm = 0.022572
# Epoch  75: Gradient L₂ Norm = 0.025855
# Epoch  76: Gradient L₂ Norm = 0.027768
# Epoch  77: Gradient L₂ Norm = 0.020577
# Epoch  78: Gradient L₂ Norm = 0.028221
# Epoch  79: Gradient L₂ Norm = 0.025012
# Epoch  80: Gradient L₂ Norm = 0.016945
# Epoch  81: Gradient L₂ Norm = 0.041127
# Epoch  82: Gradient L₂ Norm = 0.025798
# Epoch  83: Gradient L₂ Norm = 0.020653
# Epoch  84: Gradient L₂ Norm = 0.027983
# Epoch  85: Gradient L₂ Norm = 0.028920
# Epoch  86: Gradient L₂ Norm = 0.021690
# Epoch  87: Gradient L₂ Norm = 0.024295
# Epoch  88: Gradient L₂ Norm = 0.022736
# Epoch  89: Gradient L₂ Norm = 0.031856
# Epoch  90: Gradient L₂ Norm = 0.017548
# Epoch  91: Gradient L₂ Norm = 0.025957
# Epoch  92: Gradient L₂ Norm = 0.022607
# Epoch  93: Gradient L₂ Norm = 0.023756
# Epoch  94: Gradient L₂ Norm = 0.030194
# Epoch  95: Gradient L₂ Norm = 0.032302
# Epoch  96: Gradient L₂ Norm = 0.030881
# Epoch  97: Gradient L₂ Norm = 0.025197
# Epoch  98: Gradient L₂ Norm = 0.014216
# Epoch  99: Gradient L₂ Norm = 0.019633
# Epoch 100: Gradient L₂ Norm = 0.022422
#
# --------------------------------------------------------------------------------
# SUMMARY — PGELU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.020470 ± 0.007418
# Minimum Gradient L₂ Norm : 0.007768
# Maximum Gradient L₂ Norm : 0.061822
#
# ================================================================================
# ACTIVATION: MP_GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.007954
# Epoch   2: Gradient L₂ Norm = 0.013449
# Epoch   3: Gradient L₂ Norm = 0.007426
# Epoch   4: Gradient L₂ Norm = 0.005107
# Epoch   5: Gradient L₂ Norm = 0.016084
# Epoch   6: Gradient L₂ Norm = 0.010019
# Epoch   7: Gradient L₂ Norm = 0.007681
# Epoch   8: Gradient L₂ Norm = 0.007031
# Epoch   9: Gradient L₂ Norm = 0.010001
# Epoch  10: Gradient L₂ Norm = 0.007790
# Epoch  11: Gradient L₂ Norm = 0.007210
# Epoch  12: Gradient L₂ Norm = 0.006530
# Epoch  13: Gradient L₂ Norm = 0.009167
# Epoch  14: Gradient L₂ Norm = 0.008290
# Epoch  15: Gradient L₂ Norm = 0.007681
# Epoch  16: Gradient L₂ Norm = 0.010105
# Epoch  17: Gradient L₂ Norm = 0.006795
# Epoch  18: Gradient L₂ Norm = 0.008884
# Epoch  19: Gradient L₂ Norm = 0.007018
# Epoch  20: Gradient L₂ Norm = 0.007388
# Epoch  21: Gradient L₂ Norm = 0.006696
# Epoch  22: Gradient L₂ Norm = 0.012944
# Epoch  23: Gradient L₂ Norm = 0.009624
# Epoch  24: Gradient L₂ Norm = 0.011030
# Epoch  25: Gradient L₂ Norm = 0.010506
# Epoch  26: Gradient L₂ Norm = 0.008645
# Epoch  27: Gradient L₂ Norm = 0.008295
# Epoch  28: Gradient L₂ Norm = 0.009270
# Epoch  29: Gradient L₂ Norm = 0.010265
# Epoch  30: Gradient L₂ Norm = 0.010090
# Epoch  31: Gradient L₂ Norm = 0.014001
# Epoch  32: Gradient L₂ Norm = 0.009937
# Epoch  33: Gradient L₂ Norm = 0.011063
# Epoch  34: Gradient L₂ Norm = 0.008273
# Epoch  35: Gradient L₂ Norm = 0.006224
# Epoch  36: Gradient L₂ Norm = 0.009376
# Epoch  37: Gradient L₂ Norm = 0.010084
# Epoch  38: Gradient L₂ Norm = 0.007634
# Epoch  39: Gradient L₂ Norm = 0.012977
# Epoch  40: Gradient L₂ Norm = 0.007065
# Epoch  41: Gradient L₂ Norm = 0.009126
# Epoch  42: Gradient L₂ Norm = 0.008685
# Epoch  43: Gradient L₂ Norm = 0.006532
# Epoch  44: Gradient L₂ Norm = 0.008273
# Epoch  45: Gradient L₂ Norm = 0.009327
# Epoch  46: Gradient L₂ Norm = 0.009414
# Epoch  47: Gradient L₂ Norm = 0.011706
# Epoch  48: Gradient L₂ Norm = 0.013885
# Epoch  49: Gradient L₂ Norm = 0.010924
# Epoch  50: Gradient L₂ Norm = 0.006971
# Epoch  51: Gradient L₂ Norm = 0.010931
# Epoch  52: Gradient L₂ Norm = 0.007983
# Epoch  53: Gradient L₂ Norm = 0.007514
# Epoch  54: Gradient L₂ Norm = 0.010745
# Epoch  55: Gradient L₂ Norm = 0.009257
# Epoch  56: Gradient L₂ Norm = 0.011584
# Epoch  57: Gradient L₂ Norm = 0.007267
# Epoch  58: Gradient L₂ Norm = 0.007698
# Epoch  59: Gradient L₂ Norm = 0.008384
# Epoch  60: Gradient L₂ Norm = 0.008457
# Epoch  61: Gradient L₂ Norm = 0.010114
# Epoch  62: Gradient L₂ Norm = 0.011189
# Epoch  63: Gradient L₂ Norm = 0.006886
# Epoch  64: Gradient L₂ Norm = 0.010788
# Epoch  65: Gradient L₂ Norm = 0.006629
# Epoch  66: Gradient L₂ Norm = 0.015240
# Epoch  67: Gradient L₂ Norm = 0.008902
# Epoch  68: Gradient L₂ Norm = 0.011399
# Epoch  69: Gradient L₂ Norm = 0.008753
# Epoch  70: Gradient L₂ Norm = 0.010836
# Epoch  71: Gradient L₂ Norm = 0.007929
# Epoch  72: Gradient L₂ Norm = 0.010381
# Epoch  73: Gradient L₂ Norm = 0.009319
# Epoch  74: Gradient L₂ Norm = 0.008273
# Epoch  75: Gradient L₂ Norm = 0.013519
# Epoch  76: Gradient L₂ Norm = 0.007547
# Epoch  77: Gradient L₂ Norm = 0.008486
# Epoch  78: Gradient L₂ Norm = 0.008804
# Epoch  79: Gradient L₂ Norm = 0.012107
# Epoch  80: Gradient L₂ Norm = 0.009825
# Epoch  81: Gradient L₂ Norm = 0.009538
# Epoch  82: Gradient L₂ Norm = 0.009059
# Epoch  83: Gradient L₂ Norm = 0.009595
# Epoch  84: Gradient L₂ Norm = 0.007483
# Epoch  85: Gradient L₂ Norm = 0.014414
# Epoch  86: Gradient L₂ Norm = 0.007258
# Epoch  87: Gradient L₂ Norm = 0.007761
# Epoch  88: Gradient L₂ Norm = 0.007143
# Epoch  89: Gradient L₂ Norm = 0.009512
# Epoch  90: Gradient L₂ Norm = 0.013451
# Epoch  91: Gradient L₂ Norm = 0.010370
# Epoch  92: Gradient L₂ Norm = 0.007733
# Epoch  93: Gradient L₂ Norm = 0.010133
# Epoch  94: Gradient L₂ Norm = 0.012424
# Epoch  95: Gradient L₂ Norm = 0.010150
# Epoch  96: Gradient L₂ Norm = 0.010422
# Epoch  97: Gradient L₂ Norm = 0.009154
# Epoch  98: Gradient L₂ Norm = 0.009700
# Epoch  99: Gradient L₂ Norm = 0.008951
# Epoch 100: Gradient L₂ Norm = 0.008845
#
# --------------------------------------------------------------------------------
# SUMMARY — MP_GELU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.009403 ± 0.002135
# Minimum Gradient L₂ Norm : 0.005107
# Maximum Gradient L₂ Norm : 0.016084
#
# ================================================================================
# ACTIVATION: ReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.006437
# Epoch   2: Gradient L₂ Norm = 0.009432
# Epoch   3: Gradient L₂ Norm = 0.018488
# Epoch   4: Gradient L₂ Norm = 0.011884
# Epoch   5: Gradient L₂ Norm = 0.010245
# Epoch   6: Gradient L₂ Norm = 0.017870
# Epoch   7: Gradient L₂ Norm = 0.011527
# Epoch   8: Gradient L₂ Norm = 0.031808
# Epoch   9: Gradient L₂ Norm = 0.008612
# Epoch  10: Gradient L₂ Norm = 0.013917
# Epoch  11: Gradient L₂ Norm = 0.015913
# Epoch  12: Gradient L₂ Norm = 0.018687
# Epoch  13: Gradient L₂ Norm = 0.009245
# Epoch  14: Gradient L₂ Norm = 0.013849
# Epoch  15: Gradient L₂ Norm = 0.008645
# Epoch  16: Gradient L₂ Norm = 0.011639
# Epoch  17: Gradient L₂ Norm = 0.009490
# Epoch  18: Gradient L₂ Norm = 0.011376
# Epoch  19: Gradient L₂ Norm = 0.009594
# Epoch  20: Gradient L₂ Norm = 0.009712
# Epoch  21: Gradient L₂ Norm = 0.009520
# Epoch  22: Gradient L₂ Norm = 0.011454
# Epoch  23: Gradient L₂ Norm = 0.011932
# Epoch  24: Gradient L₂ Norm = 0.017514
# Epoch  25: Gradient L₂ Norm = 0.010296
# Epoch  26: Gradient L₂ Norm = 0.010104
# Epoch  27: Gradient L₂ Norm = 0.009948
# Epoch  28: Gradient L₂ Norm = 0.009503
# Epoch  29: Gradient L₂ Norm = 0.010495
# Epoch  30: Gradient L₂ Norm = 0.014578
# Epoch  31: Gradient L₂ Norm = 0.009236
# Epoch  32: Gradient L₂ Norm = 0.010560
# Epoch  33: Gradient L₂ Norm = 0.012383
# Epoch  34: Gradient L₂ Norm = 0.010698
# Epoch  35: Gradient L₂ Norm = 0.023180
# Epoch  36: Gradient L₂ Norm = 0.012302
# Epoch  37: Gradient L₂ Norm = 0.008244
# Epoch  38: Gradient L₂ Norm = 0.007565
# Epoch  39: Gradient L₂ Norm = 0.013067
# Epoch  40: Gradient L₂ Norm = 0.011379
# Epoch  41: Gradient L₂ Norm = 0.007402
# Epoch  42: Gradient L₂ Norm = 0.012288
# Epoch  43: Gradient L₂ Norm = 0.010320
# Epoch  44: Gradient L₂ Norm = 0.012953
# Epoch  45: Gradient L₂ Norm = 0.009320
# Epoch  46: Gradient L₂ Norm = 0.011814
# Epoch  47: Gradient L₂ Norm = 0.009294
# Epoch  48: Gradient L₂ Norm = 0.021801
# Epoch  49: Gradient L₂ Norm = 0.012634
# Epoch  50: Gradient L₂ Norm = 0.012337
# Epoch  51: Gradient L₂ Norm = 0.012319
# Epoch  52: Gradient L₂ Norm = 0.010430
# Epoch  53: Gradient L₂ Norm = 0.009958
# Epoch  54: Gradient L₂ Norm = 0.007697
# Epoch  55: Gradient L₂ Norm = 0.009971
# Epoch  56: Gradient L₂ Norm = 0.015536
# Epoch  57: Gradient L₂ Norm = 0.010698
# Epoch  58: Gradient L₂ Norm = 0.007957
# Epoch  59: Gradient L₂ Norm = 0.009293
# Epoch  60: Gradient L₂ Norm = 0.009550
# Epoch  61: Gradient L₂ Norm = 0.009374
# Epoch  62: Gradient L₂ Norm = 0.012023
# Epoch  63: Gradient L₂ Norm = 0.012594
# Epoch  64: Gradient L₂ Norm = 0.008562
# Epoch  65: Gradient L₂ Norm = 0.007994
# Epoch  66: Gradient L₂ Norm = 0.016123
# Epoch  67: Gradient L₂ Norm = 0.008518
# Epoch  68: Gradient L₂ Norm = 0.010541
# Epoch  69: Gradient L₂ Norm = 0.014730
# Epoch  70: Gradient L₂ Norm = 0.007854
# Epoch  71: Gradient L₂ Norm = 0.011404
# Epoch  72: Gradient L₂ Norm = 0.008907
# Epoch  73: Gradient L₂ Norm = 0.012755
# Epoch  74: Gradient L₂ Norm = 0.007853
# Epoch  75: Gradient L₂ Norm = 0.011275
# Epoch  76: Gradient L₂ Norm = 0.011344
# Epoch  77: Gradient L₂ Norm = 0.009829
# Epoch  78: Gradient L₂ Norm = 0.012988
# Epoch  79: Gradient L₂ Norm = 0.011895
# Epoch  80: Gradient L₂ Norm = 0.009119
# Epoch  81: Gradient L₂ Norm = 0.010813
# Epoch  82: Gradient L₂ Norm = 0.019717
# Epoch  83: Gradient L₂ Norm = 0.011511
# Epoch  84: Gradient L₂ Norm = 0.010383
# Epoch  85: Gradient L₂ Norm = 0.007273
# Epoch  86: Gradient L₂ Norm = 0.012357
# Epoch  87: Gradient L₂ Norm = 0.012041
# Epoch  88: Gradient L₂ Norm = 0.014862
# Epoch  89: Gradient L₂ Norm = 0.008158
# Epoch  90: Gradient L₂ Norm = 0.011441
# Epoch  91: Gradient L₂ Norm = 0.007880
# Epoch  92: Gradient L₂ Norm = 0.015219
# Epoch  93: Gradient L₂ Norm = 0.009937
# Epoch  94: Gradient L₂ Norm = 0.011341
# Epoch  95: Gradient L₂ Norm = 0.010974
# Epoch  96: Gradient L₂ Norm = 0.010270
# Epoch  97: Gradient L₂ Norm = 0.010461
# Epoch  98: Gradient L₂ Norm = 0.012740
# Epoch  99: Gradient L₂ Norm = 0.008365
# Epoch 100: Gradient L₂ Norm = 0.012843
#
# --------------------------------------------------------------------------------
# SUMMARY — ReLU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.011602 ± 0.003692
# Minimum Gradient L₂ Norm : 0.006437
# Maximum Gradient L₂ Norm : 0.031808
#
# ================================================================================
# ACTIVATION: GELU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.010216
# Epoch   2: Gradient L₂ Norm = 0.005383
# Epoch   3: Gradient L₂ Norm = 0.009218
# Epoch   4: Gradient L₂ Norm = 0.007251
# Epoch   5: Gradient L₂ Norm = 0.006028
# Epoch   6: Gradient L₂ Norm = 0.008231
# Epoch   7: Gradient L₂ Norm = 0.016705
# Epoch   8: Gradient L₂ Norm = 0.007890
# Epoch   9: Gradient L₂ Norm = 0.005050
# Epoch  10: Gradient L₂ Norm = 0.005692
# Epoch  11: Gradient L₂ Norm = 0.013513
# Epoch  12: Gradient L₂ Norm = 0.011309
# Epoch  13: Gradient L₂ Norm = 0.005822
# Epoch  14: Gradient L₂ Norm = 0.009088
# Epoch  15: Gradient L₂ Norm = 0.004214
# Epoch  16: Gradient L₂ Norm = 0.005175
# Epoch  17: Gradient L₂ Norm = 0.009361
# Epoch  18: Gradient L₂ Norm = 0.007580
# Epoch  19: Gradient L₂ Norm = 0.006881
# Epoch  20: Gradient L₂ Norm = 0.006871
# Epoch  21: Gradient L₂ Norm = 0.005936
# Epoch  22: Gradient L₂ Norm = 0.007582
# Epoch  23: Gradient L₂ Norm = 0.007800
# Epoch  24: Gradient L₂ Norm = 0.005897
# Epoch  25: Gradient L₂ Norm = 0.007567
# Epoch  26: Gradient L₂ Norm = 0.004942
# Epoch  27: Gradient L₂ Norm = 0.017082
# Epoch  28: Gradient L₂ Norm = 0.006252
# Epoch  29: Gradient L₂ Norm = 0.008240
# Epoch  30: Gradient L₂ Norm = 0.010033
# Epoch  31: Gradient L₂ Norm = 0.010192
# Epoch  32: Gradient L₂ Norm = 0.007835
# Epoch  33: Gradient L₂ Norm = 0.006719
# Epoch  34: Gradient L₂ Norm = 0.007004
# Epoch  35: Gradient L₂ Norm = 0.008769
# Epoch  36: Gradient L₂ Norm = 0.008433
# Epoch  37: Gradient L₂ Norm = 0.007312
# Epoch  38: Gradient L₂ Norm = 0.009856
# Epoch  39: Gradient L₂ Norm = 0.007485
# Epoch  40: Gradient L₂ Norm = 0.006978
# Epoch  41: Gradient L₂ Norm = 0.006611
# Epoch  42: Gradient L₂ Norm = 0.009040
# Epoch  43: Gradient L₂ Norm = 0.009470
# Epoch  44: Gradient L₂ Norm = 0.007715
# Epoch  45: Gradient L₂ Norm = 0.009028
# Epoch  46: Gradient L₂ Norm = 0.006105
# Epoch  47: Gradient L₂ Norm = 0.008048
# Epoch  48: Gradient L₂ Norm = 0.008531
# Epoch  49: Gradient L₂ Norm = 0.009074
# Epoch  50: Gradient L₂ Norm = 0.009151
# Epoch  51: Gradient L₂ Norm = 0.010567
# Epoch  52: Gradient L₂ Norm = 0.010676
# Epoch  53: Gradient L₂ Norm = 0.009942
# Epoch  54: Gradient L₂ Norm = 0.009505
# Epoch  55: Gradient L₂ Norm = 0.011935
# Epoch  56: Gradient L₂ Norm = 0.015900
# Epoch  57: Gradient L₂ Norm = 0.012525
# Epoch  58: Gradient L₂ Norm = 0.008708
# Epoch  59: Gradient L₂ Norm = 0.010389
# Epoch  60: Gradient L₂ Norm = 0.008950
# Epoch  61: Gradient L₂ Norm = 0.008449
# Epoch  62: Gradient L₂ Norm = 0.006846
# Epoch  63: Gradient L₂ Norm = 0.007944
# Epoch  64: Gradient L₂ Norm = 0.009354
# Epoch  65: Gradient L₂ Norm = 0.008987
# Epoch  66: Gradient L₂ Norm = 0.005945
# Epoch  67: Gradient L₂ Norm = 0.009243
# Epoch  68: Gradient L₂ Norm = 0.007377
# Epoch  69: Gradient L₂ Norm = 0.008274
# Epoch  70: Gradient L₂ Norm = 0.007544
# Epoch  71: Gradient L₂ Norm = 0.007549
# Epoch  72: Gradient L₂ Norm = 0.007952
# Epoch  73: Gradient L₂ Norm = 0.011155
# Epoch  74: Gradient L₂ Norm = 0.009023
# Epoch  75: Gradient L₂ Norm = 0.007046
# Epoch  76: Gradient L₂ Norm = 0.007989
# Epoch  77: Gradient L₂ Norm = 0.007427
# Epoch  78: Gradient L₂ Norm = 0.008691
# Epoch  79: Gradient L₂ Norm = 0.008204
# Epoch  80: Gradient L₂ Norm = 0.011224
# Epoch  81: Gradient L₂ Norm = 0.008374
# Epoch  82: Gradient L₂ Norm = 0.012125
# Epoch  83: Gradient L₂ Norm = 0.009231
# Epoch  84: Gradient L₂ Norm = 0.008234
# Epoch  85: Gradient L₂ Norm = 0.007748
# Epoch  86: Gradient L₂ Norm = 0.009091
# Epoch  87: Gradient L₂ Norm = 0.009080
# Epoch  88: Gradient L₂ Norm = 0.006921
# Epoch  89: Gradient L₂ Norm = 0.008919
# Epoch  90: Gradient L₂ Norm = 0.008568
# Epoch  91: Gradient L₂ Norm = 0.008509
# Epoch  92: Gradient L₂ Norm = 0.009851
# Epoch  93: Gradient L₂ Norm = 0.011453
# Epoch  94: Gradient L₂ Norm = 0.009078
# Epoch  95: Gradient L₂ Norm = 0.012415
# Epoch  96: Gradient L₂ Norm = 0.010470
# Epoch  97: Gradient L₂ Norm = 0.009982
# Epoch  98: Gradient L₂ Norm = 0.008348
# Epoch  99: Gradient L₂ Norm = 0.010327
# Epoch 100: Gradient L₂ Norm = 0.010869
#
# --------------------------------------------------------------------------------
# SUMMARY — GELU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.008711 ± 0.002266
# Minimum Gradient L₂ Norm : 0.004214
# Maximum Gradient L₂ Norm : 0.017082
#
# ================================================================================
# ACTIVATION: LeakyReLU
# ================================================================================
# Epoch   1: Gradient L₂ Norm = 0.019700
# Epoch   2: Gradient L₂ Norm = 0.033643
# Epoch   3: Gradient L₂ Norm = 0.008635
# Epoch   4: Gradient L₂ Norm = 0.007862
# Epoch   5: Gradient L₂ Norm = 0.008730
# Epoch   6: Gradient L₂ Norm = 0.008823
# Epoch   7: Gradient L₂ Norm = 0.008637
# Epoch   8: Gradient L₂ Norm = 0.018059
# Epoch   9: Gradient L₂ Norm = 0.009524
# Epoch  10: Gradient L₂ Norm = 0.014745
# Epoch  11: Gradient L₂ Norm = 0.013384
# Epoch  12: Gradient L₂ Norm = 0.015407
# Epoch  13: Gradient L₂ Norm = 0.010191
# Epoch  14: Gradient L₂ Norm = 0.010408
# Epoch  15: Gradient L₂ Norm = 0.008578
# Epoch  16: Gradient L₂ Norm = 0.010821
# Epoch  17: Gradient L₂ Norm = 0.009621
# Epoch  18: Gradient L₂ Norm = 0.008311
# Epoch  19: Gradient L₂ Norm = 0.009012
# Epoch  20: Gradient L₂ Norm = 0.011092
# Epoch  21: Gradient L₂ Norm = 0.014110
# Epoch  22: Gradient L₂ Norm = 0.011665
# Epoch  23: Gradient L₂ Norm = 0.013031
# Epoch  24: Gradient L₂ Norm = 0.009143
# Epoch  25: Gradient L₂ Norm = 0.011511
# Epoch  26: Gradient L₂ Norm = 0.010795
# Epoch  27: Gradient L₂ Norm = 0.008808
# Epoch  28: Gradient L₂ Norm = 0.010037
# Epoch  29: Gradient L₂ Norm = 0.010611
# Epoch  30: Gradient L₂ Norm = 0.011731
# Epoch  31: Gradient L₂ Norm = 0.010415
# Epoch  32: Gradient L₂ Norm = 0.007905
# Epoch  33: Gradient L₂ Norm = 0.010007
# Epoch  34: Gradient L₂ Norm = 0.013672
# Epoch  35: Gradient L₂ Norm = 0.012111
# Epoch  36: Gradient L₂ Norm = 0.009144
# Epoch  37: Gradient L₂ Norm = 0.008525
# Epoch  38: Gradient L₂ Norm = 0.010081
# Epoch  39: Gradient L₂ Norm = 0.006997
# Epoch  40: Gradient L₂ Norm = 0.012281
# Epoch  41: Gradient L₂ Norm = 0.010247
# Epoch  42: Gradient L₂ Norm = 0.010349
# Epoch  43: Gradient L₂ Norm = 0.009056
# Epoch  44: Gradient L₂ Norm = 0.009925
# Epoch  45: Gradient L₂ Norm = 0.010193
# Epoch  46: Gradient L₂ Norm = 0.011423
# Epoch  47: Gradient L₂ Norm = 0.009902
# Epoch  48: Gradient L₂ Norm = 0.010881
# Epoch  49: Gradient L₂ Norm = 0.010702
# Epoch  50: Gradient L₂ Norm = 0.012188
# Epoch  51: Gradient L₂ Norm = 0.011459
# Epoch  52: Gradient L₂ Norm = 0.011486
# Epoch  53: Gradient L₂ Norm = 0.007123
# Epoch  54: Gradient L₂ Norm = 0.011267
# Epoch  55: Gradient L₂ Norm = 0.009812
# Epoch  56: Gradient L₂ Norm = 0.013150
# Epoch  57: Gradient L₂ Norm = 0.011437
# Epoch  58: Gradient L₂ Norm = 0.006429
# Epoch  59: Gradient L₂ Norm = 0.007362
# Epoch  60: Gradient L₂ Norm = 0.009456
# Epoch  61: Gradient L₂ Norm = 0.009237
# Epoch  62: Gradient L₂ Norm = 0.013797
# Epoch  63: Gradient L₂ Norm = 0.015356
# Epoch  64: Gradient L₂ Norm = 0.010352
# Epoch  65: Gradient L₂ Norm = 0.014424
# Epoch  66: Gradient L₂ Norm = 0.008418
# Epoch  67: Gradient L₂ Norm = 0.009966
# Epoch  68: Gradient L₂ Norm = 0.007969
# Epoch  69: Gradient L₂ Norm = 0.008454
# Epoch  70: Gradient L₂ Norm = 0.009123
# Epoch  71: Gradient L₂ Norm = 0.009592
# Epoch  72: Gradient L₂ Norm = 0.007672
# Epoch  73: Gradient L₂ Norm = 0.008324
# Epoch  74: Gradient L₂ Norm = 0.008902
# Epoch  75: Gradient L₂ Norm = 0.013791
# Epoch  76: Gradient L₂ Norm = 0.007195
# Epoch  77: Gradient L₂ Norm = 0.011963
# Epoch  78: Gradient L₂ Norm = 0.009874
# Epoch  79: Gradient L₂ Norm = 0.010105
# Epoch  80: Gradient L₂ Norm = 0.012075
# Epoch  81: Gradient L₂ Norm = 0.011680
# Epoch  82: Gradient L₂ Norm = 0.012598
# Epoch  83: Gradient L₂ Norm = 0.012345
# Epoch  84: Gradient L₂ Norm = 0.010871
# Epoch  85: Gradient L₂ Norm = 0.008865
# Epoch  86: Gradient L₂ Norm = 0.010919
# Epoch  87: Gradient L₂ Norm = 0.010602
# Epoch  88: Gradient L₂ Norm = 0.015675
# Epoch  89: Gradient L₂ Norm = 0.010063
# Epoch  90: Gradient L₂ Norm = 0.009780
# Epoch  91: Gradient L₂ Norm = 0.011167
# Epoch  92: Gradient L₂ Norm = 0.010989
# Epoch  93: Gradient L₂ Norm = 0.011881
# Epoch  94: Gradient L₂ Norm = 0.009726
# Epoch  95: Gradient L₂ Norm = 0.012727
# Epoch  96: Gradient L₂ Norm = 0.015165
# Epoch  97: Gradient L₂ Norm = 0.012179
# Epoch  98: Gradient L₂ Norm = 0.012636
# Epoch  99: Gradient L₂ Norm = 0.009956
# Epoch 100: Gradient L₂ Norm = 0.011284
#
# --------------------------------------------------------------------------------
# SUMMARY — LeakyReLU
# --------------------------------------------------------------------------------
# Average Gradient L₂ Norm : 0.010993 ± 0.003259
# Minimum Gradient L₂ Norm : 0.006429
# Maximum Gradient L₂ Norm : 0.033643
